# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold

# %% [markdown]
# ## Parameters

# %%
target = 'athleteplaysforteam'
#test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.95
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %%
[facts, pos, neg] = get_nell_dataset(target)

# %% [markdown]
# ## Background  configuration

# %%
bk = ['athleteledsportsteam(+athlete,+sportsteam).',
      'athleteledsportsteam(+athlete,-sportsteam).',
      'athleteledsportsteam(-athlete,+sportsteam).',
      'athleteplaysforteam(+athlete,+sportsteam).',
      'athleteplaysforteam(+athlete,-sportsteam).',
      'athleteplaysforteam(-athlete,+sportsteam).',
      'athleteplaysinleague(+athlete,+sportsleague).',
      'athleteplaysinleague(+athlete,-sportsleague).',
      'athleteplaysinleague(-athlete,+sportsleague).',
      'athleteplayssport(+athlete,+sport).',
      'athleteplayssport(+athlete,-sport).',
      'athleteplayssport(-athlete,+sport).',
      'teamalsoknownas(+sportsteam,+sportsteam).',
      'teamalsoknownas(+sportsteam,-sportsteam).',
      'teamalsoknownas(-sportsteam,+sportsteam).',
      'teamplaysagainstteam(+sportsteam,+sportsteam).',
      'teamplaysagainstteam(+sportsteam,-sportsteam).',
      'teamplaysagainstteam(-sportsteam,+sportsteam).',
      'teamplaysinleague(+sportsteam,+sportsleague).',
      'teamplaysinleague(+sportsteam,-sportsleague).',
      'teamplaysinleague(-sportsteam,+sportsleague).',
      'teamplayssport(+sportsteam,+sport).',
      'teamplayssport(+sportsteam,-sport).',
      'teamplayssport(-sportsteam,+sport).']

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

neg = neg[:len(pos)] # balanced

import numpy as np
pos = np.array(pos)
neg = np.array(neg)
small_dataset_aucroc = []
complete_dataset_aucroc = []
revision_dataset_aucroc = []
small_learning_time = []
small_inference_time = []
complete_learning_time = []
complete_inference_time = []
revision_learning_time = []
revision_inference_time = []

# separate train and test
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(pos):
    train_pos, test_pos = pos[train_index], pos[test_index]
    train_neg, test_neg = neg[train_index], neg[test_index]

    # learn from scratch in a small dataset
    s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
    s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

    # shuffle all train examples
    random.shuffle(train_pos)
    random.shuffle(train_neg)

    # train set used in revision and validation set
    r_train_pos = train_pos[int(validation_size*len(train_pos)):]
    r_train_neg = train_neg[int(validation_size*len(train_neg)):]
    validation_pos = train_pos[:int(validation_size*len(train_pos))]
    validation_neg = train_neg[:int(validation_size*len(train_neg))]

    print('Total examples')
    print('Positive examples: %s' % len(pos))
    print('Negative examples: %s' % len(neg))
    print('\n')
    print('Train and test sets from total')
    print('Train Positive examples: %s' % len(train_pos))
    print('Train Negative examples: %s' % len(train_neg))
    print('Test Positive examples: %s' % len(test_pos))
    print('Test Negative examples: %s' % len(test_neg))
    print('\n')
    print('Small dataset')
    print('Train Positive examples: %s' % len(s_train_pos))
    print('Train Negative examples: %s' % len(s_train_neg))
    print('\n')
    print('Revision theory train dataset and validation')
    print('Train Positive examples: %s' % len(r_train_pos))
    print('Train Negative examples: %s' % len(r_train_neg))
    print('Validation Positive examples: %s' % len(validation_pos))
    print('Validation Negative examples: %s' % len(validation_neg))
    
    # learning from small dataset
    [model, learning_time, inference_time, t_results, small_structured] = learn_test_model(background, boostsrl, target, s_train_pos, s_train_neg, facts, test_pos, test_neg, trees=10)
    small_dataset_aucroc.append(t_results['AUC ROC'])
    small_learning_time.append(learning_time)
    small_inference_time.append(inference_time)
    
    # learning from complete dataset
    [model, learning_time, inference_time, t_results, structured] = learn_test_model(background, boostsrl, target, train_pos, train_neg, facts, test_pos, test_neg, trees=10)
    complete_dataset_aucroc.append(t_results['AUC ROC'])
    complete_learning_time.append(learning_time)
    complete_inference_time.append(inference_time)
    
    # theory revision
    [model, total_revision_time, inference_time, t_results, structured] = theory_revision(background, boostsrl, target, r_train_pos, r_train_neg, facts, validation_pos, validation_neg, test_pos, test_neg, revision_threshold, small_structured, max_revision_iterations=10)
    revision_dataset_aucroc.append(t_results['AUC ROC'])
    revision_learning_time.append(total_revision_time)
    revision_inference_time.append(inference_time)
# Out:
# Total examples
# Positive examples: 1458
# Negative examples: 1458
#
#
# Train and test sets from total
# Train Positive examples: 1312
# Train Negative examples: 1312
# Test Positive examples: 146
# Test Negative examples: 146
#
#
# Small dataset
# Train Positive examples: 393
# Train Negative examples: 393
#
#
# Revision theory train dataset and validation
# Train Positive examples: 1050
# Train Negative examples: 1050
# Validation Positive examples: 262
# Validation Negative examples: 262
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 4.206277228909364;  // std dev = 0,285, 680,000 (wgt'ed) examples reached here.  /* #pos=680 */
# %   | else return 1.782291565861202;  // std dev = 4,403, 3.780,000 (wgt'ed) examples reached here.  /* #neg=1.680 #pos=2.100 */
# %   else if ( teamalsoknownas(B, F), teamplaysinleague(B, G) )
# %   | then return -0.38626876130962284;  // std dev = 3,374, 620,000 (wgt'ed) examples reached here.  /* #neg=510 #pos=110 */
# %   | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, H), teamalsoknownas(I, J) )
# %   | | then return -0.5074747449020663;  // std dev = 2,853, 490,000 (wgt'ed) examples reached here.  /* #neg=430 #pos=60 */
# %   | | else if ( teamplaysinleague(B, K), teamplaysinleague(L, K), teamplayssport(L, M) )
# %   | | | then if ( teamalsoknownas(L, N), teamalsoknownas(P, L), teamplaysagainstteam(Q, B) )
# %   | | | | then if ( athleteplayssport(A, R), teamplayssport(Q, R) )
# %   | | | | | then return 3.655100567002705;  // std dev = 33,404, 70,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=50 */
# %   | | | | | else return -0.6620874788880029;  // std dev = 73,486, 370,000 (wgt'ed) examples reached here.  /* #neg=300 #pos=70 */
# %   | | | | else if ( athleteplayssport(A, S), teamalsoknownas(L, T) )
# %   | | | | | then return -0.17788779604216431;  // std dev = 36,870, 160,000 (wgt'ed) examples reached here.  /* #neg=140 #pos=20 */
# %   | | | | | else return 2.7276876723728374;  // std dev = 168,030, 1.260,000 (wgt'ed) examples reached here.  /* #neg=530 #pos=730 */
# %   | | | else return 0.4499268747407256;  // std dev = 4,143, 430,000 (wgt'ed) examples reached here.  /* #neg=320 #pos=110 */
#
#
# Results:
# {'AUC PR': 0.748055, 'Precision': [0.75, 0.5], 'AUC ROC': 0.741743, 'CLL': -0.580145, 'Recall': 0.349315, 'F1': 0.476636}
#
#
# Total learning time: 384.85 seconds
# Total inference time: 1.664 seconds
# AUC ROC: 0.741743
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 3.8993956228930147;  // std dev = 0,139, 770,000 (wgt'ed) examples reached here.  /* #pos=770 */
# %   else if ( athleteledsportsteam(A, C), teamplayssport(C, D), teamplaysagainstteam(E, C) )
# %   | then return 0.16519582672400462;  // std dev = 3,710, 1.310,000 (wgt'ed) examples reached here.  /* #neg=1.000 #pos=310 */
# %   | else if ( teamplaysagainstteam(F, B), teamalsoknownas(G, F), teamplaysagainstteam(B, G) )
# %   | | then if ( athleteledsportsteam(H, F), athleteledsportsteam(I, G), teamplaysagainstteam(B, F) )
# %   | | | then if ( teamplaysagainstteam(G, B), athleteplaysinleague(I, J), teamplaysinleague(B, J) )
# %   | | | | then if ( athleteplaysinleague(A, J), athleteledsportsteam(K, B) )
# %   | | | | | then return 3.513704672929959;  // std dev = 82,532, 550,000 (wgt'ed) examples reached here.  /* #neg=80 #pos=470 */
# %   | | | | | else return 1.771983902443617;  // std dev = 211,050, 1.960,000 (wgt'ed) examples reached here.  /* #neg=880 #pos=1.080 */
# %   | | | | else return 3.7245793881712626;  // std dev = 3,908, 540,000 (wgt'ed) examples reached here.  /* #neg=120 #pos=420 */
# %   | | | else return -0.3532835905814598;  // std dev = 3,808, 230,000 (wgt'ed) examples reached here.  /* #neg=180 #pos=50 */
# %   | | else if ( athleteplayssport(A, L) )
# %   | | | then return -1.046889887794768;  // std dev = 2,284, 430,000 (wgt'ed) examples reached here.  /* #neg=400 #pos=30 */
# %   | | | else if ( teamplaysagainstteam(M, B), teamplaysinleague(B, N), teamplaysagainstteam(B, P) )
# %   | | | | then return 1.6162911406378462;  // std dev = 4,696, 1.580,000 (wgt'ed) examples reached here.  /* #neg=890 #pos=690 */
# %   | | | | else return 0.2647513294834242;  // std dev = 4,112, 490,000 (wgt'ed) examples reached here.  /* #neg=380 #pos=110 */
#
#
# Results:
# {'AUC PR': 0.836162, 'Precision': [0.936508, 0.5], 'AUC ROC': 0.802003, 'CLL': -0.544189, 'Recall': 0.40411, 'F1': 0.564593}
#
#
# Total learning time: 2308.945 seconds
# Total inference time: 0.978 seconds
# AUC ROC: 0.802003
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else return 0.3926657003855036;  // std dev = 15,884, 1.014,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=542 */
# %   else if ( teamalsoknownas(B, F), teamplaysinleague(B, G) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, H), teamalsoknownas(I, J) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else if ( teamplaysinleague(B, K), teamplaysinleague(L, K), teamplayssport(L, M) )
# %   | | | then if ( teamalsoknownas(L, N), teamalsoknownas(P, L), teamplaysagainstteam(Q, B) )
# %   | | | | then if ( athleteplayssport(A, R), teamplayssport(Q, R) )
# %   | | | | | then return 0.31648226843284566;  // std dev = 2,441, 24,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=11 */
# %   | | | | | else return 0.020311097261674523;  // std dev = 3,883, 111,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=18 */
# %   | | | | else if ( athleteplayssport(A, S), teamalsoknownas(L, T) )
# %   | | | | | then return 0.06223056775257359;  // std dev = 2,821, 49,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=10 */
# %   | | | | | else return 0.4623785423502639;  // std dev = 8,897, 331,000 (wgt'ed) examples reached here.  /* #neg=131 #pos=200 */
# %   | | | else return 0.07174116810922081;  // std dev = 4,159, 103,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=22 */
#
#
# Results:
# {'AUC PR': 0.732221, 'Precision': [nan, 0.5], 'AUC ROC': 0.719997, 'CLL': -0.890349, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 4.018 seconds
# Total inference time: 1.419 seconds
# AUC ROC: 0.719997
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else return 0.3926657003855036;  // std dev = 15,884, 1.014,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=542 */
# %   else if ( teamalsoknownas(B, F), teamplaysinleague(B, G) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, H), teamalsoknownas(I, J) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else if ( teamplaysinleague(B, K), teamplaysinleague(L, K), teamplayssport(L, M) )
# %   | | | then if ( teamalsoknownas(L, N), teamalsoknownas(P, L), teamplaysagainstteam(Q, B) )
# %   | | | | then if ( athleteplayssport(A, R), teamplayssport(Q, R) )
# %   | | | | | then return 0.31648226843284566;  // std dev = 2,441, 24,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=11 */
# %   | | | | | else return 0.020311097261674523;  // std dev = 3,883, 111,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=18 */
# %   | | | | else if ( athleteplayssport(A, S), teamalsoknownas(L, T) )
# %   | | | | | then return 0.06223056775257359;  // std dev = 2,821, 49,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=10 */
# %   | | | | | else return 0.4623785423502639;  // std dev = 8,897, 331,000 (wgt'ed) examples reached here.  /* #neg=131 #pos=200 */
# %   | | | else return 0.07174116810922081;  // std dev = 0,410, 103,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=22 */
#
#
# Results:
# {'AUC PR': 0.732221, 'Precision': [nan, 0.5], 'AUC ROC': 0.719997, 'CLL': -0.890349, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 3.933 seconds
# Total inference time: 1.758 seconds
# AUC ROC: 0.719997
# Refining candidate 2 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else return 0.3926657003855036;  // std dev = 15,884, 1.014,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=542 */
# %   else if ( teamalsoknownas(B, F), teamplaysinleague(B, G) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, H), teamalsoknownas(I, J) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else if ( teamplaysinleague(B, K), teamplaysinleague(L, K), teamplayssport(L, M) )
# %   | | | then if ( teamalsoknownas(L, N), teamalsoknownas(P, L), teamplaysagainstteam(Q, B) )
# %   | | | | then return 0.07296374991432625;  // std dev = 4,772, 135,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=29 */
# %   | | | | else if ( athleteplayssport(A, R), teamalsoknownas(L, S) )
# %   | | | | | then return 0.06223056775257359;  // std dev = 2,821, 49,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=10 */
# %   | | | | | else return 0.4623785423502639;  // std dev = 8,897, 331,000 (wgt'ed) examples reached here.  /* #neg=131 #pos=200 */
# %   | | | else return 0.07174116810922081;  // std dev = 4,159, 103,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=22 */
#
#
# Results:
# {'AUC PR': 0.731372, 'Precision': [nan, 0.5], 'AUC ROC': 0.717674, 'CLL': -0.891293, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 3.79 seconds
# Total inference time: 1.637 seconds
# AUC ROC: 0.717674
# Refining candidate 3 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else return 0.3926657003855036;  // std dev = 15,884, 1.014,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=542 */
# %   else if ( teamalsoknownas(B, F), teamplaysinleague(B, G) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, H), teamalsoknownas(I, J) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else if ( teamplaysinleague(B, K), teamplaysinleague(L, K), teamplayssport(L, M) )
# %   | | | then if ( teamalsoknownas(L, N), teamalsoknownas(P, L), teamplaysagainstteam(Q, B) )
# %   | | | | then if ( athleteplayssport(A, R), teamplayssport(Q, R) )
# %   | | | | | then return 0.31648226843284566;  // std dev = 2,441, 24,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=11 */
# %   | | | | | else return 0.020311097261674523;  // std dev = 3,883, 111,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=18 */
# %   | | | | else return 0.4107805140468781;  // std dev = 9,693, 380,000 (wgt'ed) examples reached here.  /* #neg=170 #pos=210 */
# %   | | | else return 0.07174116810922081;  // std dev = 4,159, 103,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=22 */
#
#
# Results:
# {'AUC PR': 0.707245, 'Precision': [nan, 0.5], 'AUC ROC': 0.690512, 'CLL': -0.894701, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 3.778 seconds
# Total inference time: 1.402 seconds
# AUC ROC: 0.690512
# Refining candidate 4 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 0,436, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 0,457, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 0,395, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else if ( teamalsoknownas(B, M), teamplayssport(B, N), teamplaysagainstteam(B, M) )
# %   | | | | | then return 0.46159721096158013;  // std dev = 3,725, 58,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=35 */
# %   | | | | | else return 0.2734988222326912;  // std dev = 10,372, 443,000 (wgt'ed) examples reached here.  /* #neg=259 #pos=184 */
# %   else if ( teamalsoknownas(B, P), teamplaysinleague(B, Q) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, R), teamplaysagainstteam(S, R), teamalsoknownas(S, T) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 0,494, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.76244, 'Precision': [nan, 0.5], 'AUC ROC': 0.721134, 'CLL': -0.888389, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 65.068 seconds
# Total inference time: 3.132 seconds
# AUC ROC: 0.721134
# Refining candidate 5 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else return 0.3926657003855036;  // std dev = 15,884, 1.014,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=542 */
# %   else if ( teamalsoknownas(B, F), teamplaysinleague(B, G) )
# %   | then if ( athleteledsportsteam(A, H), teamplaysinleague(H, I), athleteplaysinleague(J, I) )
# %   | | then return -0.10851773156715441;  // std dev = 0,180, 30,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=1 */
# %   | | else return 0.1461489350995109;  // std dev = 0,453, 125,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=36 */
# %   | else if ( athleteledsportsteam(A, K), teamplaysagainstteam(L, K), teamalsoknownas(L, M) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else if ( teamplaysinleague(B, N), teamplaysinleague(P, N), teamplayssport(P, Q) )
# %   | | | then if ( teamalsoknownas(P, R), teamalsoknownas(S, P), teamplaysagainstteam(T, B) )
# %   | | | | then return 0.07296374991432625;  // std dev = 0,411, 135,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=29 */
# %   | | | | else if ( athleteplayssport(A, U), teamalsoknownas(P, W) )
# %   | | | | | then return 0.06223056775257359;  // std dev = 2,821, 49,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=10 */
# %   | | | | | else return 0.4623785423502639;  // std dev = 8,897, 331,000 (wgt'ed) examples reached here.  /* #neg=131 #pos=200 */
# %   | | | else return 0.07174116810922081;  // std dev = 4,159, 103,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=22 */
#
#
# Results:
# {'AUC PR': 0.732378, 'Precision': [nan, 0.5], 'AUC ROC': 0.720762, 'CLL': -0.890507, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 4.422 seconds
# Total inference time: 1.483 seconds
# AUC ROC: 0.720762
# Refining candidate 6 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else return 0.3926657003855036;  // std dev = 15,884, 1.014,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=542 */
# %   else if ( teamalsoknownas(B, F), teamplaysinleague(B, G) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, H), teamalsoknownas(I, J) )
# %   | | then return -0.0697789928284156;  // std dev = 0,259, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else if ( teamplaysinleague(B, K), teamplaysinleague(L, K), teamplayssport(L, M) )
# %   | | | then if ( teamalsoknownas(L, N), teamalsoknownas(P, L), teamplaysagainstteam(Q, B) )
# %   | | | | then if ( athleteplayssport(A, R), teamplayssport(Q, R) )
# %   | | | | | then return 0.31648226843284566;  // std dev = 2,441, 24,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=11 */
# %   | | | | | else return 0.020311097261674523;  // std dev = 3,883, 111,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=18 */
# %   | | | | else if ( athleteplayssport(A, S), teamalsoknownas(L, T) )
# %   | | | | | then return 0.06223056775257359;  // std dev = 2,821, 49,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=10 */
# %   | | | | | else return 0.4623785423502639;  // std dev = 8,897, 331,000 (wgt'ed) examples reached here.  /* #neg=131 #pos=200 */
# %   | | | else return 0.07174116810922081;  // std dev = 4,159, 103,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=22 */
#
#
# Results:
# {'AUC PR': 0.732221, 'Precision': [nan, 0.5], 'AUC ROC': 0.719997, 'CLL': -0.890349, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 3.801 seconds
# Total inference time: 1.531 seconds
# AUC ROC: 0.719997
# Best Tree AUC ROC so far: 0.721134
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining candidate 1 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else return 0.29527468360250275;  // std dev = 11,103, 501,000 (wgt'ed) examples reached here.  /* #neg=282 #pos=219 */
# %   else if ( teamalsoknownas(B, M), teamplaysinleague(B, N) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, P), teamplaysagainstteam(Q, P), teamalsoknownas(Q, R) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.766551, 'Precision': [nan, 0.5], 'AUC ROC': 0.728257, 'CLL': -0.88864, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 25.673 seconds
# Total inference time: 3.074 seconds
# AUC ROC: 0.728257
# Refining candidate 2 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else if ( teamalsoknownas(B, M), teamplayssport(B, N), teamplaysagainstteam(B, M) )
# %   | | | | | then return 0.46159721096158013;  // std dev = 3,725, 58,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=35 */
# %   | | | | | else return 0.2734988222326912;  // std dev = 10,372, 443,000 (wgt'ed) examples reached here.  /* #neg=259 #pos=184 */
# %   else if ( teamalsoknownas(B, P), teamplaysinleague(B, Q) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else return 0.22714756335739522;  // std dev = 13,028, 729,000 (wgt'ed) examples reached here.  /* #neg=460 #pos=269 */
#
#
# Results:
# {'AUC PR': 0.7616, 'Precision': [nan, 0.5], 'AUC ROC': 0.713697, 'CLL': -0.892261, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 27.985 seconds
# Total inference time: 3.481 seconds
# AUC ROC: 0.713697
# Refining candidate 3 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 0,457, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else if ( teamalsoknownas(B, M), teamplayssport(B, N), teamplaysagainstteam(B, M) )
# %   | | | | | then return 0.46159721096158013;  // std dev = 3,725, 58,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=35 */
# %   | | | | | else return 0.2734988222326912;  // std dev = 10,372, 443,000 (wgt'ed) examples reached here.  /* #neg=259 #pos=184 */
# %   else if ( teamalsoknownas(B, P), teamplaysinleague(B, Q) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, R), teamplaysagainstteam(S, R), teamalsoknownas(S, T) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.76244, 'Precision': [nan, 0.5], 'AUC ROC': 0.721134, 'CLL': -0.888389, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 25.651 seconds
# Total inference time: 3.021 seconds
# AUC ROC: 0.721134
# Refining candidate 4 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 0,395, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else if ( teamalsoknownas(B, M), teamplayssport(B, N), teamplaysagainstteam(B, M) )
# %   | | | | | then return 0.46159721096158013;  // std dev = 3,725, 58,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=35 */
# %   | | | | | else return 0.2734988222326912;  // std dev = 10,372, 443,000 (wgt'ed) examples reached here.  /* #neg=259 #pos=184 */
# %   else if ( teamalsoknownas(B, P), teamplaysinleague(B, Q) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, R), teamplaysagainstteam(S, R), teamalsoknownas(S, T) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.76244, 'Precision': [nan, 0.5], 'AUC ROC': 0.721134, 'CLL': -0.888389, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 25.903 seconds
# Total inference time: 3.078 seconds
# AUC ROC: 0.721134
# Refining candidate 5 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else if ( teamalsoknownas(B, M), teamplayssport(B, N), teamplaysagainstteam(B, M) )
# %   | | | | | then return 0.46159721096158013;  // std dev = 3,725, 58,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=35 */
# %   | | | | | else return 0.2734988222326912;  // std dev = 10,372, 443,000 (wgt'ed) examples reached here.  /* #neg=259 #pos=184 */
# %   else if ( teamalsoknownas(B, P), teamplaysinleague(B, Q) )
# %   | then return 0.09685861251886575;  // std dev = 0,426, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, R), teamplaysagainstteam(S, R), teamalsoknownas(S, T) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.76244, 'Precision': [nan, 0.5], 'AUC ROC': 0.721134, 'CLL': -0.888389, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 26.129 seconds
# Total inference time: 3.226 seconds
# AUC ROC: 0.721134
# Refining candidate 6 of 6
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 0,436, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else if ( teamalsoknownas(B, M), teamplayssport(B, N), teamplaysagainstteam(B, M) )
# %   | | | | | then return 0.46159721096158013;  // std dev = 3,725, 58,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=35 */
# %   | | | | | else return 0.2734988222326912;  // std dev = 10,372, 443,000 (wgt'ed) examples reached here.  /* #neg=259 #pos=184 */
# %   else if ( teamalsoknownas(B, P), teamplaysinleague(B, Q) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, R), teamplaysagainstteam(S, R), teamalsoknownas(S, T) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.76244, 'Precision': [nan, 0.5], 'AUC ROC': 0.721134, 'CLL': -0.888389, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 26.568 seconds
# Total inference time: 3.235 seconds
# AUC ROC: 0.721134
# Best Tree AUC ROC so far: 0.728257
# ******************************************
#
# Refining iteration 3
# ******************************************
# Refining candidate 1 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then if ( teamplayssport(B, K), athleteplayssport(A, K) )
# %   | | | | then return 0.37427796735757685;  // std dev = 0,500, 31,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=16 */
# %   | | | | else return 0.09781835658711473;  // std dev = 0,427, 121,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=29 */
# %   | | | else if ( athleteplaysinleague(A, L), athleteplaysinleague(M, L), athleteledsportsteam(M, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else return 0.29527468360250275;  // std dev = 11,103, 501,000 (wgt'ed) examples reached here.  /* #neg=282 #pos=219 */
# %   else if ( teamalsoknownas(B, N), teamplaysinleague(B, P) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, Q), teamplaysagainstteam(R, Q), teamalsoknownas(R, S) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.771505, 'Precision': [nan, 0.5], 'AUC ROC': 0.735964, 'CLL': -0.886899, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 342.076 seconds
# Total inference time: 4.296 seconds
# AUC ROC: 0.735964
# Refining candidate 2 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else return 0.37827277410879573;  // std dev = 12,698, 646,000 (wgt'ed) examples reached here.  /* #neg=310 #pos=336 */
# %   else if ( teamalsoknownas(B, K), teamplaysinleague(B, L) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, M), teamplaysagainstteam(N, M), teamalsoknownas(N, P) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.736098, 'Precision': [nan, 0.5], 'AUC ROC': 0.709173, 'CLL': -0.897486, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 5.85 seconds
# Total inference time: 1.754 seconds
# AUC ROC: 0.709173
# Refining candidate 3 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else return 0.29527468360250275;  // std dev = 11,103, 501,000 (wgt'ed) examples reached here.  /* #neg=282 #pos=219 */
# %   else if ( teamalsoknownas(B, M), teamplaysinleague(B, N) )
# %   | then if ( athleteledsportsteam(A, P), teamplaysinleague(P, Q), athleteplaysinleague(R, Q) )
# %   | | then return -0.10851773156715441;  // std dev = 0,180, 30,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=1 */
# %   | | else return 0.1461489350995109;  // std dev = 0,453, 125,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=36 */
# %   | else if ( athleteledsportsteam(A, S), teamplaysagainstteam(T, S), teamalsoknownas(T, U) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.766863, 'Precision': [nan, 0.5], 'AUC ROC': 0.729365, 'CLL': -0.887853, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 28.001 seconds
# Total inference time: 3.091 seconds
# AUC ROC: 0.729365
# Refining candidate 4 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else return 0.29527468360250275;  // std dev = 11,103, 501,000 (wgt'ed) examples reached here.  /* #neg=282 #pos=219 */
# %   else if ( teamalsoknownas(B, M), teamplaysinleague(B, N) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else return 0.22714756335739522;  // std dev = 13,028, 729,000 (wgt'ed) examples reached here.  /* #neg=460 #pos=269 */
#
#
# Results:
# {'AUC PR': 0.76089, 'Precision': [nan, 0.5], 'AUC ROC': 0.713056, 'CLL': -0.892512, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 25.512 seconds
# Total inference time: 3.137 seconds
# AUC ROC: 0.713056
# Refining candidate 5 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then if ( athleteledsportsteam(A, H), teamplaysagainstteam(H, I), teamalsoknownas(I, J) )
# %   | | | then return 0.2391013160518933;  // std dev = 0,486, 21,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=8 */
# %   | | | else return 0.6427643197148941;  // std dev = 0,411, 195,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=153 */
# %   | | else if ( athleteledsportsteam(A, K), teamplaysagainstteam(L, B), teamplayssport(L, M) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, N), athleteplaysinleague(P, N), athleteledsportsteam(P, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else return 0.29527468360250275;  // std dev = 11,103, 501,000 (wgt'ed) examples reached here.  /* #neg=282 #pos=219 */
# %   else if ( teamalsoknownas(B, Q), teamplaysinleague(B, R) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, S), teamplaysagainstteam(T, S), teamalsoknownas(T, U) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.769953, 'Precision': [nan, 0.5], 'AUC ROC': 0.731921, 'CLL': -0.887365, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 33.057 seconds
# Total inference time: 3.316 seconds
# AUC ROC: 0.731921
# Best Tree AUC ROC so far: 0.735964
# ******************************************
#
# Refining iteration 4
# ******************************************
# Refining candidate 1 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then return 0.15420156667845947;  // std dev = 5,628, 152,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=45 */
# %   | | | else if ( athleteplaysinleague(A, K), athleteplaysinleague(L, K), athleteledsportsteam(L, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else return 0.29527468360250275;  // std dev = 11,103, 501,000 (wgt'ed) examples reached here.  /* #neg=282 #pos=219 */
# %   else if ( teamalsoknownas(B, M), teamplaysinleague(B, N) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, P), teamplaysagainstteam(Q, P), teamalsoknownas(Q, R) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.766551, 'Precision': [nan, 0.5], 'AUC ROC': 0.728257, 'CLL': -0.88864, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 25.783 seconds
# Total inference time: 3.049 seconds
# AUC ROC: 0.728257
# Refining candidate 2 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then if ( teamplayssport(B, K), athleteplayssport(A, K) )
# %   | | | | then return 0.37427796735757685;  // std dev = 2,782, 31,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=16 */
# %   | | | | else return 0.09781835658711473;  // std dev = 4,696, 121,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=29 */
# %   | | | else return 0.37827277410879573;  // std dev = 12,698, 646,000 (wgt'ed) examples reached here.  /* #neg=310 #pos=336 */
# %   else if ( teamalsoknownas(B, L), teamplaysinleague(B, M) )
# %   | then return 0.09685861251886575;  // std dev = 5,307, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, N), teamplaysagainstteam(P, N), teamalsoknownas(P, Q) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.738277, 'Precision': [nan, 0.5], 'AUC ROC': 0.71401, 'CLL': -0.895745, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 16.514 seconds
# Total inference time: 2.686 seconds
# AUC ROC: 0.71401
# Refining candidate 3 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# %   | else if ( teamalsoknownas(F, B), teamplayssport(F, G), teamplayssport(B, G) )
# %   | | then return 0.6035193054698794;  // std dev = 6,403, 216,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=161 */
# %   | | else if ( athleteledsportsteam(A, H), teamplaysagainstteam(I, B), teamplayssport(I, J) )
# %   | | | then if ( teamplayssport(B, K), athleteplayssport(A, K) )
# %   | | | | then return 0.37427796735757685;  // std dev = 2,782, 31,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=16 */
# %   | | | | else return 0.09781835658711473;  // std dev = 4,696, 121,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=29 */
# %   | | | else if ( athleteplaysinleague(A, L), athleteplaysinleague(M, L), athleteledsportsteam(M, B) )
# %   | | | | then return 0.665045486823648;  // std dev = 4,753, 145,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=117 */
# %   | | | | else return 0.29527468360250275;  // std dev = 11,103, 501,000 (wgt'ed) examples reached here.  /* #neg=282 #pos=219 */
# %   else if ( teamalsoknownas(B, N), teamplaysinleague(B, P) )
# %   | then return 0.09685861251886575;  // std dev = 0,426, 155,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=37 */
# %   | else if ( athleteledsportsteam(A, Q), teamplaysagainstteam(R, Q), teamalsoknownas(R, S) )
# %   | | then return -0.0697789928284156;  // std dev = 2,725, 111,000 (wgt'ed) examples reached here.  /* #neg=103 #pos=8 */
# %   | | else return 0.28047903218688663;  // std dev = 12,279, 618,000 (wgt'ed) examples reached here.  /* #neg=357 #pos=261 */
#
#
# Results:
# {'AUC PR': 0.771505, 'Precision': [nan, 0.5], 'AUC ROC': 0.735964, 'CLL': -0.886899, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 36.486 seconds
# Total inference time: 3.77 seconds
# AUC ROC: 0.735964
# Refining candidate 4 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteledsportsteam(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 202,000 (wgt'ed) examples reached here.  /* #pos=202 */
# ...
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(D, C), teamalsoknownas(E, D) )
# %   | then return -0.31448433611334337;  // std dev = 3,583, 4.350,000 (wgt'ed) examples reached here.  /* #neg=3.420 #pos=930 */
# %   | else if ( teamplaysagainstteam(B, F), teamplaysinleague(B, G), athleteplaysinleague(A, G) )
# %   | | then return 3.495090397516947;  // std dev = 3,700, 2.920,000 (wgt'ed) examples reached here.  /* #neg=470 #pos=2.450 */
# %   | | else if ( teamplaysagainstteam(H, B), teamplaysagainstteam(B, I), teamalsoknownas(I, H) )
# %   | | | then if ( athleteplaysinleague(A, J), teamplaysinleague(K, J), teamplaysagainstteam(H, I) )
# %   | | | | then return -0.046739008855109405;  // std dev = 3,480, 1.150,000 (wgt'ed) examples reached here.  /* #neg=950 #pos=200 */
# %   | | | | else if ( teamplaysagainstteam(B, H), teamplaysinleague(I, L), athleteplaysinleague(M, L) )
# %   | | | | | then return 2.448973941540327;  // std dev = 394,879, 7.230,000 (wgt'ed) examples reached here.  /* #neg=2.590 #pos=4.640 */
# %   | | | | | else return 0.32241781103478445;  // std dev = 120,663, 720,000 (wgt'ed) examples reached here.  /* #neg=500 #pos=220 */
# %   | | | else if ( athleteplaysinleague(A, N), teamplaysinleague(P, N) )
# %   | | | | then return -1.1181900079996259;  // std dev = 1,949, 1.440,000 (wgt'ed) examples reached here.  /* #neg=1.380 #pos=60 */
# %   | | | | else if ( teamplaysagainstteam(Q, B), teamalsoknownas(B, Q), teamplayssport(B, R) )
# %   | | | | | then return 3.7513992559658624;  // std dev = 68,025, 230,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=160 */
# %   | | | | | else return 0.9833681586826305;  // std dev = 349,206, 5.720,000 (wgt'ed) examples reached here.  /* #neg=3.750 #pos=1.970 */
#
#
# Results:
# {'AUC PR': 0.808704, 'Precision': [0.718954, 0.5], 'AUC ROC': 0.789536, 'CLL': -0.553819, 'Recall': 0.758621, 'F1': 0.738255}
#
#
# Total learning time: 2234.154 seconds
# Total inference time: 1.213 seconds
# AUC ROC: 0.789536
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995093;  // std dev = 1,08e-06, 195,000 (wgt'ed) examples reached here.  /* #pos=195 */
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(C, D), teamalsoknownas(D, E) )
# %   | then return 0.0506017652881914;  // std dev = 6,418, 265,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=51 */
# %   | else if ( teamplaysinleague(B, F), teamplayssport(B, G), athleteplayssport(A, G) )
# %   | | then return 0.625194389644964;  // std dev = 5,608, 176,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=135 */
# %   | | else if ( athleteplaysinleague(A, H), teamplaysinleague(I, H) )
# %   | | | then if ( teamplaysinleague(B, H), teamplayssport(B, J) )
# %   | | | | then return 0.7331489350995108;  // std dev = 3,500, 112,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=98 */
# %   | | | | else return -0.08124500429442723;  // std dev = 3,627, 231,000 (wgt'ed) examples reached here.  /* #neg=217 #pos=14 */
# %   | | | else if ( athleteledsportsteam(K, B), teamplaysagainstteam(L, B), teamalsoknownas(L, B) )
# %   | | | | then if ( athleteplayssport(A, M) )
# %   | | | | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | | else return 0.5882102847927613;  // std dev = 5,668, 163,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=119 */
# %   | | | | else if ( teamplaysinleague(B, N), athleteplaysinleague(P, N), athleteledsportsteam(P, Q) )
# %   | | | | | then return 0.35543154379515984;  // std dev = 13,564, 736,000 (wgt'ed) examples reached here.  /* #neg=370 #pos=366 */
# %   | | | | | else return 0.18404179224236908;  // std dev = 7,015, 224,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=73 */
#
#
# Results:
# {'AUC PR': 0.839254, 'Precision': [nan, 0.5], 'AUC ROC': 0.82182, 'CLL': -0.861801, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 2.305 seconds
# Total inference time: 1.072 seconds
# AUC ROC: 0.82182
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995093;  // std dev = 1,08e-06, 195,000 (wgt'ed) examples reached here.  /* #pos=195 */
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(C, D), teamalsoknownas(D, E) )
# %   | then return 0.0506017652881914;  // std dev = 6,418, 265,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=51 */
# %   | else if ( teamplaysinleague(B, F), teamplayssport(B, G), athleteplayssport(A, G) )
# %   | | then return 0.625194389644964;  // std dev = 0,423, 176,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=135 */
# %   | | else if ( athleteplaysinleague(A, H), teamplaysinleague(I, H) )
# %   | | | then if ( teamplaysinleague(B, H), teamplayssport(B, J) )
# %   | | | | then return 0.7331489350995108;  // std dev = 3,500, 112,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=98 */
# %   | | | | else return -0.08124500429442723;  // std dev = 3,627, 231,000 (wgt'ed) examples reached here.  /* #neg=217 #pos=14 */
# %   | | | else if ( athleteledsportsteam(K, B), teamplaysagainstteam(L, B), teamalsoknownas(L, B) )
# %   | | | | then if ( athleteplayssport(A, M) )
# %   | | | | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | | else return 0.5882102847927613;  // std dev = 5,668, 163,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=119 */
# %   | | | | else if ( teamplaysinleague(B, N), athleteplaysinleague(P, N), athleteledsportsteam(P, Q) )
# %   | | | | | then return 0.35543154379515984;  // std dev = 13,564, 736,000 (wgt'ed) examples reached here.  /* #neg=370 #pos=366 */
# %   | | | | | else return 0.18404179224236908;  // std dev = 7,015, 224,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=73 */
#
#
# Results:
# {'AUC PR': 0.839254, 'Precision': [nan, 0.5], 'AUC ROC': 0.82182, 'CLL': -0.861801, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 2.328 seconds
# Total inference time: 1.024 seconds
# AUC ROC: 0.82182
# Refining candidate 2 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995093;  // std dev = 1,08e-06, 195,000 (wgt'ed) examples reached here.  /* #pos=195 */
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(C, D), teamalsoknownas(D, E) )
# %   | then return 0.0506017652881914;  // std dev = 6,418, 265,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=51 */
# %   | else if ( teamplaysinleague(B, F), teamplayssport(B, G), athleteplayssport(A, G) )
# %   | | then return 0.625194389644964;  // std dev = 5,608, 176,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=135 */
# %   | | else if ( athleteplaysinleague(A, H), teamplaysinleague(I, H) )
# %   | | | then if ( teamplaysinleague(B, H), teamplayssport(B, J) )
# %   | | | | then return 0.7331489350995108;  // std dev = 3,500, 112,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=98 */
# %   | | | | else return -0.08124500429442723;  // std dev = 3,627, 231,000 (wgt'ed) examples reached here.  /* #neg=217 #pos=14 */
# %   | | | else if ( athleteledsportsteam(K, B), teamplaysagainstteam(L, B), teamalsoknownas(L, B) )
# %   | | | | then if ( athleteplayssport(A, M) )
# %   | | | | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | | else return 0.5882102847927613;  // std dev = 0,444, 163,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=119 */
# %   | | | | else if ( teamplaysinleague(B, N), athleteplaysinleague(P, N), athleteledsportsteam(P, Q) )
# %   | | | | | then return 0.35543154379515984;  // std dev = 13,564, 736,000 (wgt'ed) examples reached here.  /* #neg=370 #pos=366 */
# %   | | | | | else return 0.18404179224236908;  // std dev = 7,015, 224,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=73 */
#
#
# Results:
# {'AUC PR': 0.839254, 'Precision': [nan, 0.5], 'AUC ROC': 0.82182, 'CLL': -0.861801, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 2.068 seconds
# Total inference time: 1.041 seconds
# AUC ROC: 0.82182
# Refining candidate 3 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995093;  // std dev = 1,08e-06, 195,000 (wgt'ed) examples reached here.  /* #pos=195 */
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(C, D), teamalsoknownas(D, E) )
# %   | then return 0.0506017652881914;  // std dev = 0,394, 265,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=51 */
# %   | else if ( teamplaysinleague(B, F), teamplayssport(B, G), athleteplayssport(A, G) )
# %   | | then return 0.625194389644964;  // std dev = 5,608, 176,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=135 */
# %   | | else if ( athleteplaysinleague(A, H), teamplaysinleague(I, H) )
# %   | | | then if ( teamplaysinleague(B, H), teamplayssport(B, J) )
# %   | | | | then return 0.7331489350995108;  // std dev = 3,500, 112,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=98 */
# %   | | | | else return -0.08124500429442723;  // std dev = 3,627, 231,000 (wgt'ed) examples reached here.  /* #neg=217 #pos=14 */
# %   | | | else if ( athleteledsportsteam(K, B), teamplaysagainstteam(L, B), teamalsoknownas(L, B) )
# %   | | | | then if ( athleteplayssport(A, M) )
# %   | | | | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | | else return 0.5882102847927613;  // std dev = 5,668, 163,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=119 */
# %   | | | | else if ( teamplaysinleague(B, N), athleteplaysinleague(P, N), athleteledsportsteam(P, Q) )
# %   | | | | | then return 0.35543154379515984;  // std dev = 13,564, 736,000 (wgt'ed) examples reached here.  /* #neg=370 #pos=366 */
# %   | | | | | else return 0.18404179224236908;  // std dev = 7,015, 224,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=73 */
#
#
# Results:
# {'AUC PR': 0.839254, 'Precision': [nan, 0.5], 'AUC ROC': 0.82182, 'CLL': -0.861801, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 2.194 seconds
# Total inference time: 1.048 seconds
# AUC ROC: 0.82182
# Refining candidate 4 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995093;  // std dev = 1,08e-06, 195,000 (wgt'ed) examples reached here.  /* #pos=195 */
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(C, D), teamalsoknownas(D, E) )
# %   | then return 0.0506017652881914;  // std dev = 6,418, 265,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=51 */
# %   | else if ( teamplaysinleague(B, F), teamplayssport(B, G), athleteplayssport(A, G) )
# %   | | then return 0.625194389644964;  // std dev = 5,608, 176,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=135 */
# %   | | else if ( athleteplaysinleague(A, H), teamplaysinleague(I, H) )
# %   | | | then if ( teamplaysinleague(B, H), teamplayssport(B, J) )
# %   | | | | then return 0.7331489350995108;  // std dev = 3,500, 112,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=98 */
# %   | | | | else return -0.08124500429442723;  // std dev = 3,627, 231,000 (wgt'ed) examples reached here.  /* #neg=217 #pos=14 */
# %   | | | else if ( athleteledsportsteam(K, B), teamplaysagainstteam(L, B), teamalsoknownas(L, B) )
# %   | | | | then if ( athleteplayssport(A, M) )
# %   | | | | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | | else return 0.5882102847927613;  // std dev = 5,668, 163,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=119 */
# %   | | | | else return 0.31544060176617467;  // std dev = 15,435, 960,000 (wgt'ed) examples reached here.  /* #neg=521 #pos=439 */
#
#
# Results:
# {'AUC PR': 0.828262, 'Precision': [nan, 0.5], 'AUC ROC': 0.804928, 'CLL': -0.863796, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 1.758 seconds
# Total inference time: 1.062 seconds
# AUC ROC: 0.804928
# Refining candidate 5 of 5
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995093;  // std dev = 1,08e-06, 195,000 (wgt'ed) examples reached here.  /* #pos=195 */
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(C, D), teamalsoknownas(D, E) )
# %   | then return 0.0506017652881914;  // std dev = 6,418, 265,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=51 */
# %   | else if ( teamplaysinleague(B, F), teamplayssport(B, G), athleteplayssport(A, G) )
# %   | | then return 0.625194389644964;  // std dev = 5,608, 176,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=135 */
# %   | | else if ( athleteplaysinleague(A, H), teamplaysinleague(I, H) )
# %   | | | then return 0.18467954734440636;  // std dev = 8,685, 343,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=112 */
# %   | | | else if ( athleteledsportsteam(J, B), teamplaysagainstteam(K, B), teamalsoknownas(K, B) )
# %   | | | | then if ( athleteplayssport(A, L) )
# %   | | | | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | | else return 0.5882102847927613;  // std dev = 5,668, 163,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=119 */
# %   | | | | else if ( teamplaysinleague(B, M), athleteplaysinleague(N, M), athleteledsportsteam(N, P) )
# %   | | | | | then return 0.35543154379515984;  // std dev = 13,564, 736,000 (wgt'ed) examples reached here.  /* #neg=370 #pos=366 */
# %   | | | | | else return 0.18404179224236908;  // std dev = 7,015, 224,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=73 */
#
#
# Results:
# {'AUC PR': 0.827895, 'Precision': [nan, 0.5], 'AUC ROC': 0.795802, 'CLL': -0.875017, 'Recall': 0.0, 'F1': nan}
#
#
# Total learning time: 2.01 seconds
# Total inference time: 1.054 seconds
# AUC ROC: 0.795802
# Best Tree AUC ROC so far: 0.82182
# ******************************************
#
# ******************************************
# Total revision time: 18.964000000000002
# Best validation AUC ROC: 0.82182
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995093;  // std dev = 1,08e-06, 195,000 (wgt'ed) examples reached here.  /* #pos=195 */
# %   else if ( athleteledsportsteam(A, C), teamplaysagainstteam(C, D), teamalsoknownas(D, E) )
# %   | then return 0.0506017652881914;  // std dev = 6,418, 265,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=51 */
# %   | else if ( teamplaysinleague(B, F), teamplayssport(B, G), athleteplayssport(A, G) )
# %   | | then return 0.625194389644964;  // std dev = 5,608, 176,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=135 */
# %   | | else if ( athleteplaysinleague(A, H), teamplaysinleague(I, H) )
# %   | | | then if ( teamplaysinleague(B, H), teamplayssport(B, J) )
# %   | | | | then return 0.7331489350995108;  // std dev = 3,500, 112,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=98 */
# %   | | | | else return -0.08124500429442723;  // std dev = 3,627, 231,000 (wgt'ed) examples reached here.  /* #neg=217 #pos=14 */
# %   | | | else if ( athleteledsportsteam(K, B), teamplaysagainstteam(L, B), teamalsoknownas(L, B) )
# %   | | | | then if ( athleteplayssport(A, M) )
# %   | | | | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | | else return 0.5882102847927613;  // std dev = 5,668, 163,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=119 */
# %   | | | | else if ( teamplaysinleague(B, N), athleteplaysinleague(P, N), athleteledsportsteam(P, Q) )
# %   | | | | | then return 0.35543154379515984;  // std dev = 13,564, 736,000 (wgt'ed) examples reached here.  /* #neg=370 #pos=366 */
# %   | | | | | else return 0.18404179224236908;  // std dev = 7,015, 224,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=73 */
#
#
# Results:
# {'AUC PR': 0.819094, 'Precision': [nan, 0.5], 'AUC ROC': 0.799073, 'CLL': -0.861731, 'Recall': 0.0, 'F1': nan}
#
#
# Total inference time: 0.98 seconds
# AUC ROC: 0.799073

# %%
small_dataset_aucroc
# Out:
# [0.741743,
#  0.74559,
#  0.749601,
#  0.732619,
#  0.730015,
#  0.802871,
#  0.74803,
#  0.800737,
#  0.783686,
#  0.804209]

# %%
complete_dataset_aucroc
# Out:
# [0.802003,
#  0.691101,
#  0.687254,
#  0.760251,
#  0.765106,
#  0.796983,
#  0.767639,
#  0.798743,
#  0.817218,
#  0.789536]

# %%
revision_dataset_aucroc
# Out:
# [0.796585,
#  0.751126,
#  0.772213,
#  0.760931,
#  0.784082,
#  0.805264,
#  0.802918,
#  0.804583,
#  0.783639,
#  0.799073]

# %%
print('Small dataset AUC ROC: %s +/- %s' % ((np.array(small_dataset_aucroc)).mean(), (np.array(small_dataset_aucroc)).std()))
print('Complete dataset AUC ROC: %s +/- %s' % ((np.array(complete_dataset_aucroc)).mean(), (np.array(complete_dataset_aucroc)).std()))
print('Theory revision dataset AUC ROC: %s +/- %s' % ((np.array(revision_dataset_aucroc)).mean(), (np.array(revision_dataset_aucroc)).std()))
print('Small dataset learning time: %s +/- %s' % ((np.array(small_learning_time)).mean(), (np.array(small_learning_time)).std()))
print('Small dataset inference time: %s +/- %s' % ((np.array(small_inference_time)).mean(), (np.array(small_inference_time)).std()))
print('Complete dataset learning time: %s +/- %s' % ((np.array(complete_learning_time)).mean(), (np.array(complete_learning_time)).std()))
print('Complete dataset inference time: %s +/- %s' % ((np.array(complete_inference_time)).mean(), (np.array(complete_inference_time)).std()))
print('Revision time: %s +/- %s' % ((np.array(revision_learning_time)).mean(), (np.array(revision_learning_time)).std()))
print('Revision model inference time: %s +/- %s' % ((np.array(revision_inference_time)).mean(), (np.array(revision_inference_time)).std()))
# Out:
# Small dataset AUC ROC: 0.7639101000000001 +/- 0.028811811645399876
# Complete dataset AUC ROC: 0.7675834 +/- 0.04281092253899698
# Theory revision dataset AUC ROC: 0.7860414 +/- 0.01824708682064072
# Small dataset learning time: 629.8982 +/- 310.957204002673
# Small dataset inference time: 1.0429 +/- 0.2432021587075246
# Complete dataset learning time: 1495.6859000000002 +/- 665.3716977738759
# Complete dataset inference time: 0.9577000000000002 +/- 0.10197847812161154
# Revision time: 126.03519999999999 +/- 257.9179714113772
# Revision model inference time: 1.1384 +/- 0.4437907615081684

# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random

# %% [markdown]
# ## Parameters

# %%
target = 'athleteplaysforteam'
test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.95
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %%
[facts, pos, neg] = get_nell_dataset(target)

# %% [markdown]
# ## Background  configuration

# %%
bk = ['athleteledsportsteam(+athlete,+sportsteam).',
      'athleteledsportsteam(+athlete,-sportsteam).',
      'athleteledsportsteam(-athlete,+sportsteam).',
      'athleteplaysforteam(+athlete,+sportsteam).',
      'athleteplaysforteam(+athlete,-sportsteam).',
      'athleteplaysforteam(-athlete,+sportsteam).',
      'athleteplaysinleague(+athlete,+sportsleague).',
      'athleteplaysinleague(+athlete,-sportsleague).',
      'athleteplaysinleague(-athlete,+sportsleague).',
      'athleteplayssport(+athlete,+sport).',
      'athleteplayssport(+athlete,-sport).',
      'athleteplayssport(-athlete,+sport).',
      'teamalsoknownas(+sportsteam,+sportsteam).',
      'teamalsoknownas(+sportsteam,-sportsteam).',
      'teamalsoknownas(-sportsteam,+sportsteam).',
      'teamplaysagainstteam(+sportsteam,+sportsteam).',
      'teamplaysagainstteam(+sportsteam,-sportsteam).',
      'teamplaysagainstteam(-sportsteam,+sportsteam).',
      'teamplaysinleague(+sportsteam,+sportsleague).',
      'teamplaysinleague(+sportsteam,-sportsleague).',
      'teamplaysinleague(-sportsteam,+sportsleague).',
      'teamplayssport(+sportsteam,+sport).',
      'teamplayssport(+sportsteam,-sport).',
      'teamplayssport(-sportsteam,+sport).']

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

# separate train and test
test_pos = pos[:int(test_size*len(pos))]
test_neg = neg[:int(test_size*len(neg))]
train_pos = pos[int(test_size*len(pos)):]
train_neg = neg[int(test_size*len(neg)):]

# learn from scratch in a small dataset
s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

# shuffle all train examples
random.shuffle(train_pos)
random.shuffle(train_neg)

# train set used in revision and validation set
r_train_pos = train_pos[int(validation_size*len(train_pos)):]
r_train_neg = train_neg[int(validation_size*len(train_neg)):]
validation_pos = train_pos[:int(validation_size*len(train_pos))]
validation_neg = train_neg[:int(validation_size*len(train_neg))]

print('Total examples')
print('Positive examples: %s' % len(pos))
print('Negative examples: %s' % len(neg))
print('\n')
print('Train and test sets from total')
print('Train Positive examples: %s' % len(train_pos))
print('Train Negative examples: %s' % len(train_neg))
print('Test Positive examples: %s' % len(test_pos))
print('Test Negative examples: %s' % len(test_neg))
print('\n')
print('Small dataset')
print('Train Positive examples: %s' % len(s_train_pos))
print('Train Negative examples: %s' % len(s_train_neg))
print('\n')
print('Revision theory train dataset and validation')
print('Train Positive examples: %s' % len(r_train_pos))
print('Train Negative examples: %s' % len(r_train_neg))
print('Validation Positive examples: %s' % len(validation_pos))
print('Validation Negative examples: %s' % len(validation_neg))
# Out:
# Total examples
# Positive examples: 1458
# Negative examples: 1458
#
#
# Train and test sets from total
# Train Positive examples: 1021
# Train Negative examples: 1021
# Test Positive examples: 437
# Test Negative examples: 437
#
#
# Small dataset
# Train Positive examples: 306
# Train Negative examples: 306
#
#
# Revision theory train dataset and validation
# Train Positive examples: 817
# Train Negative examples: 817
# Validation Positive examples: 204
# Validation Negative examples: 204

# %% [markdown]
# ## Learning from small dataset

# %%
delete_model_files()
model = boostsrl.train(background, s_train_pos, s_train_neg, facts, trees=10)
learning_time = model.traintime()
will = model.get_will_produced_tree()
structured = model.get_structured_tree().copy()
results = boostsrl.test(model, test_pos, test_neg, facts, trees=10)
inference_time = results.testtime()
t_results = results.summarize_results()
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total learning time: %s seconds' % learning_time)
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
print('Tree:')
model.tree(0, target, image=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      68         p = subprocess.Popen(call, shell=True)
# ---> 69         os.waitpid(p.pid, 0)
#      70     except:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-c8425ad3c816> in <module>()
#       1 delete_model_files()
# ----> 2 model = boostsrl.train(background, s_train_pos, s_train_neg, facts, trees=10)
#       3 learning_time = model.traintime()
#       4 will = model.get_will_produced_tree()
#       5 structured = model.get_structured_tree().copy()
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in __init__(self, background, train_pos, train_neg, train_facts, refine, save, advice, softm, alpha, beta, trees)
#     249         CALL = '(cd boostsrl; java -jar v1-0.jar -l ' + ('-refine refine.txt ' if refine else '') + combine + '-train train/ -target ' + ','.join(self.target) + \
#     250                ' -trees ' + str(self.trees) + ' > train_output.txt 2>&1)'
# --> 251         call_process(CALL)
#     252
#     253     def tree(self, treenumber, target, image=False):
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      69         os.waitpid(p.pid, 0)
#      70     except:
# ---> 71         raise(Exception('Encountered problems while running process: ', call))
#      72
#      73 def inspect_mode_syntax(example):
#
# Exception: ('Encountered problems while running process: ', '(cd boostsrl; java -jar v1-0.jar -l -combine -train train/ -target athleteplaysforteam -trees 10 > train_output.txt 2>&1)')

# %% [markdown]
# ## Learning from complete dataset

# %%
delete_model_files()
model = boostsrl.train(background, train_pos, train_neg, facts, trees=10)
learning_time = model.traintime()
will = model.get_will_produced_tree()
#structured = model.get_structured_tree().copy()
results = boostsrl.test(model, test_pos, test_neg, facts, trees=10)
inference_time = results.testtime()
t_results = results.summarize_results()
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total learning time: %s seconds' % learning_time)
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
print('Tree:')
model.tree(0, target, image=True)
# Out:
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(C, B), athleteplaysinleague(C, D), athleteplaysinleague(A, D) )
# %   then return 0.6832720878088678;  // std dev = 0,380, 406,000 (wgt'ed) examples reached here.  /* #neg=71 #pos=335 */
# %   else if ( teamplaysagainstteam(B, E), teamalsoknownas(E, F), teamplaysagainstteam(F, B) )
# %   | then if ( athleteplaysinleague(A, G) )
# %   | | then return 0.08891816586874221;  // std dev = 0,421, 182,000 (wgt'ed) examples reached here.  /* #neg=140 #pos=42 */
# %   | | else if ( teamplaysagainstteam(E, F), teamalsoknownas(E, H), teamalsoknownas(H, I) )
# %   | | | then if ( teamalsoknownas(F, B) )
# %   | | | | then return 0.6624967611864696;  // std dev = 0,397, 92,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=74 */
# %   | | | | else if ( teamplaysagainstteam(F, H), teamplaysagainstteam(H, B), athleteledsportsteam(J, E) )
# %   | | | | | then return 0.44112765850376423;  // std dev = 7,559, 235,000 (wgt'ed) examples reached here.  /* #neg=98 #pos=137 */
# %   | | | | | else return 0.1536034805540578;  // std dev = 4,280, 88,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=26 */
# %   | | | else if ( athleteledsportsteam(A, B) )
# %   | | | | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | | | | else if ( athleteledsportsteam(K, B), athleteplaysinleague(K, L) )
# %   | | | | | then return 0.35421192722549766;  // std dev = 5,635, 127,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=63 */
# %   | | | | | else return 0.6676727446233203;  // std dev = 4,761, 147,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=119 */
# %   | else return 0.13038613186501039;  // std dev = 0,445, 742,000 (wgt'ed) examples reached here.  /* #neg=540 #pos=202 */
#
#
# Results:
# {'F1': 0.721271, 'AUC PR': 0.842824, 'CLL': -0.506517, 'AUC ROC': 0.838183, 'Recall': 0.675057, 'Precision': [0.774278, 0.5]}
#
#
# Total learning time: 515.382 seconds
# Total inference time: 1.805 seconds
# AUC ROC: 0.838183
#
#
# Tree:

# %% [markdown]
# ## Theory Revision

# %%
total_revision_time = 0
best_aucroc = 0
best_structured = None

print('Performing parameter learning')
print('******************************************')
delete_model_files()
model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=get_refine_file(structured))
learning_time = model.traintime()
will = model.get_will_produced_tree()
structured = model.get_structured_tree().copy()
results = boostsrl.test(model, validation_pos, validation_neg, facts)
inference_time = results.testtime()
t_results = results.summarize_results()
total_revision_time += learning_time + inference_time
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total learning time: %s seconds' % learning_time)
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
#print('Tree:')
#model.tree(0, target, image=True)

best_aucroc = t_results['AUC ROC']
best_structured = structured.copy()
save_model_files()

for i in range(max_revision_iterations):
    print('Refining iteration %s' % str(i+1))
    print('******************************************')
    found_better = False
    for candidate in get_cantidates(best_structured, revision_threshold):
        print('Refining node candidate')
        print('******************************************')
        delete_model_files()
        model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=candidate)
        learning_time = model.traintime()
        will = model.get_will_produced_tree()
        results = boostsrl.test(model, validation_pos, validation_neg, facts)
        inference_time = results.testtime()
        t_results = results.summarize_results()
        total_revision_time += learning_time + inference_time
        print('WILL-Produced Tree:')
        print_will_produced_tree(will)
        print('\n')
        print('Results:')
        print(t_results)
        print('\n')
        print('Total learning time: %s seconds' % learning_time)
        print('Total inference time: %s seconds' % inference_time)
        print('AUC ROC: %s' % t_results['AUC ROC'])
        print('\n')
        #print('Tree:')
        #model.tree(0, target, image=True)
        print('******************************************')

        if t_results['AUC ROC'] > best_aucroc:
            found_better = True
            best_aucroc = t_results['AUC ROC']
            best_structured = model.get_structured_tree().copy()
            save_model_files()
    print('Best Tree AUC ROC so far: %s' % best_aucroc)
    print('******************************************\n')
    if found_better == False:
        break

print('******************************************')
delete_model_files()
get_saved_model_files()
delete_test_files()
print('Total revision time: %s' % total_revision_time)
print('Best validation AUC ROC: %s' % best_aucroc)
will = model.get_will_produced_tree()
results = boostsrl.test(model, test_pos, test_neg, facts)
inference_time = results.testtime()
t_results = results.summarize_results()
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
print('Tree:')
model.tree(0, target, image=True)
# Out:
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else if ( athleteledsportsteam(J, E), teamplaysagainstteam(B, D) )
# %   | | | | | then return 0.535191736655929;  // std dev = 7,496, 257,000 (wgt'ed) examples reached here.  /* #neg=83 #pos=174 */
# %   | | | | | else return 0.12644161802634163;  // std dev = 2,837, 41,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=11 */
# %   | | else if ( teamalsoknownas(B, K), teamplaysinleague(K, L), teamalsoknownas(K, M) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.806336, 'AUC ROC': 0.785479, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.86959}
#
#
# Total learning time: 1.919 seconds
# Total inference time: 0.992 seconds
# AUC ROC: 0.785479
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 0,461, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else if ( athleteledsportsteam(J, E), teamplaysagainstteam(B, D) )
# %   | | | | | then return 0.535191736655929;  // std dev = 7,496, 257,000 (wgt'ed) examples reached here.  /* #neg=83 #pos=174 */
# %   | | | | | else return 0.12644161802634163;  // std dev = 2,837, 41,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=11 */
# %   | | else if ( teamalsoknownas(B, K), teamplaysinleague(K, L), teamalsoknownas(K, M) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.806336, 'AUC ROC': 0.785479, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.86959}
#
#
# Total learning time: 2.154 seconds
# Total inference time: 0.935 seconds
# AUC ROC: 0.785479
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 0,410, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else if ( athleteledsportsteam(J, E), teamplaysagainstteam(B, D) )
# %   | | | | | then return 0.535191736655929;  // std dev = 7,496, 257,000 (wgt'ed) examples reached here.  /* #neg=83 #pos=174 */
# %   | | | | | else return 0.12644161802634163;  // std dev = 2,837, 41,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=11 */
# %   | | else if ( teamalsoknownas(B, K), teamplaysinleague(K, L), teamalsoknownas(K, M) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.806336, 'AUC ROC': 0.785479, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.86959}
#
#
# Total learning time: 1.697 seconds
# Total inference time: 0.969 seconds
# AUC ROC: 0.785479
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then return 0.3954623679353301;  // std dev = 7,069, 201,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=108 */
# %   | | | | else if ( athleteledsportsteam(H, E), teamplaysagainstteam(B, D) )
# %   | | | | | then return 0.535191736655929;  // std dev = 7,496, 257,000 (wgt'ed) examples reached here.  /* #neg=83 #pos=174 */
# %   | | | | | else return 0.12644161802634163;  // std dev = 2,837, 41,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=11 */
# %   | | else if ( teamalsoknownas(B, I), teamplaysinleague(I, J), teamalsoknownas(I, K) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.806268, 'AUC ROC': 0.784001, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.873467}
#
#
# Total learning time: 1.904 seconds
# Total inference time: 0.878 seconds
# AUC ROC: 0.784001
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, J), teamplaysinleague(J, K), teamalsoknownas(J, L) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.805492, 'AUC ROC': 0.786837, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.871895}
#
#
# Total learning time: 1.742 seconds
# Total inference time: 0.961 seconds
# AUC ROC: 0.786837
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else if ( athleteledsportsteam(J, E), teamplaysagainstteam(B, D) )
# %   | | | | | then return 0.535191736655929;  // std dev = 7,496, 257,000 (wgt'ed) examples reached here.  /* #neg=83 #pos=174 */
# %   | | | | | else return 0.12644161802634163;  // std dev = 2,837, 41,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=11 */
# %   | | else return 0.18863934021678283;  // std dev = 10,187, 469,000 (wgt'ed) examples reached here.  /* #neg=314 #pos=155 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.804415, 'AUC ROC': 0.780265, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.870427}
#
#
# Total learning time: 1.822 seconds
# Total inference time: 0.942 seconds
# AUC ROC: 0.780265
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.786837
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then if ( teamplayssport(B, G), teamplaysinleague(B, H), athleteplaysinleague(A, H) )
# %   | | | | then return 0.7936328060672536;  // std dev = 0,246, 31,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=29 */
# %   | | | | else return 0.5103228481429879;  // std dev = 0,476, 184,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=120 */
# %   | | | else if ( teamalsoknownas(D, I) )
# %   | | | | then if ( athleteledsportsteam(J, B), athleteplayssport(A, K), athleteplayssport(J, K) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, L), teamplaysinleague(L, M), teamalsoknownas(L, N) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.8058, 'AUC ROC': 0.786921, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.873166}
#
#
# Total learning time: 7.991 seconds
# Total inference time: 1.0 seconds
# AUC ROC: 0.786921
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then if ( athleteledsportsteam(D, B), teamplaysinleague(B, E), athleteplaysinleague(A, E) )
# %   | | then return 0.46529179224236833;  // std dev = 0,488, 56,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=34 */
# %   | | else return -0.020002325404689335;  // std dev = 0,327, 238,000 (wgt'ed) examples reached here.  /* #neg=209 #pos=29 */
# %   | else if ( teamplaysagainstteam(F, B), teamalsoknownas(G, F), teamplaysagainstteam(B, G) )
# %   | | then if ( teamalsoknownas(F, G), teamalsoknownas(F, H), teamalsoknownas(G, H) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(F, I) )
# %   | | | | then if ( athleteledsportsteam(J, B), athleteplayssport(A, K), athleteplayssport(J, K) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, L), teamplaysinleague(L, M), teamalsoknownas(L, N) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.819262, 'AUC ROC': 0.816729, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.862668}
#
#
# Total learning time: 3.147 seconds
# Total inference time: 0.916 seconds
# AUC ROC: 0.816729
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then return 0.3954623679353301;  // std dev = 7,069, 201,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=108 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, H), teamplaysinleague(H, I), teamalsoknownas(H, J) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.803915, 'AUC ROC': 0.783941, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.875772}
#
#
# Total learning time: 1.832 seconds
# Total inference time: 0.951 seconds
# AUC ROC: 0.783941
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else if ( teamplaysinleague(B, J), teamplaysagainstteam(B, K), teamalsoknownas(L, K) )
# %   | | | | | then return 0.5115785379875952;  // std dev = 7,920, 277,000 (wgt'ed) examples reached here.  /* #neg=96 #pos=181 */
# %   | | | | | else return 0.0486251255757027;  // std dev = 1,799, 21,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=4 */
# %   | | else if ( teamalsoknownas(B, M), teamplaysinleague(M, N), teamalsoknownas(M, P) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.806977, 'AUC ROC': 0.787269, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.869989}
#
#
# Total learning time: 6.763 seconds
# Total inference time: 0.965 seconds
# AUC ROC: 0.787269
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else return 0.18863934021678283;  // std dev = 10,187, 469,000 (wgt'ed) examples reached here.  /* #neg=314 #pos=155 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.803944, 'AUC ROC': 0.782536, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.872732}
#
#
# Total learning time: 1.749 seconds
# Total inference time: 0.967 seconds
# AUC ROC: 0.782536
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.816729
# ******************************************
#
# Refining iteration 3
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 0,410, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then if ( teamplayssport(B, G), teamplaysinleague(B, H), athleteplaysinleague(A, H) )
# %   | | | | then return 0.7936328060672536;  // std dev = 0,246, 31,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=29 */
# %   | | | | else return 0.5103228481429879;  // std dev = 0,476, 184,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=120 */
# %   | | | else if ( teamalsoknownas(D, I) )
# %   | | | | then if ( athleteledsportsteam(J, B), athleteplayssport(A, K), athleteplayssport(J, K) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, L), teamplaysinleague(L, M), teamalsoknownas(L, N) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.8058, 'AUC ROC': 0.786921, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.873166}
#
#
# Total learning time: 7.833 seconds
# Total inference time: 1.024 seconds
# AUC ROC: 0.786921
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 7,036, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, J), teamplaysinleague(J, K), teamalsoknownas(J, L) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.805492, 'AUC ROC': 0.786837, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.871895}
#
#
# Total learning time: 1.783 seconds
# Total inference time: 0.924 seconds
# AUC ROC: 0.786837
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then if ( athleteledsportsteam(D, B), teamplaysinleague(B, E), athleteplaysinleague(A, E) )
# %   | | then return 0.46529179224236833;  // std dev = 3,655, 56,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=34 */
# %   | | else return -0.020002325404689335;  // std dev = 5,046, 238,000 (wgt'ed) examples reached here.  /* #neg=209 #pos=29 */
# %   | else if ( teamplaysagainstteam(F, B), teamalsoknownas(G, F), teamplaysagainstteam(B, G) )
# %   | | then if ( teamalsoknownas(F, G), teamalsoknownas(F, H), teamalsoknownas(G, H) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(F, I) )
# %   | | | | then return 0.3954623679353301;  // std dev = 7,069, 201,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=108 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, J), teamplaysinleague(J, K), teamalsoknownas(J, L) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.818355, 'AUC ROC': 0.814579, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.866545}
#
#
# Total learning time: 1.644 seconds
# Total inference time: 0.975 seconds
# AUC ROC: 0.814579
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then return 0.0724346493852272;  // std dev = 0,410, 294,000 (wgt'ed) examples reached here.  /* #neg=231 #pos=63 */
# %   | else if ( teamplaysagainstteam(D, B), teamalsoknownas(E, D), teamplaysagainstteam(B, E) )
# %   | | then if ( teamalsoknownas(D, E), teamalsoknownas(D, F), teamalsoknownas(E, F) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(D, G) )
# %   | | | | then if ( athleteledsportsteam(H, B), athleteplayssport(A, I), athleteplayssport(H, I) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else if ( teamplaysinleague(B, J), teamplaysagainstteam(B, K), teamalsoknownas(L, K) )
# %   | | | | | then return 0.5115785379875952;  // std dev = 7,920, 277,000 (wgt'ed) examples reached here.  /* #neg=96 #pos=181 */
# %   | | | | | else return 0.0486251255757027;  // std dev = 1,799, 21,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=4 */
# %   | | else if ( teamalsoknownas(B, M), teamplaysinleague(M, N), teamalsoknownas(M, P) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.806977, 'AUC ROC': 0.787269, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.869989}
#
#
# Total learning time: 5.817 seconds
# Total inference time: 0.799 seconds
# AUC ROC: 0.787269
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then if ( athleteledsportsteam(D, B), teamplaysinleague(B, E), athleteplaysinleague(A, E) )
# %   | | then return 0.46529179224236833;  // std dev = 3,655, 56,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=34 */
# %   | | else return -0.020002325404689335;  // std dev = 5,046, 238,000 (wgt'ed) examples reached here.  /* #neg=209 #pos=29 */
# %   | else if ( teamplaysagainstteam(F, B), teamalsoknownas(G, F), teamplaysagainstteam(B, G) )
# %   | | then if ( teamalsoknownas(F, G), teamalsoknownas(F, H), teamalsoknownas(G, H) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(F, I) )
# %   | | | | then if ( athleteledsportsteam(J, B), athleteplayssport(A, K), athleteplayssport(J, K) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else return 0.18863934021678283;  // std dev = 10,187, 469,000 (wgt'ed) examples reached here.  /* #neg=314 #pos=155 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.818327, 'AUC ROC': 0.814422, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.863505}
#
#
# Total learning time: 1.862 seconds
# Total inference time: 0.893 seconds
# AUC ROC: 0.814422
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.816729
# ******************************************
#
# ******************************************
# Total revision time: 66.75
# Best validation AUC ROC: 0.816729
# WILL-Produced Tree:
# % FOR athleteplaysforteam(A, B):
# %   if ( athleteledsportsteam(A, B) )
# %   then return 0.8581489350995097;  // std dev = 9,83e-07, 157,000 (wgt'ed) examples reached here.  /* #pos=157 */
# %   else if ( athleteledsportsteam(A, C) )
# %   | then if ( athleteledsportsteam(D, B), teamplaysinleague(B, E), athleteplaysinleague(A, E) )
# %   | | then return 0.46529179224236833;  // std dev = 0,488, 56,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=34 */
# %   | | else return -0.020002325404689335;  // std dev = 0,327, 238,000 (wgt'ed) examples reached here.  /* #neg=209 #pos=29 */
# %   | else if ( teamplaysagainstteam(F, B), teamalsoknownas(G, F), teamplaysagainstteam(B, G) )
# %   | | then if ( teamalsoknownas(F, G), teamalsoknownas(F, H), teamalsoknownas(G, H) )
# %   | | | then return 0.5511721909134626;  // std dev = 6,763, 215,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=149 */
# %   | | | else if ( teamalsoknownas(F, I) )
# %   | | | | then if ( athleteledsportsteam(J, B), athleteplayssport(A, K), athleteplayssport(J, K) )
# %   | | | | | then return 0.7331489350995126;  // std dev = 2,646, 64,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=56 */
# %   | | | | | else return 0.23771097889513312;  // std dev = 5,680, 137,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=52 */
# %   | | | | else return 0.4789543042270253;  // std dev = 8,376, 298,000 (wgt'ed) examples reached here.  /* #neg=113 #pos=185 */
# %   | | else if ( teamalsoknownas(B, L), teamplaysinleague(L, M), teamalsoknownas(L, N) )
# %   | | | then return 0.03358753159074043;  // std dev = 2,872, 57,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=10 */
# %   | | | else return 0.21009068267232403;  // std dev = 9,694, 412,000 (wgt'ed) examples reached here.  /* #neg=267 #pos=145 */
#
#
# Results:
# {'Recall': 0.0, 'AUC PR': 0.798903, 'AUC ROC': 0.781813, 'Precision': [nan, 0.5], 'F1': nan, 'CLL': -0.873404}
#
#
# Total inference time: 1.095 seconds
# AUC ROC: 0.781813
#
#
# Tree:

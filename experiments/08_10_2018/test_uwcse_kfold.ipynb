# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold

# %% [markdown]
# ## Parameters

# %%
target = 'advisedby'
#test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.8
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %% [markdown]
# Sameproject, sameperson and samecourse predicates are not being used.

# %%
[facts, pos, neg] = get_uwcse_dataset(target, acceptedPredicates=[
'professor',
'student',
'advisedby',
'tempadvisedby',
'ta',
'hasposition',
'publication',
'inphase',
'courselevel',
'yearsinprogram',
'projectmember',
])

# %% [markdown]
# ## Background  configuration

# %%
bk = ['professor(+person).',
'student(+person).',
'advisedby(+person,+person).',
'advisedby(+person,-person).',
'advisedby(-person,+person).',
'tempadvisedby(+person,+person).',
'tempadvisedby(+person,-person).',
'tempadvisedby(-person,+person).',
'ta(+course,+person,+quarter).',
'ta(-course,+person,+quarter).',
'ta(+course,-person,+quarter).',
'ta(+course,+person,-quarter).',
'ta(-course,+person,-quarter).',
'ta(+course,-person,-quarter).',
'hasposition(+person,+faculty).',
'hasposition(+person,-faculty).',
'hasposition(-person,+faculty).',
'publication(+title,+person).',
'publication(+title,-person).',
'publication(-title,+person).',
'inphase(+person,+prequals).',
'inphase(+person,-prequals).',
'inphase(-person,+prequals).',
'courselevel(+course,+level).',
'courselevel(+course,-level).',
'courselevel(-course,+level).',
'yearsinprogram(+person,+year).',
'yearsinprogram(-person,+year).',
'yearsinprogram(+person,-year).',
'projectmember(+project,+person).',
'projectmember(+project,-person).',
'projectmember(-project,+person).']
#'sameproject(project, project).',
#'samecourse(course, course).',
#'sameperson(person, person).',]

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

neg = neg[:len(pos)] # balanced

import numpy as np
pos = np.array(pos)
neg = np.array(neg)
small_dataset_aucroc = []
complete_dataset_aucroc = []
revision_dataset_aucroc = []
small_learning_time = []
small_inference_time = []
complete_learning_time = []
complete_inference_time = []
revision_learning_time = []
revision_inference_time = []

# separate train and test
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(pos):
    train_pos, test_pos = pos[train_index], pos[test_index]
    train_neg, test_neg = neg[train_index], neg[test_index]

    # learn from scratch in a small dataset
    s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
    s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

    # shuffle all train examples
    random.shuffle(train_pos)
    random.shuffle(train_neg)

    # train set used in revision and validation set
    r_train_pos = train_pos[int(validation_size*len(train_pos)):]
    r_train_neg = train_neg[int(validation_size*len(train_neg)):]
    validation_pos = train_pos[:int(validation_size*len(train_pos))]
    validation_neg = train_neg[:int(validation_size*len(train_neg))]

    print('Total examples')
    print('Positive examples: %s' % len(pos))
    print('Negative examples: %s' % len(neg))
    print('\n')
    print('Train and test sets from total')
    print('Train Positive examples: %s' % len(train_pos))
    print('Train Negative examples: %s' % len(train_neg))
    print('Test Positive examples: %s' % len(test_pos))
    print('Test Negative examples: %s' % len(test_neg))
    print('\n')
    print('Small dataset')
    print('Train Positive examples: %s' % len(s_train_pos))
    print('Train Negative examples: %s' % len(s_train_neg))
    print('\n')
    print('Revision theory train dataset and validation')
    print('Train Positive examples: %s' % len(r_train_pos))
    print('Train Negative examples: %s' % len(r_train_neg))
    print('Validation Positive examples: %s' % len(validation_pos))
    print('Validation Negative examples: %s' % len(validation_neg))
    
    # learning from small dataset
    [model, learning_time, inference_time, t_results, small_structured] = learn_test_model(background, boostsrl, target, s_train_pos, s_train_neg, facts, test_pos, test_neg, trees=10)
    small_dataset_aucroc.append(t_results['AUC ROC'])
    small_learning_time.append(learning_time)
    small_inference_time.append(inference_time)
    
    # learning from complete dataset
    [model, learning_time, inference_time, t_results, structured] = learn_test_model(background, boostsrl, target, train_pos, train_neg, facts, test_pos, test_neg, trees=10)
    complete_dataset_aucroc.append(t_results['AUC ROC'])
    complete_learning_time.append(learning_time)
    complete_inference_time.append(inference_time)
    
    # theory revision
    [model, total_revision_time, inference_time, t_results, structured] = theory_revision(background, boostsrl, target, r_train_pos, r_train_neg, facts, validation_pos, validation_neg, test_pos, test_neg, revision_threshold, small_structured, max_revision_iterations=10)
    revision_dataset_aucroc.append(t_results['AUC ROC'])
    revision_learning_time.append(total_revision_time)
    revision_inference_time.append(inference_time)
# Out:
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 101
# Train Negative examples: 101
# Test Positive examples: 12
# Test Negative examples: 12
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 81
# Train Negative examples: 81
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, B), publication(F, A), tempadvisedby(G, B) )
# %   | | then if ( publication(E, A) )
# %   | | | then return 4.27215511084593;  // std dev = 0,269, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | | else return 1.3246924694611444;  // std dev = 4,448, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   | | else return 3.885309388258713;  // std dev = 0,247, 110,000 (wgt'ed) examples reached here.  /* #pos=110 */
# %   | else if ( publication(H, B), publication(H, A) )
# %   | | then return 3.7358272315665535;  // std dev = 0,099, 60,000 (wgt'ed) examples reached here.  /* #pos=60 */
# %   | | else if ( projectmember(I, B) )
# %   | | | then return 4.266469987375092;  // std dev = 0,116, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | | else if ( publication(J, B) )
# %   | | | | then if ( publication(K, A), publication(J, L), publication(K, L) )
# %   | | | | | then return -1.825195235353266;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | | | else return 2.6367887126654472;  // std dev = 42,772, 90,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=60 */
# %   | | | | else return -2.5578399959059346;  // std dev = 0,373, 20,000 (wgt'ed) examples reached here.  /* #neg=20 */
# %   else return -0.9437262371086383;  // std dev = 0,000, 230,000 (wgt'ed) examples reached here.  /* #neg=230 */
#
#
# Results:
# {'Precision': [1.0, 0.5], 'Recall': 0.916667, 'AUC PR': 0.957428, 'F1': 0.956522, 'AUC ROC': 0.916667, 'CLL': -0.269877}
#
#
# Total learning time: 10.14 seconds
# Total inference time: 0.653 seconds
# AUC ROC: 0.916667
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then return 3.801324262939899;  // std dev = 0,331, 330,000 (wgt'ed) examples reached here.  /* #pos=330 */
# %   | else if ( publication(D, A), publication(D, E), professor(E) )
# %   | | then if ( ta(F, A, G), hasposition(B, H), hasposition(E, H) )
# %   | | | then if ( publication(I, B) )
# %   | | | | then return 4.517002120462061;  // std dev = 0,211, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | | else if ( projectmember(J, B) )
# %   | | | | | then return 4.128325214309526;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | | else return 1.8764607094058416;  // std dev = 21,998, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   | | | else if ( publication(K, B), publication(K, E) )
# %   | | | | then return -2.133329198910675;  // std dev = 1,138, 40,000 (wgt'ed) examples reached here.  /* #neg=40 */
# %   | | | | else if ( tempadvisedby(L, B), inphase(L, M), inphase(A, M) )
# %   | | | | | then return -2.870842822140916;  // std dev = 1,69e-07, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | | | else return 2.782537992937712;  // std dev = 40,065, 90,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=60 */
# %   | | else return 3.1938306361785322;  // std dev = 3,163, 670,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=580 */
# %   else return -0.9437262371086447;  // std dev = 0,000, 830,000 (wgt'ed) examples reached here.  /* #neg=830 */
#
#
# Results:
# {'Precision': [1.0, 0.5], 'Recall': 1.0, 'AUC PR': 1.0, 'F1': 1.0, 'AUC ROC': 1.0, 'CLL': -0.11037}
#
#
# Total learning time: 12.98 seconds
# Total inference time: 0.398 seconds
# AUC ROC: 1.0
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, B), publication(F, A), tempadvisedby(G, B) )
# %   | | then if ( publication(E, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | else return 0.7427643197148969;  // std dev = 1,629, 26,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=23 */
# %   | else if ( publication(H, B), publication(H, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 18,000 (wgt'ed) examples reached here.  /* #pos=18 */
# %   | | else if ( projectmember(I, B) )
# %   | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else if ( publication(J, B) )
# %   | | | | then if ( publication(K, A), publication(J, L), publication(K, L) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | | | | else return 0.7043027812533584;  // std dev = 1,840, 26,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=22 */
# %   | | | | else return 0.5724346493852266;  // std dev = 1,195, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   else return -0.14185106490048768;  // std dev = 5,96e-08, 69,000 (wgt'ed) examples reached here.  /* #neg=69 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.94143, 'F1': nan, 'AUC ROC': 0.95375, 'CLL': -0.751217}
#
#
# Total learning time: 0.596 seconds
# Total inference time: 0.512 seconds
# AUC ROC: 0.95375
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 1
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, B), publication(F, A), tempadvisedby(G, B) )
# %   | | then if ( publication(E, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | else return 0.7427643197148969;  // std dev = 1,629, 26,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=23 */
# %   | else if ( publication(H, B), publication(H, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 18,000 (wgt'ed) examples reached here.  /* #pos=18 */
# %   | | else if ( projectmember(I, B) )
# %   | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else if ( publication(J, B) )
# %   | | | | then if ( publication(K, A), publication(J, L), publication(K, L) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | | | | else return 0.7043027812533584;  // std dev = 1,840, 26,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=22 */
# %   | | | | else return 0.5724346493852266;  // std dev = 0,452, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   else return -0.14185106490048768;  // std dev = 5,96e-08, 69,000 (wgt'ed) examples reached here.  /* #neg=69 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.94143, 'F1': nan, 'AUC ROC': 0.95375, 'CLL': -0.751217}
#
#
# Total learning time: 0.798 seconds
# Total inference time: 0.556 seconds
# AUC ROC: 0.95375
# Best Tree AUC ROC so far: 0.95375
# ******************************************
#
# ******************************************
# Total revision time: 2.462
# Best validation AUC ROC: 0.95375
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, B), publication(F, A), tempadvisedby(G, B) )
# %   | | then if ( publication(E, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | else return 0.7427643197148969;  // std dev = 1,629, 26,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=23 */
# %   | else if ( publication(H, B), publication(H, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 18,000 (wgt'ed) examples reached here.  /* #pos=18 */
# %   | | else if ( projectmember(I, B) )
# %   | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else if ( publication(J, B) )
# %   | | | | then if ( publication(K, A), publication(J, L), publication(K, L) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | | | | else return 0.7043027812533584;  // std dev = 1,840, 26,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=22 */
# %   | | | | else return 0.5724346493852266;  // std dev = 1,195, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   else return -0.14185106490048768;  // std dev = 5,96e-08, 69,000 (wgt'ed) examples reached here.  /* #neg=69 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 1.0, 'F1': nan, 'AUC ROC': 1.0, 'CLL': -0.725513}
#
#
# Total inference time: 0.523 seconds
# AUC ROC: 1.0
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 101
# Train Negative examples: 101
# Test Positive examples: 12
# Test Negative examples: 12
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 81
# Train Negative examples: 81
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, A) )
# %   | | then return 3.795081645944857;  // std dev = 0,010, 70,000 (wgt'ed) examples reached here.  /* #pos=70 */
# %   | | else return 3.9547802507564356;  // std dev = 0,158, 60,000 (wgt'ed) examples reached here.  /* #pos=60 */
# %   | else if ( publication(F, A) )
# %   | | then return 3.7929510237193766;  // std dev = 0,014, 110,000 (wgt'ed) examples reached here.  /* #pos=110 */
# %   | | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | | then if ( tempadvisedby(H, B) )
# %   | | | | then return 4.275992448681359;  // std dev = 1,69e-07, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | else return -4.342463657264739;  // std dev = 1,69e-07, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | else if ( tempadvisedby(I, B) )
# %   | | | | then return 3.7243403200167067;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | | else if ( publication(J, B) )
# %   | | | | | then return 4.873753728935598;  // std dev = 3,37e-07, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | | else return 4.4299079798194425;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   else return -0.9437262371086406;  // std dev = 0,000, 290,000 (wgt'ed) examples reached here.  /* #neg=290 */
#
#
# Results:
# {'Precision': [0.769231, 0.5], 'Recall': 0.833333, 'AUC PR': 0.812522, 'F1': 0.8, 'AUC ROC': 0.763889, 'CLL': -0.84636}
#
#
# Total learning time: 7.45 seconds
# Total inference time: 0.534 seconds
# AUC ROC: 0.763889
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then return 3.887317683712511;  // std dev = 0,506, 340,000 (wgt'ed) examples reached here.  /* #pos=340 */
# %   | else if ( publication(D, A), tempadvisedby(E, B) )
# %   | | then if ( ta(F, E, G), ta(H, A, G) )
# %   | | | then return -5.447785219915178;  // std dev = 3,37e-07, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | else if ( ta(I, A, J) )
# %   | | | | then return 4.179036878109087;  // std dev = 0,408, 50,000 (wgt'ed) examples reached here.  /* #pos=50 */
# %   | | | | else if ( projectmember(K, B), publication(D, L), tempadvisedby(L, M) )
# %   | | | | | then return 5.608382383065533;  // std dev = 4,77e-07, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | | | else return -0.97437198632443;  // std dev = 19,370, 40,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=10 */
# %   | | else if ( hasposition(B, N), hasposition(P, N), tempadvisedby(Q, P) )
# %   | | | then return 3.3496775459450365;  // std dev = 2,793, 580,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=510 */
# %   | | | else if ( publication(R, B), publication(R, S), tempadvisedby(T, S) )
# %   | | | | then return 0.5401702532525892;  // std dev = 4,179, 50,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=30 */
# %   | | | | else return 3.507686931761529;  // std dev = 3,794, 60,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=50 */
# %   else return -0.9437262371086448;  // std dev = 0,000, 870,000 (wgt'ed) examples reached here.  /* #neg=870 */
#
#
# Results:
# {'Precision': [0.857143, 0.5], 'Recall': 1.0, 'AUC PR': 0.870622, 'F1': 0.923077, 'AUC ROC': 0.923611, 'CLL': -0.275445}
#
#
# Total learning time: 14.367 seconds
# Total inference time: 0.554 seconds
# AUC ROC: 0.923611
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else return 0.8126943896449667;  // std dev = 0,977, 22,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=21 */
# %   | else if ( publication(F, A) )
# %   | | then return 0.6857351419960634;  // std dev = 2,034, 29,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=24 */
# %   | | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | | then if ( tempadvisedby(H, B) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | | | else if ( tempadvisedby(I, B) )
# %   | | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( publication(J, B) )
# %   | | | | | then return 0.8581489350995122;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #pos=1 */
# %   | | | | | else return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 67,000 (wgt'ed) examples reached here.  /* #neg=67 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 1.0, 'F1': nan, 'AUC ROC': 1.0, 'CLL': -0.774495}
#
#
# Total learning time: 0.762 seconds
# Total inference time: 0.515 seconds
# AUC ROC: 1.0
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 2
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else return 0.8126943896449667;  // std dev = 0,977, 22,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=21 */
# %   | else if ( publication(F, A) )
# %   | | then return 0.6857351419960634;  // std dev = 2,034, 29,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=24 */
# %   | | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | | then if ( tempadvisedby(H, B) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | | | else if ( tempadvisedby(I, B) )
# %   | | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( publication(J, B) )
# %   | | | | | then return 0.8581489350995122;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #pos=1 */
# %   | | | | | else return 0.3581489350995122;  // std dev = 0,500, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 67,000 (wgt'ed) examples reached here.  /* #neg=67 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 1.0, 'F1': nan, 'AUC ROC': 1.0, 'CLL': -0.774495}
#
#
# Total learning time: 0.745 seconds
# Total inference time: 0.402 seconds
# AUC ROC: 1.0
# Refining candidate 2 of 2
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else return 0.8126943896449667;  // std dev = 0,977, 22,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=21 */
# %   | else if ( publication(F, A) )
# %   | | then return 0.6857351419960634;  // std dev = 2,034, 29,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=24 */
# %   | | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | | then if ( tempadvisedby(H, B) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | | | else if ( tempadvisedby(I, B) )
# %   | | | | then return 0.3581489350995122;  // std dev = 0,500, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( publication(J, B) )
# %   | | | | | then return 0.8581489350995122;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #pos=1 */
# %   | | | | | else return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 67,000 (wgt'ed) examples reached here.  /* #neg=67 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 1.0, 'F1': nan, 'AUC ROC': 1.0, 'CLL': -0.774495}
#
#
# Total learning time: 0.776 seconds
# Total inference time: 0.415 seconds
# AUC ROC: 1.0
# Best Tree AUC ROC so far: 1.0
# ******************************************
#
# ******************************************
# Total revision time: 3.615
# Best validation AUC ROC: 1.0
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else return 0.8126943896449667;  // std dev = 0,977, 22,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=21 */
# %   | else if ( publication(F, A) )
# %   | | then return 0.6857351419960634;  // std dev = 2,034, 29,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=24 */
# %   | | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | | then if ( tempadvisedby(H, B) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | | | else if ( tempadvisedby(I, B) )
# %   | | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( publication(J, B) )
# %   | | | | | then return 0.8581489350995122;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #pos=1 */
# %   | | | | | else return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 67,000 (wgt'ed) examples reached here.  /* #neg=67 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.857626, 'F1': nan, 'AUC ROC': 0.875, 'CLL': -0.77492}
#
#
# Total inference time: 0.496 seconds
# AUC ROC: 0.875
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 101
# Train Negative examples: 101
# Test Positive examples: 12
# Test Negative examples: 12
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 81
# Train Negative examples: 81
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 3.9249246613581037;  // std dev = 0,556, 110,000 (wgt'ed) examples reached here.  /* #pos=110 */
# %   | | else if ( publication(C, A) )
# %   | | | then return 3.7995564593597555;  // std dev = 0,057, 70,000 (wgt'ed) examples reached here.  /* #pos=70 */
# %   | | | else return 2.5448241646247234;  // std dev = 3,541, 80,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=60 */
# %   | else if ( tempadvisedby(G, B), inphase(G, H), inphase(A, H) )
# %   | | then return -2.4612953822698387;  // std dev = 1,69e-07, 20,000 (wgt'ed) examples reached here.  /* #neg=20 */
# %   | | else if ( publication(I, A), publication(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then return -3.7088958030647254;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | | else return 4.19463051637739;  // std dev = 1,69e-07, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else if ( projectmember(M, B) )
# %   | | | | then return 2.313295364513185;  // std dev = 4,775, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   | | | | else return 5.084700680873382;  // std dev = 0,601, 40,000 (wgt'ed) examples reached here.  /* #pos=40 */
# %   else return -0.9437262371086396;  // std dev = 0,000, 240,000 (wgt'ed) examples reached here.  /* #neg=240 */
#
#
# Results:
# {'Precision': [1.0, 0.5], 'Recall': 0.916667, 'AUC PR': 0.958333, 'F1': 0.956522, 'AUC ROC': 0.920139, 'CLL': -0.276826}
#
#
# Total learning time: 17.595 seconds
# Total inference time: 0.517 seconds
# AUC ROC: 0.920139
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then return 3.8684824680992747;  // std dev = 8,74e-06, 380,000 (wgt'ed) examples reached here.  /* #pos=380 */
# %   | else if ( ta(D, A, E), ta(D, F, G), tempadvisedby(F, H) )
# %   | | then return 4.066138606861647;  // std dev = 0,091, 120,000 (wgt'ed) examples reached here.  /* #pos=120 */
# %   | | else if ( publication(I, A), publication(I, J), professor(J) )
# %   | | | then if ( ta(K, A, L), hasposition(B, M), hasposition(J, M) )
# %   | | | | then return 3.326727681547474;  // std dev = 3,291, 50,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=40 */
# %   | | | | else if ( publication(N, B), publication(N, J) )
# %   | | | | | then return -1.9512989884023397;  // std dev = 3,082, 40,000 (wgt'ed) examples reached here.  /* #neg=40 */
# %   | | | | | else return 1.8802653519976347;  // std dev = 36,058, 90,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=50 */
# %   | | | else if ( publication(P, B), publication(P, Q), student(Q) )
# %   | | | | then if ( ta(R, Q, S), publication(P, T), tempadvisedby(T, U) )
# %   | | | | | then return 4.521210024711839;  // std dev = 3,566, 80,000 (wgt'ed) examples reached here.  /* #pos=80 */
# %   | | | | | else return 2.2188141571385107;  // std dev = 62,344, 260,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=200 */
# %   | | | | else return 3.4726223691633775;  // std dev = 3,024, 160,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=140 */
# %   else return -0.9437262371086447;  // std dev = 0,000, 840,000 (wgt'ed) examples reached here.  /* #neg=840 */
#
#
# Results:
# {'Precision': [0.923077, 0.5], 'Recall': 1.0, 'AUC PR': 0.969039, 'F1': 0.96, 'AUC ROC': 0.972222, 'CLL': -0.220466}
#
#
# Total learning time: 18.274 seconds
# Total inference time: 0.534 seconds
# AUC ROC: 0.972222
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | | else if ( publication(C, A) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | else return 0.524815601766179;  // std dev = 2,309, 24,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=16 */
# %   | else if ( tempadvisedby(G, B), inphase(G, H), inphase(A, H) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( publication(I, A), publication(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | else if ( projectmember(M, B) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 65,000 (wgt'ed) examples reached here.  /* #neg=65 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.974679, 'F1': nan, 'AUC ROC': 0.95, 'CLL': -0.761947}
#
#
# Total learning time: 0.72 seconds
# Total inference time: 0.574 seconds
# AUC ROC: 0.95
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 4
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | | else if ( publication(C, A) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | else return 0.524815601766179;  // std dev = 2,309, 24,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=16 */
# %   | else if ( tempadvisedby(G, B), inphase(G, H), inphase(A, H) )
# %   | | then return 0.5248156017661788;  // std dev = 0,471, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( publication(I, A), publication(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | else if ( projectmember(M, B) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 65,000 (wgt'ed) examples reached here.  /* #neg=65 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.974679, 'F1': nan, 'AUC ROC': 0.95, 'CLL': -0.761947}
#
#
# Total learning time: 0.825 seconds
# Total inference time: 0.426 seconds
# AUC ROC: 0.95
# Refining candidate 2 of 4
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | | else if ( publication(C, A) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | else return 0.524815601766179;  // std dev = 0,471, 24,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=16 */
# %   | else if ( tempadvisedby(G, B), inphase(G, H), inphase(A, H) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( publication(I, A), publication(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | else if ( projectmember(M, B) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 65,000 (wgt'ed) examples reached here.  /* #neg=65 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.974679, 'F1': nan, 'AUC ROC': 0.95, 'CLL': -0.761947}
#
#
# Total learning time: 0.593 seconds
# Total inference time: 0.547 seconds
# AUC ROC: 0.95
# Refining candidate 3 of 4
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | | else if ( publication(C, A) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | else return 0.524815601766179;  // std dev = 2,309, 24,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=16 */
# %   | else if ( tempadvisedby(G, B), inphase(G, H), inphase(A, H) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( publication(I, A), publication(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,471, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | else if ( projectmember(M, B) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 65,000 (wgt'ed) examples reached here.  /* #neg=65 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.974679, 'F1': nan, 'AUC ROC': 0.95, 'CLL': -0.761947}
#
#
# Total learning time: 1.041 seconds
# Total inference time: 0.528 seconds
# AUC ROC: 0.95
# Refining candidate 4 of 4
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | | else if ( publication(C, A) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | else return 0.524815601766179;  // std dev = 2,309, 24,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=16 */
# %   | else if ( tempadvisedby(G, B), inphase(G, H), inphase(A, H) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( publication(I, A), publication(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | else if ( projectmember(M, B) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,433, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 65,000 (wgt'ed) examples reached here.  /* #neg=65 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.974679, 'F1': nan, 'AUC ROC': 0.95, 'CLL': -0.761947}
#
#
# Total learning time: 0.891 seconds
# Total inference time: 0.568 seconds
# AUC ROC: 0.95
# Best Tree AUC ROC so far: 0.95
# ******************************************
#
# ******************************************
# Total revision time: 6.712999999999999
# Best validation AUC ROC: 0.95
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | | else if ( publication(C, A) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | else return 0.524815601766179;  // std dev = 2,309, 24,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=16 */
# %   | else if ( tempadvisedby(G, B), inphase(G, H), inphase(A, H) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( publication(I, A), publication(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | else if ( projectmember(M, B) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 65,000 (wgt'ed) examples reached here.  /* #neg=65 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.996795, 'F1': nan, 'AUC ROC': 0.996528, 'CLL': -0.758859}
#
#
# Total inference time: 0.512 seconds
# AUC ROC: 0.996528
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 102
# Train Negative examples: 102
# Test Positive examples: 11
# Test Negative examples: 11
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 82
# Train Negative examples: 82
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then return 3.7923578397416704;  // std dev = 0,698, 270,000 (wgt'ed) examples reached here.  /* #pos=270 */
# %   | else if ( tempadvisedby(D, B), inphase(D, E), inphase(A, E) )
# %   | | then if ( projectmember(F, B) )
# %   | | | then return 5.654674468704307;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else return -3.271491982925434;  // std dev = 5,84e-07, 20,000 (wgt'ed) examples reached here.  /* #neg=20 */
# %   | | else if ( tempadvisedby(G, B) )
# %   | | | then return 5.325871670406769;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else return 6.24867643681339;  // std dev = 2,38e-07, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   else return -0.9437262371086402;  // std dev = 0,000, 280,000 (wgt'ed) examples reached here.  /* #neg=280 */
#
#
# Results:
# {'Precision': [0.785714, 0.5], 'Recall': 1.0, 'AUC PR': 0.862982, 'F1': 0.88, 'AUC ROC': 0.88843, 'CLL': -0.365569}
#
#
# Total learning time: 6.189 seconds
# Total inference time: 0.482 seconds
# AUC ROC: 0.88843
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then return 3.8035948594930318;  // std dev = 0,108, 370,000 (wgt'ed) examples reached here.  /* #pos=370 */
# %   | else if ( publication(D, A), publication(D, E), professor(E) )
# %   | | then if ( tempadvisedby(F, B), publication(G, B) )
# %   | | | then return -2.180486430176764;  // std dev = 0,084, 20,000 (wgt'ed) examples reached here.  /* #neg=20 */
# %   | | | else if ( publication(H, B), publication(H, I), ta(J, I, K) )
# %   | | | | then return 5.013633833962942;  // std dev = 0,748, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | | | else if ( projectmember(L, B), publication(D, M), tempadvisedby(M, E) )
# %   | | | | | then return 4.356002976291758;  // std dev = 0,018, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | | | | else return -0.4404287166187555;  // std dev = 37,247, 70,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=20 */
# %   | | else if ( ta(N, A, P) )
# %   | | | then return 3.7609247438291624;  // std dev = 1,737, 300,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=290 */
# %   | | | else if ( publication(Q, A) )
# %   | | | | then return 4.855660752581982;  // std dev = 0,154, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | | | else return 2.721418851118849;  // std dev = 3,714, 320,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=250 */
# %   else return -0.9437262371086448;  // std dev = 0,000, 870,000 (wgt'ed) examples reached here.  /* #neg=870 */
#
#
# Results:
# {'Precision': [0.818182, 0.5], 'Recall': 0.818182, 'AUC PR': 0.766532, 'F1': 0.818182, 'AUC ROC': 0.805785, 'CLL': -0.635356}
#
#
# Total learning time: 12.397 seconds
# Total inference time: 0.502 seconds
# AUC ROC: 0.805785
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then return 0.7470378239884018;  // std dev = 2,828, 81,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=72 */
# %   | else if ( tempadvisedby(D, B), inphase(D, E), inphase(A, E) )
# %   | | then if ( projectmember(F, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #pos=1 */
# %   | | | else return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | else if ( tempadvisedby(G, B) )
# %   | | | then return 0.6081489350995123;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 1.0, 'F1': nan, 'AUC ROC': 1.0, 'CLL': -0.743737}
#
#
# Total learning time: 0.583 seconds
# Total inference time: 0.491 seconds
# AUC ROC: 1.0
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 1
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then return 0.7470378239884018;  // std dev = 2,828, 81,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=72 */
# %   | else if ( tempadvisedby(D, B), inphase(D, E), inphase(A, E) )
# %   | | then if ( projectmember(F, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #pos=1 */
# %   | | | else return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | else return 0.6081489350995123;  // std dev = 1,500, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 1.0, 'F1': nan, 'AUC ROC': 1.0, 'CLL': -0.743737}
#
#
# Total learning time: 0.489 seconds
# Total inference time: 0.385 seconds
# AUC ROC: 1.0
# Best Tree AUC ROC so far: 1.0
# ******************************************
#
# ******************************************
# Total revision time: 1.948
# Best validation AUC ROC: 1.0
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then return 0.7470378239884018;  // std dev = 2,828, 81,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=72 */
# %   | else if ( tempadvisedby(D, B), inphase(D, E), inphase(A, E) )
# %   | | then if ( projectmember(F, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #pos=1 */
# %   | | | else return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | else if ( tempadvisedby(G, B) )
# %   | | | then return 0.6081489350995123;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.821172, 'F1': nan, 'AUC ROC': 0.863636, 'CLL': -0.766754}
#
#
# Total inference time: 0.41 seconds
# AUC ROC: 0.863636
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 102
# Train Negative examples: 102
# Test Positive examples: 11
# Test Negative examples: 11
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 82
# Train Negative examples: 82
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 3.8063293320811447;  // std dev = 0,091, 160,000 (wgt'ed) examples reached here.  /* #pos=160 */
# %   | else if ( publication(E, A), publication(E, F), professor(F) )
# %   | | then if ( publication(E, B) )
# %   | | | then return 3.8791934759614155;  // std dev = 0,025, 50,000 (wgt'ed) examples reached here.  /* #pos=50 */
# %   | | | else if ( tempadvisedby(G, B) )
# %   | | | | then if ( ta(H, G, I) )
# %   | | | | | then return -2.518483777487107;  // std dev = 1,46e-07, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | | | else return -2.8195718699188035;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | | else if ( publication(J, B), publication(J, F) )
# %   | | | | | then return -2.518483777487107;  // std dev = 1,46e-07, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | | | else return 5.898882534340205;  // std dev = 4,083, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( publication(K, A) )
# %   | | | then return 5.453772173572112;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else return 3.7974515009886787;  // std dev = 0,147, 60,000 (wgt'ed) examples reached here.  /* #pos=60 */
# %   else return -0.9437262371086399;  // std dev = 0,000, 270,000 (wgt'ed) examples reached here.  /* #neg=270 */
#
#
# Results:
# {'Precision': [0.846154, 0.5], 'Recall': 1.0, 'AUC PR': 0.713124, 'F1': 0.916667, 'AUC ROC': 0.847107, 'CLL': -0.372494}
#
#
# Total learning time: 11.281 seconds
# Total inference time: 0.507 seconds
# AUC ROC: 0.847107
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then return 3.7999915594241616;  // std dev = 9,20e-06, 400,000 (wgt'ed) examples reached here.  /* #pos=400 */
# %   | else if ( ta(D, A, E) )
# %   | | then if ( publication(F, A), tempadvisedby(G, B) )
# %   | | | then return 2.4369642319524836;  // std dev = 3,836, 70,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=50 */
# %   | | | else return 3.7346482361499818;  // std dev = 1,782, 280,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=270 */
# %   | | else if ( projectmember(H, B), tempadvisedby(I, B), ta(J, I, K) )
# %   | | | then return 4.053475945630799;  // std dev = 0,199, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | | else if ( tempadvisedby(L, B), inphase(L, M), inphase(A, M) )
# %   | | | | then if ( publication(N, B) )
# %   | | | | | then return 4.896273782728545;  // std dev = 2,92e-07, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | | else return -1.0999359509527644;  // std dev = 20,320, 40,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=10 */
# %   | | | | else if ( publication(P, B), publication(Q, A), tempadvisedby(R, B) )
# %   | | | | | then return 0.6250116579040659;  // std dev = 21,820, 40,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=10 */
# %   | | | | | else return 2.8128760418103065;  // std dev = 70,116, 310,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=240 */
# %   else return -0.9437262371086448;  // std dev = 0,000, 860,000 (wgt'ed) examples reached here.  /* #neg=860 */
#
#
# Results:
# {'Precision': [0.846154, 0.5], 'Recall': 1.0, 'AUC PR': 0.896635, 'F1': 0.916667, 'AUC ROC': 0.921488, 'CLL': -0.282428}
#
#
# Total learning time: 12.236 seconds
# Total inference time: 0.533 seconds
# AUC ROC: 0.921488
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7748156017661781;  // std dev = 1,658, 36,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=33 */
# %   | else if ( publication(E, A), publication(E, F), professor(F) )
# %   | | then if ( publication(E, B) )
# %   | | | then return 0.858148935099512;  // std dev = 1,33e-07, 25,000 (wgt'ed) examples reached here.  /* #pos=25 */
# %   | | | else if ( tempadvisedby(G, B) )
# %   | | | | then if ( ta(H, G, I) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( publication(J, B), publication(J, F) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 1,000 (wgt'ed) examples reached here.  /* #neg=1 */
# %   | | | | | else return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | else if ( publication(K, A) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.5664822684328457;  // std dev = 2,227, 24,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=17 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 1.0, 'F1': nan, 'AUC ROC': 1.0, 'CLL': -0.74997}
#
#
# Total learning time: 0.672 seconds
# Total inference time: 0.512 seconds
# AUC ROC: 1.0
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 2
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# ...
# %   | | else return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | else if ( publication(G, A), publication(G, H), hasposition(H, I) )
# %   | | then if ( publication(G, B) )
# %   | | | then return 0.8581489350995115;  // std dev = 2,38e-07, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   | | | else if ( publication(J, B), tempadvisedby(K, B) )
# %   | | | | then if ( publication(J, H) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | | | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | else return 0.3581489350995122;  // std dev = 1,414, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | else return 0.698148935099512;  // std dev = 2,592, 50,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=42 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 67,000 (wgt'ed) examples reached here.  /* #neg=67 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.969667, 'F1': nan, 'AUC ROC': 0.945, 'CLL': -0.79585}
#
#
# Total learning time: 0.653 seconds
# Total inference time: 0.539 seconds
# AUC ROC: 0.945
# Best Tree AUC ROC so far: 0.945
# ******************************************
#
# ******************************************
# Total revision time: 3.523
# Best validation AUC ROC: 0.945
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( projectmember(C, B), publication(D, A) )
# %   | then if ( ta(E, A, F) )
# %   | | then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | else return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | else if ( publication(G, A), publication(G, H), hasposition(H, I) )
# %   | | then if ( publication(G, B) )
# %   | | | then return 0.8581489350995115;  // std dev = 2,38e-07, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   | | | else if ( publication(J, B), tempadvisedby(K, B) )
# %   | | | | then if ( publication(J, H) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #neg=2 */
# %   | | | | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | else if ( publication(L, B) )
# %   | | | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.698148935099512;  // std dev = 2,592, 50,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=42 */
# %   else return -0.14185106490048768;  // std dev = 5,77e-08, 67,000 (wgt'ed) examples reached here.  /* #neg=67 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.954237, 'F1': nan, 'AUC ROC': 0.96281, 'CLL': -0.771068}
#
#
# Total inference time: 0.487 seconds
# AUC ROC: 0.96281
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 102
# Train Negative examples: 102
# Test Positive examples: 11
# Test Negative examples: 11
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 82
# Train Negative examples: 82
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), ta(E, D, F) )
# %   | then return 3.808839444609416;  // std dev = 0,076, 200,000 (wgt'ed) examples reached here.  /* #pos=200 */
# %   | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | then return 0.721581289686213;  // std dev = 3,357, 40,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=20 */
# %   | | else if ( publication(I, A), tempadvisedby(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then if ( ta(M, J, N) )
# %   | | | | | then return -2.703509486044386;  // std dev = 1,69e-07, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | | | else return 4.738103875831079;  // std dev = 4,726, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | | else return -3.4243658983935683;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | | | else if ( tempadvisedby(P, B) )
# %   | | | | then return 5.910962149879481;  // std dev = 0,337, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | | else if ( publication(Q, B) )
# %   | | | | | then return 5.248863792668964;  // std dev = 6,927, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | | | | else return 0.7100992316729908;  // std dev = 22,361, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   else return -0.9437262371086393;  // std dev = 0,000, 250,000 (wgt'ed) examples reached here.  /* #neg=250 */
#
#
# Results:
# {'Precision': [0.875, 0.5], 'Recall': 0.636364, 'AUC PR': 0.78986, 'F1': 0.736842, 'AUC ROC': 0.913223, 'CLL': -0.502313}
#
#
# Total learning time: 7.224 seconds
# Total inference time: 0.496 seconds
# AUC ROC: 0.913223
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D), ta(C, E, F), tempadvisedby(E, G) )
# %   | then return 3.902308420458637;  // std dev = 1,17e-06, 190,000 (wgt'ed) examples reached here.  /* #pos=190 */
# %   | else if ( publication(H, B), publication(H, A) )
# %   | | then return 3.8297172108980932;  // std dev = 0,068, 320,000 (wgt'ed) examples reached here.  /* #pos=320 */
# %   | | else if ( publication(I, A), tempadvisedby(J, B) )
# %   | | | then if ( ta(K, J, L), publication(M, B) )
# %   | | | | then return -1.698478411772844;  // std dev = 0,961, 30,000 (wgt'ed) examples reached here.  /* #neg=30 */
# %   | | | | else if ( ta(N, A, P) )
# %   | | | | | then return 3.2878526359602427;  // std dev = 23,836, 50,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=40 */
# %   | | | | | else return 0.7738443868500969;  // std dev = 23,656, 50,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=20 */
# %   | | | else if ( tempadvisedby(Q, B), publication(R, B) )
# %   | | | | then return 3.3677258559130867;  // std dev = 2,922, 200,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=180 */
# %   | | | | else if ( hasposition(B, S), hasposition(T, S), tempadvisedby(U, T) )
# %   | | | | | then return 3.2100075195566706;  // std dev = 59,443, 280,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=230 */
# %   | | | | | else return 0.7385039047995151;  // std dev = 41,870, 70,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=40 */
# %   else return -0.9437262371086447;  // std dev = 0,000, 850,000 (wgt'ed) examples reached here.  /* #neg=850 */
#
#
# Results:
# {'Precision': [0.9, 0.5], 'Recall': 0.818182, 'AUC PR': 0.983402, 'F1': 0.857143, 'AUC ROC': 0.983471, 'CLL': -0.284446}
#
#
# Total learning time: 12.206 seconds
# Total inference time: 0.491 seconds
# AUC ROC: 0.983471
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), ta(E, D, F) )
# %   | then return 0.7470378239884012;  // std dev = 2,309, 54,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=48 */
# %   | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | then return 0.6842358916212513;  // std dev = 1,818, 23,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=19 */
# %   | | else if ( publication(I, A), tempadvisedby(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then if ( ta(M, J, N) )
# %   | | | | | then return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( tempadvisedby(P, B) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else if ( publication(Q, B) )
# %   | | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 66,000 (wgt'ed) examples reached here.  /* #neg=66 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.994994, 'F1': nan, 'AUC ROC': 0.995, 'CLL': -0.784338}
#
#
# Total learning time: 0.701 seconds
# Total inference time: 0.509 seconds
# AUC ROC: 0.995
# Refining iteration 1
# ******************************************
# Refining candidate 1 of 3
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), ta(E, D, F) )
# %   | then return 0.7470378239884012;  // std dev = 2,309, 54,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=48 */
# %   | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | then return 0.6842358916212513;  // std dev = 1,818, 23,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=19 */
# %   | | else if ( publication(I, A), tempadvisedby(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then if ( ta(M, J, N) )
# %   | | | | | then return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | else return 0.3581489350995122;  // std dev = 0,500, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( tempadvisedby(P, B) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else if ( publication(Q, B) )
# %   | | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 66,000 (wgt'ed) examples reached here.  /* #neg=66 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.994994, 'F1': nan, 'AUC ROC': 0.995, 'CLL': -0.784338}
#
#
# Total learning time: 0.859 seconds
# Total inference time: 0.514 seconds
# AUC ROC: 0.995
# Refining candidate 2 of 3
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), ta(E, D, F) )
# %   | then return 0.7470378239884012;  // std dev = 2,309, 54,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=48 */
# %   | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | then return 0.6842358916212513;  // std dev = 1,818, 23,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=19 */
# %   | | else if ( publication(I, A), tempadvisedby(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then if ( ta(M, J, N) )
# %   | | | | | then return 0.3581489350995122;  // std dev = 0,500, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( tempadvisedby(P, B) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else if ( publication(Q, B) )
# %   | | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 66,000 (wgt'ed) examples reached here.  /* #neg=66 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.994994, 'F1': nan, 'AUC ROC': 0.995, 'CLL': -0.784338}
#
#
# Total learning time: 0.766 seconds
# Total inference time: 0.427 seconds
# AUC ROC: 0.995
# Refining candidate 3 of 3
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), ta(E, D, F) )
# %   | then return 0.7470378239884012;  // std dev = 2,309, 54,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=48 */
# %   | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | then return 0.6842358916212513;  // std dev = 1,818, 23,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=19 */
# %   | | else if ( publication(I, A), tempadvisedby(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then if ( ta(M, J, N) )
# %   | | | | | then return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( tempadvisedby(P, B) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else if ( publication(Q, B) )
# %   | | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | else return 0.6081489350995122;  // std dev = 0,433, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 66,000 (wgt'ed) examples reached here.  /* #neg=66 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.994994, 'F1': nan, 'AUC ROC': 0.995, 'CLL': -0.784338}
#
#
# Total learning time: 0.554 seconds
# Total inference time: 0.481 seconds
# AUC ROC: 0.995
# Best Tree AUC ROC so far: 0.995
# ******************************************
#
# ******************************************
# Total revision time: 4.811
# Best validation AUC ROC: 0.995
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), ta(E, D, F) )
# %   | then return 0.7470378239884012;  // std dev = 2,309, 54,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=48 */
# %   | else if ( publication(G, B), publication(G, H), student(H) )
# %   | | then return 0.6842358916212513;  // std dev = 1,818, 23,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=19 */
# %   | | else if ( publication(I, A), tempadvisedby(J, B) )
# %   | | | then if ( ta(K, A, L) )
# %   | | | | then if ( ta(M, J, N) )
# %   | | | | | then return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( tempadvisedby(P, B) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else if ( publication(Q, B) )
# %   | | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.1418510649004877;  // std dev = 5,16e-08, 66,000 (wgt'ed) examples reached here.  /* #neg=66 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'Recall': 0.0, 'AUC PR': 0.950899, 'F1': nan, 'AUC ROC': 0.958678, 'CLL': -0.788486}
#
#
# Total inference time: 0.524 seconds
# AUC ROC: 0.958678

# %%
small_dataset_aucroc
# Out:
# [0.916667,
#  0.763889,
#  0.920139,
#  0.88843,
#  0.847107,
#  0.661157,
#  0.884298,
#  0.834711,
#  0.764463,
#  0.913223]

# %%
complete_dataset_aucroc
# Out:
# [1.0,
#  0.923611,
#  0.972222,
#  0.805785,
#  0.921488,
#  0.979339,
#  0.863636,
#  0.96281,
#  1.0,
#  0.983471]

# %%
revision_dataset_aucroc
# Out:
# [1.0,
#  0.875,
#  0.996528,
#  0.863636,
#  0.847107,
#  0.983471,
#  0.900826,
#  0.921488,
#  0.96281,
#  0.958678]

# %%
print('Small dataset AUC ROC: %s +/- %s' % ((np.array(small_dataset_aucroc)).mean(), (np.array(small_dataset_aucroc)).std()))
print('Complete dataset AUC ROC: %s +/- %s' % ((np.array(complete_dataset_aucroc)).mean(), (np.array(complete_dataset_aucroc)).std()))
print('Theory revision dataset AUC ROC: %s +/- %s' % ((np.array(revision_dataset_aucroc)).mean(), (np.array(revision_dataset_aucroc)).std()))

print('Small dataset learning time: %s +/- %s' % ((np.array(small_learning_time)).mean(), (np.array(small_learning_time)).std()))
print('Small dataset inference time: %s +/- %s' % ((np.array(small_inference_time)).mean(), (np.array(small_inference_time)).std()))
print('Complete dataset learning time: %s +/- %s' % ((np.array(complete_learning_time)).mean(), (np.array(complete_learning_time)).std()))
print('Complete dataset inference time: %s +/- %s' % ((np.array(complete_inference_time)).mean(), (np.array(complete_inference_time)).std()))
print('Revision time: %s +/- %s' % ((np.array(revision_learning_time)).mean(), (np.array(revision_learning_time)).std()))
print('Revision model inference time: %s +/- %s' % ((np.array(revision_inference_time)).mean(), (np.array(revision_inference_time)).std()))
# Out:
# Small dataset AUC ROC: 0.8394084000000002 +/- 0.08094936568398792
# Complete dataset AUC ROC: 0.9412362 +/- 0.06052848620905698
# Theory revision dataset AUC ROC: 0.9309544000000001 +/- 0.05412849894501047
# Small dataset learning time: 9.930499999999999 +/- 3.448080255736516
# Small dataset inference time: 0.5179 +/- 0.047632866804340056
# Complete dataset learning time: 15.666300000000001 +/- 6.107232794809774
# Complete dataset inference time: 0.48810000000000003 +/- 0.05266963071828016
# Revision time: 4.848800000000001 +/- 2.4179522658646513
# Revision model inference time: 0.48410000000000003 +/- 0.0461810567224268

# %%
'''sem boosting

Small dataset AUC ROC: 0.9278783 +/- 0.03755699045197845
Complete dataset AUC ROC: 0.9256486 +/- 0.0576748788211991
Theory revision dataset AUC ROC: 0.9243744000000002 +/- 0.042361955547873385
Small dataset learning time: 2.9913999999999996 +/- 1.7272083950699173
Small dataset inference time: 0.5094000000000001 +/- 0.027868261517360583
Complete dataset learning time: 4.038400000000001 +/- 0.3932762896488931
Complete dataset inference time: 0.5464999999999999 +/- 0.06962650357442918
Revision time: 2.3796 +/- 1.6737868562036204
Revision model inference time: 0.5252000000000001 +/- 0.03326499661806686
'''
# Out:
# 'sem boosting\n\nSmall dataset AUC ROC: 0.9278783 +/- 0.03755699045197845\nComplete dataset AUC ROC: 0.9256486 +/- 0.0576748788211991\nTheory revision dataset AUC ROC: 0.9243744000000002 +/- 0.042361955547873385\nSmall dataset learning time: 2.9913999999999996 +/- 1.7272083950699173\nSmall dataset inference time: 0.5094000000000001 +/- 0.027868261517360583\nComplete dataset learning time: 4.038400000000001 +/- 0.3932762896488931\nComplete dataset inference time: 0.5464999999999999 +/- 0.06962650357442918\nRevision time: 2.3796 +/- 1.6737868562036204\nRevision model inference time: 0.5252000000000001 +/- 0.03326499661806686\n'

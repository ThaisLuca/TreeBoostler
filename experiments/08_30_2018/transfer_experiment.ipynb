# %%
from datasets.get_datasets import *
from boostedrevision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold
import numpy as np

# %% [markdown]
# ## Transfer Learning IMDB -> UW-CSE

# %%
source_target = 'workedunder'
validation_size = 0.1
test_size= 0.1
target_size = 1.0
max_revision_iterations = 10
revision_threshold = 0.8

# %%
[source_facts, source_pos, source_neg] = get_imdb_dataset(source_target)

source_bk = ['workedunder(+person,+person).',
      'workedunder(+person,-person).',
      'workedunder(-person,+person).',
      'female(+person).',
      'actor(+person).',
      'director(+person).',
      'movie(+movie,+person).',
      'movie(+movie,-person).',
      'movie(-movie,+person).',
      'genre(+person,+genre).']

# %%
target_target = 'advisedby'

[target_facts, target_pos, target_neg] = get_uwcse_dataset(target_target, acceptedPredicates=[
'professor',
'student',
'advisedby',
'tempadvisedby',
'ta',
'hasposition',
'publication',
'inphase',
'courselevel',
'yearsinprogram',
'projectmember',
])

target_bk = ['professor(+person).',
'student(+person).',
'advisedby(+person,+person).',
'advisedby(+person,-person).',
'advisedby(-person,+person).',
'tempadvisedby(+person,+person).',
'tempadvisedby(+person,-person).',
'tempadvisedby(-person,+person).',
'ta(+course,+person,+quarter).',
'ta(-course,+person,+quarter).',
'ta(+course,-person,+quarter).',
'ta(+course,+person,-quarter).',
'ta(-course,+person,-quarter).',
'ta(+course,-person,-quarter).',
'hasposition(+person,+faculty).',
'hasposition(+person,-faculty).',
'hasposition(-person,+faculty).',
'publication(+title,+person).',
'publication(+title,-person).',
'publication(-title,+person).',
'inphase(+person,+prequals).',
'inphase(+person,-prequals).',
'inphase(-person,+prequals).',
'courselevel(+course,+level).',
'courselevel(+course,-level).',
'courselevel(-course,+level).',
'yearsinprogram(+person,+year).',
'yearsinprogram(-person,+year).',
'yearsinprogram(+person,-year).',
'projectmember(+project,+person).',
'projectmember(+project,-person).',
'projectmember(-project,+person).']
#'sameproject(project, project).',
#'samecourse(course, course).',
#'sameperson(person, person).',]

# %%
background = boostsrl.modes(source_bk, [source_target], useStdLogicVariables=False, maxTreeDepth=12, nodeSize=3, numOfClauses=12)

# shuffle all examples
random.shuffle(source_pos)
random.shuffle(source_neg)
source_neg = source_neg[:len(source_pos)]

# separate train and test
test_pos = source_pos[:int(test_size*len(source_pos))]
test_neg = source_neg[:int(test_size*len(source_neg))]
train_pos = source_pos[int(test_size*len(source_pos)):]
train_neg = source_neg[int(test_size*len(source_neg)):]

train_pos = train_pos[int(validation_size*len(train_pos)):]
train_neg = train_neg[int(validation_size*len(train_neg)):]
validation_pos = train_pos[:int(validation_size*len(train_pos))]
validation_neg = train_neg[:int(validation_size*len(train_neg))]

print('Train pos size: %s' % len(train_pos))
print('Train neg size: %s' % len(train_neg))
print('Validation pos size: %s' % len(validation_pos))
print('Validation neg size: %s' % len(validation_neg))
print('Test pos size: %s' % len(test_pos))
print('Test neg size: %s' % len(test_neg))
# Out:
# Train pos size: 310
# Train neg size: 310
# Validation pos size: 31
# Validation neg size: 31
# Test pos size: 38
# Test neg size: 38

# %% [markdown]
# ## Learning from source domain

# %%
[model, total_revision_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, source_target, train_pos, train_neg, source_facts, test_pos, test_neg, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.8581489350995101;  // std dev = 8,68e-07, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.8463146155728823;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.14185106490048793;  // std dev = 0,000, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #2
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then return 0.714353580259372;  // std dev = 0,080, 312,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=310 */
# %   else return -0.12544463852839194;  // std dev = 0,000, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #3
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.5566303391493649;  // std dev = 4,69e-07, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.5477146568172927;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.1123163781936069;  // std dev = 0,000, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #4
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.4184516279605201;  // std dev = 0,000, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.41167519566405547;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.10159632948783658;  // std dev = 0,000, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #5
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.3213478576446628;  // std dev = 2,70e-07, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.3155458808992812;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.09269127618926046;  // std dev = 1,41e-07, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #6
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.2556061765783794;  // std dev = 1,12e-07, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.25016478941768183;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.08518475138839678;  // std dev = 1,01e-07, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #7
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.21006419358853987;  // std dev = 7,30e-08, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.20473554061008895;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.07877675473109144;  // std dev = 5,16e-08, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #8
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.17732125214750766;  // std dev = 1,91e-07, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.1720117334043823;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.07324622576333693;  // std dev = 1,03e-07, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #9
# % FOR workedunder(A, B):
# %   if ( director(B), movie(C, A), movie(C, B) )
# %   then if ( female(A) )
# %   | then return 0.15291433549185393;  // std dev = 8,43e-08, 143,000 (wgt'ed) examples reached here.  /* #pos=143 */
# %   | else return 0.14759022439160366;  // std dev = 0,108, 169,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=167 */
# %   else return -0.0684269778442029;  // std dev = 0,000, 308,000 (wgt'ed) examples reached here.  /* #neg=308 */
# WILL Produced-Tree #10
# % FOR workedunder(A, B):
# %   if ( director(B), actor(A) )
# %   then if ( movie(C, A), movie(C, B) )
# %   | then return 0.13763373634836226;  // std dev = 0,057, 310,000 (wgt'ed) examples reached here.  /* #pos=310 */
# %   | else return -0.06419184008202614;  // std dev = 0,000, 18,000 (wgt'ed) examples reached here.  /* #neg=18 */
# %   else if ( actor(A) )
# %   | then return -0.06419184008202623;  // std dev = 3,33e-08, 251,000 (wgt'ed) examples reached here.  /* #neg=251 */
# %   | else if ( actor(B) )
# %   | | then return -0.06419184008202612;  // std dev = 1,05e-08, 34,000 (wgt'ed) examples reached here.  /* #neg=34 */
# %   | | else return -0.2913869460772477;  // std dev = 0,359, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.118026
#    Precision = 0.974359 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.987013
#
#
# Total learning time: 7.182 seconds
# Total inference time: 0.743 seconds
# AUC ROC: 1.0

# %%
from boostedtransfer import *

transferred_structured = transfer(structured, ['workedunder(A, B) -> advisedby(A, B)',
            'director(A) -> professor(A)',
            'actor(A) -> student(A)',
            'movie(A, B) -> publication(A, B)',
            'female(A) -> student(A)'
            ])

# %%
transferred_structured
# Out:
# [['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [0.0, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [8.68e-07, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)'},
#   {'false': [0.0, 308, 0], 'true': [0.08, 2, 310]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [0.0, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [4.69e-07, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [0.0, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [0.0, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [1.41e-07, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [2.7e-07, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [1.01e-07, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [1.12e-07, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [5.16e-08, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [7.3e-08, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [1.03e-07, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [1.91e-07, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), publication(C, A), publication(C, B)',
#    'true': 'student(A)'},
#   {'false': [0.0, 308, 0],
#    'true,false': [0.108, 2, 167],
#    'true,true': [8.43e-08, 0, 143]}],
#  ['advisedby(A, B)',
#   {'': 'professor(B), student(A)',
#    'false': 'student(A)',
#    'false,false': 'student(B)',
#    'true': 'publication(C, A), publication(C, B)'},
#   {'false,false,false': [0.359, 7, 0],
#    'false,false,true': [1.05e-08, 34, 0],
#    'false,true': [3.33e-08, 251, 0],
#    'true,false': [0.0, 18, 0],
#    'true,true': [0.057, 0, 310]}]]

# %% [markdown]
# ## Transfer Learning

# %%
background = boostsrl.modes(target_bk, [target_target], useStdLogicVariables=False, maxTreeDepth=12, nodeSize=3, numOfClauses=12)

# shuffle all examples
random.shuffle(target_pos)
random.shuffle(target_neg)
target_pos = target_pos[:int(target_size*len(target_pos))]
target_neg = target_neg[:len(target_pos)]

# separate train and test
test_pos = target_pos[:int(test_size*len(target_pos))]
test_neg = target_neg[:int(test_size*len(target_neg))]
train_pos = target_pos[int(test_size*len(target_pos)):]
train_neg = target_neg[int(test_size*len(target_neg)):]

train_pos = train_pos[int(validation_size*len(train_pos)):]
train_neg = train_neg[int(validation_size*len(train_neg)):]
validation_pos = train_pos[:int(validation_size*len(train_pos))]
validation_neg = train_neg[:int(validation_size*len(train_neg))]

print('Train pos size: %s' % len(train_pos))
print('Train neg size: %s' % len(train_neg))
print('Validation pos size: %s' % len(validation_pos))
print('Validation neg size: %s' % len(validation_neg))
print('Test pos size: %s' % len(test_pos))
print('Test neg size: %s' % len(test_neg))
# Out:
# Train pos size: 92
# Train neg size: 92
# Validation pos size: 9
# Validation neg size: 9
# Test pos size: 11
# Test neg size: 11

# %%
[model, total_revision_time, inference_time, t_results, structured] = theory_revision(background, boostsrl, target_target, train_pos, train_neg, target_facts, validation_pos, validation_neg, test_pos, test_neg, revision_threshold, transferred_structured.copy(), trees=10, max_revision_iterations=10, verbose=True)
# Out:
# ******************************************
# Performing Parameter Learning
# ******************************************
# Refine
# ['0;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '0;true;student(A).;false;false', '1;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;false;false', '2;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '2;true;student(A).;false;false', '3;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '3;true;student(A).;false;false', '4;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '4;true;student(A).;false;false', '5;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '5;true;student(A).;false;false', '6;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '6;true;student(A).;false;false', '7;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '7;true;student(A).;false;false', '8;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;false', '8;true;student(A).;false;false', '9;;advisedby(A, B) :- professor(B), student(A).;true;true', '9;true;publication(C, A), publication(C, B).;false;false', '9;false;student(A).;false;true', '9;false,false;student(B).;false;false']
# WILL Produced-Tree #1
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.8295775065280829;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.25814893509951226;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #2
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then return 0.6123166924373469;  // std dev = 1,843, 39,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=34 */
# %   else return 0.22373365448410562;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #3
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.5600103961199596;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.20923639589758175;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.18886832215749763;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #4
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.4211232001504397;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.1767140399419271;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.15570029437174346;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #5
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.3205217116904127;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.15245366347652786;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.12582628229372078;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #6
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.2516124880669642;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.13378043877970416;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.10008916917880593;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #7
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.20376555999215895;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.11902256553740069;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.07866279780602634;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #8
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.16941491885021864;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.10709714443575152;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.061272608607422445;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #9
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.1438813850180482;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.09727827784782463;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else return 0.047415491488114477;  // std dev = 5,899, 145,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=58 */
# WILL Produced-Tree #10
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.12430406491745218;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return 0.4650893185443074;  // std dev = 3,153, 70,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=58 */
# %   else if ( student(A) )
# %   | then return -0.36348211002712116;  // std dev = 6,66e-08, 54,000 (wgt'ed) examples reached here.  /* #neg=54 */
# %   | else if ( student(B) )
# %   | | then return -0.36348211002712133;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   | | else return -0.24151852473629404;  // std dev = 0,409, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.340109
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 0.666667
#    F1        = 0.8
#
#
# Total learning time: 5.493 seconds
# Total inference time: 0.487 seconds
# AUC ROC: 1.0
#
#
# Structure after Parameter Learning
# [['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)'}, {'true': [1.843, 5, 34], 'false': [5.899, 87, 58]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), publication(C, A), publication(C, B)', 'true': 'student(A)'}, {'true,true': [0.986, 1, 34], 'false': [5.899, 87, 58], 'true,false': [0.0, 4, 0]}], ['advisedby(A, B)', {'': 'professor(B), student(A)', 'true': 'publication(C, A), publication(C, B)', 'false': 'student(A)', 'false,false': 'student(B)'}, {'true,true': [0.986, 1, 34], 'false,false,true': [0.0, 16, 0], 'false,false,false': [0.409, 9, 0], 'true,false': [3.153, 12, 58], 'false,true': [6.66e-08, 54, 0]}]]
# ******************************************
# Performing Theory Revision
# ******************************************
# Refining iteration 1
# ********************************
# Candidate for revision
# ['0;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '0;true;student(A).;false;false', '1;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;false;true', '2;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '2;true;student(A).;false;false', '3;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '3;true;student(A).;false;false', '4;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '4;true;student(A).;false;false', '5;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '5;true;student(A).;false;false', '6;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '6;true;student(A).;false;false', '7;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '7;true;student(A).;false;false', '8;;advisedby(A, B) :- professor(B), publication(C, A), publication(C, B).;true;true', '8;true;student(A).;false;false', '9;;advisedby(A, B) :- professor(B), student(A).;true;true', '9;true;publication(C, A), publication(C, B).;false;false', '9;false;student(A).;false;true', '9;false,false;student(B).;false;false']
# Refining candidate
# ***************************
# Revision points found
# Tree #1: [('false', 0.6)]
# Tree #2: [('false', 0.6)]
# Tree #3: [('false', 0.6)]
# Tree #4: [('false', 0.6)]
# Tree #5: [('false', 0.6)]
# Tree #6: [('false', 0.6)]
# Tree #7: [('false', 0.6)]
# Tree #8: [('false', 0.6)]
# Tree #9: [('false', 0.6)]
# Tree #10: []
#
#
# WILL Produced-Tree #1
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.8295775065280829;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( professor(B), student(A) )
# %   | then if ( ta(D, A, E), publication(F, B) )
# %   | | then if ( tempadvisedby(G, B), ta(D, H, E), publication(I, H) )
# %   | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.8581489350995123;  // std dev = 0,000, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | else if ( publication(J, B), publication(K, A) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( tempadvisedby(M, B), publication(N, M) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( tempadvisedby(P, B) )
# %   | | | | | then if ( publication(Q, B), ta(R, P, S) )
# %   | | | | | | then if ( ta(R, T, U), publication(W, T) )
# %   | | | | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | | | else return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | | else return 0.8581489350995122;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | | | else if ( publication(X, B) )
# %   | | | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else return -0.14185106490048768;  // std dev = 6,83e-08, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #2
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then return 0.6123166924373469;  // std dev = 1,843, 39,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=34 */
# %   else if ( professor(B), student(A) )
# %   | then if ( publication(D, A), tempadvisedby(E, B), publication(F, B) )
# %   | | then if ( ta(G, A, H) )
# %   | | | then return 0.47540780245230163;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.050922032513554226;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( publication(I, A) )
# %   | | | then if ( tempadvisedby(J, B) )
# %   | | | | then return 0.7194734122109545;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else if ( ta(K, A, L), publication(M, B) )
# %   | | | | | then return 0.7194734122109544;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | else return 0.2948514112693306;  // std dev = 1,226, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else if ( publication(N, B), publication(N, P), inphase(P, Q) )
# %   | | | | then if ( tempadvisedby(P, R) )
# %   | | | | | then return 0.7527435884825767;  // std dev = 0,063, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | | | else if ( ta(S, A, T) )
# %   | | | | | | then if ( ta(U, P, T) )
# %   | | | | | | | then return 0.5373269569258905;  // std dev = 0,815, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | | | else return 0.7194734122109543;  // std dev = 4,21e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | | | else if ( ta(W, P, X), tempadvisedby(Y, B) )
# %   | | | | | | | then return 0.5760146409086447;  // std dev = 0,871, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | | | | else return 0.3401342988176338;  // std dev = 1,069, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.7301371195892231;  // std dev = 0,070, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | else return -0.12544463852839152;  // std dev = 0,000, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #3
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.5600103961199596;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.20923639589758175;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( professor(B), student(A) )
# %   | then if ( publication(D, A), publication(E, B), tempadvisedby(F, B) )
# %   | | then if ( ta(G, A, H) )
# %   | | | then return 0.3910766638751551;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.04434629760466851;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( publication(I, A), publication(I, J), ta(K, J, L) )
# %   | | | then if ( tempadvisedby(M, B) )
# %   | | | | then return 0.5553664367462845;  // std dev = 1,05e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else return 0.2817934587148423;  // std dev = 0,948, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else if ( publication(N, B), publication(N, P), inphase(P, Q) )
# %   | | | | then if ( tempadvisedby(P, R) )
# %   | | | | | then return 0.5897349313060506;  // std dev = 0,081, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | | | else if ( ta(S, A, T) )
# %   | | | | | | then return 0.5109759495054884;  // std dev = 0,214, 15,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=14 */
# %   | | | | | | else if ( tempadvisedby(U, B), ta(W, P, X) )
# %   | | | | | | | then return 0.4524941760131338;  // std dev = 0,861, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | | | | else if ( ta(Y, P, Z) )
# %   | | | | | | | | then return 0.22106677944112763;  // std dev = 1,003, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | | | | | else return 0.4353505032376327;  // std dev = 0,865, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.5752617006669153;  // std dev = 0,166, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else return -0.11231637819360626;  // std dev = 5,48e-08, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #4
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.4211232001504397;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.1767140399419271;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( professor(B), student(A) )
# %   | then if ( publication(D, A) )
# %   | | then if ( ta(E, A, F), publication(G, B) )
# %   | | | then if ( tempadvisedby(H, B) )
# %   | | | | then return 0.3066672319919183;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.48515041678358073;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else if ( publication(I, B), publication(D, J), publication(I, J) )
# %   | | | | then return -0.20229774989228888;  // std dev = 0,100, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else if ( ta(K, A, L) )
# %   | | | | | then return 0.16138488572128554;  // std dev = 0,627, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else if ( tempadvisedby(M, B), publication(N, B) )
# %   | | | | | | then return 0.17176199557023794;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | | else return 0.41760468884085056;  // std dev = 0,830, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else if ( tempadvisedby(P, B), inphase(P, Q), inphase(A, Q) )
# %   | | | then if ( publication(R, P) )
# %   | | | | then return 0.14856749723002172;  // std dev = 0,722, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.29009853701153904;  // std dev = 0,781, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else if ( ta(S, A, T), publication(U, B) )
# %   | | | | then return 0.42826988103715796;  // std dev = 0,094, 19,000 (wgt'ed) examples reached here.  /* #pos=19 */
# %   | | | | else return 0.3928673596356454;  // std dev = 0,252, 22,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=20 */
# %   | else return -0.10159632948783617;  // std dev = 5,16e-08, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #5
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then return 0.27201141680149565;  // std dev = 0,213, 39,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=34 */
# %   else if ( professor(B), student(A) )
# %   | then if ( publication(D, A), publication(E, B), tempadvisedby(F, B) )
# %   | | then if ( ta(G, A, H) )
# %   | | | then return 0.23344024020308365;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.03387164764073609;  // std dev = 0,873, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( publication(I, A), publication(I, J), ta(K, J, L) )
# %   | | | then if ( tempadvisedby(M, B) )
# %   | | | | then return 0.3594731902141815;  // std dev = 0,047, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else return 0.11502003863880594;  // std dev = 0,873, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else if ( publication(N, B), publication(N, P), inphase(P, Q) )
# %   | | | | then if ( tempadvisedby(P, B) )
# %   | | | | | then return 0.3997472984506086;  // std dev = 0,059, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | else if ( ta(R, A, S), inphase(A, Q) )
# %   | | | | | | then return 0.3240488821644391;  // std dev = 0,022, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | | | | else if ( tempadvisedby(T, B) )
# %   | | | | | | | then if ( inphase(A, Q) )
# %   | | | | | | | | then return 0.38441165340714195;  // std dev = 0,072, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | | | | else if ( ta(U, A, W), inphase(T, X), inphase(A, X) )
# %   | | | | | | | | | then return 0.09573776755389617;  // std dev = 0,699, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | | | | | else return 0.20971067771245772;  // std dev = 0,353, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   | | | | | | | else return 0.28752511557485133;  // std dev = 0,321, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | | else return 0.33950282326463854;  // std dev = 0,168, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else return -0.09269127618926105;  // std dev = 0,000, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #6
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then if ( student(A) )
# %   | then return 0.2614995780999477;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return -0.19100805018484815;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( professor(B), student(A) )
# %   | then if ( publication(D, A), publication(D, E), tempadvisedby(F, E) )
# %   | | then if ( ta(G, A, H) )
# %   | | | then return 0.21609098025816306;  // std dev = 0,794, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | else return -0.032181797941559454;  // std dev = 0,781, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( tempadvisedby(I, B), inphase(I, J), inphase(A, J) )
# %   | | | then if ( publication(K, I) )
# %   | | | | then return 0.03400222011465507;  // std dev = 0,690, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.1277411691931197;  // std dev = 0,822, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else if ( publication(L, B), publication(L, M), ta(N, M, P) )
# %   | | | | then if ( publication(Q, A), publication(Q, R), ta(S, R, P) )
# %   | | | | | then return 0.49675556575892593;  // std dev = 0,382, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | else if ( ta(T, A, P) )
# %   | | | | | | then return 0.3052869267723528;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | | else if ( tempadvisedby(U, B), ta(N, U, W) )
# %   | | | | | | | then return 0.3261849040921846;  // std dev = 0,109, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | | | else return 0.2345306889312318;  // std dev = 0,240, 16,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=14 */
# %   | | | | else if ( publication(X, A), publication(X, Y), ta(Z, Y, AB) )
# %   | | | | | then return -0.032895080987055424;  // std dev = 0,682, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.2340222057927158;  // std dev = 0,181, 21,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=20 */
# %   | else return -0.0851847513883968;  // std dev = 1,83e-08, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #7
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then return 0.1723722458992993;  // std dev = 0,194, 39,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=34 */
# %   else if ( professor(B), student(A) )
# %   | then if ( publication(D, A), publication(D, E), tempadvisedby(F, E) )
# %   | | then if ( publication(G, B), publication(H, F) )
# %   | | | then return -0.1492134283535368;  // std dev = 0,536, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else if ( ta(I, F, J), tempadvisedby(K, B) )
# %   | | | | then return 0.055081520018371855;  // std dev = 0,748, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.3282674599287182;  // std dev = 0,212, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( ta(L, A, M), publication(N, B) )
# %   | | | then return 0.21353074191985102;  // std dev = 0,162, 26,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=25 */
# %   | | | else if ( publication(P, A), publication(P, Q), ta(R, Q, S) )
# %   | | | | then return -0.007669940948689641;  // std dev = 0,862, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else if ( publication(T, B), tempadvisedby(U, B), ta(W, U, X) )
# %   | | | | | then if ( ta(W, Y, Z), publication(AB, Y) )
# %   | | | | | | then if ( publication(AB, B) )
# %   | | | | | | | then return 0.31885011282943126;  // std dev = 0,030, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | | | else return -0.1727927444143556;  // std dev = 0,807, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | | | else return 0.2865994557741145;  // std dev = 0,132, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | else if ( tempadvisedby(BB, B), publication(CB, B) )
# %   | | | | | | then return 0.27305512015035377;  // std dev = 0,027, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | | else if ( publication(DB, B), publication(DB, EB), student(EB) )
# %   | | | | | | | then return 0.15923862663495822;  // std dev = 0,867, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | | | else return 0.24390752106313565;  // std dev = 0,113, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | else return -0.07877675473109168;  // std dev = 3,73e-08, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #8
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then return 0.14293088394293463;  // std dev = 0,193, 39,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=34 */
# %   else if ( professor(B), student(A) )
# %   | then if ( publication(D, A), publication(D, E), tempadvisedby(F, E) )
# %   | | then if ( publication(G, B), publication(H, F) )
# %   | | | then return -0.11944769491942989;  // std dev = 0,535, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else if ( ta(I, F, J), publication(K, B) )
# %   | | | | then return 0.03778719308886965;  // std dev = 0,746, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.2670335443264239;  // std dev = 0,190, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( ta(L, A, M), ta(L, N, M), publication(P, N) )
# %   | | | then return 0.014571762935667568;  // std dev = 0,918, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else if ( ta(Q, A, R) )
# %   | | | | then return 0.1940439968088895;  // std dev = 0,156, 22,000 (wgt'ed) examples reached here.  /* #pos=22 */
# %   | | | | else if ( publication(S, B), tempadvisedby(T, B), ta(U, T, W) )
# %   | | | | | then if ( ta(U, X, Y), publication(S, X) )
# %   | | | | | | then return 0.2539783047457965;  // std dev = 0,026, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | | else if ( ta(U, Z, AB), publication(BB, Z) )
# %   | | | | | | | then return -0.138443643851589;  // std dev = 0,797, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | | | | else return 0.15518680028999396;  // std dev = 0,366, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | | else if ( publication(CB, A) )
# %   | | | | | | then return 0.31987051261394156;  // std dev = 0,661, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | | else if ( tempadvisedby(DB, B) )
# %   | | | | | | | then return 0.20231765814862804;  // std dev = 0,060, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | | | | | else return 0.12272802653314879;  // std dev = 0,289, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   | else return -0.07324622576333704;  // std dev = 0,000, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #9
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, A), publication(C, B) )
# %   then return 0.12024046943806563;  // std dev = 0,194, 39,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=34 */
# %   else if ( professor(B), student(A) )
# %   | then if ( ta(D, A, E), publication(F, B) )
# %   | | then if ( tempadvisedby(G, B), publication(F, H), inphase(H, I) )
# %   | | | then if ( ta(J, G, E) )
# %   | | | | then return 0.20261181722993715;  // std dev = 0,084, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else if ( inphase(A, I) )
# %   | | | | | then return 0.04436404801994659;  // std dev = 0,742, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.029650097398775;  // std dev = 0,691, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.19364374028353482;  // std dev = 0,081, 18,000 (wgt'ed) examples reached here.  /* #pos=18 */
# %   | | else if ( publication(K, A), publication(K, L), ta(M, L, N) )
# %   | | | then if ( publication(P, B) )
# %   | | | | then return -0.05156379541210907;  // std dev = 0,802, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else return 0.026585165165179003;  // std dev = 0,505, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else if ( publication(Q, B), publication(Q, R), inphase(R, S) )
# %   | | | | then if ( tempadvisedby(R, T) )
# %   | | | | | then return 0.17603449257447817;  // std dev = 0,133, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | | | | else if ( publication(U, A) )
# %   | | | | | | then return 0.16717463263172672;  // std dev = 0,501, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | | else if ( ta(W, R, X), tempadvisedby(Y, B) )
# %   | | | | | | | then return 0.08551536640796768;  // std dev = 0,596, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | | | | else return -0.0697291291398006;  // std dev = 0,973, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.17160144192517698;  // std dev = 0,081, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else return -0.06842697784420268;  // std dev = 2,89e-08, 75,000 (wgt'ed) examples reached here.  /* #neg=75 */
# WILL Produced-Tree #10
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.14051969243777404;  // std dev = 0,986, 35,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=34 */
# %   | else return 0.09606295088251955;  // std dev = 2,036, 70,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=58 */
# %   else if ( student(A) )
# %   | then return -0.06419184008202625;  // std dev = 0,000, 54,000 (wgt'ed) examples reached here.  /* #neg=54 */
# %   | else if ( student(B) )
# %   | | then return -0.06419184008202619;  // std dev = 7,45e-09, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   | | else return -0.1386240099663457;  // std dev = 0,250, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.113585
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 1.0
#
#
# Total learning time: 17.924 seconds
# Total inference time: 0.608 seconds
# AUC ROC: 1.0
#
#
# Best model AUC ROC so far: 1.0
#
#
# ******************************************
# Best model found
# ******************************************
# Total revision time: 24.512
# Best validation AUC ROC: 1.0
#
#
# Results
#    AUC ROC   = 0.933884
#    AUC PR    = 0.919119
#    CLL	      = -0.461835
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 0.272727
#    F1        = 0.428571
#
#
# Total inference time: 0.618 seconds
# AUC ROC: 0.933884

# %% [markdown]
# ## Results

# %%
source_target = 'workedunder'
validation_size = 0.1
test_size= 0.1
target_size = 0.2
max_revision_iterations = 10
revision_threshold = 0.9

[source_facts, source_pos, source_neg] = get_imdb_dataset(source_target)

source_bk = ['workedunder(+person,+person).',
      'workedunder(+person,-person).',
      'workedunder(-person,+person).',
      'female(+person).',
      'actor(+person).',
      'director(+person).',
      'movie(+movie,+person).',
      'movie(+movie,-person).',
      'movie(-movie,+person).',
      'genre(+person,+genre).']

target_target = 'advisedby'

[target_facts, target_pos, target_neg] = get_uwcse_dataset(target_target, acceptedPredicates=[
'professor',
'student',
'advisedby',
'tempadvisedby',
'ta',
'hasposition',
'publication',
'inphase',
'courselevel',
'yearsinprogram',
'projectmember',
])

target_bk = ['professor(+person).',
'student(+person).',
'advisedby(+person,+person).',
'advisedby(+person,-person).',
'advisedby(-person,+person).',
'tempadvisedby(+person,+person).',
'tempadvisedby(+person,-person).',
'tempadvisedby(-person,+person).',
'ta(+course,+person,+quarter).',
'ta(-course,+person,+quarter).',
'ta(+course,-person,+quarter).',
'ta(+course,+person,-quarter).',
'ta(-course,+person,-quarter).',
'ta(+course,-person,-quarter).',
'hasposition(+person,+faculty).',
'hasposition(+person,-faculty).',
'hasposition(-person,+faculty).',
'publication(+title,+person).',
'publication(+title,-person).',
'publication(-title,+person).',
'inphase(+person,+prequals).',
'inphase(+person,-prequals).',
'inphase(-person,+prequals).',
'courselevel(+course,+level).',
'courselevel(+course,-level).',
'courselevel(-course,+level).',
'yearsinprogram(+person,+year).',
'yearsinprogram(-person,+year).',
'yearsinprogram(+person,-year).',
'projectmember(+project,+person).',
'projectmember(+project,-person).',
'projectmember(-project,+person).']
#'sameproject(project, project).',
#'samecourse(course, course).',
#'sameperson(person, person).',]

# %%
small_target_dataset_aucroc = []
small_target_dataset_aucpr = []
transfer_dataset_aucroc = {}
transfer_dataset_aucpr = {}

revisions = 6
   
transfer_mapping = {'workedunder': 'advisedby',
                   'actor': 'student',
                   'director': 'professor',
                   'movie': 'publication',
                   'genre': 'hasposition',
                   'female': 'student'}

def transfer(s):
    for key, value in transfer_mapping.items():
        s = s.replace(key, value)
    return s

def transfer_struct(structured):
    transfered_structured = structured.copy()
    for item in transfered_structured:
        item[0] = transfer(item[0])
        for key, value in item[1].items():
            item[1][key] = transfer(value)
    return transfered_structured

# %%
import sys
import time

start = time.time()
for revision_threshold in np.linspace(0.5, 1.0, num=revisions):
    transfer_dataset_aucroc[str(revision_threshold)] = []
    transfer_dataset_aucpr[str(revision_threshold)] = []

for fold in range(1, 31):
    # shuffle all examples
    random.shuffle(source_pos)
    random.shuffle(source_neg)
    s_pos = source_pos[:]
    s_neg = source_neg[:len(source_pos)]

    # separate train and test
    s_test_pos = s_pos[:int(test_size*len(s_pos))]
    s_test_neg = s_neg[:int(test_size*len(s_neg))]
    s_train_pos = s_pos[int(test_size*len(s_pos)):]
    s_train_neg = s_neg[int(test_size*len(s_neg)):]

    # shuffle all examples
    random.shuffle(target_pos)
    random.shuffle(target_neg)
    t_pos = target_pos[:int(target_size*len(target_pos))]
    t_neg = target_neg[:len(target_pos)]

    # separate train and test
    t_test_pos = t_pos[:int(test_size*len(t_pos))]
    t_test_neg = t_neg[:int(test_size*len(t_neg))]
    t_train_pos = t_pos[int(test_size*len(t_pos)):]
    t_train_neg = t_neg[int(test_size*len(t_neg)):]

    t_train_pos = t_train_pos[int(validation_size*len(t_train_pos)):]
    t_train_neg = t_train_neg[int(validation_size*len(t_train_neg)):]
    validation_pos = t_train_pos[:int(validation_size*len(t_train_pos))]
    validation_neg = t_train_neg[:int(validation_size*len(t_train_neg))]

    # Learning from source
    background = boostsrl.modes(source_bk, [source_target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)
    [model, total_revision_time, inference_time, t_results, target_structured, will] = learn_test_model(background, boostsrl, source_target, s_train_pos, s_train_neg, source_facts, s_test_pos, s_test_neg, refine=None, trees=10, verbose=False)

    sys.stdout.write('\rFold: %s, %s, time: %s' % (fold, 'learning from source', time.strftime('%H:%M:%S', time.gmtime(time.time()-start))))
    sys.stdout.flush()

    # Learning from scratch
    background = boostsrl.modes(target_bk, [target_target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)
    [model, total_revision_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target_target, t_train_pos, t_train_neg, target_facts, t_test_pos, t_test_neg, refine=None, trees=10, verbose=False)
    small_target_dataset_aucroc.append(t_results['AUC ROC'])
    small_target_dataset_aucpr.append(t_results['AUC PR'])

    sys.stdout.write('\rFold: %s, %s, time: %s' % (fold, 'learning from scratch target', time.strftime('%H:%M:%S', time.gmtime(time.time()-start))))
    sys.stdout.flush()

    for revision_threshold in np.linspace(0.5, 1.0, num=revisions):
        # Transfer
        structured = transfer_struct(target_structured)

        # Transfer Learning and Revision Theory
        try:
            [model, total_revision_time, inference_time, t_results, structured] = theory_revision(background, boostsrl, target_target, t_train_pos, t_train_neg, target_facts, validation_pos, validation_neg, t_test_pos, t_test_neg, revision_threshold, structured.copy(), max_revision_iterations=10, trees=10, verbose=False)
            transfer_dataset_aucroc[str(revision_threshold)].append(t_results['AUC ROC'])
            transfer_dataset_aucpr[str(revision_threshold)].append(t_results['AUC PR'])

            sys.stdout.write('\rFold: %s, revision_threshold: %s, %s, time: %s' % (fold, revision_threshold, 'transfer learning', time.strftime('%H:%M:%S', time.gmtime(time.time()-start))))
            sys.stdout.flush()
        except:
            pass
# Out:
# Fold: 30, revision_threshold: 1.0, transfer learning, time: 00:47:25

# %%
small_target_dataset_aucroc
# Out:
# [0.931818,
#  0.931818,
#  1.0,
#  0.886364,
#  0.954545,
#  0.909091,
#  0.863636,
#  0.931818,
#  0.931818,
#  1.0,
#  0.863636,
#  1.0,
#  1.0,
#  0.909091,
#  0.931818,
#  1.0,
#  1.0,
#  1.0,
#  0.931818,
#  0.954545,
#  0.840909,
#  0.909091,
#  0.863636,
#  0.931818,
#  1.0,
#  0.909091,
#  0.931818,
#  0.909091,
#  1.0,
#  0.954545,
#  0.931818]

# %%
transfer_dataset_aucroc
# Out:
# {'0.5': [0.659091,
#   0.909091,
#   0.5,
#   0.977273,
#   0.5,
#   0.931818,
#   0.75,
#   1.0,
#   0.545455,
#   0.75,
#   0.772727,
#   0.5,
#   0.75,
#   0.977273,
#   0.545455,
#   0.977273,
#   0.5,
#   0.75,
#   0.5,
#   0.5,
#   0.909091,
#   0.954545],
#  '0.6': [0.659091,
#   0.909091,
#   0.5,
#   0.5,
#   0.931818,
#   0.75,
#   1.0,
#   0.545455,
#   0.75,
#   0.772727,
#   0.5,
#   0.75,
#   1.0,
#   0.545455,
#   0.977273,
#   0.5,
#   0.75,
#   0.5,
#   0.5,
#   0.75,
#   0.727273],
#  '0.7': [0.659091,
#   1.0,
#   0.5,
#   0.954545,
#   0.5,
#   0.931818,
#   1.0,
#   1.0,
#   0.954545,
#   0.75,
#   1.0,
#   0.5,
#   0.75,
#   0.954545,
#   0.545455,
#   0.977273,
#   0.5,
#   0.75,
#   0.5,
#   0.931818,
#   0.909091,
#   0.954545],
#  '0.8': [0.659091,
#   0.909091,
#   0.863636,
#   0.931818,
#   1.0,
#   0.931818,
#   0.886364,
#   0.954545,
#   0.931818,
#   1.0,
#   1.0,
#   0.954545,
#   0.75,
#   1.0,
#   1.0,
#   0.977273,
#   0.931818,
#   1.0,
#   0.954545,
#   0.931818,
#   0.909091,
#   0.954545],
#  '0.9': [0.659091,
#   0.909091,
#   0.818182,
#   0.954545,
#   1.0,
#   0.931818,
#   0.954545,
#   0.954545,
#   0.863636,
#   1.0,
#   1.0,
#   0.909091,
#   0.75,
#   1.0,
#   1.0,
#   0.977273,
#   0.863636,
#   0.931818,
#   1.0,
#   0.909091,
#   0.931818,
#   0.909091,
#   0.954545],
#  '1.0': [0.659091,
#   0.909091,
#   0.886364,
#   1.0,
#   1.0,
#   0.863636,
#   0.931818,
#   0.954545,
#   0.931818,
#   1.0,
#   1.0,
#   0.931818,
#   0.75,
#   1.0,
#   1.0,
#   0.977273,
#   0.886364,
#   0.931818,
#   1.0,
#   0.840909,
#   0.931818,
#   0.931818]}

# %%
import matplotlib.pyplot as plt
x = []
y = []
base = np.array(small_target_dataset_aucroc)
base = base.mean()
base = revisions * [base]
for revision_threshold in np.linspace(0.5, 1.0, num=revisions):
    x.append(revision_threshold)
    v = transfer_dataset_aucroc[str(revision_threshold)]
    v = np.array(v)
    y.append(v.mean())
plt.plot(x, y, color='blue')
plt.plot(x, base, linestyle=':', color='blue')
plt.xlim(0.3,1.0)
plt.xlabel('Revision threshold')
plt.ylabel('AUC ROC')
plt.legend(loc='upper left')
plt.show()

x = []
y = []
base = np.array(small_target_dataset_aucpr)
base = base.mean()
base = revisions * [base]
for revision_threshold in np.linspace(0.5, 1.0, num=revisions):
    x.append(revision_threshold)
    v = transfer_dataset_aucpr[str(revision_threshold)]
    v = np.array(v)
    y.append(v.mean())
plt.plot(x, y, color='blue')
plt.plot(x, base, linestyle=':', color='blue')
plt.xlim(0.3,1.0)
plt.xlabel('Revision threshold')
plt.ylabel('AUC PR')
plt.legend(loc='upper left')
plt.show()
# Out:
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## Transfer Learning UW-CSE -> IMDB

# %%
source_target = 'advisedby'
validation_size = 0.1
test_size= 0.1
target_size = 1.0
max_revision_iterations = 10
revision_threshold = 0.8

# %%
source_target = 'advisedby'

[source_facts, source_pos, source_neg] = get_uwcse_dataset(source_target, acceptedPredicates=[
'professor',
'student',
'advisedby',
'tempadvisedby',
'ta',
'hasposition',
'publication',
'inphase',
'courselevel',
'yearsinprogram',
'projectmember',
])

source_bk = ['professor(+person).',
'student(+person).',
'advisedby(+person,+person).',
'advisedby(+person,-person).',
'advisedby(-person,+person).',
'tempadvisedby(+person,+person).',
'tempadvisedby(+person,-person).',
'tempadvisedby(-person,+person).',
'ta(+course,+person,+quarter).',
'ta(-course,+person,+quarter).',
'ta(+course,-person,+quarter).',
'ta(+course,+person,-quarter).',
'ta(-course,+person,-quarter).',
'ta(+course,-person,-quarter).',
'hasposition(+person,+faculty).',
'hasposition(+person,-faculty).',
'hasposition(-person,+faculty).',
'publication(+title,+person).',
'publication(+title,-person).',
'publication(-title,+person).',
'inphase(+person,+prequals).',
'inphase(+person,-prequals).',
'inphase(-person,+prequals).',
'courselevel(+course,+level).',
'courselevel(+course,-level).',
'courselevel(-course,+level).',
'yearsinprogram(+person,+year).',
'yearsinprogram(-person,+year).',
'yearsinprogram(+person,-year).',
'projectmember(+project,+person).',
'projectmember(+project,-person).',
'projectmember(-project,+person).']
#'sameproject(project, project).',
#'samecourse(course, course).',
#'sameperson(person, person).',]

# %%
target_target = 'workedunder'
[target_facts, target_pos, target_neg] = get_imdb_dataset(target_target)

target_bk = ['workedunder(+person,+person).',
      'workedunder(+person,-person).',
      'workedunder(-person,+person).',
      'female(+person).',
      'actor(+person).',
      'director(+person).',
      'movie(+movie,+person).',
      'movie(+movie,-person).',
      'movie(-movie,+person).',
      'genre(+person,+genre).']

# %%
background = boostsrl.modes(source_bk, [source_target], useStdLogicVariables=False, maxTreeDepth=12, nodeSize=3, numOfClauses=12)

# shuffle all examples
random.shuffle(source_pos)
random.shuffle(source_neg)
source_neg = source_neg[:len(source_pos)]

# separate train and test
test_pos = source_pos[:int(test_size*len(source_pos))]
test_neg = source_neg[:int(test_size*len(source_neg))]
train_pos = source_pos[int(test_size*len(source_pos)):]
train_neg = source_neg[int(test_size*len(source_neg)):]

train_pos = train_pos[int(validation_size*len(train_pos)):]
train_neg = train_neg[int(validation_size*len(train_neg)):]
validation_pos = train_pos[:int(validation_size*len(train_pos))]
validation_neg = train_neg[:int(validation_size*len(train_neg))]

print('Train pos size: %s' % len(train_pos))
print('Train neg size: %s' % len(train_neg))
print('Validation pos size: %s' % len(validation_pos))
print('Validation neg size: %s' % len(validation_neg))
print('Test pos size: %s' % len(test_pos))
print('Test neg size: %s' % len(test_neg))
# Out:
# Train pos size: 92
# Train neg size: 92
# Validation pos size: 9
# Validation neg size: 9
# Test pos size: 11
# Test neg size: 11

# %% [markdown]
# ## Learning from source domain

# %%
[model, total_revision_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, source_target, train_pos[:int(0.25*len(train_pos))], train_neg[:int(0.25*len(train_neg))], source_facts, test_pos, test_neg, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( tempadvisedby(C, B) )
# %   | then if ( publication(D, C), publication(D, B) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.8581489350995123;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | else if ( ta(E, A, F), publication(G, A) )
# %   | | then return -0.14185106490048777;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else if ( publication(H, A) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return -0.1418510649004878;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #2
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( tempadvisedby(C, B) )
# %   | then if ( ta(D, A, E), ta(F, C, G), ta(D, H, G) )
# %   | | then return 0.4850122940520396;  // std dev = 0,812, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | else return 0.7298326667716779;  // std dev = 0,080, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | else if ( ta(I, A, J), publication(K, A) )
# %   | | then return -0.12544463852839138;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else if ( publication(L, A) )
# %   | | | then return 0.7194734122109545;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.3927941835770488;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return -0.12544463852839138;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #3
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( tempadvisedby(C, B) )
# %   | then if ( publication(D, C), publication(D, B) )
# %   | | then return 0.31799375203466423;  // std dev = 0,772, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.5665277899023938;  // std dev = 0,090, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | else if ( ta(E, A, F), publication(G, A) )
# %   | | then return -0.11231637819360639;  // std dev = 2,63e-09, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else if ( publication(H, A) )
# %   | | | then return 0.5553664367462845;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.32092546969114216;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return -0.11231637819360635;  // std dev = 1,49e-08, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #4
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( ta(C, A, D), publication(E, A) )
# %   | then if ( publication(E, B) )
# %   | | then return 0.45752623866782177;  // std dev = 0,052, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else return -0.05532008819344272;  // std dev = 0,577, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | else if ( tempadvisedby(F, B) )
# %   | | then if ( publication(G, F) )
# %   | | | then return 0.4603915260744625;  // std dev = 0,167, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.4122893341284042;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( publication(H, A) )
# %   | | | then return 0.4175135841583099;  // std dev = 1,49e-08, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.25206564481433;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return -0.10159632948783631;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #5
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( tempadvisedby(C, B) )
# %   | then if ( publication(D, C), publication(E, A) )
# %   | | then return 0.21638196705116652;  // std dev = 0,655, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | else if ( ta(F, C, G) )
# %   | | | then return 0.3395258251039371;  // std dev = 0,055, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.37309710132939333;  // std dev = 0,122, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( ta(H, A, I), ta(H, J, I), publication(K, J) )
# %   | | then return -0.020824734251552873;  // std dev = 0,737, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( publication(L, A) )
# %   | | | then return 0.32071184716014967;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.2595905310482807;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   else return -0.09269127618926094;  // std dev = 9,13e-09, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #6
# % FOR advisedby(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), tempadvisedby(E, D) )
# %   then if ( ta(F, A, G), ta(F, H, G), publication(I, H) )
# %   | then if ( publication(I, B) )
# %   | | then return 0.2742830245451904;  // std dev = 0,046, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else return -0.013114096624865809;  // std dev = 0,911, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | else if ( ta(J, A, K) )
# %   | | then return 0.34206647163010473;  // std dev = 0,229, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( tempadvisedby(L, B), publication(M, L) )
# %   | | | then return 0.29896399314331445;  // std dev = 0,128, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.25239392018097073;  // std dev = 0,012, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   else if ( publication(N, B), publication(N, P), tempadvisedby(Q, P) )
# %   | then return -0.1494729705632589;  // std dev = 0,352, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | else if ( publication(R, A) )
# %   | | then return -0.08639341267254719;  // std dev = 0,009, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | | else return 0.01719369610340778;  // std dev = 0,561, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# WILL Produced-Tree #7
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( ta(C, A, D), ta(C, E, D), publication(F, E) )
# %   | then if ( publication(F, B) )
# %   | | then return 0.22329025673482703;  // std dev = 0,040, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( publication(F, G), professor(G) )
# %   | | | then return -0.1737012386926426;  // std dev = 0,284, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.1810345093634266;  // std dev = 0,734, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | else if ( ta(H, A, I) )
# %   | | then return 0.27477959526225015;  // std dev = 0,207, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( tempadvisedby(J, B) )
# %   | | | then if ( ta(K, J, L), publication(M, A) )
# %   | | | | then return 0.2315297254275004;  // std dev = 0,100, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | | else return 0.23049859994074076;  // std dev = 0,071, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( publication(N, A), publication(N, B) )
# %   | | | | then return 0.21021862010085512;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else return 0.12783379602169326;  // std dev = 0,698, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.07968669558895294;  // std dev = 0,020, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #8
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( ta(C, A, D), publication(E, A) )
# %   | then if ( publication(E, B) )
# %   | | then return 0.187033654747378;  // std dev = 0,035, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else return -0.06225136426878656;  // std dev = 0,483, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | else if ( publication(F, A) )
# %   | | then if ( tempadvisedby(G, B), publication(H, G) )
# %   | | | then return 0.1932954498895867;  // std dev = 0,089, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.17944726826195465;  // std dev = 0,021, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else if ( tempadvisedby(I, B) )
# %   | | | then return 0.17888772028243538;  // std dev = 0,076, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.10375544805847339;  // std dev = 1,027, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return -0.07403667111205708;  // std dev = 0,018, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #9
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( ta(C, A, D), ta(C, E, D), publication(F, E) )
# %   | then if ( publication(F, B) )
# %   | | then return 0.16028870548622604;  // std dev = 0,031, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( publication(F, G), professor(G) )
# %   | | | then return -0.146276889860176;  // std dev = 0,251, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.12576211596652026;  // std dev = 0,744, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | else if ( ta(H, A, I) )
# %   | | then return 0.20438387045405346;  // std dev = 0,183, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( publication(J, A) )
# %   | | | then if ( tempadvisedby(K, B), publication(L, K) )
# %   | | | | then return 0.16518212646206368;  // std dev = 0,079, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | | else return 0.1545358234496432;  // std dev = 0,019, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.08326907380969002;  // std dev = 0,706, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.0691197721714389;  // std dev = 0,017, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# WILL Produced-Tree #10
# % FOR advisedby(A, B):
# %   if ( professor(B) )
# %   then if ( tempadvisedby(C, B) )
# %   | then if ( ta(D, C, E), ta(F, A, G) )
# %   | | then return 0.05501427025470651;  // std dev = 0,424, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | else if ( ta(H, C, I) )
# %   | | | then return 0.14247000687380232;  // std dev = 0,072, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else return 0.18159085310783782;  // std dev = 0,139, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( ta(J, A, K) )
# %   | | then return 0.019090317419980223;  // std dev = 0,778, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | else if ( publication(L, A), publication(L, B) )
# %   | | | then return 0.13379534489436662;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.055339390053668475;  // std dev = 0,700, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.064803858405538;  // std dev = 0,016, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# Results
#    AUC ROC   = 0.780992
#    AUC PR    = 0.731573
#    CLL	      = -0.590867
#    Precision = 0.666667 at threshold = 0.5
#    Recall    = 0.909091
#    F1        = 0.769231
#
#
# Total learning time: 9.75 seconds
# Total inference time: 0.536 seconds
# AUC ROC: 0.780992

# %%
transferred_structured = transfer(structured, ['professor(A) -> director(A)',
            'student(A) -> actor(A)',
            'advisedby(A, B) -> workedunder(A, B)',
            'publication(A, B) -> movie(A, B)',
            'hasposition(A, B) -> gender(A, B)'
            ])

# %%
transferred_structured
# Out:
# [['workedunder(A, B)',
#   {'': 'director(B)',
#    'true,false,false': 'movie(H, A)',
#    'true,true': 'movie(D, C), movie(D, B)'},
#   {'false': [0.0, 17, 0],
#    'true,false,false,false': [1.095, 2, 3],
#    'true,false,false,true': [0.0, 0, 5],
#    'true,false,true': [0.0, 3, 0],
#    'true,true,false': [0.0, 0, 13],
#    'true,true,true': [0.816, 1, 2]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)', 'true,false,false': 'movie(L, A)'},
#   {'false': [0.0, 17, 0],
#    'true,false,false,false': [1.095, 2, 3],
#    'true,false,false,true': [0.0, 0, 5],
#    'true,false,true': [0.0, 3, 0],
#    'true,true,false': [0.08, 0, 12],
#    'true,true,true': [0.812, 1, 3]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)',
#    'true,false,false': 'movie(H, A)',
#    'true,true': 'movie(D, C), movie(D, B)'},
#   {'false': [1.49e-08, 17, 0],
#    'true,false,false,false': [1.095, 2, 3],
#    'true,false,false,true': [0.0, 0, 5],
#    'true,false,true': [2.63e-09, 3, 0],
#    'true,true,false': [0.09, 0, 13],
#    'true,true,true': [0.772, 1, 2]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)',
#    'true': 'movie(E, A)',
#    'true,false,false': 'movie(H, A)',
#    'true,false,true': 'movie(G, F)',
#    'true,true': 'movie(E, B)'},
#   {'false': [0.0, 17, 0],
#    'true,false,false,false': [1.095, 2, 3],
#    'true,false,false,true': [1.49e-08, 0, 5],
#    'true,false,true,false': [0.0, 0, 4],
#    'true,false,true,true': [0.167, 0, 6],
#    'true,true,false': [0.577, 4, 1],
#    'true,true,true': [0.052, 0, 4]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)', 'true,false,false': 'movie(L, A)'},
#   {'false': [9.13e-09, 17, 0],
#    'true,false,false,false': [0.816, 1, 2],
#    'true,false,false,true': [0.0, 0, 5],
#    'true,false,true': [0.737, 4, 1],
#    'true,true,false,false': [0.122, 0, 4],
#    'true,true,false,true': [0.055, 0, 6],
#    'true,true,true': [0.655, 1, 5]}],
#  ['workedunder(A, B)',
#   {'': 'gender(B, C), gender(D, C)',
#    'false': 'movie(N, B), movie(N, P)',
#    'false,false': 'movie(R, A)',
#    'true': 'movie(I, H)',
#    'true,false,false': 'movie(M, L)',
#    'true,true': 'movie(I, B)'},
#   {'false,false,false': [0.561, 5, 1],
#    'false,false,true': [0.009, 8, 0],
#    'false,true': [0.352, 6, 0],
#    'true,false,false,false': [0.012, 0, 7],
#    'true,false,false,true': [0.128, 0, 6],
#    'true,false,true': [0.229, 0, 3],
#    'true,true,false': [0.911, 4, 2],
#    'true,true,true': [0.046, 0, 4]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)',
#    'true': 'movie(F, E)',
#    'true,false,false,true': 'movie(M, A)',
#    'true,true': 'movie(F, B)',
#    'true,true,false': 'movie(F, G), director(G)'},
#   {'false': [0.02, 17, 0],
#    'true,false,false,false,false': [0.698, 1, 3],
#    'true,false,false,false,true': [0.0, 0, 3],
#    'true,false,false,true,false': [0.071, 0, 3],
#    'true,false,false,true,true': [0.1, 0, 5],
#    'true,false,true': [0.207, 0, 3],
#    'true,true,false,false': [0.734, 1, 2],
#    'true,true,false,true': [0.284, 4, 0],
#    'true,true,true': [0.04, 0, 4]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)',
#    'true': 'movie(E, A)',
#    'true,false': 'movie(F, A)',
#    'true,false,true': 'movie(H, G)',
#    'true,true': 'movie(E, B)'},
#   {'false': [0.018, 17, 0],
#    'true,false,false,false': [1.027, 2, 3],
#    'true,false,false,true': [0.076, 0, 4],
#    'true,false,true,false': [0.021, 0, 6],
#    'true,false,true,true': [0.089, 0, 5],
#    'true,true,false': [0.483, 4, 1],
#    'true,true,true': [0.035, 0, 4]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)',
#    'true': 'movie(F, E)',
#    'true,false,false': 'movie(J, A)',
#    'true,false,false,true': 'movie(L, K)',
#    'true,true': 'movie(F, B)',
#    'true,true,false': 'movie(F, G), director(G)'},
#   {'false': [0.017, 17, 0],
#    'true,false,false,false': [0.706, 1, 3],
#    'true,false,false,true,false': [0.019, 0, 6],
#    'true,false,false,true,true': [0.079, 0, 5],
#    'true,false,true': [0.183, 0, 3],
#    'true,true,false,false': [0.744, 1, 2],
#    'true,true,false,true': [0.251, 4, 0],
#    'true,true,true': [0.031, 0, 4]}],
#  ['workedunder(A, B)',
#   {'': 'director(B)', 'true,false,false': 'movie(L, A), movie(L, B)'},
#   {'false': [0.016, 17, 0],
#    'true,false,false,false': [0.7, 1, 3],
#    'true,false,false,true': [0.0, 0, 3],
#    'true,false,true': [0.778, 4, 2],
#    'true,true,false,false': [0.139, 0, 4],
#    'true,true,false,true': [0.072, 0, 6],
#    'true,true,true': [0.424, 1, 5]}]]

# %% [markdown]
# ## Transfer Learning

# %%
background = boostsrl.modes(target_bk, [target_target], useStdLogicVariables=False, maxTreeDepth=12, nodeSize=3, numOfClauses=12)

# shuffle all examples
random.shuffle(target_pos)
random.shuffle(target_neg)
target_pos = target_pos[:int(target_size*len(target_pos))]
target_neg = target_neg[:len(target_pos)]

# separate train and test
test_pos = target_pos[:int(test_size*len(target_pos))]
test_neg = target_neg[:int(test_size*len(target_neg))]
train_pos = target_pos[int(test_size*len(target_pos)):]
train_neg = target_neg[int(test_size*len(target_neg)):]

train_pos = train_pos[int(validation_size*len(train_pos)):]
train_neg = train_neg[int(validation_size*len(train_neg)):]
validation_pos = train_pos[:int(validation_size*len(train_pos))]
validation_neg = train_neg[:int(validation_size*len(train_neg))]

print('Train pos size: %s' % len(train_pos))
print('Train neg size: %s' % len(train_neg))
print('Validation pos size: %s' % len(validation_pos))
print('Validation neg size: %s' % len(validation_neg))
print('Test pos size: %s' % len(test_pos))
print('Test neg size: %s' % len(test_neg))
# Out:
# Train pos size: 310
# Train neg size: 310
# Validation pos size: 31
# Validation neg size: 31
# Test pos size: 38
# Test neg size: 38

# %%
[model, total_revision_time, inference_time, t_results, structured] = theory_revision(background, boostsrl, target_target, train_pos, train_neg, target_facts, validation_pos, validation_neg, test_pos, test_neg, revision_threshold, transferred_structured.copy(), trees=10, max_revision_iterations=10, verbose=True)
# Out:
# ******************************************
# Performing Parameter Learning
# ******************************************
# Refine
# ['0;;workedunder(A, B) :- director(B).;false;false', '0;true,true;movie(D, C), movie(D, B).;false;false', '0;true,false,false;movie(H, A).;false;false', '1;;workedunder(A, B) :- director(B).;false;false', '1;true,false,false;movie(L, A).;false;false', '2;;workedunder(A, B) :- director(B).;false;false', '2;true,true;movie(D, C), movie(D, B).;false;false', '2;true,false,false;movie(H, A).;false;false', '3;;workedunder(A, B) :- director(B).;true;false', '3;true,true;movie(E, B).;false;false', '3;true;movie(E, A).;true;false', '3;true,false,true;movie(G, F).;false;false', '3;true,false,false;movie(H, A).;false;false', '4;;workedunder(A, B) :- director(B).;false;false', '4;true,false,false;movie(L, A).;false;false', '5;;workedunder(A, B) :- gender(B, C), gender(D, C).;true;true', '5;true;movie(I, H).;true;false', '5;false;movie(N, B), movie(N, P).;false;true', '5;true,true;movie(I, B).;false;false', '5;true,false,false;movie(M, L).;false;false', '5;false,false;movie(R, A).;false;false', '6;;workedunder(A, B) :- director(B).;true;false', '6;true,true;movie(F, B).;false;true', '6;true,true,false;movie(F, G), director(G).;false;false', '6;true;movie(F, E).;true;false', '6;true,false,false,true;movie(M, A).;false;false', '7;;workedunder(A, B) :- director(B).;true;false', '7;true,true;movie(E, B).;false;false', '7;true;movie(E, A).;true;true', '7;true,false,true;movie(H, G).;false;false', '7;true,false;movie(F, A).;true;false', '8;;workedunder(A, B) :- director(B).;true;false', '8;true;movie(F, E).;true;false', '8;true,true;movie(F, B).;false;true', '8;true,false,false,true;movie(L, K).;false;false', '8;true,false,false;movie(J, A).;true;false', '8;true,true,false;movie(F, G), director(G).;false;false', '9;;workedunder(A, B) :- director(B).;false;false', '9;true,false,false;movie(L, A), movie(L, B).;false;false']
# WILL Produced-Tree #1
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.7541026923249419;  // std dev = 5,679, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.14185106490048802;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #2
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.6359400489705721;  // std dev = 5,679, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.12544463852839194;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #3
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.49703138746865777;  // std dev = 5,679, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.11231637819360694;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #4
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, A) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.4686605467620563;  // std dev = 1,724, 313,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=310 */
# %   | | else return -0.5217547887012048;  // std dev = 0,000, 33,000 (wgt'ed) examples reached here.  /* #neg=33 */
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.1015963294878366;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #5
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.2836131072131175;  // std dev = 4,435, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.09269127618926044;  // std dev = 1,30e-07, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #6
# % FOR workedunder(A, B):
# %   if ( gender(B, C), gender(D, C) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( movie(E, B), movie(E, F) )
# %   | then return 0.0852043688087626;  // std dev = 5,849, 620,000 (wgt'ed) examples reached here.  /* #neg=310 #pos=310 */
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# WILL Produced-Tree #7
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, D) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.2021530712745138;  // std dev = 4,486, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.09206354742726823;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #8
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, A) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.23518498824292544;  // std dev = 1,724, 313,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=310 */
# %   | | else return -0.5340198284644744;  // std dev = 0,000, 33,000 (wgt'ed) examples reached here.  /* #neg=33 */
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.08465174584007681;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #9
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, D) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.13748497793822873;  // std dev = 3,685, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.07831887980723815;  // std dev = 1,18e-07, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #10
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.11492296954328583;  // std dev = 3,744, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.07284887478194937;  // std dev = 1,07e-07, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.134923
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 1.0
#
#
# Total learning time: 4.501 seconds
# Total inference time: 0.652 seconds
# AUC ROC: 1.0
#
#
# Structure after Parameter Learning
# [['workedunder(A, B)', {'': 'director(B)'}, {'true': [5.679, 36, 310], 'false': [0.0, 274, 0]}], ['workedunder(A, B)', {'': 'director(B)'}, {'true': [5.679, 36, 310], 'false': [0.0, 274, 0]}], ['workedunder(A, B)', {'': 'director(B)'}, {'true': [5.679, 36, 310], 'false': [0.0, 274, 0]}], ['workedunder(A, B)', {'': 'director(B)', 'true,true': 'movie(C, B)', 'true': 'movie(C, A)'}, {'true,true,false': [0.0, 33, 0], 'false': [0.0, 274, 0], 'true,false': [0.0, 0, 0], 'true,true,true': [1.724, 3, 310]}], ['workedunder(A, B)', {'': 'director(B)'}, {'true': [4.435, 36, 310], 'false': [1.3e-07, 274, 0]}], ['workedunder(A, B)', {'': 'gender(B, C), gender(D, C)', 'false': 'movie(E, B), movie(E, F)'}, {'true': [0.0, 0, 0], 'false,false': [0.0, 0, 0], 'false,true': [5.849, 310, 310]}], ['workedunder(A, B)', {'': 'director(B)', 'true,true': 'movie(C, B)', 'true': 'movie(C, D)'}, {'true,true,false': [0.0, 0, 0], 'false': [0.0, 274, 0], 'true,false': [0.0, 0, 0], 'true,true,true': [4.486, 36, 310]}], ['workedunder(A, B)', {'': 'director(B)', 'true,true': 'movie(C, B)', 'true': 'movie(C, A)'}, {'true,true,false': [0.0, 33, 0], 'false': [0.0, 274, 0], 'true,false': [0.0, 0, 0], 'true,true,true': [1.724, 3, 310]}], ['workedunder(A, B)', {'': 'director(B)', 'true,true': 'movie(C, B)', 'true': 'movie(C, D)'}, {'true,true,false': [0.0, 0, 0], 'false': [1.18e-07, 274, 0], 'true,false': [0.0, 0, 0], 'true,true,true': [3.685, 36, 310]}], ['workedunder(A, B)', {'': 'director(B)'}, {'true': [3.744, 36, 310], 'false': [1.07e-07, 274, 0]}]]
# ******************************************
# Performing Theory Revision
# ******************************************
# Refining iteration 1
# ********************************
# Candidate for revision
# ['0;;workedunder(A, B) :- director(B).;false;false', '1;;workedunder(A, B) :- director(B).;false;false', '2;;workedunder(A, B) :- director(B).;false;false', '3;;workedunder(A, B) :- director(B).;true;false', '3;true,true;movie(C, B).;false;false', '3;true;movie(C, A).;true;false', '4;;workedunder(A, B) :- director(B).;false;false', '5;;workedunder(A, B) :- gender(B, C), gender(D, C).;false;true', '5;false;movie(E, B), movie(E, F).;true;false', '6;;workedunder(A, B) :- director(B).;true;false', '6;true,true;movie(C, B).;false;false', '6;true;movie(C, D).;true;false', '7;;workedunder(A, B) :- director(B).;true;false', '7;true,true;movie(C, B).;false;false', '7;true;movie(C, A).;true;false', '8;;workedunder(A, B) :- director(B).;true;false', '8;true,true;movie(C, B).;false;false', '8;true;movie(C, D).;true;false', '9;;workedunder(A, B) :- director(B).;false;false']
# Refining candidate
# ***************************
# Revision points found
# Tree #1: []
# Tree #2: []
# Tree #3: []
# Tree #4: []
# Tree #5: []
# Tree #6: [('false,true', 0.5)]
# Tree #7: []
# Tree #8: []
# Tree #9: []
# Tree #10: []
#
#
# WILL Produced-Tree #1
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.7541026923249419;  // std dev = 5,679, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.14185106490048802;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #2
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.6359400489705721;  // std dev = 5,679, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.12544463852839194;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #3
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.49703138746865777;  // std dev = 5,679, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.11231637819360694;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #4
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, A) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.4686605467620563;  // std dev = 1,724, 313,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=310 */
# %   | | else return -0.5217547887012048;  // std dev = 0,000, 33,000 (wgt'ed) examples reached here.  /* #neg=33 */
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.1015963294878366;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #5
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.2836131072131175;  // std dev = 4,435, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.09269127618926044;  // std dev = 1,30e-07, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #6
# % FOR workedunder(A, B):
# %   if ( gender(B, C), gender(D, C) )
# %   then return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else if ( movie(E, B), movie(E, F) )
# %   | then if ( director(B), actor(A) )
# %   | | then if ( movie(G, A), movie(G, B) )
# %   | | | then return 0.3016721662691319;  // std dev = 5,36e-07, 310,000 (wgt'ed) examples reached here.  /* #pos=310 */
# %   | | | else return -0.46230477273893206;  // std dev = 5,96e-08, 26,000 (wgt'ed) examples reached here.  /* #neg=26 */
# %   | | else if ( actor(B) )
# %   | | | then return -0.08518475138839678;  // std dev = 9,77e-08, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# %   | | | else return -0.5331116910365127;  // std dev = 0,108, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# WILL Produced-Tree #7
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, D) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.178764521031173;  // std dev = 3,480, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.07877675473109143;  // std dev = 5,16e-08, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #8
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, A) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.20290097070072086;  // std dev = 1,430, 313,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=310 */
# %   | | else return -0.3894719405129661;  // std dev = 0,039, 33,000 (wgt'ed) examples reached here.  /* #neg=33 */
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.07324622576333688;  // std dev = 1,10e-07, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #9
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then if ( movie(C, D) )
# %   | then if ( movie(C, B) )
# %   | | then return 0.12588443702716734;  // std dev = 2,965, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   | | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   | else return 0;  // std dev = 0,000, 0,000 (wgt'ed) examples reached here.
# %   else return -0.06842697784420287;  // std dev = 0,000, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# WILL Produced-Tree #10
# % FOR workedunder(A, B):
# %   if ( director(B) )
# %   then return 0.10714042060739196;  // std dev = 3,018, 346,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=310 */
# %   else return -0.0641918400820261;  // std dev = 8,43e-08, 274,000 (wgt'ed) examples reached here.  /* #neg=274 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.116965
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 1.0
#
#
# Total learning time: 6.827 seconds
# Total inference time: 0.505 seconds
# AUC ROC: 1.0
#
#
# Best model AUC ROC so far: 1.0
#
#
# ******************************************
# Best model found
# ******************************************
# Total revision time: 12.485
# Best validation AUC ROC: 1.0
#
#
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.155095
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 1.0
#
#
# Total inference time: 0.502 seconds
# AUC ROC: 1.0

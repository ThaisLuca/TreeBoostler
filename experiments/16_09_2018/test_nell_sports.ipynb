# %%
from datasets.get_datasets import *
from boostedrevision import *
from boostsrl import boostsrl
import random

# %% [markdown]
# ## Dataset

# %%
target = 'teamplayssport'

bk = ['athleteledsportsteam(+athlete,+sportsteam).',
    'athleteledsportsteam(+athlete,-sportsteam).',
    'athleteledsportsteam(-athlete,+sportsteam).',
    'athleteplaysforteam(+athlete,+sportsteam).',
    'athleteplaysforteam(+athlete,-sportsteam).',
    'athleteplaysforteam(-athlete,+sportsteam).',
    'athleteplaysinleague(+athlete,+sportsleague).',
    'athleteplaysinleague(+athlete,-sportsleague).',
    'athleteplaysinleague(-athlete,+sportsleague).',
    'athleteplayssport(+athlete,+sport).',
    'athleteplayssport(+athlete,-sport).',
    'athleteplayssport(-athlete,+sport).',
    'teamalsoknownas(+sportsteam,+sportsteam).',
    'teamalsoknownas(+sportsteam,-sportsteam).',
    'teamalsoknownas(-sportsteam,+sportsteam).',
    'teamplaysagainstteam(+sportsteam,+sportsteam).',
    'teamplaysagainstteam(+sportsteam,-sportsteam).',
    'teamplaysagainstteam(-sportsteam,+sportsteam).',
    'teamplaysinleague(+sportsteam,+sportsleague).',
    'teamplaysinleague(+sportsteam,-sportsleague).',
    'teamplaysinleague(-sportsteam,+sportsleague).',
    'teamplayssport(+sportsteam,+sport).',
    'teamplayssport(+sportsteam,-sport).',
    'teamplayssport(-sportsteam,+sport).']

[facts, pos, neg] = datasets.load('nell_sports', bk, target=target)

pos = datasets.split_into_folds(pos[0])
neg = datasets.split_into_folds(neg[0])

# %% [markdown]
# ## Background  configuration

# %%
background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Learning

# %%
for i in range(len(pos)):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, A) )
# %   | then return 0.8581489350995123;  // std dev = 0,000, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | else if ( athleteledsportsteam(C, E), teamplaysinleague(A, D), teamalsoknownas(E, F) )
# %   | | then if ( athleteledsportsteam(G, A), athleteplaysinleague(G, D) )
# %   | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.8581489350995123;  // std dev = 0,000, 18,000 (wgt'ed) examples reached here.  /* #pos=18 */
# %   | | else if ( teamplaysinleague(A, D) )
# %   | | | then return -0.1418510649004878;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | else if ( teamplaysagainstteam(H, A), teamplaysagainstteam(I, A), teamalsoknownas(H, I) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | | else if ( athleteplaysforteam(J, A), athleteplaysforteam(C, K) )
# %   | | | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | | else return 0.587315601766178;  // std dev = 3,079, 48,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=35 */
# %   else if ( teamplaysinleague(A, L) )
# %   | then return -0.14185106490048768;  // std dev = 4,71e-08, 45,000 (wgt'ed) examples reached here.  /* #neg=45 */
# %   | else return 0.011995088945666036;  // std dev = 0,361, 13,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=2 */
# WILL Produced-Tree #2
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, E), teamplaysinleague(A, D), teamalsoknownas(E, F) )
# %   | then return 0.6982294546334414;  // std dev = 0,155, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | else if ( teamplaysinleague(A, D) )
# %   | | then return -0.12544463852839138;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else if ( teamalsoknownas(A, G), teamalsoknownas(H, G), teamplaysinleague(H, D) )
# %   | | | then return -0.014487650261658113;  // std dev = 0,880, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | else if ( teamalsoknownas(A, I) )
# %   | | | | then return 0.7764423361848938;  // std dev = 0,071, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | | | else if ( teamalsoknownas(J, A), athleteledsportsteam(C, K) )
# %   | | | | | then return 0.12867153108791085;  // std dev = 0,788, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.4879178286197275;  // std dev = 2,644, 36,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=26 */
# %   else if ( teamplaysinleague(A, L) )
# %   | then return -0.12544463852839152;  // std dev = 0,000, 45,000 (wgt'ed) examples reached here.  /* #neg=45 */
# %   | else if ( teamplaysagainstteam(M, A) )
# %   | | then return -0.14331750143463115;  // std dev = 2,63e-09, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.05668249856536887;  // std dev = 0,400, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# WILL Produced-Tree #3
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, E), teamplaysinleague(A, D), teamalsoknownas(E, F) )
# %   | then return 0.5406738001095603;  // std dev = 0,154, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | else if ( teamalsoknownas(A, G), teamplaysagainstteam(H, A), teamalsoknownas(G, H) )
# %   | | then return 0.662683228441006;  // std dev = 0,136, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( teamplaysinleague(A, D) )
# %   | | | then return -0.11231637819360639;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | else if ( athleteledsportsteam(I, A) )
# %   | | | | then return 0.6101704007465888;  // std dev = 0,003, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else if ( athleteledsportsteam(C, J), teamplaysagainstteam(A, K), teamalsoknownas(K, L) )
# %   | | | | | then return 0.07362151898600465;  // std dev = 1,032, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | | | else return 0.40088688192446753;  // std dev = 2,827, 45,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=33 */
# %   else if ( teamplaysinleague(A, M) )
# %   | then return -0.11231637819360635;  // std dev = 1,83e-08, 45,000 (wgt'ed) examples reached here.  /* #neg=45 */
# %   | else if ( teamalsoknownas(A, N) )
# %   | | then return -0.13454235648052706;  // std dev = 0,019, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.05196291571237781;  // std dev = 0,399, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# WILL Produced-Tree #4
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, E), athleteplaysforteam(C, E), teamalsoknownas(E, F) )
# %   | then if ( teamplaysinleague(A, D), teamplaysinleague(F, D) )
# %   | | then return 0.4298123805160796;  // std dev = 0,067, 28,000 (wgt'ed) examples reached here.  /* #pos=28 */
# %   | | else if ( teamalsoknownas(F, E), teamplaysinleague(A, G) )
# %   | | | then return 0.4625766413747488;  // std dev = 0,637, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | else if ( teamalsoknownas(F, H), teamplaysinleague(A, I) )
# %   | | | | then return -0.321227159173532;  // std dev = 0,159, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | | | | else if ( teamalsoknownas(F, E) )
# %   | | | | | then return -0.11020772872486122;  // std dev = 0,758, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.19611631346297426;  // std dev = 1,577, 14,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=8 */
# %   | else if ( athleteledsportsteam(C, J) )
# %   | | then return 0.4974167902507109;  // std dev = 0,129, 31,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=30 */
# %   | | else if ( teamplaysagainstteam(K, A) )
# %   | | | then return 0.3238603304956829;  // std dev = 0,303, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | | else return -0.3812973950853727;  // std dev = 0,094, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   else return -0.07720446843820127;  // std dev = 0,175, 58,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=2 */
# WILL Produced-Tree #5
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, E), athleteplaysforteam(C, E), teamalsoknownas(E, F) )
# %   | then if ( teamplaysinleague(A, D), teamplaysinleague(F, D) )
# %   | | then return 0.329123532696909;  // std dev = 0,062, 28,000 (wgt'ed) examples reached here.  /* #pos=28 */
# %   | | else if ( teamalsoknownas(F, E), teamalsoknownas(A, G) )
# %   | | | then return 0.47989733163741866;  // std dev = 0,175, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else if ( teamalsoknownas(F, H) )
# %   | | | | then if ( teamplaysagainstteam(A, I) )
# %   | | | | | then return -0.24069538772145643;  // std dev = 0,306, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | | | else return -0.058397340023526235;  // std dev = 1,173, 10,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=3 */
# %   | | | | else if ( teamalsoknownas(A, J) )
# %   | | | | | then return -0.03462628117922902;  // std dev = 0,766, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.21137501200406267;  // std dev = 1,202, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | else if ( athleteledsportsteam(C, K) )
# %   | | then return 0.3790379173981737;  // std dev = 0,118, 31,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=30 */
# %   | | else return 0.12017460863743568;  // std dev = 0,344, 12,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=6 */
# %   else return -0.06980072754454153;  // std dev = 0,175, 58,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=2 */
# WILL Produced-Tree #6
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, E), athleteplaysforteam(C, E), teamalsoknownas(E, F) )
# %   | then if ( teamplaysagainstteam(A, E) )
# %   | | then return 0.2646545916998306;  // std dev = 0,108, 22,000 (wgt'ed) examples reached here.  /* #pos=22 */
# %   | | else if ( teamalsoknownas(F, E), teamplaysinleague(A, G) )
# %   | | | then return 0.3033013917172799;  // std dev = 0,205, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | | else if ( teamalsoknownas(F, H), teamplaysinleague(A, I) )
# %   | | | | then return -0.1828273506852911;  // std dev = 0,197, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | | else if ( teamalsoknownas(F, E) )
# %   | | | | | then return -0.11381014278891899;  // std dev = 0,650, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.15005687425259528;  // std dev = 1,551, 18,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=12 */
# %   | else if ( athleteledsportsteam(C, J) )
# %   | | then return 0.29504640308244634;  // std dev = 0,110, 31,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=30 */
# %   | | else if ( teamplaysagainstteam(K, A) )
# %   | | | then return 0.23481310426770552;  // std dev = 0,275, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | | else return -0.32255712300505684;  // std dev = 0,086, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   else return -0.0634823601473265;  // std dev = 0,176, 58,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=2 */
# WILL Produced-Tree #7
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, E), teamplaysinleague(A, D), teamalsoknownas(E, F) )
# %   | then return 0.1987914024543573;  // std dev = 0,092, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | else if ( teamplaysinleague(A, D) )
# %   | | then return -0.15891458562922584;  // std dev = 0,071, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else if ( teamplaysagainstteam(G, A), teamalsoknownas(A, H), teamalsoknownas(I, G) )
# %   | | | then return 0.32049886679130846;  // std dev = 0,300, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else if ( teamplaysagainstteam(J, A), athleteledsportsteam(C, K), teamalsoknownas(J, L) )
# %   | | | | then if ( teamplaysagainstteam(A, L) )
# %   | | | | | then return 0.2977403460831004;  // std dev = 0,062, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | else return -0.1444248790212943;  // std dev = 0,679, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else if ( teamalsoknownas(A, M), teamalsoknownas(N, M), teamplaysinleague(N, D) )
# %   | | | | | then return -0.3148021384985074;  // std dev = 0,145, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | | else return 0.189755608139102;  // std dev = 1,802, 40,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=31 */
# %   else if ( teamplaysinleague(A, P) )
# %   | then return -0.08393077079221414;  // std dev = 1,97e-08, 45,000 (wgt'ed) examples reached here.  /* #neg=45 */
# %   | else return 0.031610593338678515;  // std dev = 0,357, 13,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=2 */
# WILL Produced-Tree #8
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysinleague(C, D) )
# %   then if ( athleteledsportsteam(C, E), teamplaysinleague(A, D), teamalsoknownas(E, F) )
# %   | then return 0.16700265671193124;  // std dev = 0,093, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | else if ( teamplaysinleague(A, D) )
# %   | | then return -0.1394861698650978;  // std dev = 0,063, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else if ( teamplaysagainstteam(G, A), teamalsoknownas(A, H) )
# %   | | | then return 0.23724827138815036;  // std dev = 0,174, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | | else if ( teamplaysagainstteam(I, A), athleteledsportsteam(C, J), teamplaysagainstteam(A, K) )
# %   | | | | then if ( teamalsoknownas(I, K) )
# %   | | | | | then return 0.23965930611234273;  // std dev = 0,054, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | else return -0.11951619943986992;  // std dev = 0,686, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | | else if ( teamplaysagainstteam(L, A) )
# %   | | | | | then return 0.35368765234515587;  // std dev = 0,053, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | | | else return 0.0919192367504266;  // std dev = 1,788, 35,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=24 */
# %   else if ( teamplaysinleague(A, M) )
# %   | then return -0.07769891677655895;  // std dev = 1,05e-08, 45,000 (wgt'ed) examples reached here.  /* #neg=45 */
# %   | else return 0.028185061123998108;  // std dev = 0,357, 13,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=2 */
# WILL Produced-Tree #9
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteledsportsteam(C, D) )
# %   then if ( athleteplaysforteam(E, A), teamplaysinleague(A, F), teamplaysinleague(D, F) )
# %   | then return 0.14401377549012345;  // std dev = 0,117, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | else if ( teamplaysagainstteam(A, G), athleteplaysforteam(C, D), teamalsoknownas(D, H) )
# %   | | then if ( teamplaysagainstteam(G, H) )
# %   | | | then return 0.11733240341792336;  // std dev = 0,174, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return -0.27291604146888926;  // std dev = 0,298, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else if ( teamalsoknownas(I, A), teamalsoknownas(I, J), teamplaysagainstteam(D, J) )
# %   | | | then return 0.21701722273478855;  // std dev = 0,112, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else if ( teamplaysagainstteam(K, A), teamplaysinleague(A, L) )
# %   | | | | then return 0.22110204215840187;  // std dev = 0,092, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | else if ( teamalsoknownas(A, M), teamalsoknownas(M, N), teamplaysagainstteam(D, N) )
# %   | | | | | then return 0.214914537467528;  // std dev = 0,191, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | | | else return 0.0655795025197799;  // std dev = 1,626, 30,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=20 */
# %   else if ( teamplaysinleague(A, P) )
# %   | then return -0.06446802456388022;  // std dev = 0,090, 53,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=3 */
# %   | else return 0.04323431929425355;  // std dev = 0,339, 17,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=5 */
# WILL Produced-Tree #10
# % FOR teamplayssport(A, B):
# %   if ( athleteplayssport(C, B), athleteplaysforteam(C, D), athleteledsportsteam(E, D) )
# %   then if ( teamalsoknownas(D, F), athleteplaysforteam(E, F), teamplaysinleague(A, G) )
# %   | then if ( teamplaysinleague(D, G) )
# %   | | then return 0.14472759390502557;  // std dev = 0,059, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | | else return -0.23154562751871674;  // std dev = 0,145, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | else if ( athleteplayssport(E, B), teamplaysinleague(A, H), teamplaysinleague(D, H) )
# %   | | then return 0.15232726103535854;  // std dev = 0,080, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | | else if ( teamplaysagainstteam(A, I), teamalsoknownas(I, J) )
# %   | | | then if ( teamplaysagainstteam(A, J), athleteplayssport(E, B) )
# %   | | | | then return 0.1848929792502558;  // std dev = 0,017, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else return -0.13015072441713008;  // std dev = 0,148, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | else if ( teamalsoknownas(K, A) )
# %   | | | | then return 0.00818650551848124;  // std dev = 0,657, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else if ( teamalsoknownas(A, L) )
# %   | | | | | then return 0.0315993497337585;  // std dev = 0,713, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | | | else return 0.15295697974131506;  // std dev = 1,353, 21,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=14 */
# %   else return -0.04497446917953188;  // std dev = 0,166, 61,000 (wgt'ed) examples reached here.  /* #neg=54 #pos=7 */
# Results
#    AUC ROC   = 0.936953
#    AUC PR    = 0.920383
#    CLL	      = -0.338809
#    Precision = 0.822857 at threshold = 0.5
#    Recall    = 0.908517
#    F1        = 0.863568
#
#
# Total learning time: 677.288 seconds
# Total inference time: 7.712 seconds
# AUC ROC: 0.936953
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      68         p = subprocess.Popen(call, shell=True)
# ---> 69         os.waitpid(p.pid, 0)
#      70     except:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-a930b299928b> in <module>()
#       4     [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
#       5     [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
# ----> 6     [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
#
# /home/rodrigoazs/Projetos/TPRE/boostedrevision.py in learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine, trees, verbose)
#     222     '''Train and test a boosted or single tree'''
#     223     delete_model_files()
# --> 224     model = boostsrl.train(background, train_pos, train_neg, train_facts, refine=refine, trees=trees)
#     225     will = ['WILL Produced-Tree #'+str(i+1)+'\n'+('\n'.join(model.get_will_produced_tree(treenumber=i+1))) for i in range(trees)]
#     226     if verbose:
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in __init__(self, background, train_pos, train_neg, train_facts, refine, save, advice, softm, alpha, beta, trees)
#     249         CALL = '(cd boostsrl; java -jar v1-0.jar -l ' + ('-refine refine.txt ' if refine else '') + combine + '-train train/ -target ' + ','.join(self.target) + \
#     250                ' -trees ' + str(self.trees) + ' > train_output.txt 2>&1)'
# --> 251         call_process(CALL)
#     252
#     253     def tree(self, treenumber, target, image=False):
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      69         os.waitpid(p.pid, 0)
#      70     except:
# ---> 71         raise(Exception('Encountered problems while running process: ', call))
#      72
#      73 def inspect_mode_syntax(example):
#
# Exception: ('Encountered problems while running process: ', '(cd boostsrl; java -jar v1-0.jar -l -combine -train train/ -target teamplayssport -trees 10 > train_output.txt 2>&1)')

# %%
target = 'teamalsoknownas'

bk = ['athleteledsportsteam(+athlete,+sportsteam).',
    'athleteledsportsteam(+athlete,-sportsteam).',
    'athleteledsportsteam(-athlete,+sportsteam).',
    'athleteplaysforteam(+athlete,+sportsteam).',
    'athleteplaysforteam(+athlete,-sportsteam).',
    'athleteplaysforteam(-athlete,+sportsteam).',
    'athleteplaysinleague(+athlete,+sportsleague).',
    'athleteplaysinleague(+athlete,-sportsleague).',
    'athleteplaysinleague(-athlete,+sportsleague).',
    'athleteplayssport(+athlete,+sport).',
    'athleteplayssport(+athlete,-sport).',
    'athleteplayssport(-athlete,+sport).',
    'teamalsoknownas(+sportsteam,+sportsteam).',
    'teamalsoknownas(+sportsteam,-sportsteam).',
    'teamalsoknownas(-sportsteam,+sportsteam).',
    'teamplaysagainstteam(+sportsteam,+sportsteam).',
    'teamplaysagainstteam(+sportsteam,-sportsteam).',
    'teamplaysagainstteam(-sportsteam,+sportsteam).',
    'teamplaysinleague(+sportsteam,+sportsleague).',
    'teamplaysinleague(+sportsteam,-sportsleague).',
    'teamplaysinleague(-sportsteam,+sportsleague).',
    'teamplayssport(+sportsteam,+sport).',
    'teamplayssport(+sportsteam,-sport).',
    'teamplayssport(-sportsteam,+sport).']

[facts, pos, neg] = datasets.load('nell_sports', bk, target=target)

pos = datasets.split_into_folds(pos[0])
neg = datasets.split_into_folds(neg[0])

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(1):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(C, B), teamplaysagainstteam(C, D), teamplayssport(D, E) )
# %   then if ( teamplaysagainstteam(A, C), teamplaysagainstteam(A, D), teamplaysagainstteam(B, D) )
# %   | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | else return -0.1418510649004877;  // std dev = 3,49e-08, 35,000 (wgt'ed) examples reached here.  /* #neg=35 */
# %   else if ( teamplayssport(B, F), teamplaysinleague(B, G) )
# %   | then return 0.7391013160518923;  // std dev = 0,324, 42,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=37 */
# %   | else if ( teamplaysinleague(A, H), teamplayssport(A, I) )
# %   | | then if ( athleteplaysinleague(J, H), teamplaysinleague(K, H), athleteledsportsteam(L, K) )
# %   | | | then return -0.030739953789376676;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else if ( teamplayssport(B, M) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | else if ( teamplaysinleague(B, H) )
# %   | | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | else if ( teamplaysagainstteam(N, A) )
# %   | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return -0.016851064900487787;  // std dev = 0,331, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# WILL Produced-Tree #2
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(C, B), teamplaysagainstteam(C, D), teamplayssport(D, E) )
# %   then return 0.015375036594832985;  // std dev = 0,315, 42,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=7 */
# %   else if ( teamplayssport(B, F), teamplaysinleague(B, G) )
# %   | then if ( teamplaysagainstteam(A, H), teamplayssport(I, F), teamplaysagainstteam(I, A) )
# %   | | then return 0.07619558084592319;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else return 0.6659391705895132;  // std dev = 0,266, 39,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=36 */
# %   | else if ( teamplaysinleague(A, J), teamplayssport(A, K) )
# %   | | then if ( athleteplaysinleague(L, J), teamplaysinleague(M, J), athleteledsportsteam(N, M) )
# %   | | | then return -0.027039036105351237;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else if ( teamplayssport(B, P) )
# %   | | | | then return 0.7194734122109545;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | else if ( teamplaysinleague(B, J) )
# %   | | | | | then return 0.5170719622367217;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.4136573287083127;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | else if ( teamplayssport(B, Q) )
# %   | | | then return 0.1845270641581451;  // std dev = 0,828, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return -0.02155773922603032;  // std dev = 0,323, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# WILL Produced-Tree #3
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(C, B), teamplaysagainstteam(C, D), teamplayssport(D, E) )
# %   then if ( teamplaysagainstteam(A, C), teamplaysagainstteam(A, D), teamplaysagainstteam(B, D) )
# %   | then return 0.7163598014530211;  // std dev = 4,21e-08, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | else return -0.1271411437851588;  // std dev = 0,000, 35,000 (wgt'ed) examples reached here.  /* #neg=35 */
# %   else if ( teamplayssport(B, F), teamplayssport(G, F), athleteledsportsteam(H, G) )
# %   | then if ( athleteplayssport(H, F) )
# %   | | then return 0.20059355747402707;  // std dev = 0,444, 15,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=8 */
# %   | | else return 0.6015561660323353;  // std dev = 0,129, 32,000 (wgt'ed) examples reached here.  /* #pos=32 */
# %   | else if ( teamplaysinleague(A, I), teamplaysinleague(B, I) )
# %   | | then return 0.5259174066529965;  // std dev = 0,360, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | else if ( teamplayssport(A, J), teamplaysinleague(A, K) )
# %   | | | then if ( teamplaysinleague(B, L) )
# %   | | | | then return -0.16564863629204168;  // std dev = 0,137, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | | else if ( teamplaysagainstteam(A, M), teamplaysinleague(M, K) )
# %   | | | | | then return 0.1472270320841097;  // std dev = 1,124, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | | | else return 0.4039130662725589;  // std dev = 1,664, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | | else return -0.173722691138963;  // std dev = 0,087, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# WILL Produced-Tree #4
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(C, B), teamplaysagainstteam(C, D), teamplayssport(D, E) )
# %   then return -0.0026833887319929;  // std dev = 0,248, 42,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=7 */
# %   else if ( teamplayssport(B, F), teamplayssport(G, F), athleteledsportsteam(H, G) )
# %   | then if ( athleteplayssport(H, F), teamplaysinleague(A, I), athleteplaysinleague(J, I) )
# %   | | then return -0.319578483128057;  // std dev = 0,262, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else return 0.4580639187930222;  // std dev = 0,121, 41,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=40 */
# %   | else if ( teamplaysinleague(A, K), teamplaysinleague(B, K) )
# %   | | then return 0.40489146745392207;  // std dev = 0,365, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | else if ( teamplayssport(A, L), teamplaysinleague(A, M) )
# %   | | | then if ( athleteplaysinleague(N, M), teamplaysinleague(P, M), athleteledsportsteam(Q, P) )
# %   | | | | then if ( athleteplayssport(N, L) )
# %   | | | | | then return 0.19235023069854404;  // std dev = 0,802, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return -0.1312958743369534;  // std dev = 0,040, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | | else if ( athleteplaysforteam(R, A) )
# %   | | | | | then return 0.32774837156204817;  // std dev = 0,794, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.2470661505913257;  // std dev = 1,715, 13,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=8 */
# %   | | | else return -0.15131758665000336;  // std dev = 0,080, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# WILL Produced-Tree #5
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(C, B), teamplaysagainstteam(C, D), teamplayssport(D, E) )
# %   then if ( teamplaysagainstteam(A, C), teamplaysagainstteam(A, D), teamplaysagainstteam(B, D) )
# %   | then return 0.553000051582794;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | else return -0.11341729110855522;  // std dev = 2,11e-08, 35,000 (wgt'ed) examples reached here.  /* #neg=35 */
# %   else if ( teamplayssport(B, F), teamplayssport(G, F), athleteledsportsteam(H, G) )
# %   | then if ( athleteplayssport(H, F), teamplaysinleague(B, I) )
# %   | | then return 0.008103859396632258;  // std dev = 0,372, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | else return 0.3184054955746602;  // std dev = 0,160, 40,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=37 */
# %   | else if ( teamplaysinleague(A, J), teamplaysinleague(B, J) )
# %   | | then return 0.3073845950226544;  // std dev = 0,368, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | | else if ( teamplayssport(A, K), teamplaysinleague(A, L) )
# %   | | | then if ( teamplaysinleague(B, M) )
# %   | | | | then return -0.15103373687373436;  // std dev = 0,175, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | | else if ( teamplaysagainstteam(A, N), teamplayssport(N, K), athleteplaysinleague(P, L) )
# %   | | | | | then return 0.39444176079263477;  // std dev = 0,730, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.16811802613956908;  // std dev = 1,845, 16,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=9 */
# %   | | | else return -0.13373455092557374;  // std dev = 0,074, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# WILL Produced-Tree #6
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(A, B) )
# %   then return 0.44161434402645927;  // std dev = 0,063, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   else if ( teamplaysagainstteam(C, B) )
# %   | then return -0.08810677104405466;  // std dev = 0,085, 36,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=1 */
# %   | else if ( teamplayssport(B, D), teamplayssport(E, D), athleteledsportsteam(F, E) )
# %   | | then if ( athleteplayssport(F, G), teamplayssport(A, G) )
# %   | | | then return -0.2593219956480966;  // std dev = 0,154, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else if ( teamplayssport(A, H) )
# %   | | | | then return 0.3123461574420037;  // std dev = 0,060, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | | else return 0.21245567880695604;  // std dev = 0,220, 23,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=20 */
# %   | | else if ( teamplayssport(A, I), teamplaysinleague(A, J) )
# %   | | | then if ( teamplaysinleague(B, K), athleteplayssport(L, I), athleteledsportsteam(L, M) )
# %   | | | | then return -0.12775531746915253;  // std dev = 0,668, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else if ( teamplaysagainstteam(A, N), teamplaysinleague(N, J) )
# %   | | | | | then return 0.03317007635805171;  // std dev = 1,090, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# %   | | | | | else return 0.2117472173704565;  // std dev = 1,744, 18,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=13 */
# %   | | | else return -0.11962177591645091;  // std dev = 0,068, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# WILL Produced-Tree #7
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(C, B), teamplaysagainstteam(C, D), teamplayssport(D, E) )
# %   then return -0.023638133390618373;  // std dev = 0,160, 42,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=7 */
# %   else if ( teamplayssport(B, F), teamplaysinleague(B, G), teamplaysinleague(A, G) )
# %   | then return 0.2629794258473591;  // std dev = 0,057, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# %   | else if ( teamplayssport(B, H), athleteplayssport(I, H), athleteplaysforteam(I, J) )
# %   | | then if ( teamplaysinleague(B, K) )
# %   | | | then return -0.2858105562076784;  // std dev = 0,185, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else if ( teamplayssport(A, L) )
# %   | | | | then return 0.1791503293286287;  // std dev = 0,344, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | else return -0.016237229099642553;  // std dev = 0,771, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else if ( teamplayssport(B, M) )
# %   | | | then return 0.2305165829148918;  // std dev = 0,110, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | | | else if ( athleteplaysforteam(N, A), teamplaysagainstteam(A, P), athleteledsportsteam(N, P) )
# %   | | | | then return 0.26410433927904936;  // std dev = 0,732, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( teamplayssport(A, Q), athleteplayssport(R, Q), athleteledsportsteam(R, S) )
# %   | | | | | then return -0.09364619164466909;  // std dev = 1,040, 11,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=2 */
# %   | | | | | else return 0.08686775227092713;  // std dev = 1,778, 21,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=11 */
# WILL Produced-Tree #8
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(A, B) )
# %   then return 0.33377601807200713;  // std dev = 0,095, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   else if ( teamplaysagainstteam(C, B) )
# %   | then return -0.07778646800087158;  // std dev = 0,088, 36,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=1 */
# %   | else if ( teamplayssport(B, D), teamplaysinleague(B, E) )
# %   | | then if ( teamplaysinleague(A, F), athleteplaysinleague(G, F) )
# %   | | | then return 0.06025441614509709;  // std dev = 0,203, 16,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=11 */
# %   | | | else return 0.20453092225716857;  // std dev = 0,199, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | else if ( teamplayssport(A, H), teamplaysinleague(A, I) )
# %   | | | then if ( teamplaysinleague(B, J), athleteplayssport(K, H), athleteledsportsteam(K, L) )
# %   | | | | then return -0.21515560153155422;  // std dev = 0,427, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | | else if ( teamplaysagainstteam(A, M), teamplaysinleague(M, I), athleteplaysinleague(N, I) )
# %   | | | | | then return -0.014886806356067215;  // std dev = 0,784, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   | | | | | else return 0.14695783852310518;  // std dev = 1,894, 23,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=17 */
# %   | | | else if ( teamplayssport(B, P) )
# %   | | | | then return -0.012609915632968057;  // std dev = 0,771, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return -0.09001729316529303;  // std dev = 0,041, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# WILL Produced-Tree #9
# % FOR teamalsoknownas(A, B):
# %   if ( athleteplaysforteam(C, A), teamplaysinleague(B, D), athleteplaysinleague(E, D) )
# %   then if ( athleteplaysforteam(E, A) )
# %   | then return 0.2666302496294007;  // std dev = 0,084, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | else return 0.024328691301285652;  // std dev = 0,490, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   else if ( teamplaysagainstteam(F, B), teamplaysinleague(B, G) )
# %   | then return -0.08633339724470741;  // std dev = 0,000, 31,000 (wgt'ed) examples reached here.  /* #neg=31 */
# %   | else if ( teamplayssport(B, H), teamplayssport(I, H), athleteledsportsteam(J, I) )
# %   | | then if ( athleteplayssport(J, H), teamplaysinleague(A, K) )
# %   | | | then return 0.013725927020225395;  // std dev = 0,235, 13,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=7 */
# %   | | | else return 0.16410863324430627;  // std dev = 0,124, 34,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=33 */
# %   | | else if ( teamplaysinleague(A, L), teamplaysinleague(M, L), teamplayssport(M, N) )
# %   | | | then if ( athleteplaysforteam(P, A), athleteplayssport(Q, N), athleteplaysinleague(Q, L) )
# %   | | | | then return 0.19078444947980333;  // std dev = 0,740, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( athleteplaysinleague(R, L) )
# %   | | | | | then return -0.1376420707716745;  // std dev = 0,128, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | | | else return 0.0648281389371779;  // std dev = 1,984, 23,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=15 */
# %   | | | else return -0.08293010790844936;  // std dev = 0,038, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# WILL Produced-Tree #10
# % FOR teamalsoknownas(A, B):
# %   if ( teamplaysagainstteam(C, B), teamplayssport(B, D), athleteplayssport(E, D) )
# %   then return -0.03988688515837121;  // std dev = 0,100, 35,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=5 */
# %   else if ( teamplayssport(B, F) )
# %   | then if ( teamplaysagainstteam(A, G), athleteplayssport(H, F), athleteledsportsteam(H, I) )
# %   | | then return -0.19205134219663564;  // std dev = 0,096, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else return 0.135490088688211;  // std dev = 0,162, 47,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=43 */
# %   | else if ( teamplaysinleague(B, J), teamplayssport(A, K) )
# %   | | then if ( teamplaysinleague(A, J) )
# %   | | | then return 0.05406485741537523;  // std dev = 0,695, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else return -0.12443034982417868;  // std dev = 0,108, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else if ( athleteplaysforteam(L, A), teamplaysagainstteam(A, M), athleteledsportsteam(L, M) )
# %   | | | then return 0.27861669346974793;  // std dev = 0,541, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( teamplaysinleague(A, N) )
# %   | | | | then if ( athleteplaysinleague(P, N), teamplaysinleague(Q, N), athleteledsportsteam(R, Q) )
# %   | | | | | then return -0.15257543983644678;  // std dev = 0,139, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | | | else return 0.06660530559591044;  // std dev = 1,822, 18,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=11 */
# %   | | | | else return -0.07175747576118682;  // std dev = 0,014, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# Results
#    AUC ROC   = 0.907549
#    AUC PR    = 0.912954
#    CLL	      = -0.407369
#    Precision = 0.800738 at threshold = 0.5
#    Recall    = 0.861111
#    F1        = 0.829828
#
#
# Total learning time: 101.561 seconds
# Total inference time: 2.377 seconds
# AUC ROC: 0.907549

# %%
from datasets.get_datasets import *
from boostedrevision import *
from boostsrl import boostsrl
import random

# %% [markdown]
# ## Dataset

# %%
target = 'accounttype'

bk = ['accounttype(+account,+type).',
      'accounttype(+account,-type).',
      'accounttype(-account,+type).',
      'tweets(+account,+word).',
      'tweets(+account,-word).',
      'tweets(-account,+word).',
      'follows(+account,+account).',
      'follows(+account,-account).',
      'follows(-account,+account).']

[facts, pos, neg] = datasets.load('twitter', bk, target=target)

# %% [markdown]
# ## Background  configuration

# %%
background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Learning

# %%
for i in range(len(pos)):
    [train_facts, test_facts] = datasets.get_kfold_small(i, facts)
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      68         p = subprocess.Popen(call, shell=True)
# ---> 69         os.waitpid(p.pid, 0)
#      70     except:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-259394e1ab0e> in <module>()
#       3     [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
#       4     [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
# ----> 5     [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
#
# /home/rodrigoazs/Projetos/TPRE/boostedrevision.py in learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine, trees, verbose)
#     222     '''Train and test a boosted or single tree'''
#     223     delete_model_files()
# --> 224     model = boostsrl.train(background, train_pos, train_neg, train_facts, refine=refine, trees=trees)
#     225     will = ['WILL Produced-Tree #'+str(i+1)+'\n'+('\n'.join(model.get_will_produced_tree(treenumber=i+1))) for i in range(trees)]
#     226     if verbose:
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in __init__(self, background, train_pos, train_neg, train_facts, refine, save, advice, softm, alpha, beta, trees)
#     249         CALL = '(cd boostsrl; java -jar v1-0.jar -l ' + ('-refine refine.txt ' if refine else '') + combine + '-train train/ -target ' + ','.join(self.target) + \
#     250                ' -trees ' + str(self.trees) + ' > train_output.txt 2>&1)'
# --> 251         call_process(CALL)
#     252
#     253     def tree(self, treenumber, target, image=False):
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      69         os.waitpid(p.pid, 0)
#      70     except:
# ---> 71         raise(Exception('Encountered problems while running process: ', call))
#      72
#      73 def inspect_mode_syntax(example):
#
# Exception: ('Encountered problems while running process: ', '(cd boostsrl; java -jar v1-0.jar -l -combine -train train/ -target accounttype -trees 10 > train_output.txt 2>&1)')

# %% [markdown]
# ## Tweets

# %%
target = 'tweets'

bk = ['accounttype(+account,+type).',
      'accounttype(+account,-type).',
      'accounttype(-account,+type).',
      'tweets(+account,+word).',
      'tweets(+account,-word).',
      'tweets(-account,+word).',
      'follows(+account,+account).',
      'follows(+account,-account).',
      'follows(-account,+account).']

[facts, pos, neg] = datasets.load('twitter', bk, target=target)

# %%
background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %%
for i in range(len(pos)):
    [train_facts, test_facts] = datasets.get_kfold_small(i, facts)
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(A, D), follows(D, C) )
# %   | | then return 0.35814893509950757;  // std dev = 0,500, 924,000 (wgt'ed) examples reached here.  /* #neg=462 #pos=462 */
# %   | | else if ( follows(A, E), follows(C, E) )
# %   | | | then return 0.3581489350995117;  // std dev = 0,500, 42,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=21 */
# %   | | | else return 0.3581489350995113;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | else if ( follows(C, F) )
# %   | | then if ( follows(F, A) )
# %   | | | then return 0.3581489350995123;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else if ( follows(A, F) )
# %   | | | | then if ( follows(F, C) )
# %   | | | | | then return 0.35814893509951135;  // std dev = 3,391, 46,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=23 */
# %   | | | | | else return 0.35814893509951234;  // std dev = 2,915, 34,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=17 */
# %   | | | | else return 0.35814893509951223;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | | else return 0.3581489350995112;  // std dev = 0,500, 60,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=30 */
# %   else return 0.3581489350995135;  // std dev = 0,500, 148,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=74 */
# WILL Produced-Tree #2
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(C, D), follows(D, A) )
# %   | | then if ( follows(D, C) )
# %   | | | then if ( follows(A, D), accounttype(A, E), accounttype(C, E) )
# %   | | | | then if ( accounttype(D, E) )
# %   | | | | | then return 0.3087411357856286;  // std dev = 10,770, 464,000 (wgt'ed) examples reached here.  /* #neg=232 #pos=232 */
# %   | | | | | else return 0.30874113578563767;  // std dev = 7,211, 208,000 (wgt'ed) examples reached here.  /* #neg=104 #pos=104 */
# %   | | | | else return 0.3087411357856351;  // std dev = 0,500, 98,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=49 */
# %   | | | else if ( follows(A, D) )
# %   | | | | then if ( follows(A, F), follows(D, F) )
# %   | | | | | then return 0.308741135785636;  // std dev = 2,449, 24,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=12 */
# %   | | | | | else return 0.3087411357856358;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.3087411357856347;  // std dev = 0,500, 28,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=14 */
# %   | | else return 0.30874113578563755;  // std dev = 0,500, 188,000 (wgt'ed) examples reached here.  /* #neg=94 #pos=94 */
# %   | else return 0.30874113578563744;  // std dev = 0,500, 186,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=93 */
# %   else return 0.30874113578563733;  // std dev = 0,500, 148,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=74 */
# WILL Produced-Tree #3
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(A, D), follows(D, C) )
# %   | | then if ( follows(C, D) )
# %   | | | then return 0.2564123687585748;  // std dev = 0,500, 894,000 (wgt'ed) examples reached here.  /* #neg=447 #pos=447 */
# %   | | | else if ( follows(D, A) )
# %   | | | | then if ( follows(A, E), follows(C, E) )
# %   | | | | | then return 0.25641236875858725;  // std dev = 2,000, 16,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=8 */
# %   | | | | | else return 0.2564123687585872;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.25641236875858686;  // std dev = 0,500, 10,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=5 */
# %   | | else if ( accounttype(A, F), accounttype(C, F) )
# %   | | | then if ( follows(C, G), follows(G, A) )
# %   | | | | then return 0.25641236875858703;  // std dev = 0,500, 34,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=17 */
# %   | | | | else return 0.2564123687585862;  // std dev = 0,500, 16,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=8 */
# %   | | | else return 0.25641236875858575;  // std dev = 0,500, 40,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=20 */
# %   | else return 0.2564123687585883;  // std dev = 0,500, 186,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=93 */
# %   else return 0.2564123687585881;  // std dev = 0,500, 148,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=74 */
# WILL Produced-Tree #4
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then if ( follows(C, D), follows(D, A) )
# %   | | then return 0.2061374073445514;  // std dev = 0,500, 826,000 (wgt'ed) examples reached here.  /* #neg=413 #pos=413 */
# %   | | else if ( follows(A, E), follows(C, E) )
# %   | | | then if ( follows(E, C) )
# %   | | | | then if ( accounttype(A, F), accounttype(E, F) )
# %   | | | | | then return 0.20613740734454217;  // std dev = 3,674, 54,000 (wgt'ed) examples reached here.  /* #neg=27 #pos=27 */
# %   | | | | | else return 0.20613740734454217;  // std dev = 4,123, 68,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=34 */
# %   | | | | else if ( follows(E, G) )
# %   | | | | | then return 0.2061374073445401;  // std dev = 1,732, 12,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=6 */
# %   | | | | | else return 0.2061374073445394;  // std dev = 1,581, 10,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=5 */
# %   | | | else return 0.20613740734453964;  // std dev = 0,500, 44,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=22 */
# %   | else return 0.20613740734454133;  // std dev = 0,500, 202,000 (wgt'ed) examples reached here.  /* #neg=101 #pos=101 */
# %   else if ( follows(A, H), follows(H, I) )
# %   | then return 0.20613740734453861;  // std dev = 0,500, 80,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=40 */
# %   | else return 0.20613740734453861;  // std dev = 0,500, 52,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=26 */
# WILL Produced-Tree #5
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(A, D), follows(C, D) )
# %   | | then if ( follows(D, C) )
# %   | | | then if ( follows(D, A) )
# %   | | | | then return 0.16162857548414486;  // std dev = 0,500, 752,000 (wgt'ed) examples reached here.  /* #neg=376 #pos=376 */
# %   | | | | else return 0.1616285754841493;  // std dev = 0,500, 142,000 (wgt'ed) examples reached here.  /* #neg=71 #pos=71 */
# %   | | | else return 0.1616285754841452;  // std dev = 0,500, 72,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=36 */
# %   | | else return 0.16162857548414591;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | else if ( follows(C, E) )
# %   | | then if ( follows(E, A) )
# %   | | | then return 0.1616285754841453;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else if ( follows(A, E) )
# %   | | | | then return 0.1616285754841457;  // std dev = 0,500, 80,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=40 */
# %   | | | | else return 0.161628575484146;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | | else return 0.16162857548414628;  // std dev = 0,500, 60,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=30 */
# %   else return 0.1616285754841443;  // std dev = 0,500, 148,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=74 */
# WILL Produced-Tree #6
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(A, D), follows(C, D) )
# %   | | then return 0.12455597792082067;  // std dev = 0,500, 966,000 (wgt'ed) examples reached here.  /* #neg=483 #pos=483 */
# %   | | else return 0.12455597792081911;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | else if ( follows(C, E) )
# %   | | then if ( follows(A, E) )
# %   | | | then if ( follows(E, C) )
# %   | | | | then if ( follows(F, A) )
# %   | | | | | then return 0.12455597792081884;  // std dev = 2,550, 26,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=13 */
# %   | | | | | else return 0.12455597792081911;  // std dev = 2,646, 28,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=14 */
# %   | | | | else if ( follows(E, G) )
# %   | | | | | then return 0.12455597792081904;  // std dev = 1,871, 14,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=7 */
# %   | | | | | else return 0.12455597792081867;  // std dev = 2,236, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   | | | else return 0.124555977920819;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | | else return 0.12455597792081911;  // std dev = 0,500, 60,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=30 */
# %   else return 0.12455597792081889;  // std dev = 0,500, 148,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=74 */
# WILL Produced-Tree #7
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(A, D), follows(C, D) )
# %   | | then return 0.09492800936731205;  // std dev = 0,500, 966,000 (wgt'ed) examples reached here.  /* #neg=483 #pos=483 */
# %   | | else return 0.09492800936730655;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | else if ( follows(C, E) )
# %   | | then if ( follows(E, A) )
# %   | | | then return 0.09492800936730594;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else if ( follows(A, E) )
# %   | | | | then if ( follows(E, C) )
# %   | | | | | then return 0.09492800936730639;  // std dev = 3,391, 46,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=23 */
# %   | | | | | else return 0.09492800936730605;  // std dev = 2,915, 34,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=17 */
# %   | | | | else return 0.09492800936730639;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | | else if ( follows(F, A) )
# %   | | | then return 0.09492800936730594;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else return 0.09492800936730642;  // std dev = 0,500, 52,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=26 */
# %   else return 0.09492800936730614;  // std dev = 0,500, 148,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=74 */
# WILL Produced-Tree #8
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then if ( follows(A, D), follows(C, D) )
# %   | | then if ( follows(D, C) )
# %   | | | then if ( follows(D, A) )
# %   | | | | then if ( accounttype(A, E), accounttype(C, E) )
# %   | | | | | then return 0.07186088850056353;  // std dev = 12,961, 672,000 (wgt'ed) examples reached here.  /* #neg=336 #pos=336 */
# %   | | | | | else return 0.07186088850055919;  // std dev = 4,472, 80,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=40 */
# %   | | | | else return 0.07186088850055906;  // std dev = 0,500, 142,000 (wgt'ed) examples reached here.  /* #neg=71 #pos=71 */
# %   | | | else return 0.0718608885005559;  // std dev = 0,500, 72,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=36 */
# %   | | else return 0.0718608885005587;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | else if ( follows(F, C) )
# %   | | then return 0.07186088850055904;  // std dev = 0,500, 182,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=91 */
# %   | | else return 0.07186088850055765;  // std dev = 0,500, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   else if ( follows(A, G), follows(G, H) )
# %   | then return 0.0718608885005586;  // std dev = 0,500, 80,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=40 */
# %   | else return 0.07186088850055798;  // std dev = 0,500, 52,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=26 */
# WILL Produced-Tree #9
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then if ( follows(C, D), follows(D, A) )
# %   | | then if ( follows(D, C) )
# %   | | | then if ( follows(A, D), accounttype(A, E), accounttype(C, E) )
# %   | | | | then if ( accounttype(D, E) )
# %   | | | | | then return 0.054183073759546764;  // std dev = 10,770, 464,000 (wgt'ed) examples reached here.  /* #neg=232 #pos=232 */
# %   | | | | | else return 0.05418307375954645;  // std dev = 7,211, 208,000 (wgt'ed) examples reached here.  /* #neg=104 #pos=104 */
# %   | | | | else return 0.05418307375954925;  // std dev = 0,500, 98,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=49 */
# %   | | | else return 0.05418307375954651;  // std dev = 0,500, 56,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=28 */
# %   | | else if ( follows(A, F), follows(F, C) )
# %   | | | then return 0.05418307375954993;  // std dev = 0,500, 132,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=66 */
# %   | | | else return 0.05418307375954937;  // std dev = 0,500, 56,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=28 */
# %   | else if ( follows(G, C) )
# %   | | then return 0.05418307375954785;  // std dev = 0,500, 182,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=91 */
# %   | | else return 0.05418307375954878;  // std dev = 0,500, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   else return 0.054183073759549116;  // std dev = 0,500, 132,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=66 */
# WILL Produced-Tree #10
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(A, D), follows(D, C) )
# %   | | then return 0.04076025323305949;  // std dev = 0,500, 924,000 (wgt'ed) examples reached here.  /* #neg=462 #pos=462 */
# %   | | else return 0.04076025323305506;  // std dev = 0,500, 90,000 (wgt'ed) examples reached here.  /* #neg=45 #pos=45 */
# %   | else if ( follows(C, E) )
# %   | | then if ( follows(E, A) )
# %   | | | then return 0.040760253233055765;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else if ( follows(A, E) )
# %   | | | | then if ( follows(E, C) )
# %   | | | | | then return 0.0407602532330562;  // std dev = 3,391, 46,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=23 */
# %   | | | | | else return 0.04076025323305588;  // std dev = 2,915, 34,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=17 */
# %   | | | | else return 0.04076025323305587;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | | else if ( follows(F, A) )
# %   | | | then return 0.040760253233055765;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else return 0.040760253233056355;  // std dev = 0,500, 52,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=26 */
# %   else return 0.040760253233055564;  // std dev = 0,500, 148,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=74 */
# Results
#    AUC ROC   = 0.5
#    AUC PR    = 0.5
#    CLL	      = -0.695026
#    Precision = nan at threshold = 0.5
#    Recall    = 0.0
#    F1        = nan
#
#
# Total learning time: 432.976 seconds
# Total inference time: 1.938 seconds
# AUC ROC: 0.5
#
#
# WILL Produced-Tree #1
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then return 0.35814893509950757;  // std dev = 0,500, 880,000 (wgt'ed) examples reached here.  /* #neg=440 #pos=440 */
# %   | else if ( follows(C, D) )
# %   | | then return 0.3581489350995088;  // std dev = 0,500, 250,000 (wgt'ed) examples reached here.  /* #neg=125 #pos=125 */
# %   | | else return 0.3581489350995131;  // std dev = 0,500, 94,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=47 */
# %   else if ( follows(E, A) )
# %   | then if ( follows(E, F), follows(F, A) )
# %   | | then if ( follows(F, E) )
# %   | | | then if ( accounttype(E, G), accounttype(F, G) )
# %   | | | | then if ( accounttype(A, G) )
# %   | | | | | then return 0.3581489350995112;  // std dev = 3,808, 58,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=29 */
# %   | | | | | else return 0.35814893509951107;  // std dev = 4,123, 68,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=34 */
# %   | | | | else return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | else return 0.35814893509951234;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# WILL Produced-Tree #2
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(C, D), follows(D, A) )
# %   | | then if ( follows(D, C) )
# %   | | | then if ( follows(A, D) )
# %   | | | | then if ( accounttype(C, E), accounttype(D, E) )
# %   | | | | | then return 0.30874113578563767;  // std dev = 8,916, 318,000 (wgt'ed) examples reached here.  /* #neg=159 #pos=159 */
# %   | | | | | else return 0.30874113578563755;  // std dev = 6,633, 176,000 (wgt'ed) examples reached here.  /* #neg=88 #pos=88 */
# %   | | | | else return 0.3087411357856355;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | | | else return 0.3087411357856351;  // std dev = 0,500, 68,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=34 */
# %   | | else if ( follows(A, F), follows(F, C) )
# %   | | | then return 0.3087411357856376;  // std dev = 0,500, 192,000 (wgt'ed) examples reached here.  /* #neg=96 #pos=96 */
# %   | | | else return 0.30874113578563506;  // std dev = 0,500, 78,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=39 */
# %   | else if ( follows(C, G) )
# %   | | then return 0.3087411357856377;  // std dev = 0,500, 250,000 (wgt'ed) examples reached here.  /* #neg=125 #pos=125 */
# %   | | else return 0.30874113578563617;  // std dev = 0,500, 94,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=47 */
# %   else return 0.3087411357856374;  // std dev = 0,500, 172,000 (wgt'ed) examples reached here.  /* #neg=86 #pos=86 */
# WILL Produced-Tree #3
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then if ( follows(C, D), follows(D, A) )
# %   | | then if ( follows(D, C) )
# %   | | | then if ( follows(A, D) )
# %   | | | | then if ( accounttype(C, E), accounttype(D, E) )
# %   | | | | | then return 0.2564123687585887;  // std dev = 8,916, 318,000 (wgt'ed) examples reached here.  /* #neg=159 #pos=159 */
# %   | | | | | else return 0.2564123687585884;  // std dev = 6,633, 176,000 (wgt'ed) examples reached here.  /* #neg=88 #pos=88 */
# %   | | | | else if ( accounttype(C, F), accounttype(D, F) )
# %   | | | | | then return 0.25641236875858725;  // std dev = 2,345, 22,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=11 */
# %   | | | | | else return 0.25641236875858725;  // std dev = 2,550, 26,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=13 */
# %   | | | else if ( follows(A, G), follows(D, G) )
# %   | | | | then return 0.2564123687585876;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | | | | else return 0.2564123687585873;  // std dev = 0,500, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   | | else return 0.25641236875858864;  // std dev = 0,500, 270,000 (wgt'ed) examples reached here.  /* #neg=135 #pos=135 */
# %   | else return 0.25641236875858847;  // std dev = 0,500, 268,000 (wgt'ed) examples reached here.  /* #neg=134 #pos=134 */
# %   else return 0.2564123687585886;  // std dev = 0,500, 248,000 (wgt'ed) examples reached here.  /* #neg=124 #pos=124 */
# WILL Produced-Tree #4
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then return 0.2061374073445392;  // std dev = 0,500, 880,000 (wgt'ed) examples reached here.  /* #neg=440 #pos=440 */
# %   | else if ( follows(C, D) )
# %   | | then return 0.20613740734454147;  // std dev = 0,500, 250,000 (wgt'ed) examples reached here.  /* #neg=125 #pos=125 */
# %   | | else if ( follows(E, A) )
# %   | | | then if ( accounttype(C, F), accounttype(E, F) )
# %   | | | | then return 0.20613740734453864;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | | | | else return 0.20613740734453895;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else return 0.20613740734453861;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   else if ( follows(G, A) )
# %   | then if ( follows(G, H), follows(H, A) )
# %   | | then if ( follows(H, G) )
# %   | | | then return 0.20613740734454047;  // std dev = 0,500, 132,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=66 */
# %   | | | else return 0.20613740734453878;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.2061374073445388;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | else return 0.20613740734453861;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# WILL Produced-Tree #5
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then return 0.16162857548414442;  // std dev = 0,500, 880,000 (wgt'ed) examples reached here.  /* #neg=440 #pos=440 */
# %   | else if ( follows(D, C) )
# %   | | then if ( follows(D, A) )
# %   | | | then return 0.16162857548414444;  // std dev = 0,500, 184,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=92 */
# %   | | | else if ( follows(A, E) )
# %   | | | | then if ( follows(E, D) )
# %   | | | | | then return 0.161628575484146;  // std dev = 2,828, 32,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=16 */
# %   | | | | | else return 0.161628575484146;  // std dev = 2,449, 24,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=12 */
# %   | | | | else return 0.16162857548414578;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | else return 0.161628575484146;  // std dev = 0,500, 22,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=11 */
# %   else if ( follows(A, F) )
# %   | then if ( follows(F, G) )
# %   | | then return 0.16162857548414447;  // std dev = 0,500, 180,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=90 */
# %   | | else return 0.161628575484146;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | else return 0.16162857548414594;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# WILL Produced-Tree #6
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then return 0.12455597792081481;  // std dev = 0,500, 880,000 (wgt'ed) examples reached here.  /* #neg=440 #pos=440 */
# %   | else if ( follows(D, C) )
# %   | | then if ( follows(D, A) )
# %   | | | then if ( follows(E, D), follows(C, E), follows(E, A) )
# %   | | | | then return 0.12455597792082047;  // std dev = 0,500, 138,000 (wgt'ed) examples reached here.  /* #neg=69 #pos=69 */
# %   | | | | else return 0.12455597792081904;  // std dev = 0,500, 46,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=23 */
# %   | | | else return 0.12455597792081939;  // std dev = 0,500, 62,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=31 */
# %   | | else return 0.124555977920819;  // std dev = 0,500, 22,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=11 */
# %   else if ( follows(A, F) )
# %   | then if ( follows(F, G) )
# %   | | then if ( follows(A, G) )
# %   | | | then return 0.1245559779208201;  // std dev = 0,500, 92,000 (wgt'ed) examples reached here.  /* #neg=46 #pos=46 */
# %   | | | else return 0.12455597792082006;  // std dev = 0,500, 88,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=44 */
# %   | | else return 0.124555977920819;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | else return 0.12455597792081896;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# WILL Produced-Tree #7
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then return 0.09492800936731711;  // std dev = 0,500, 880,000 (wgt'ed) examples reached here.  /* #neg=440 #pos=440 */
# %   | else if ( follows(D, C) )
# %   | | then if ( follows(D, A) )
# %   | | | then if ( follows(A, E) )
# %   | | | | then return 0.09492800936730643;  // std dev = 0,500, 48,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=24 */
# %   | | | | else return 0.09492800936730612;  // std dev = 0,500, 136,000 (wgt'ed) examples reached here.  /* #neg=68 #pos=68 */
# %   | | | else return 0.09492800936730607;  // std dev = 0,500, 62,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=31 */
# %   | | else return 0.09492800936730639;  // std dev = 0,500, 22,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=11 */
# %   else if ( follows(A, F) )
# %   | then if ( follows(F, G) )
# %   | | then if ( follows(A, G) )
# %   | | | then return 0.09492800936730732;  // std dev = 0,500, 92,000 (wgt'ed) examples reached here.  /* #neg=46 #pos=46 */
# %   | | | else return 0.09492800936730726;  // std dev = 0,500, 88,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=44 */
# %   | | else return 0.09492800936730639;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | else return 0.09492800936730639;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# WILL Produced-Tree #8
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then return 0.0718608885005613;  // std dev = 0,500, 880,000 (wgt'ed) examples reached here.  /* #neg=440 #pos=440 */
# %   | else if ( follows(C, D) )
# %   | | then if ( follows(A, D) )
# %   | | | then return 0.0718608885005589;  // std dev = 0,500, 140,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=70 */
# %   | | | else return 0.07186088850055873;  // std dev = 0,500, 110,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=55 */
# %   | | else return 0.07186088850055858;  // std dev = 0,500, 94,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=47 */
# %   else if ( follows(E, A) )
# %   | then if ( follows(E, F), follows(F, A) )
# %   | | then if ( follows(F, E) )
# %   | | | then if ( accounttype(A, G), accounttype(E, G) )
# %   | | | | then return 0.0718608885005587;  // std dev = 0,500, 112,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=56 */
# %   | | | | else return 0.0718608885005585;  // std dev = 0,500, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   | | | else return 0.0718608885005587;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.07186088850055826;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | else return 0.0718608885005583;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# WILL Produced-Tree #9
# % FOR tweets(A, B):
# %   if ( follows(C, A) )
# %   then if ( follows(A, C) )
# %   | then if ( follows(C, D), follows(D, A) )
# %   | | then if ( follows(D, C) )
# %   | | | then return 0.05418307375954867;  // std dev = 0,500, 542,000 (wgt'ed) examples reached here.  /* #neg=271 #pos=271 */
# %   | | | else return 0.05418307375954933;  // std dev = 0,500, 68,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=34 */
# %   | | else return 0.054183073759547236;  // std dev = 0,500, 270,000 (wgt'ed) examples reached here.  /* #neg=135 #pos=135 */
# %   | else if ( follows(E, C) )
# %   | | then return 0.05418307375954752;  // std dev = 0,500, 246,000 (wgt'ed) examples reached here.  /* #neg=123 #pos=123 */
# %   | | else return 0.054183073759548846;  // std dev = 0,500, 22,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=11 */
# %   else if ( follows(A, F) )
# %   | then if ( follows(F, G) )
# %   | | then if ( follows(A, G) )
# %   | | | then return 0.05418307375954945;  // std dev = 0,500, 92,000 (wgt'ed) examples reached here.  /* #neg=46 #pos=46 */
# %   | | | else return 0.05418307375954943;  // std dev = 0,500, 88,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=44 */
# %   | | else return 0.054183073759549075;  // std dev = 0,500, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | else return 0.05418307375954882;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# WILL Produced-Tree #10
# % FOR tweets(A, B):
# %   if ( follows(A, C) )
# %   then if ( follows(C, A) )
# %   | then if ( follows(C, D), follows(D, A) )
# %   | | then return 0.04076025323305796;  // std dev = 0,500, 610,000 (wgt'ed) examples reached here.  /* #neg=305 #pos=305 */
# %   | | else return 0.040760253233055016;  // std dev = 0,500, 270,000 (wgt'ed) examples reached here.  /* #neg=135 #pos=135 */
# %   | else return 0.040760253233056286;  // std dev = 0,500, 344,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=172 */
# %   else if ( follows(E, A) )
# %   | then if ( follows(E, F), follows(F, A) )
# %   | | then if ( follows(F, E) )
# %   | | | then if ( accounttype(A, G), accounttype(E, G) )
# %   | | | | then if ( accounttype(F, G) )
# %   | | | | | then return 0.040760253233056404;  // std dev = 3,808, 58,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=29 */
# %   | | | | | else return 0.040760253233056376;  // std dev = 3,674, 54,000 (wgt'ed) examples reached here.  /* #neg=27 #pos=27 */
# %   | | | | else return 0.04076025323305651;  // std dev = 0,500, 20,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=10 */
# %   | | | else return 0.04076025323305667;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.04076025323305632;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | else return 0.04076025323305621;  // std dev = 0,500, 30,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=15 */
# Results
#    AUC ROC   = 0.5
#    AUC PR    = 0.5
#    CLL	      = -0.695026
#    Precision = nan at threshold = 0.5
#    Recall    = 0.0
#    F1        = nan
#
#
# Total learning time: 560.935 seconds
# Total inference time: 1.639 seconds
# AUC ROC: 0.5

# %% [markdown]
# ## Follows

# %%
target = 'follows'

bk = ['accounttype(+account,+type).',
      'accounttype(+account,-type).',
      'accounttype(-account,+type).',
      'tweets(+account,+word).',
      'tweets(+account,-word).',
      'tweets(-account,+word).',
      'follows(+account,+account).',
      'follows(+account,-account).',
      'follows(-account,+account).']

[facts, pos, neg] = datasets.load('twitter', bk, target=target)

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(len(pos)):
    [train_facts, test_facts] = datasets.get_kfold_small(i, facts)
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.32332999359533;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.6353886445426075;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(A, E) )
# %   | then if ( accounttype(A, F), accounttype(B, F) )
# %   | | then return 0.12527222277074612;  // std dev = 0,442, 292,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=78 */
# %   | | else if ( tweets(B, G) )
# %   | | | then return 0.2537533307039092;  // std dev = 0,489, 182,000 (wgt'ed) examples reached here.  /* #neg=110 #pos=72 */
# %   | | | else return 0.14981560176617864;  // std dev = 0,455, 72,000 (wgt'ed) examples reached here.  /* #neg=51 #pos=21 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(B, I) )
# %   | | | then return 0.28934159564997186;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.06504548682365029;  // std dev = 0,405, 29,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=6 */
# %   | | else if ( tweets(B, J) )
# %   | | | then return 0.5385613062335338;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | | | else return 0.1438632208137979;  // std dev = 0,452, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# WILL Produced-Tree #2
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.2792501363792812;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.5394093215813847;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(A, E) )
# %   | then if ( accounttype(A, F), accounttype(B, F) )
# %   | | then return 0.10932842680220828;  // std dev = 0,442, 292,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=78 */
# %   | | else if ( tweets(B, G) )
# %   | | | then return 0.21997536862057532;  // std dev = 0,489, 182,000 (wgt'ed) examples reached here.  /* #neg=110 #pos=72 */
# %   | | | else return 0.1305826374806452;  // std dev = 0,455, 72,000 (wgt'ed) examples reached here.  /* #neg=51 #pos=21 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(B, I) )
# %   | | | then return 0.25035142239059655;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.05694161201725068;  // std dev = 0,405, 29,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=6 */
# %   | | else if ( tweets(B, J) )
# %   | | | then return 0.4596860426109287;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | | | else return 0.12543301544918353;  // std dev = 0,452, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# WILL Produced-Tree #3
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.23324653324866684;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.4286404529234367;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(A, E) )
# %   | then if ( accounttype(A, F), accounttype(B, F) )
# %   | | then return 0.09425004758704647;  // std dev = 0,442, 292,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=78 */
# %   | | else if ( tweets(B, G) )
# %   | | | then return 0.1858275909321291;  // std dev = 0,489, 182,000 (wgt'ed) examples reached here.  /* #neg=110 #pos=72 */
# %   | | | else return 0.11214649702022365;  // std dev = 0,455, 72,000 (wgt'ed) examples reached here.  /* #neg=51 #pos=21 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(B, I) )
# %   | | | then return 0.21027160903852193;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.04953777887492802;  // std dev = 0,405, 29,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=6 */
# %   | | else if ( tweets(B, J) )
# %   | | | then return 0.3707616364547131;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | | | else return 0.10782354562777509;  // std dev = 0,452, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# WILL Produced-Tree #4
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.18913765663152196;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.32622249604095294;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(A, E) )
# %   | then if ( accounttype(A, F), accounttype(B, F) )
# %   | | then return 0.08035529922322107;  // std dev = 0,442, 292,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=78 */
# %   | | else if ( tweets(B, G) )
# %   | | | then return 0.1533654909364104;  // std dev = 0,489, 182,000 (wgt'ed) examples reached here.  /* #neg=110 #pos=72 */
# %   | | | else return 0.09503092830334735;  // std dev = 0,455, 72,000 (wgt'ed) examples reached here.  /* #neg=51 #pos=21 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(B, I) )
# %   | | | then return 0.17197435224648763;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.04285719044558163;  // std dev = 0,405, 29,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=6 */
# %   | | else if ( tweets(B, J) )
# %   | | | then return 0.28652265987951103;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | | | else return 0.09150383240113759;  // std dev = 0,452, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# WILL Produced-Tree #5
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.14979026290702482;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.24486981805980457;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(A, E), accounttype(B, F), accounttype(A, F) )
# %   | then return 0.06784225872385179;  // std dev = 0,442, 292,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=78 */
# %   | else if ( tweets(B, G) )
# %   | | then if ( tweets(A, H) )
# %   | | | then if ( accounttype(A, I), accounttype(J, I), tweets(J, G) )
# %   | | | | then if ( tweets(J, H) )
# %   | | | | | then return 0.1552620220825817;  // std dev = 6,197, 157,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=67 */
# %   | | | | | else return -0.021489570274107098;  // std dev = 1,732, 16,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=4 */
# %   | | | | else return -0.16037845916299603;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else if ( accounttype(A, K), accounttype(B, K) )
# %   | | | | then return 0.13761291641748175;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | | else return 0.21646677370479728;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | | else return 0.06794050988204162;  // std dev = 0,442, 108,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=29 */
# WILL Produced-Tree #6
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.11659165331053105;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.18468640148565374;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(A, E), accounttype(B, F), accounttype(A, F) )
# %   | then return 0.05679566843181235;  // std dev = 0,442, 292,000 (wgt'ed) examples reached here.  /* #neg=214 #pos=78 */
# %   | else if ( tweets(B, G) )
# %   | | then if ( tweets(A, H) )
# %   | | | then if ( accounttype(A, I), accounttype(J, I), tweets(J, G) )
# %   | | | | then if ( tweets(J, H) )
# %   | | | | | then return 0.12349041042005404;  // std dev = 6,197, 157,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=67 */
# %   | | | | | else return -0.017260230268151933;  // std dev = 1,732, 16,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=4 */
# %   | | | | else return -0.12984282665820726;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else if ( accounttype(A, K), accounttype(B, K) )
# %   | | | | then return 0.10828649707955408;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | | else return 0.16242053787235622;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | | else return 0.056849472609033586;  // std dev = 0,442, 108,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=29 */
# WILL Produced-Tree #7
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.08967189081625093;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.14096832844419083;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(B, E) )
# %   | then if ( tweets(A, F) )
# %   | | then if ( accounttype(A, G), accounttype(B, G) )
# %   | | | then return 0.05436973582034546;  // std dev = 0,446, 175,000 (wgt'ed) examples reached here.  /* #neg=127 #pos=48 */
# %   | | | else if ( accounttype(A, H), accounttype(I, H), tweets(I, E) )
# %   | | | | then if ( tweets(I, F) )
# %   | | | | | then return 0.09678270665705026;  // std dev = 6,197, 157,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=67 */
# %   | | | | | else return -0.01389372870163869;  // std dev = 1,732, 16,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=4 */
# %   | | | | else return -0.10689914713713239;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | else if ( accounttype(A, J), accounttype(B, J) )
# %   | | | then return 0.08417209890999892;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.12207453718004369;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | else return 0.04164748837716882;  // std dev = 0,439, 225,000 (wgt'ed) examples reached here.  /* #neg=166 #pos=59 */
# WILL Produced-Tree #8
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.06842065388814991;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.10901081900571935;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(B, E) )
# %   | then if ( tweets(A, F) )
# %   | | then if ( accounttype(A, G), accounttype(B, G) )
# %   | | | then return 0.0449005831021371;  // std dev = 0,446, 175,000 (wgt'ed) examples reached here.  /* #neg=127 #pos=48 */
# %   | | | else if ( accounttype(A, H), accounttype(I, H), tweets(I, E) )
# %   | | | | then if ( tweets(I, F) )
# %   | | | | | then return 0.07504431135891587;  // std dev = 6,197, 157,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=67 */
# %   | | | | | else return -0.011203686385122761;  // std dev = 1,732, 16,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=4 */
# %   | | | | else return -0.08922441321125801;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | else if ( accounttype(A, J), accounttype(B, J) )
# %   | | | then return 0.06486167644453979;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.09222102754759359;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | else return 0.0344124291413062;  // std dev = 0,439, 225,000 (wgt'ed) examples reached here.  /* #neg=166 #pos=59 */
# WILL Produced-Tree #9
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.05193472499383744;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.08530149899627872;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(B, E) )
# %   | then if ( tweets(A, F) )
# %   | | then if ( accounttype(A, G), accounttype(B, G) )
# %   | | | then return 0.036867354819393246;  // std dev = 0,446, 175,000 (wgt'ed) examples reached here.  /* #neg=127 #pos=48 */
# %   | | | else if ( accounttype(A, H), accounttype(I, H), tweets(I, E) )
# %   | | | | then if ( tweets(I, F) )
# %   | | | | | then return 0.057749159136371776;  // std dev = 6,197, 157,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=67 */
# %   | | | | | else return -0.009047431606060412;  // std dev = 1,732, 16,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=4 */
# %   | | | | else return -0.07531177130578276;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | else if ( accounttype(A, J), accounttype(B, J) )
# %   | | | then return 0.04967885473545552;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.0700788146525635;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | else return 0.028309354943367733;  // std dev = 0,439, 225,000 (wgt'ed) examples reached here.  /* #neg=166 #pos=59 */
# WILL Produced-Tree #10
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.03928777612396126;  // std dev = 0,499, 359,000 (wgt'ed) examples reached here.  /* #neg=192 #pos=167 */
# %   | else return 0.06742222556450865;  // std dev = 0,416, 413,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=321 */
# %   else if ( tweets(B, E) )
# %   | then if ( tweets(A, F) )
# %   | | then if ( accounttype(A, G), accounttype(B, G) )
# %   | | | then return 0.030128009521169636;  // std dev = 0,446, 175,000 (wgt'ed) examples reached here.  /* #neg=127 #pos=48 */
# %   | | | else if ( accounttype(A, H), accounttype(I, H), tweets(I, E) )
# %   | | | | then if ( tweets(I, F) )
# %   | | | | | then return 0.04420416209585011;  // std dev = 6,197, 157,000 (wgt'ed) examples reached here.  /* #neg=90 #pos=67 */
# %   | | | | | else return -0.007314640066076246;  // std dev = 1,732, 16,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=4 */
# %   | | | | else return -0.06415796111913968;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | else if ( accounttype(A, J), accounttype(B, J) )
# %   | | | then return 0.0378896114214694;  // std dev = 0,495, 109,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=47 */
# %   | | | else return 0.05354680645215623;  // std dev = 0,466, 97,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=66 */
# %   | else return 0.023204288568792718;  // std dev = 0,439, 225,000 (wgt'ed) examples reached here.  /* #neg=166 #pos=59 */
# Results
#    AUC ROC   = 0.730385
#    AUC PR    = 0.70203
#    CLL	      = -0.602132
#    Precision = 0.770021 at threshold = 0.5
#    Recall    = 0.529661
#    F1        = 0.627615
#
#
# Total learning time: 182.279 seconds
# Total inference time: 1.303 seconds
# AUC ROC: 0.730385
#
#
# WILL Produced-Tree #1
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.3104216623722353;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else return 0.6207388631570622;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   else if ( tweets(A, E) )
# %   | then if ( tweets(B, F), accounttype(A, G), accounttype(B, G) )
# %   | | then return -0.04507687135210057;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else if ( tweets(B, H) )
# %   | | | then return 0.2995903765409547;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else if ( accounttype(A, I), accounttype(B, I) )
# %   | | | | then return 0.1273797043302805;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | | else return 0.16767274462332188;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# %   | else if ( accounttype(A, J), accounttype(B, J) )
# %   | | then if ( tweets(B, K) )
# %   | | | then return 0.1634120929942479;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   | | | else return 0.088918165868743;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.672434649385227;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# WILL Produced-Tree #2
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.26828770220423254;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else return 0.5274048562536565;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   else if ( tweets(A, E) )
# %   | then if ( tweets(B, F), accounttype(A, G), accounttype(B, G) )
# %   | | then return -0.039677772042477834;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else if ( tweets(B, H) )
# %   | | | then return 0.25907700357341;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else if ( accounttype(A, I), accounttype(B, I) )
# %   | | | | then return 0.11115563121567716;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | | else return 0.14601200958288355;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# %   | else if ( accounttype(A, J), accounttype(B, J) )
# %   | | then if ( tweets(B, K) )
# %   | | | then return 0.1423332763725481;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   | | | else return 0.07774578121441031;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.5696750276457073;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# WILL Produced-Tree #3
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( accounttype(A, D), accounttype(B, D) )
# %   | then return 0.22456332480457664;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else return 0.42001857731667136;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   else if ( tweets(A, E), accounttype(B, F), accounttype(A, F) )
# %   | then if ( tweets(B, G) )
# %   | | then return -0.035069505775371025;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.09579419157416352;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | else if ( tweets(B, H), accounttype(A, I), accounttype(B, I) )
# %   | | then return 0.1219791686517744;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   | | else if ( tweets(A, J) )
# %   | | | then if ( tweets(B, K) )
# %   | | | | then return 0.21723733230548056;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | | else return 0.12504837641143246;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# %   | | | else if ( tweets(B, L) )
# %   | | | | then return 0.4502499756299776;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | | | | else return 0.06739536297660921;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# WILL Produced-Tree #4
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then return 0.24964276219870896;  // std dev = 0,469, 857,000 (wgt'ed) examples reached here.  /* #neg=340 #pos=517 */
# %   else if ( tweets(A, D), accounttype(B, E), accounttype(A, E) )
# %   | then if ( tweets(B, F) )
# %   | | then return -0.031106983705180776;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.08162919635455543;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | else if ( tweets(B, G) )
# %   | | then if ( accounttype(A, H), accounttype(B, H) )
# %   | | | then return 0.10301069781885405;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   | | | else if ( tweets(A, I) )
# %   | | | | then return 0.17721098528570028;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | | else return 0.3411698485045716;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | | else if ( tweets(A, J) )
# %   | | | then return 0.10548932956099023;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# %   | | | else return 0.0579733820773872;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# WILL Produced-Tree #5
# % FOR follows(A, B):
# %   if ( tweets(B, C), accounttype(A, D), accounttype(B, D) )
# %   then if ( tweets(A, C) )
# %   | then return 0.13081583256867263;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else if ( tweets(A, E) )
# %   | | then return -0.027677669567785973;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.08588001957713456;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   else if ( tweets(B, F) )
# %   | then if ( tweets(A, F) )
# %   | | then return 0.25813878091734377;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   | | else if ( tweets(A, G) )
# %   | | | then return 0.14135458705933585;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else return 0.25616722850984197;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(A, I) )
# %   | | | then return 0.06887003201680404;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | else return 0.049528997355293175;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.08782218798556223;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# WILL Produced-Tree #6
# % FOR follows(A, B):
# %   if ( tweets(B, C), accounttype(A, D), accounttype(B, D) )
# %   then if ( tweets(A, C) )
# %   | then return 0.10164217858029356;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else if ( tweets(A, E) )
# %   | | then return -0.02469302495228808;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.07081900188351425;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   else if ( tweets(B, F) )
# %   | then if ( tweets(A, F) )
# %   | | then return 0.19403840505188916;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   | | else if ( tweets(A, G) )
# %   | | | then return 0.11085408037830394;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else return 0.1942507272828459;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(A, I) )
# %   | | | then return 0.05760797484163206;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | else return 0.04206293300387109;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.07229904665724325;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# WILL Produced-Tree #7
# % FOR follows(A, B):
# %   if ( tweets(B, C), accounttype(A, D), accounttype(B, D) )
# %   then if ( tweets(A, C) )
# %   | then return 0.07816314225475406;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else if ( tweets(A, E) )
# %   | | then return -0.02208249342209084;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.057870293588665224;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   else if ( tweets(B, F) )
# %   | then if ( tweets(A, F) )
# %   | | then return 0.14721037407014145;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   | | else if ( tweets(A, G) )
# %   | | | then return 0.08587867428722323;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else return 0.149666555618741;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(A, I) )
# %   | | | then return 0.04783712226512366;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | else return 0.03553879177151896;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.058969153134612914;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# WILL Produced-Tree #8
# % FOR follows(A, B):
# %   if ( tweets(B, C), accounttype(A, D), accounttype(B, D) )
# %   then if ( tweets(A, C) )
# %   | then return 0.05968873395705641;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else if ( tweets(A, E) )
# %   | | then return -0.01978919381995034;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.046938692322424466;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   else if ( tweets(B, F) )
# %   | then if ( tweets(A, F) )
# %   | | then return 0.11301014343070571;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   | | else if ( tweets(A, G) )
# %   | | | then return 0.06596585306681163;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else return 0.11716716322571377;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(A, I) )
# %   | | | then return 0.03948125962869671;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | else return 0.029894556746069525;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.047734093750073855;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# WILL Produced-Tree #9
# % FOR follows(A, B):
# %   if ( tweets(B, C), accounttype(A, D), accounttype(B, D) )
# %   then if ( tweets(A, C) )
# %   | then return 0.04536768274564491;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else if ( tweets(A, E) )
# %   | | then return -0.0177667864195837;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.0378440714123445;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   else if ( tweets(B, F) )
# %   | then if ( tweets(A, F) )
# %   | | then return 0.0877401622402442;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   | | else if ( tweets(A, G) )
# %   | | | then return 0.05037486128754743;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else return 0.09301346263785536;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(A, I) )
# %   | | | then return 0.03242004672125653;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | else return 0.025052826506284376;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.038404891693387413;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# WILL Produced-Tree #10
# % FOR follows(A, B):
# %   if ( tweets(B, C), accounttype(A, D), accounttype(B, D) )
# %   then if ( tweets(A, C) )
# %   | then return 0.03437440417933066;  // std dev = 0,498, 440,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=199 */
# %   | else if ( tweets(A, E) )
# %   | | then return -0.015977158173243595;  // std dev = 0,296, 124,000 (wgt'ed) examples reached here.  /* #neg=112 #pos=12 */
# %   | | else return 0.030365251686314786;  // std dev = 0,461, 95,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=29 */
# %   else if ( tweets(B, F) )
# %   | then if ( tweets(A, F) )
# %   | | then return 0.06879042234037792;  // std dev = 0,425, 417,000 (wgt'ed) examples reached here.  /* #neg=99 #pos=318 */
# %   | | else if ( tweets(A, G) )
# %   | | | then return 0.038315291908912336;  // std dev = 0,497, 111,000 (wgt'ed) examples reached here.  /* #neg=62 #pos=49 */
# %   | | | else return 0.07470419403974071;  // std dev = 0,389, 70,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=57 */
# %   | else if ( accounttype(A, H), accounttype(B, H) )
# %   | | then if ( tweets(A, I) )
# %   | | | then return 0.02651082262561333;  // std dev = 0,444, 104,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=28 */
# %   | | | else return 0.020929078465113212;  // std dev = 0,421, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | else return 0.030749214914953575;  // std dev = 0,462, 42,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=13 */
# Results
#    AUC ROC   = 0.704365
#    AUC PR    = 0.67343
#    CLL	      = -0.633096
#    Precision = 0.758824 at threshold = 0.5
#    Recall    = 0.496154
#    F1        = 0.6
#
#
# Total learning time: 202.171 seconds
# Total inference time: 1.472 seconds
# AUC ROC: 0.704365

# %%
def load(dataset, bk, target=None, seed=None):
    '''Load dataset from json and accept only predicates presented in bk'''
    pattern = '^(\w+)\(.*\).$'
    accepted = set()
    for line in bk:
        m = re.search(pattern, line)
        if m:
            relation = re.sub('[ _]', '', m.group(1))
            accepted.add(relation)
    data = datasets.get_json_dataset(dataset)
    facts = []
    pos = []
    neg = []
    for i in range(len(data[0])): #positives
        facts.append([])
        pos.append([])
        neg.append([])
        for relation, value in data[0][i].items():
            if relation in accepted or relation == 'accounttype':
                if relation == target or (target in ['fan', 'news', 'club'] and relation == 'accounttype'):
                    for example in value:
                        if relation == 'accounttype':
                            if example[1] == target:
                                pos[i].append(example[1] + '(' + example[0] + ').')
                            else:
                                facts[i].append(example[1] + '(' + example[0] + ').')
                        else:
                            pos[i].append(relation + '(' + ','.join(example)+ ').')
                else:
                    for example in value:
                        if relation == 'accounttype':
                            facts[i].append(example[1] + '(' + example[0] + ').')
                        else:
                            facts[i].append(relation + '(' + ','.join(example)+ ').')
    if target:
        for i in range(len(data[1])): #negatives
            if target in ['fan', 'news', 'club']:
                for j in data[0][i]['accounttype']:
                    if j[1] != target:
                        neg[i].append(target + '(' + j[0] + ').')
    return [facts, pos, neg]

# %%
target = 'fan'

bk = ['fan(+account).',
      'news(+account).',
      'club(+account).',
      'tweets(+account,+word).',
      'tweets(+account,-word).',
      'tweets(-account,+word).',
      'follows(+account,+account).',
      'follows(+account,-account).',
      'follows(-account,+account).']

[facts, pos, neg] = load('twitter', bk, target='fan')

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(len(pos)):
    [train_facts, test_facts] = datasets.get_kfold_small(i, facts)
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR fan(A):
# %   if ( follows(B, A), news(B), tweets(A, C) )
# %   then if ( news(A) )
# %   | then return -0.1418510649004878;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else if ( club(A) )
# %   | | then return -0.1418510649004878;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | | else return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   else if ( follows(D, A), follows(A, D), tweets(A, E) )
# %   | then return 0.8581489350995115;  // std dev = 2,38e-07, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   | else if ( follows(F, A), follows(A, G), news(G) )
# %   | | then if ( news(A) )
# %   | | | then return -0.14185106490048777;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return 0.8581489350995123;  // std dev = 0,000, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | | else if ( tweets(A, H) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | | else if ( follows(A, I), follows(I, J) )
# %   | | | | then return 0.8581489350995123;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | | else return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# WILL Produced-Tree #2
# % FOR fan(A):
# %   if ( follows(B, A), news(B), tweets(A, C) )
# %   then if ( news(A) )
# %   | then return -0.12544463852839138;  // std dev = 5,27e-09, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else if ( follows(A, B) )
# %   | | then if ( tweets(B, C), follows(A, D), club(D) )
# %   | | | then if ( tweets(D, C) )
# %   | | | | then return 0.7194734122109543;  // std dev = 5,96e-08, 17,000 (wgt'ed) examples reached here.  /* #pos=17 */
# %   | | | | else return 0.29701438684128156;  // std dev = 1,035, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else return 0.3815061919152162;  // std dev = 0,926, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else if ( club(A) )
# %   | | | then return -0.12544463852839138;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.7194734122109545;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   else if ( tweets(A, E), follows(A, F), follows(F, A) )
# %   | then return 0.7194734122109548;  // std dev = 0,000, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   | else if ( follows(G, A), follows(A, H), follows(G, H) )
# %   | | then return 0.6042573143828617;  // std dev = 0,290, 22,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=19 */
# %   | | else return 0.6859015593720996;  // std dev = 0,195, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# WILL Produced-Tree #3
# % FOR fan(A):
# %   if ( follows(B, A), news(B), tweets(A, C) )
# %   then if ( news(A) )
# %   | then return -0.11231637819360638;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else if ( follows(A, B) )
# %   | | then if ( tweets(B, C), follows(A, D), club(D) )
# %   | | | then if ( tweets(D, C) )
# %   | | | | then return 0.5553664367462846;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #pos=17 */
# %   | | | | else return 0.247018984736318;  // std dev = 1,001, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else return 0.3124805338637125;  // std dev = 0,887, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else if ( club(A) )
# %   | | | then return -0.11231637819360639;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.5553664367462845;  // std dev = 1,05e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   else if ( follows(E, A), follows(A, E), tweets(A, F) )
# %   | then return 0.5553664367462844;  // std dev = 9,42e-08, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   | else if ( follows(G, A), follows(A, H), news(H) )
# %   | | then return 0.45057804286766934;  // std dev = 0,295, 18,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=15 */
# %   | | else return 0.5401632057959469;  // std dev = 0,181, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# WILL Produced-Tree #4
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( tweets(A, B), follows(C, A), news(C) )
# %   | then return -0.10159632948783628;  // std dev = 3,73e-09, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else return -0.35113279021847327;  // std dev = 0,206, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( tweets(A, D), follows(E, A), news(E) )
# %   | then if ( follows(A, E) )
# %   | | then if ( club(A) )
# %   | | | then return -0.20812560371129424;  // std dev = 0,027, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else if ( follows(A, F), club(F), tweets(F, D) )
# %   | | | | then if ( follows(F, A), tweets(E, D) )
# %   | | | | | then return 0.41751358415830986;  // std dev = 3,33e-08, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | | | else return 0.4536435122756421;  // std dev = 0,229, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | else return 0.5707788854441433;  // std dev = 0,032, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( club(A) )
# %   | | | then return -0.10159632948783628;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.41751358415830997;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.43598038582866544;  // std dev = 0,194, 77,000 (wgt'ed) examples reached here.  /* #pos=77 */
# WILL Produced-Tree #5
# % FOR fan(A):
# %   if ( follows(B, A), news(B), tweets(A, C) )
# %   then if ( news(A) )
# %   | then return -0.09269127618926097;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else if ( club(A) )
# %   | | then return -0.13893174776066566;  // std dev = 0,042, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | | else if ( tweets(B, C), tweets(D, C), club(D) )
# %   | | | then if ( follows(A, D) )
# %   | | | | then return 0.3172364651846509;  // std dev = 0,016, 18,000 (wgt'ed) examples reached here.  /* #pos=18 */
# %   | | | | else return 0.42819294998779744;  // std dev = 0,135, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.4043775636675877;  // std dev = 0,101, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( tweets(A, E), follows(F, A), follows(A, F) )
# %   | then return 0.3167021376912303;  // std dev = 7,60e-08, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   | else if ( follows(G, A), follows(H, G), follows(H, A) )
# %   | | then return 0.358123160626025;  // std dev = 0,041, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | else if ( news(A) )
# %   | | | then return -0.27903573327901715;  // std dev = 0,188, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.3440520072189487;  // std dev = 0,100, 32,000 (wgt'ed) examples reached here.  /* #pos=32 */
# WILL Produced-Tree #6
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( tweets(A, B), follows(C, A), news(C) )
# %   | then return -0.08518475138839687;  // std dev = 3,73e-09, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else return -0.2285521945989053;  // std dev = 0,169, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( club(A) )
# %   | then if ( follows(A, D), club(D) )
# %   | | then return -0.12967939672780324;  // std dev = 0,085, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else return -0.11066402215683634;  // std dev = 0,071, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else if ( tweets(A, E), tweets(F, E), club(F) )
# %   | | then return 0.2607864683669391;  // std dev = 0,220, 75,000 (wgt'ed) examples reached here.  /* #pos=75 */
# %   | | else return 0.28136700047572016;  // std dev = 0,109, 28,000 (wgt'ed) examples reached here.  /* #pos=28 */
# WILL Produced-Tree #7
# % FOR fan(A):
# %   if ( follows(B, A), news(B) )
# %   then if ( club(A) )
# %   | then return -0.11071045441688093;  // std dev = 0,034, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | else if ( news(A) )
# %   | | then return -0.08512302854614555;  // std dev = 0,020, 11,000 (wgt'ed) examples reached here.  /* #neg=11 */
# %   | | else return 0.22706960744449667;  // std dev = 0,034, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   else if ( follows(C, A), club(C) )
# %   | then return 0.2080863548704018;  // std dev = 0,031, 32,000 (wgt'ed) examples reached here.  /* #pos=32 */
# %   | else if ( follows(D, A), follows(E, D), follows(E, A) )
# %   | | then return 0.2138736402635483;  // std dev = 0,033, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else if ( follows(F, A), follows(A, G), news(G) )
# %   | | | then if ( follows(A, F) )
# %   | | | | then return 0.09797594848785474;  // std dev = 0,303, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.14269988876073478;  // std dev = 0,336, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else if ( follows(A, H), follows(H, I) )
# %   | | | | then return 0.21048533409287767;  // std dev = 0,016, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# %   | | | | else return 0.16933897764871325;  // std dev = 0,164, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# WILL Produced-Tree #8
# % FOR fan(A):
# %   if ( follows(B, A), news(B) )
# %   then if ( news(A) )
# %   | then return -0.07875471812189119;  // std dev = 0,019, 11,000 (wgt'ed) examples reached here.  /* #neg=11 */
# %   | else if ( club(A) )
# %   | | then return -0.10038617204618674;  // std dev = 0,032, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | | else return 0.18990972292764963;  // std dev = 0,030, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   else if ( tweets(A, C) )
# %   | then if ( follows(D, A), follows(E, D), follows(A, E) )
# %   | | then if ( club(D) )
# %   | | | then return 0.17443092321467404;  // std dev = 1,49e-08, 25,000 (wgt'ed) examples reached here.  /* #pos=25 */
# %   | | | else return 0.11673963929398007;  // std dev = 0,311, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | else return 0.18371765291642883;  // std dev = 0,013, 21,000 (wgt'ed) examples reached here.  /* #pos=21 */
# %   | else if ( follows(F, A), follows(F, G), club(G) )
# %   | | then return 0.19326832625124568;  // std dev = 0,032, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else if ( follows(A, H), follows(I, H), club(I) )
# %   | | | then return 7.923797214779427E-5;  // std dev = 0,497, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | else return 0.20082689213258242;  // std dev = 0,029, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# WILL Produced-Tree #9
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( tweets(A, B), follows(C, A), news(C) )
# %   | then return -0.0676751542985544;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else return -0.20893920972790797;  // std dev = 0,180, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( tweets(A, D), follows(E, A), news(E) )
# %   | then if ( follows(A, E) )
# %   | | then if ( club(A) )
# %   | | | then return -0.11717023336155259;  // std dev = 0,018, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else if ( follows(A, F), club(F), tweets(F, D) )
# %   | | | | then if ( follows(F, A), follows(A, G), follows(E, G) )
# %   | | | | | then return 0.16492928889597624;  // std dev = 0,115, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | | | | | else return 0.14410141634097817;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | | else return 0.20139733989483435;  // std dev = 0,020, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( club(A) )
# %   | | | then return -0.06000939643870555;  // std dev = 0,001, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.13974190184579793;  // std dev = 0,011, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return 0.15887414123872595;  // std dev = 0,092, 77,000 (wgt'ed) examples reached here.  /* #pos=77 */
# WILL Produced-Tree #10
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( tweets(A, B), follows(C, A), news(C) )
# %   | then return -0.0635280910011774;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else return -0.17791567160636582;  // std dev = 0,161, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( tweets(A, D), follows(E, A), news(E) )
# %   | then if ( club(A) )
# %   | | then if ( follows(A, E) )
# %   | | | then return -0.1055898721419253;  // std dev = 0,017, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else return -0.0567124277307933;  // std dev = 0,001, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else if ( follows(A, E), follows(E, F), follows(F, A) )
# %   | | | then if ( club(F), tweets(E, D), tweets(F, D) )
# %   | | | | then return 0.12893211122558434;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | | else if ( tweets(F, D), follows(F, G), club(G) )
# %   | | | | | then return 0.18645508258137114;  // std dev = 0,032, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | else return 0.15169093455419166;  // std dev = 0,073, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.1305033971327215;  // std dev = 0,013, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | else return 0.13878980156049162;  // std dev = 0,083, 77,000 (wgt'ed) examples reached here.  /* #pos=77 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.136278
#    Precision = 0.992857 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.996416
#
#
# Total learning time: 18.281 seconds
# Total inference time: 0.712 seconds
# AUC ROC: 1.0
#
#
# WILL Produced-Tree #1
# % FOR fan(A):
# %   if ( news(A) )
# %   then return -0.1418510649004878;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   else if ( follows(B, A), news(B), tweets(A, C) )
# %   | then if ( club(A) )
# %   | | then return -0.1418510649004878;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else return 0.8581489350995123;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | else return 0.8581489350995124;  // std dev = 0,000, 126,000 (wgt'ed) examples reached here.  /* #pos=126 */
# WILL Produced-Tree #2
# % FOR fan(A):
# %   if ( tweets(A, B), follows(C, A), news(C) )
# %   then if ( club(A) )
# %   | then return -0.12544463852839138;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | else if ( news(A) )
# %   | | then return -0.12544463852839138;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else return 0.7194734122109542;  // std dev = 4,21e-08, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   else if ( follows(A, D), club(D), follows(D, E) )
# %   | then if ( follows(F, A) )
# %   | | then return 0.7194734122109541;  // std dev = 1,19e-07, 66,000 (wgt'ed) examples reached here.  /* #pos=66 */
# %   | | else if ( follows(A, E), tweets(A, G), news(E) )
# %   | | | then return 0.5504898020630852;  // std dev = 0,756, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.7194734122109543;  // std dev = 0,000, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( news(A) )
# %   | | then return -0.12544463852839138;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.7194734122109546;  // std dev = 0,000, 33,000 (wgt'ed) examples reached here.  /* #pos=33 */
# WILL Produced-Tree #3
# % FOR fan(A):
# %   if ( tweets(A, B), follows(C, A), news(C) )
# %   then if ( club(A) )
# %   | then return -0.11231637819360639;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | else if ( news(A) )
# %   | | then return -0.11231637819360639;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else return 0.5553664367462846;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   else if ( follows(A, D), club(D), follows(D, E) )
# %   | then if ( follows(F, A) )
# %   | | then return 0.5553664367462837;  // std dev = 2,86e-07, 66,000 (wgt'ed) examples reached here.  /* #pos=66 */
# %   | | else if ( club(E), follows(E, D) )
# %   | | | then return 0.3175954204839429;  // std dev = 0,634, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.5603157066507977;  // std dev = 0,067, 25,000 (wgt'ed) examples reached here.  /* #pos=25 */
# %   | else if ( follows(A, G), tweets(A, H) )
# %   | | then if ( news(A) )
# %   | | | then return -0.11231637819360639;  // std dev = 2,63e-09, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return 0.5553664367462843;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | else return 0.5553664367462845;  // std dev = 0,000, 25,000 (wgt'ed) examples reached here.  /* #pos=25 */
# WILL Produced-Tree #4
# % FOR fan(A):
# %   if ( news(A) )
# %   then return -0.1169054550379083;  // std dev = 0,145, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   else if ( follows(B, A), tweets(A, C), news(B) )
# %   | then if ( club(A) )
# %   | | then return -0.10159632948783627;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else return 0.4175135841583098;  // std dev = 4,21e-08, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | else return 0.41953099822652784;  // std dev = 0,134, 126,000 (wgt'ed) examples reached here.  /* #pos=126 */
# WILL Produced-Tree #5
# % FOR fan(A):
# %   if ( follows(B, A), news(B), tweets(A, C) )
# %   then if ( club(A) )
# %   | then return -0.09269127618926097;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | else if ( follows(A, B) )
# %   | | then if ( news(A) )
# %   | | | then return -0.09141178808947541;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return 0.3207118471601497;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | else if ( news(A) )
# %   | | | then return -0.09141178808947541;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return 0.32071184716014967;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   else if ( follows(A, D), club(D), follows(D, E) )
# %   | then return 0.3168786861998159;  // std dev = 0,058, 94,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=93 */
# %   | else if ( follows(A, F), follows(G, F), club(G) )
# %   | | then if ( follows(H, A), follows(I, H) )
# %   | | | then return 0.011509284170008828;  // std dev = 0,357, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.3202725009484615;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | else return 0.32027250094846155;  // std dev = 0,000, 25,000 (wgt'ed) examples reached here.  /* #pos=25 */
# WILL Produced-Tree #6
# % FOR fan(A):
# %   if ( follows(B, A), follows(C, B), news(B) )
# %   then if ( news(C), tweets(A, D), tweets(C, D) )
# %   | then if ( club(A) )
# %   | | then return -0.08518475138839687;  // std dev = 2,63e-09, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else if ( news(A) )
# %   | | | then return -0.08409778909032319;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | | else return 0.2551722425694894;  // std dev = 7,45e-09, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | else return 0.25509728989803104;  // std dev = 0,000367, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   else if ( follows(A, E), club(E), follows(E, F) )
# %   | then if ( follows(G, A) )
# %   | | then return 0.25551234263291556;  // std dev = 0,000343, 67,000 (wgt'ed) examples reached here.  /* #pos=67 */
# %   | | else if ( club(F), follows(A, H), follows(H, E) )
# %   | | | then return 0.1962088061390958;  // std dev = 0,186, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   | | | else return 0.2621928121298214;  // std dev = 0,092, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | else if ( news(A) )
# %   | | then return -0.09237220524854302;  // std dev = 1,86e-09, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.25690145511844126;  // std dev = 0,062, 31,000 (wgt'ed) examples reached here.  /* #pos=31 */
# WILL Produced-Tree #7
# % FOR fan(A):
# %   if ( follows(B, A), news(B), tweets(A, C) )
# %   then if ( news(A) )
# %   | then return -0.07784259797653291;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | else if ( club(A) )
# %   | | then return -0.07877675473109173;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else return 0.20975911386830046;  // std dev = 6,39e-05, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   else if ( follows(A, D), club(D), follows(D, E) )
# %   | then if ( follows(F, A) )
# %   | | then return 0.21000242275207756;  // std dev = 0,000, 66,000 (wgt'ed) examples reached here.  /* #pos=66 */
# %   | | else if ( club(E), tweets(A, G) )
# %   | | | then if ( follows(E, D) )
# %   | | | | then return 0.07022547956046989;  // std dev = 0,499, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.2207856720433022;  // std dev = 0,034, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.2126636401920658;  // std dev = 0,041, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | else if ( follows(A, H), follows(I, A) )
# %   | | then return 0.07142076120906281;  // std dev = 0,386, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | else return 0.20922993831606213;  // std dev = 0,000408, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# WILL Produced-Tree #8
# % FOR fan(A):
# %   if ( tweets(A, B), follows(C, A), follows(D, C) )
# %   then if ( follows(A, C) )
# %   | then if ( news(C), news(D) )
# %   | | then if ( club(A) )
# %   | | | then return -0.07324622576333704;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else if ( news(A) )
# %   | | | | then return -0.07243523872518988;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else return 0.17709993509474276;  // std dev = 1,26e-05, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else return 0.16955048539283424;  // std dev = 0,050, 55,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=53 */
# %   | else if ( news(A) )
# %   | | then return -0.07971337635715317;  // std dev = 0,020, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else if ( news(C), follows(C, D), follows(D, A) )
# %   | | | then return 0.010204921935306319;  // std dev = 0,204, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return 0.1769052522416724;  // std dev = 0,000897, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   else if ( tweets(A, E), follows(A, F), news(F) )
# %   | then return 0.15320326852579144;  // std dev = 0,142, 14,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=13 */
# %   | else return 0.17836515567897185;  // std dev = 0,074, 54,000 (wgt'ed) examples reached here.  /* #pos=54 */
# WILL Produced-Tree #9
# % FOR fan(A):
# %   if ( club(A) )
# %   then return -0.07245902254896283;  // std dev = 0,016, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   else if ( follows(B, A), follows(C, B), tweets(A, D) )
# %   | then if ( news(B), tweets(C, D), news(C) )
# %   | | then if ( news(A) )
# %   | | | then return -0.06748761762352466;  // std dev = 0,000561, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | | else return 0.15275163102104017;  // std dev = 2,91e-05, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else if ( follows(A, C) )
# %   | | | then return 0.15519341218914248;  // std dev = 0,066, 48,000 (wgt'ed) examples reached here.  /* #pos=48 */
# %   | | | else if ( club(B) )
# %   | | | | then return 0.15597136827687605;  // std dev = 0,021, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | | | else return 0.09331293749931986;  // std dev = 0,107, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   | else if ( follows(A, E), news(E), tweets(A, F) )
# %   | | then if ( follows(E, G), follows(A, G), follows(G, E) )
# %   | | | then return 0.0787036043083287;  // std dev = 0,525, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.15801054230286907;  // std dev = 0,019, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else return 0.15372108012752564;  // std dev = 0,067, 54,000 (wgt'ed) examples reached here.  /* #pos=54 */
# WILL Produced-Tree #10
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( follows(B, A), news(B) )
# %   | then return -0.06336239767935331;  // std dev = 0,000529, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | else return -0.17637289629541883;  // std dev = 0,267, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( follows(C, A), follows(D, C), news(C) )
# %   | then if ( club(A) )
# %   | | then return -0.06773976985730808;  // std dev = 0,015, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | else return 0.13548604479657814;  // std dev = 0,019, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# %   | else return 0.13762415511538245;  // std dev = 0,140, 125,000 (wgt'ed) examples reached here.  /* #pos=125 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.134519
#    Precision = 0.990385 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.995169
#
#
# Total learning time: 20.686 seconds
# Total inference time: 1.321 seconds
# AUC ROC: 1.0

# %%
target = 'news'

bk = ['fan(+account).',
      'news(+account).',
      'club(+account).',
      'tweets(+account,+word).',
      'tweets(+account,-word).',
      'tweets(-account,+word).',
      'follows(+account,+account).',
      'follows(+account,-account).',
      'follows(-account,+account).']

[facts, pos, neg] = load('twitter', bk, target=target)

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(len(pos)):
    [train_facts, test_facts] = datasets.get_kfold_small(i, facts)
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.14185106490048774;  // std dev = 1,49e-08, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
# %   else if ( club(A) )
# %   | then return -0.14185106490048777;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else return 0.8581489350995123;  // std dev = 0,000, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# WILL Produced-Tree #2
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.12544463852839138;  // std dev = 0,000, 32,000 (wgt'ed) examples reached here.  /* #neg=32 */
# %   else if ( follows(A, B) )
# %   | then return 0.7194734122109543;  // std dev = 4,21e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else return 0.4378340619645058;  // std dev = 0,976, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# WILL Produced-Tree #3
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.11231637819360639;  // std dev = 0,000, 25,000 (wgt'ed) examples reached here.  /* #neg=25 */
# %   else if ( club(A) )
# %   | then return -0.21228792110127226;  // std dev = 0,037, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else return 0.5748054195006855;  // std dev = 0,115, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# WILL Produced-Tree #4
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.10159632948783635;  // std dev = 0,000, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
# %   else return 0.4326556649209719;  // std dev = 0,118, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# WILL Produced-Tree #5
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.09269127618926097;  // std dev = 0,000, 29,000 (wgt'ed) examples reached here.  /* #neg=29 */
# %   else if ( club(A) )
# %   | then return -0.2556422444632068;  // std dev = 0,045, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.33136998656637695;  // std dev = 0,107, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# WILL Produced-Tree #6
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.08518475138839682;  // std dev = 1,83e-08, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   else if ( follows(A, B), follows(B, A), tweets(A, C) )
# %   | then if ( club(B), tweets(B, C) )
# %   | | then return 0.2466697304734533;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else return -0.06536230698352503;  // std dev = 0,382, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | else return 0.2715401276184796;  // std dev = 0,083, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# WILL Produced-Tree #7
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.07877675473109175;  // std dev = 0,000, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   else if ( follows(A, B) )
# %   | then return 0.20725896881079345;  // std dev = 0,055, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else return 0.09248666171243795;  // std dev = 0,541, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# WILL Produced-Tree #8
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.07324622576333704;  // std dev = 5,27e-09, 28,000 (wgt'ed) examples reached here.  /* #neg=28 */
# %   else if ( club(A) )
# %   | then return -0.26397790860533465;  // std dev = 0,056, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else return 0.19141875910727382;  // std dev = 0,107, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# WILL Produced-Tree #9
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.06842697784420276;  // std dev = 0,000, 25,000 (wgt'ed) examples reached here.  /* #neg=25 */
# %   else if ( follows(A, B), club(B), follows(B, A) )
# %   | then if ( club(A) )
# %   | | then return -0.2229672790271282;  // std dev = 0,060, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else return 0.14594821294519328;  // std dev = 0,003, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | else if ( follows(A, C) )
# %   | | then return 0.15279248497192882;  // std dev = 0,042, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.1211605190012478;  // std dev = 0,350, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# WILL Produced-Tree #10
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.06419184008202622;  // std dev = 0,000, 26,000 (wgt'ed) examples reached here.  /* #neg=26 */
# %   else if ( club(A) )
# %   | then return -0.1784877616659866;  // std dev = 0,038, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.14548296063190655;  // std dev = 0,092, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.07353
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 1.0
#
#
# Total learning time: 5.626 seconds
# Total inference time: 0.503 seconds
# AUC ROC: 1.0
#
#
# WILL Produced-Tree #1
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.1418510649004877;  // std dev = 2,36e-08, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   else if ( club(A) )
# %   | then return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.8581489350995122;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# WILL Produced-Tree #2
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.12544463852839138;  // std dev = 0,000, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
# %   else if ( follows(A, B), follows(B, C), follows(C, A) )
# %   | then return 0.508243899526118;  // std dev = 0,732, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else return 0.7194734122109546;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# WILL Produced-Tree #3
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.11231637819360635;  // std dev = 1,67e-08, 18,000 (wgt'ed) examples reached here.  /* #neg=18 */
# %   else if ( club(A) )
# %   | then return -0.2041976116570248;  // std dev = 0,029, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else return 0.5707769146580832;  // std dev = 0,074, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# WILL Produced-Tree #4
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.10159632948783635;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   else return 0.4293678240205785;  // std dev = 0,075, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# WILL Produced-Tree #5
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.09269127618926101;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   else if ( follows(A, B), fan(B), follows(B, A) )
# %   | then return 0.20222397214544485;  // std dev = 0,501, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else return 0.32154916033842484;  // std dev = 0,044, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# WILL Produced-Tree #6
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.08518475138839683;  // std dev = 1,18e-08, 18,000 (wgt'ed) examples reached here.  /* #neg=18 */
# %   else if ( follows(A, B), club(B) )
# %   | then return 0.2849470035942243;  // std dev = 0,067, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | else return 0.1674406754000969;  // std dev = 0,477, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# WILL Produced-Tree #7
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.07877675473109173;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   else return 0.22741947751513986;  // std dev = 0,062, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# WILL Produced-Tree #8
# % FOR news(A):
# %   if ( club(A) )
# %   then return -0.4131680270179508;  // std dev = 0,042, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   else if ( fan(A) )
# %   | then return -0.07324622576333704;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #neg=17 */
# %   | else return 0.19001909736297443;  // std dev = 0,055, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# WILL Produced-Tree #9
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.06842697784420274;  // std dev = 0,000, 18,000 (wgt'ed) examples reached here.  /* #neg=18 */
# %   else if ( follows(A, B), follows(B, C), follows(C, A) )
# %   | then return 0.06381073735039813;  // std dev = 0,406, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else return 0.15462854538889984;  // std dev = 0,026, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# WILL Produced-Tree #10
# % FOR news(A):
# %   if ( fan(A) )
# %   then return -0.06419184008202619;  // std dev = 7,45e-09, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   else if ( follows(A, B) )
# %   | then if ( club(B), follows(A, C), fan(C) )
# %   | | then return 0.044385793726801764;  // std dev = 0,401, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | else return 0.142142448876159;  // std dev = 0,029, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | else return -0.03132027465454299;  // std dev = 0,413, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# Results
#    AUC ROC   = 1.0
#    AUC PR    = 1.0
#    CLL	      = -0.097952
#    Precision = 1.0 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 1.0
#
#
# Total learning time: 3.345 seconds
# Total inference time: 0.615 seconds
# AUC ROC: 1.0

# %%
target = 'fan'

bk = ['fan(+account).',
      'news(+account).',
      'club(+account).',
      'tweets(+account,#word).',
      'tweets(+account,#word).',
      'tweets(-account,#word).',
      'follows(+account,+account).',
      'follows(+account,-account).',
      'follows(-account,+account).']

[facts, pos, neg] = load('twitter', bk, target='fan')

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(len(pos)):
    [train_facts, test_facts] = datasets.get_kfold_small(i, facts)
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR fan(A):
# %   if ( follows(A, B), tweets(C, hashwearebruges), follows(C, A) )
# %   then if ( tweets(C, hashbeekvm) )
# %   | then return -0.1418510649004878;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else if ( tweets(B, hashcobw) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( follows(A, D) )
# %   | then if ( tweets(D, hashcoym) )
# %   | | then return 0.858148935099512;  // std dev = 2,23e-07, 45,000 (wgt'ed) examples reached here.  /* #pos=45 */
# %   | | else if ( tweets(D, ezekiel) )
# %   | | | then return 0.8303711573217337;  // std dev = 0,164, 36,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=35 */
# %   | | | else if ( tweets(D, genk), tweets(D, hashcerwbe) )
# %   | | | | then return 0.28672036367094084;  // std dev = 0,495, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | | else return 0.7812258581764353;  // std dev = 0,266, 13,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=12 */
# %   | else if ( news(A) )
# %   | | then return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# WILL Produced-Tree #2
# % FOR fan(A):
# %   if ( follows(A, B), tweets(C, bruges), follows(C, A) )
# %   then if ( tweets(C, hashbeekvm) )
# %   | then return -0.12544463852839138;  // std dev = 5,27e-09, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else if ( tweets(B, hashclubbrugge) )
# %   | | then return 0.7281632419008521;  // std dev = 0,057, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | | else return 0.25575928490425626;  // std dev = 0,997, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else if ( news(A) )
# %   | then return -0.16650512010310192;  // std dev = 0,139, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | else if ( follows(A, D) )
# %   | | then return 0.726738898741199;  // std dev = 0,170, 88,000 (wgt'ed) examples reached here.  /* #pos=88 */
# %   | | else return 0.308741135785635;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# WILL Produced-Tree #3
# % FOR fan(A):
# %   if ( news(A) )
# %   then return -0.15891118133720813;  // std dev = 0,066, 14,000 (wgt'ed) examples reached here.  /* #neg=14 */
# %   else if ( tweets(A, wedstrijd) )
# %   | then if ( club(A) )
# %   | | then return -0.15607346254287544;  // std dev = 0,107, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.5578677533181516;  // std dev = 0,017, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | else if ( tweets(A, matchday), follows(B, A), tweets(B, bacca) )
# %   | | then if ( tweets(A, brugge) )
# %   | | | then return 0.5602853410352945;  // std dev = 0,000384, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return -0.15607346254287544;  // std dev = 0,107, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else if ( tweets(A, hashcoym), tweets(C, hashstaclu), follows(C, A) )
# %   | | | then return 0.3316089559019379;  // std dev = 0,544, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( tweets(A, beerschot) )
# %   | | | | then return 0.3338936506340555;  // std dev = 0,547, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( tweets(A, lestienne), follows(D, A), tweets(D, hashwearebruges) )
# %   | | | | | then return 0.6476920558771029;  // std dev = 0,145, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | else return 0.560864940487864;  // std dev = 0,765, 86,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=85 */
# WILL Produced-Tree #4
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( follows(A, B), tweets(B, matchday) )
# %   | then return -0.2080847088484835;  // std dev = 0,137, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return -0.11191472606167148;  // std dev = 0,065, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   else if ( tweets(A, match), follows(C, A), tweets(C, bruges) )
# %   | then if ( tweets(C, hashbeekvm) )
# %   | | then return -0.1510774823582081;  // std dev = 0,134, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else if ( tweets(C, hashwearebruges), follows(D, A), tweets(D, hashgntcha) )
# %   | | | then return 0.5688508235085722;  // std dev = 0,115, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.41952764731288117;  // std dev = 0,006, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | else if ( tweets(A, hashcoym), tweets(A, goal) )
# %   | | then return 0.28746813720059294;  // std dev = 0,507, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | else if ( tweets(A, beerschot), tweets(E, match), follows(E, A) )
# %   | | | then return 0.07417169536714628;  // std dev = 0,487, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return 0.4286630564258539;  // std dev = 0,348, 91,000 (wgt'ed) examples reached here.  /* #pos=91 */
# WILL Produced-Tree #5
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( follows(A, B), tweets(B, matchday) )
# %   | then return -0.17667323169600613;  // std dev = 0,120, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return -0.10130723065534339;  // std dev = 0,060, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   else if ( tweets(A, match), follows(C, A), tweets(C, beerschot) )
# %   | then if ( tweets(C, hashbeekvm) )
# %   | | then return -0.13308884814807317;  // std dev = 0,120, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else return 0.3623636876098858;  // std dev = 0,136, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( tweets(A, hashstaclu) )
# %   | | then return 0.3307197286575501;  // std dev = 0,033, 36,000 (wgt'ed) examples reached here.  /* #pos=36 */
# %   | | else if ( tweets(A, wedstrijd) )
# %   | | | then return 0.17597945663898204;  // std dev = 0,343, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( tweets(A, sutter), tweets(A, anderlecht), tweets(A, penalty) )
# %   | | | | then return 0.24164320006639242;  // std dev = 0,474, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else if ( tweets(A, matchday), tweets(D, matchday), follows(A, D) )
# %   | | | | | then return 0.37344941738946913;  // std dev = 0,122, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | else return 0.3233204536669006;  // std dev = 0,571, 54,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=53 */
# WILL Produced-Tree #6
# % FOR fan(A):
# %   if ( tweets(A, hashbeekvm) )
# %   then if ( tweets(A, anderlecht) )
# %   | then return -0.10922591090946215;  // std dev = 0,078, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else return 0.058498419468390676;  // std dev = 0,452, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else if ( club(A) )
# %   | then if ( tweets(A, matchday) )
# %   | | then return -0.10746752832795681;  // std dev = 0,079, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return -0.15509451823002934;  // std dev = 0,112, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else if ( news(A) )
# %   | | then if ( tweets(A, genk) )
# %   | | | then return -0.12349820866576093;  // std dev = 0,110, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return -0.10480561305719427;  // std dev = 0,027, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | | else if ( tweets(A, atclubbrugge) )
# %   | | | then return 0.25153196009100426;  // std dev = 0,022, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | | | else if ( follows(B, A), tweets(B, gent), tweets(B, brugge) )
# %   | | | | then return 0.2943057172121987;  // std dev = 0,064, 19,000 (wgt'ed) examples reached here.  /* #pos=19 */
# %   | | | | else return 0.2619688514328173;  // std dev = 0,025, 66,000 (wgt'ed) examples reached here.  /* #pos=66 */
# WILL Produced-Tree #7
# % FOR fan(A):
# %   if ( follows(A, B) )
# %   then if ( news(A) )
# %   | then if ( tweets(B, hashclubbrugge), follows(B, A) )
# %   | | then return -0.06880892121882119;  // std dev = 0,008, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else if ( tweets(B, matchday) )
# %   | | | then return -0.16497345760154636;  // std dev = 0,036, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else return -0.10370460609915419;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else if ( club(A) )
# %   | | then if ( tweets(A, match) )
# %   | | | then return -0.08164921629249111;  // std dev = 0,050, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return -0.18347058521500306;  // std dev = 0,068, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else if ( tweets(B, bacca), follows(A, C), tweets(C, club) )
# %   | | | then return 0.20899657026363158;  // std dev = 0,125, 58,000 (wgt'ed) examples reached here.  /* #pos=58 */
# %   | | | else return 0.2260407581299766;  // std dev = 0,034, 43,000 (wgt'ed) examples reached here.  /* #pos=43 */
# %   else if ( tweets(A, genk) )
# %   | then return -0.09136901330808628;  // std dev = 0,076, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.12144092979901018;  // std dev = 0,469, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# WILL Produced-Tree #8
# % FOR fan(A):
# %   if ( tweets(A, hashbeekvm) )
# %   then if ( tweets(A, anderlecht) )
# %   | then return -0.08852309694000654;  // std dev = 0,060, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else return 0.03972838169386215;  // std dev = 0,382, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else if ( follows(A, B), tweets(C, hashwearebruges), follows(C, A) )
# %   | then if ( tweets(C, hashbeekvm) )
# %   | | then return -0.08406184504125035;  // std dev = 0,039, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | | else return 0.18782400474563224;  // std dev = 0,089, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | else if ( follows(A, D), tweets(E, match), follows(D, E) )
# %   | | then if ( tweets(D, kortrijk), follows(A, F), tweets(F, hashbeekvm) )
# %   | | | then return 0.09469914653766205;  // std dev = 0,130, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   | | | else return 0.17779735404471425;  // std dev = 0,038, 79,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=78 */
# %   | | else if ( news(A) )
# %   | | | then return -0.09984929788845923;  // std dev = 0,081, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | else if ( tweets(A, match) )
# %   | | | | then return -0.0050862421738722225;  // std dev = 0,370, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.193235880716815;  // std dev = 0,051, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# WILL Produced-Tree #9
# % FOR fan(A):
# %   if ( follows(A, B) )
# %   then if ( tweets(B, hashwearebruges), tweets(B, brugge) )
# %   | then if ( tweets(A, brugge) )
# %   | | then return 0.14780135780435452;  // std dev = 0,013, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else if ( tweets(A, hashgntcha) )
# %   | | | then return 0.10509343337114523;  // std dev = 0,214, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( tweets(A, hashstaclu) )
# %   | | | | then return 0.011340219128623394;  // std dev = 0,165, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return -0.13401311559576934;  // std dev = 0,100, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | else if ( tweets(A, hashkrcgenk), tweets(B, hashkrcgenk) )
# %   | | then return 0.05073239289910345;  // std dev = 0,357, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else if ( tweets(B, hashbeekvm), tweets(C, bruges), follows(C, A) )
# %   | | | then return 0.07674113849646397;  // std dev = 0,108, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | | else return 0.14584466496216444;  // std dev = 0,057, 87,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=83 */
# %   else if ( tweets(A, hashcerwbe) )
# %   | then return -0.08546502841542117;  // std dev = 0,093, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.09859298495450941;  // std dev = 0,417, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# WILL Produced-Tree #10
# % FOR fan(A):
# %   if ( follows(A, B), tweets(C, bruges), follows(C, A) )
# %   then if ( tweets(C, hashbeekvm) )
# %   | then return -0.08969299346637444;  // std dev = 0,041, 10,000 (wgt'ed) examples reached here.  /* #neg=10 */
# %   | else if ( tweets(A, anderlecht) )
# %   | | then return -0.05079888459129925;  // std dev = 0,238, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else return 0.14840145137110936;  // std dev = 0,025, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   else if ( follows(A, D) )
# %   | then if ( tweets(D, kortrijk), tweets(D, hashcerwbe) )
# %   | | then if ( tweets(A, hashstaclu) )
# %   | | | then return 0.15299389992040635;  // std dev = 0,034, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else if ( news(A) )
# %   | | | | then return -0.11549197589108462;  // std dev = 0,021, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | | else return 0.12983964857298114;  // std dev = 0,009, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.13573201062375806;  // std dev = 0,033, 77,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=76 */
# %   | else if ( tweets(A, genk) )
# %   | | then return -0.07980680201431042;  // std dev = 0,089, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else return 0.08410232573634144;  // std dev = 0,405, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# Results
#    AUC ROC   = 0.989843
#    AUC PR    = 0.998647
#    CLL	      = -0.202658
#    Precision = 0.965278 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.982332
#
#
# Total learning time: 96.791 seconds
# Total inference time: 0.788 seconds
# AUC ROC: 0.989843
#
#
# WILL Produced-Tree #1
# % FOR fan(A):
# %   if ( club(A) )
# %   then return -0.1418510649004878;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   else if ( tweets(A, hashstabee), follows(B, A), tweets(B, genk) )
# %   | then if ( tweets(A, sutter) )
# %   | | then return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( tweets(A, hashclukor), follows(C, A), tweets(C, beerschot) )
# %   | | then if ( tweets(C, ezekiel) )
# %   | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( tweets(A, genk), follows(D, A) )
# %   | | | then return 0.5248156017661789;  // std dev = 1,155, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else if ( tweets(A, hashkaagent), tweets(E, club), follows(A, E) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else if ( tweets(A, hashclukor), follows(F, A), tweets(F, atclubbrugge) )
# %   | | | | | then return 0.8055173561521439;  // std dev = 0,973, 19,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=18 */
# %   | | | | | else return 0.8581489350995126;  // std dev = 0,000, 106,000 (wgt'ed) examples reached here.  /* #pos=106 */
# WILL Produced-Tree #2
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( tweets(A, anderlecht) )
# %   | then return -0.13371461257640344;  // std dev = 0,037, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | else return -0.22129844974545199;  // std dev = 0,074, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   else if ( tweets(A, matchday), follows(B, A), tweets(B, hashcobw) )
# %   | then return 0.06628538742359658;  // std dev = 0,857, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | else if ( follows(A, C) )
# %   | | then if ( tweets(A, hashstabee), tweets(C, atrscanderlecht) )
# %   | | | then return 0.4378340619645058;  // std dev = 0,690, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.7241868483117819;  // std dev = 0,146, 112,000 (wgt'ed) examples reached here.  /* #pos=112 */
# %   | | else if ( tweets(A, hashclukor) )
# %   | | | then return 0.7247229154324167;  // std dev = 0,017, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else if ( follows(D, A), tweets(D, hashjpl) )
# %   | | | | then return 0.15619471171805718;  // std dev = 0,690, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.7194734122109542;  // std dev = 2,98e-08, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# WILL Produced-Tree #3
# % FOR fan(A):
# %   if ( tweets(A, standard), tweets(A, beerschot) )
# %   then if ( news(A) )
# %   | then return -0.11818591058612435;  // std dev = 0,023, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.39023607067039895;  // std dev = 0,664, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else if ( tweets(A, wedstrijd), tweets(B, atclubbrugge), follows(B, A) )
# %   | then return 0.1417592602878032;  // std dev = 0,777, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | else if ( tweets(A, genk), follows(C, A), tweets(C, atclubbrugge) )
# %   | | then return 0.10251771868294805;  // std dev = 0,639, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else if ( news(A) )
# %   | | | then return -0.17971567318105247;  // std dev = 0,086, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else if ( tweets(A, matchday), follows(D, A), tweets(D, penalty) )
# %   | | | | then return 0.3332790756434712;  // std dev = 0,879, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else if ( follows(A, E) )
# %   | | | | | then return 0.5601850251449678;  // std dev = 0,182, 106,000 (wgt'ed) examples reached here.  /* #pos=106 */
# %   | | | | | else return 0.5347429589442669;  // std dev = 0,704, 25,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=24 */
# WILL Produced-Tree #4
# % FOR fan(A):
# %   if ( tweets(A, genk), follows(B, A), tweets(B, kortrijk) )
# %   then if ( follows(A, B) )
# %   | then return 0.5314847068695078;  // std dev = 0,083, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return -0.1413001369394588;  // std dev = 0,084, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   else if ( tweets(A, wedstrijd), tweets(C, hashlokcer), follows(A, C) )
# %   | then if ( tweets(A, hashclukor) )
# %   | | then if ( tweets(A, hashsportinglive) )
# %   | | | then return 0.22082634676680146;  // std dev = 0,476, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.457407900486297;  // std dev = 0,052, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | else return -0.18874972982424196;  // std dev = 0,073, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | else if ( tweets(A, atclubbrugge), tweets(A, matchday), follows(D, A) )
# %   | | then return 0.5050670169594129;  // std dev = 0,299, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else if ( tweets(A, goal), tweets(A, anderlecht) )
# %   | | | then return 0.16651459707549868;  // std dev = 0,721, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else if ( tweets(A, brugge), follows(E, A), tweets(E, hashwearebruges) )
# %   | | | | then return 0.06773070946140111;  // std dev = 0,667, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | else return 0.4124083357708562;  // std dev = 0,080, 119,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=117 */
# WILL Produced-Tree #5
# % FOR fan(A):
# %   if ( tweets(A, standard), follows(B, A), tweets(B, anderlecht) )
# %   then if ( tweets(A, goal) )
# %   | then return 0.038371391677554136;  // std dev = 0,345, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | else return -0.1588560408499456;  // std dev = 0,102, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   else if ( tweets(A, genk), tweets(C, atclubbrugge), follows(C, A) )
# %   | then return 0.10334614120637678;  // std dev = 0,694, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | else if ( tweets(A, matchday), tweets(D, atclubbrugge), follows(D, A) )
# %   | | then if ( club(A) )
# %   | | | then return -0.17183893825169827;  // std dev = 0,055, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | else if ( tweets(D, hashlokcer) )
# %   | | | | then return 0.2326331859650444;  // std dev = 0,405, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.4371524414668832;  // std dev = 0,284, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( tweets(A, club), follows(E, A), tweets(A, brugge) )
# %   | | | then return 0.3526134453959034;  // std dev = 0,037, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# %   | | | else if ( tweets(A, hashandlie) )
# %   | | | | then return 0.3367238959860929;  // std dev = 0,031, 32,000 (wgt'ed) examples reached here.  /* #pos=32 */
# %   | | | | else return 0.29973451814759994;  // std dev = 0,114, 88,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=84 */
# WILL Produced-Tree #6
# % FOR fan(A):
# %   if ( tweets(A, wedstrijd), tweets(B, atclubbrugge), follows(B, A) )
# %   then return 0.011271290955016647;  // std dev = 0,589, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   else if ( news(A) )
# %   | then if ( tweets(A, hashstabee) )
# %   | | then return -0.10767430713085377;  // std dev = 0,047, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else return -0.24738086900088999;  // std dev = 0,124, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else if ( tweets(A, atclubbrugge), follows(C, A), tweets(C, hashwearebruges) )
# %   | | then return 0.3736157980244055;  // std dev = 0,229, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( tweets(A, matchday), tweets(D, club), follows(A, D) )
# %   | | | then if ( club(A) )
# %   | | | | then return -0.15918181939359308;  // std dev = 0,025, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else return 0.26785210984342;  // std dev = 0,029, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | else if ( tweets(A, goal), tweets(A, lierse) )
# %   | | | | then return 0.34096869866302;  // std dev = 0,206, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | | else if ( tweets(A, brugge) )
# %   | | | | | then return 0.2364047977002694;  // std dev = 0,549, 20,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=19 */
# %   | | | | | else return 0.26198905549649715;  // std dev = 0,162, 100,000 (wgt'ed) examples reached here.  /* #pos=100 */
# WILL Produced-Tree #7
# % FOR fan(A):
# %   if ( follows(B, A), tweets(B, hashrsca), tweets(B, brugge) )
# %   then if ( tweets(B, hashsportinglive) )
# %   | then return -0.16456644593018355;  // std dev = 0,071, 9,000 (wgt'ed) examples reached here.  /* #neg=9 */
# %   | else if ( news(A) )
# %   | | then return -0.10153906393858297;  // std dev = 0,040, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else return 0.23298594379533138;  // std dev = 0,043, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   else if ( tweets(A, match), tweets(A, hashsportinglive) )
# %   | then return 0.30379307817682977;  // std dev = 0,243, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | else if ( tweets(A, match), tweets(A, wedstrijd), tweets(A, hashclukor) )
# %   | | then return 0.2615955796119668;  // std dev = 0,120, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( follows(A, C), tweets(C, goal), tweets(C, genk) )
# %   | | | then if ( tweets(A, genk), follows(D, A) )
# %   | | | | then return -0.05841980717929668;  // std dev = 0,334, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else if ( tweets(C, match), follows(E, A) )
# %   | | | | | then return 0.22081794498253174;  // std dev = 0,138, 24,000 (wgt'ed) examples reached here.  /* #pos=24 */
# %   | | | | | else return 0.16171566615856653;  // std dev = 0,578, 17,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=15 */
# %   | | | else return 0.21590219417306056;  // std dev = 0,140, 77,000 (wgt'ed) examples reached here.  /* #pos=77 */
# WILL Produced-Tree #8
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( tweets(A, hashstabee) )
# %   | then return -0.08837633111163604;  // std dev = 0,041, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | else return -0.20273641515494387;  // std dev = 0,139, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   else if ( tweets(A, hashclukor), tweets(A, hashlokcer), follows(B, A) )
# %   | then return 0.25065188514937026;  // std dev = 0,192, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | else if ( club(A) )
# %   | | then if ( tweets(A, matchday) )
# %   | | | then return -0.11426795332837335;  // std dev = 0,029, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return -0.20370450773269536;  // std dev = 0,129, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.18470792304519376;  // std dev = 0,267, 133,000 (wgt'ed) examples reached here.  /* #pos=133 */
# WILL Produced-Tree #9
# % FOR fan(A):
# %   if ( news(A) )
# %   then if ( tweets(A, hashstabee) )
# %   | then return -0.0815376337541434;  // std dev = 0,038, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | else return -0.17258258177911046;  // std dev = 0,124, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   else if ( tweets(A, hashclukor) )
# %   | then if ( tweets(A, hashlokcer), follows(B, A), tweets(B, anderlecht) )
# %   | | then return 0.2582870034625098;  // std dev = 0,116, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.15386330736983111;  // std dev = 0,041, 58,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=57 */
# %   | else if ( tweets(A, match), tweets(C, anderlecht), follows(C, A) )
# %   | | then if ( tweets(C, lestienne) )
# %   | | | then return -0.11047550185368882;  // std dev = 0,042, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.17200242390541712;  // std dev = 0,015, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( follows(A, D) )
# %   | | | then return 0.15734751746298303;  // std dev = 0,152, 62,000 (wgt'ed) examples reached here.  /* #pos=62 */
# %   | | | else if ( follows(E, A), tweets(E, hashbeerschot) )
# %   | | | | then return -0.07732062316278938;  // std dev = 0,297, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.16212199043563255;  // std dev = 0,080, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# WILL Produced-Tree #10
# % FOR fan(A):
# %   if ( tweets(A, genk), follows(B, A), tweets(B, anderlecht) )
# %   then if ( follows(A, B) )
# %   | then return 0.17040332944942513;  // std dev = 0,052, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else return -0.09396684236463283;  // std dev = 0,087, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   else if ( tweets(A, kortrijk), follows(C, A), tweets(C, ezekiel) )
# %   | then return -0.024621599261846035;  // std dev = 0,287, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | else if ( tweets(A, goal), follows(D, A), tweets(D, hashclubbrugge) )
# %   | | then return -0.011934490783797625;  // std dev = 0,281, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | else if ( tweets(A, matchday), follows(E, A) )
# %   | | | then if ( tweets(E, hashjpl) )
# %   | | | | then return 0.21825717680991732;  // std dev = 0,109, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else return 0.13606597438622314;  // std dev = 0,054, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else if ( news(A) )
# %   | | | | then return -0.15823140663577231;  // std dev = 0,103, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else if ( tweets(A, hashkvmgnt), tweets(A, hashjpl) )
# %   | | | | | then return 0.18269499988101845;  // std dev = 0,086, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | | else return 0.13098483327469573;  // std dev = 0,479, 122,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=120 */
# Results
#    AUC ROC   = 0.997889
#    AUC PR    = 0.999541
#    CLL	      = -0.19914
#    Precision = 0.971429 at threshold = 0.5
#    Recall    = 0.990291
#    F1        = 0.980769
#
#
# Total learning time: 49.871 seconds
# Total inference time: 0.827 seconds
# AUC ROC: 0.997889

# %%
target = 'follows'

bk = ['fan(+account).',
      'news(+account).',
      'club(+account).',
      'tweets(+account,+word).',
      'tweets(+account,-word).',
      'tweets(-account,+word).',
      'follows(+account,+account).',
      'follows(+account,-account).',
      'follows(-account,+account).']

[facts, pos, neg] = load('twitter', bk, target='fan')

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(len(pos)):
    [train_facts, test_facts] = datasets.get_kfold_small(i, facts)
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR follows(A, B):
# %   if ( fan(B) )
# %   then return 0.06071752821100763;  // std dev = 0,402, 1.713,000 (wgt'ed) examples reached here.  /* #neg=1.366 #pos=347 */
# %   else if ( tweets(B, C), tweets(D, C), club(D) )
# %   | then if ( tweets(A, C) )
# %   | | then if ( club(B), fan(A) )
# %   | | | then return 0.6566563977860774;  // std dev = 0,401, 134,000 (wgt'ed) examples reached here.  /* #neg=27 #pos=107 */
# %   | | | else return 0.5693558316512337;  // std dev = 0,453, 232,000 (wgt'ed) examples reached here.  /* #neg=67 #pos=165 */
# %   | | else if ( club(A), club(B) )
# %   | | | then return 0.762910839861417;  // std dev = 0,294, 21,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=19 */
# %   | | | else if ( tweets(A, E) )
# %   | | | | then if ( club(B), tweets(F, E), club(F) )
# %   | | | | | then return 0.3179190500420405;  // std dev = 4,649, 87,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=40 */
# %   | | | | | else return 0.24276431971489598;  // std dev = 3,922, 65,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=25 */
# %   | | | | else if ( news(A) )
# %   | | | | | then return 0.35814893509951234;  // std dev = 2,345, 22,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=11 */
# %   | | | | | else return 0.5025933795439576;  // std dev = 4,541, 90,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=58 */
# %   | else return -0.014866937916360743;  // std dev = 0,333, 63,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=8 */
# WILL Produced-Tree #2
# % FOR follows(A, B):
# %   if ( fan(B) )
# %   then return 0.058007738144993784;  // std dev = 0,405, 1.673,000 (wgt'ed) examples reached here.  /* #neg=1.326 #pos=347 */
# %   else if ( tweets(B, C), tweets(A, C) )
# %   | then return 0.5476080611798104;  // std dev = 0,414, 352,000 (wgt'ed) examples reached here.  /* #neg=78 #pos=274 */
# %   | else if ( tweets(B, D), tweets(E, D), club(E) )
# %   | | then if ( fan(A) )
# %   | | | then if ( club(B), tweets(E, F), tweets(A, F) )
# %   | | | | then return 0.35488669017032287;  // std dev = 0,498, 50,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=27 */
# %   | | | | else if ( tweets(A, G), club(B) )
# %   | | | | | then return 0.10178700906462369;  // std dev = 2,391, 28,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=8 */
# %   | | | | | else return 0.27671562358432106;  // std dev = 6,180, 154,000 (wgt'ed) examples reached here.  /* #neg=80 #pos=74 */
# %   | | | else if ( news(A), club(B) )
# %   | | | | then if ( tweets(A, H), tweets(E, H) )
# %   | | | | | then return 0.25933113461476837;  // std dev = 1,491, 9,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=4 */
# %   | | | | | else return 0.3558717415269138;  // std dev = 1,653, 11,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=6 */
# %   | | | | else return 0.5975382794368133;  // std dev = 0,371, 39,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=32 */
# %   | | else return -0.008903399431482247;  // std dev = 0,338, 61,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=8 */
# WILL Produced-Tree #3
# % FOR follows(A, B):
# %   if ( fan(B) )
# %   then return 0.04962087213424834;  // std dev = 0,405, 1.680,000 (wgt'ed) examples reached here.  /* #neg=1.333 #pos=347 */
# %   else if ( tweets(B, C), tweets(D, C), club(D) )
# %   | then if ( tweets(A, C) )
# %   | | then if ( club(B) )
# %   | | | then return 0.4630278498066679;  // std dev = 0,389, 162,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=132 */
# %   | | | else return 0.3974002810405227;  // std dev = 0,442, 191,000 (wgt'ed) examples reached here.  /* #neg=51 #pos=140 */
# %   | | else if ( club(A), club(B) )
# %   | | | then return 0.6081520094063892;  // std dev = 5,96e-08, 19,000 (wgt'ed) examples reached here.  /* #pos=19 */
# %   | | | else if ( news(B), tweets(A, E), tweets(D, E) )
# %   | | | | then if ( club(A) )
# %   | | | | | then return 0.15163264421399525;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | | | else return 0.017801285102674074;  // std dev = 1,960, 21,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=5 */
# %   | | | | else if ( club(B), tweets(D, F), tweets(A, F) )
# %   | | | | | then return 0.35313096554470597;  // std dev = 3,543, 52,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=31 */
# %   | | | | | else return 0.2470546291658471;  // std dev = 6,860, 190,000 (wgt'ed) examples reached here.  /* #neg=95 #pos=95 */
# %   | else return -0.02021676715282391;  // std dev = 0,328, 66,000 (wgt'ed) examples reached here.  /* #neg=58 #pos=8 */
# WILL Produced-Tree #4
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( fan(B), fan(A) )
# %   | then return 0.11727256930037294;  // std dev = 0,449, 502,000 (wgt'ed) examples reached here.  /* #neg=361 #pos=141 */
# %   | else if ( club(A) )
# %   | | then if ( news(B) )
# %   | | | then return 0.5709273768000437;  // std dev = 0,000, 14,000 (wgt'ed) examples reached here.  /* #pos=14 */
# %   | | | else if ( club(B) )
# %   | | | | then return 0.477858197745387;  // std dev = 0,266, 13,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=12 */
# %   | | | | else return 0.4389601778405725;  // std dev = 0,489, 78,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=47 */
# %   | | else if ( fan(B), tweets(D, C), club(D) )
# %   | | | then return 0.15285177147900342;  // std dev = 0,465, 79,000 (wgt'ed) examples reached here.  /* #neg=54 #pos=25 */
# %   | | | else if ( club(B), news(A) )
# %   | | | | then return 0.42144794133513064;  // std dev = 0,340, 15,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=13 */
# %   | | | | else if ( news(A), news(B) )
# %   | | | | | then return 0.13943906609782883;  // std dev = 2,442, 25,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=14 */
# %   | | | | | else return 0.30091609044507484;  // std dev = 7,513, 298,000 (wgt'ed) examples reached here.  /* #neg=76 #pos=222 */
# %   else return 0.018071634488536964;  // std dev = 0,384, 1.379,000 (wgt'ed) examples reached here.  /* #neg=1.087 #pos=292 */
# WILL Produced-Tree #5
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( club(A), fan(B) )
# %   | then return 0.4386510526420136;  // std dev = 0,470, 70,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=47 */
# %   | else if ( fan(B), tweets(D, C), club(D) )
# %   | | then if ( fan(A) )
# %   | | | then return 0.11050458576186223;  // std dev = 0,454, 478,000 (wgt'ed) examples reached here.  /* #neg=339 #pos=139 */
# %   | | | else return 0.14772490863082888;  // std dev = 0,471, 75,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=25 */
# %   | | else if ( fan(A), club(B) )
# %   | | | then return 0.32796547171440743;  // std dev = 0,336, 123,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=107 */
# %   | | | else if ( fan(A) )
# %   | | | | then if ( tweets(E, C), club(E) )
# %   | | | | | then return 0.2379018625515529;  // std dev = 5,378, 151,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=112 */
# %   | | | | | else return 0.38322505254597256;  // std dev = 1,182, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | | else if ( club(B) )
# %   | | | | | then return 0.22453591598053693;  // std dev = 2,337, 32,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=25 */
# %   | | | | | else return 0.1346005809197171;  // std dev = 3,191, 47,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=29 */
# %   else return 0.01973211687170389;  // std dev = 0,385, 1.358,000 (wgt'ed) examples reached here.  /* #neg=1.066 #pos=292 */
# WILL Produced-Tree #6
# % FOR follows(A, B):
# %   if ( fan(B) )
# %   then return 0.027147552625475142;  // std dev = 0,402, 1.626,000 (wgt'ed) examples reached here.  /* #neg=1.279 #pos=347 */
# %   else if ( tweets(B, C), tweets(D, C), club(D) )
# %   | then if ( tweets(A, E), news(A), club(B) )
# %   | | then if ( tweets(B, E) )
# %   | | | then return 0.07929825578813363;  // std dev = 0,465, 19,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=13 */
# %   | | | else if ( tweets(D, E) )
# %   | | | | then return 0.14118303044666455;  // std dev = 0,497, 9,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=4 */
# %   | | | | else return 0.10186562261799773;  // std dev = 1,090, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( tweets(A, F) )
# %   | | | then return 0.20633398444231038;  // std dev = 0,422, 475,000 (wgt'ed) examples reached here.  /* #neg=138 #pos=337 */
# %   | | | else if ( fan(A) )
# %   | | | | then if ( club(B) )
# %   | | | | | then return 0.22325370414200468;  // std dev = 3,624, 53,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=29 */
# %   | | | | | else return 0.2679206275151275;  // std dev = 3,440, 49,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=29 */
# %   | | | | else return 0.3948073199934344;  // std dev = 0,434, 15,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=11 */
# %   | else return -0.01411590801250275;  // std dev = 0,333, 63,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=8 */
# WILL Produced-Tree #7
# % FOR follows(A, B):
# %   if ( fan(B), fan(A) )
# %   then return 0.0013141812879204932;  // std dev = 0,386, 1.314,000 (wgt'ed) examples reached here.  /* #neg=1.071 #pos=243 */
# %   else if ( tweets(B, C), tweets(A, C), club(A) )
# %   | then if ( news(B) )
# %   | | then return 0.1718961580160564;  // std dev = 0,381, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | | else if ( club(B) )
# %   | | | then return 0.2573948345910228;  // std dev = 0,266, 13,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=12 */
# %   | | | else return 0.22706472591823457;  // std dev = 0,497, 85,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=47 */
# %   | else if ( fan(B), tweets(B, D) )
# %   | | then return 0.018303717660009097;  // std dev = 0,403, 186,000 (wgt'ed) examples reached here.  /* #neg=147 #pos=39 */
# %   | | else if ( tweets(B, E), tweets(F, E), club(F) )
# %   | | | then if ( fan(A), tweets(A, G), tweets(F, G) )
# %   | | | | then return 0.11829160748785306;  // std dev = 0,436, 361,000 (wgt'ed) examples reached here.  /* #neg=110 #pos=251 */
# %   | | | | else if ( news(B), club(A) )
# %   | | | | | then return 0.015105048750332058;  // std dev = 1,749, 13,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=5 */
# %   | | | | | else return 0.1997215065111766;  // std dev = 7,103, 231,000 (wgt'ed) examples reached here.  /* #neg=88 #pos=143 */
# %   | | | else return 0.040439229504721466;  // std dev = 0,397, 131,000 (wgt'ed) examples reached here.  /* #neg=105 #pos=26 */
# WILL Produced-Tree #8
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( fan(A) )
# %   | then if ( news(B) )
# %   | | then if ( tweets(D, C), club(D) )
# %   | | | then return 0.07281298956936345;  // std dev = 0,452, 157,000 (wgt'ed) examples reached here.  /* #neg=45 #pos=112 */
# %   | | | else return -0.006554432809046287;  // std dev = 0,857, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( fan(B), tweets(E, C), club(E) )
# %   | | | then return 0.08308968074560089;  // std dev = 0,451, 488,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=139 */
# %   | | | else return 0.11157842637982704;  // std dev = 0,400, 138,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=109 */
# %   | else if ( club(A), fan(B) )
# %   | | then return 0.2249835651416315;  // std dev = 0,489, 78,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=47 */
# %   | | else if ( fan(B) )
# %   | | | then if ( tweets(F, C), club(F) )
# %   | | | | then return 0.1212437469467464;  // std dev = 0,473, 74,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=25 */
# %   | | | | else return 0.09296951404374006;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else return 0.17177398962404752;  // std dev = 0,360, 64,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=53 */
# %   else return -0.008209139489609312;  // std dev = 0,374, 1.382,000 (wgt'ed) examples reached here.  /* #neg=1.090 #pos=292 */
# WILL Produced-Tree #9
# % FOR follows(A, B):
# %   if ( fan(B), fan(A) )
# %   then return -0.0067549514895065155;  // std dev = 0,382, 1.339,000 (wgt'ed) examples reached here.  /* #neg=1.096 #pos=243 */
# %   else if ( club(B) )
# %   | then return 0.1571549231855409;  // std dev = 0,411, 309,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=225 */
# %   | else if ( tweets(B, C), tweets(A, C) )
# %   | | then if ( news(B) )
# %   | | | then if ( news(A), tweets(D, C), club(D) )
# %   | | | | then return 0.1856358361381673;  // std dev = 0,381, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | | | | else if ( fan(A) )
# %   | | | | | then return 0.08512035687992626;  // std dev = 5,431, 154,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=114 */
# %   | | | | | else return 0.03376143207231625;  // std dev = 1,798, 19,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=14 */
# %   | | | else if ( news(A), tweets(E, C), club(E) )
# %   | | | | then return 0.1409159435907375;  // std dev = 0,485, 66,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=25 */
# %   | | | | else return 0.1651705805064518;  // std dev = 0,491, 81,000 (wgt'ed) examples reached here.  /* #neg=33 #pos=48 */
# %   | | else if ( fan(B), tweets(B, F) )
# %   | | | then return -0.046682938445537246;  // std dev = 0,333, 102,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=13 */
# %   | | | else return 0.07925453193882881;  // std dev = 0,449, 238,000 (wgt'ed) examples reached here.  /* #neg=154 #pos=84 */
# WILL Produced-Tree #10
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( news(B), news(A) )
# %   | then return -0.005830590342029146;  // std dev = 0,462, 21,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=14 */
# %   | else if ( fan(A), tweets(D, C), club(D) )
# %   | | then if ( club(B) )
# %   | | | then return 0.09422594810664714;  // std dev = 0,364, 127,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=107 */
# %   | | | else if ( fan(B) )
# %   | | | | then return 0.08142482964864538;  // std dev = 0,456, 470,000 (wgt'ed) examples reached here.  /* #neg=331 #pos=139 */
# %   | | | | else return 0.07060282335212634;  // std dev = 0,435, 150,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=112 */
# %   | | else if ( club(B) )
# %   | | | then return 0.07515718285748162;  // std dev = 0,372, 30,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=25 */
# %   | | | else if ( fan(A), fan(B) )
# %   | | | | then return 0.23063979204162854;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else if ( club(A) )
# %   | | | | | then return 0.12584739475934864;  // std dev = 4,560, 95,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=61 */
# %   | | | | | else return 0.10537539501417952;  // std dev = 4,113, 73,000 (wgt'ed) examples reached here.  /* #neg=45 #pos=28 */
# %   else return -0.008124274428900449;  // std dev = 0,378, 1.331,000 (wgt'ed) examples reached here.  /* #neg=1.039 #pos=292 */
# Results
#    AUC ROC   = 0.835933
#    AUC PR    = 0.19904
#    CLL	      = -0.291865
#    Precision = 0.224932 at threshold = 0.5
#    Recall    = 0.468927
#    F1        = 0.304029
#
#
# Total learning time: 79.815 seconds
# Total inference time: 9.48 seconds
# AUC ROC: 0.835933
#
#
# WILL Produced-Tree #1
# % FOR follows(A, B):
# %   if ( fan(B) )
# %   then return 0.05790753497880728;  // std dev = 0,400, 1.657,000 (wgt'ed) examples reached here.  /* #neg=1.326 #pos=331 */
# %   else if ( tweets(A, C), tweets(B, C) )
# %   | then return 0.6965635692458498;  // std dev = 0,368, 328,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=275 */
# %   | else if ( news(B), fan(A), tweets(A, D) )
# %   | | then return 0.03996711691769416;  // std dev = 0,386, 33,000 (wgt'ed) examples reached here.  /* #neg=27 #pos=6 */
# %   | | else if ( news(B) )
# %   | | | then if ( fan(A) )
# %   | | | | then return 0.39868947564005247;  // std dev = 0,498, 37,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=20 */
# %   | | | | else if ( news(A) )
# %   | | | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | | else return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( tweets(A, E) )
# %   | | | | then if ( news(A) )
# %   | | | | | then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | | else return 0.49276431971489587;  // std dev = 3,472, 52,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=33 */
# %   | | | | else return 0.5188632208137969;  // std dev = 0,473, 56,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=37 */
# WILL Produced-Tree #2
# % FOR follows(A, B):
# %   if ( fan(B), fan(A) )
# %   then return 0.024524080995975025;  // std dev = 0,379, 1.400,000 (wgt'ed) examples reached here.  /* #neg=1.157 #pos=243 */
# %   else if ( tweets(B, C), tweets(A, C) )
# %   | then return 0.5568380946486876;  // std dev = 0,407, 439,000 (wgt'ed) examples reached here.  /* #neg=96 #pos=343 */
# %   | else if ( news(A), fan(B) )
# %   | | then return -0.11268371121181801;  // std dev = 0,187, 55,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=2 */
# %   | | else if ( club(B) )
# %   | | | then if ( fan(A), tweets(A, D) )
# %   | | | | then return 0.35068658115950935;  // std dev = 0,496, 55,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=31 */
# %   | | | | else if ( fan(A) )
# %   | | | | | then return 0.42057425374119417;  // std dev = 3,660, 58,000 (wgt'ed) examples reached here.  /* #neg=21 #pos=37 */
# %   | | | | | else return 0.5046181981253766;  // std dev = 1,196, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   | | | else if ( news(B), tweets(A, E) )
# %   | | | | then return 0.09708536719739078;  // std dev = 0,436, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | | else if ( tweets(B, F) )
# %   | | | | | then return 0.2026743180818204;  // std dev = 4,064, 70,000 (wgt'ed) examples reached here.  /* #neg=43 #pos=27 */
# %   | | | | | else return 0.24380979528168867;  // std dev = 2,584, 28,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=11 */
# WILL Produced-Tree #3
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( fan(B) )
# %   | then if ( club(A) )
# %   | | then return 0.5193158955170335;  // std dev = 0,431, 73,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=55 */
# %   | | else if ( fan(A) )
# %   | | | then return 0.20364358450807027;  // std dev = 0,479, 489,000 (wgt'ed) examples reached here.  /* #neg=315 #pos=174 */
# %   | | | else return 0.036724571316120634;  // std dev = 0,444, 48,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=13 */
# %   | else return 0.4900438387945855;  // std dev = 0,350, 321,000 (wgt'ed) examples reached here.  /* #neg=46 #pos=275 */
# %   else if ( fan(B) )
# %   | then return -0.06216761084759186;  // std dev = 0,286, 982,000 (wgt'ed) examples reached here.  /* #neg=893 #pos=89 */
# %   | else if ( news(B), fan(A) )
# %   | | then if ( tweets(A, D) )
# %   | | | then return 0.04752982702866057;  // std dev = 0,405, 29,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=6 */
# %   | | | else return 0.20306469203116412;  // std dev = 0,496, 46,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=20 */
# %   | | else if ( tweets(A, E) )
# %   | | | then return 0.3337710791670778;  // std dev = 0,488, 64,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=39 */
# %   | | | else return 0.49001221118496807;  // std dev = 0,409, 47,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=37 */
# WILL Produced-Tree #4
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( club(B) )
# %   | then return 0.419198148244042;  // std dev = 0,293, 158,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=143 */
# %   | else if ( fan(B), fan(A) )
# %   | | then return 0.18442200792719413;  // std dev = 0,481, 477,000 (wgt'ed) examples reached here.  /* #neg=303 #pos=174 */
# %   | | else if ( news(A), fan(B) )
# %   | | | then return 0.04185097194771791;  // std dev = 0,450, 46,000 (wgt'ed) examples reached here.  /* #neg=33 #pos=13 */
# %   | | | else if ( club(A) )
# %   | | | | then if ( fan(B) )
# %   | | | | | then return 0.4038363633303994;  // std dev = 3,758, 74,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=55 */
# %   | | | | | else return 0.4141348571048007;  // std dev = 0,949, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# %   | | | | else if ( news(A) )
# %   | | | | | then return 0.2641348571048007;  // std dev = 1,732, 16,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=12 */
# %   | | | | | else return 0.2796520984841103;  // std dev = 5,102, 145,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=111 */
# %   else if ( fan(B) )
# %   | then return -0.054879457435218895;  // std dev = 0,285, 987,000 (wgt'ed) examples reached here.  /* #neg=898 #pos=89 */
# %   | else return 0.22570126531312992;  // std dev = 0,481, 186,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=102 */
# WILL Produced-Tree #5
# % FOR follows(A, B):
# %   if ( fan(B) )
# %   then if ( tweets(A, C), tweets(B, C) )
# %   | then if ( fan(A), tweets(D, C), club(D) )
# %   | | then return 0.1368348375453715;  // std dev = 0,476, 497,000 (wgt'ed) examples reached here.  /* #neg=325 #pos=172 */
# %   | | else return 0.18033307743864085;  // std dev = 0,456, 133,000 (wgt'ed) examples reached here.  /* #neg=63 #pos=70 */
# %   | else return -0.050929552689359996;  // std dev = 0,282, 1.016,000 (wgt'ed) examples reached here.  /* #neg=927 #pos=89 */
# %   else if ( club(B), tweets(A, E) )
# %   | then return 0.3214146487600019;  // std dev = 0,327, 207,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=179 */
# %   | else if ( news(A), tweets(B, F), tweets(A, F) )
# %   | | then return 0.3054333126413024;  // std dev = 0,350, 14,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=12 */
# %   | | else if ( fan(A), tweets(B, G), tweets(A, G) )
# %   | | | then return 0.2728139991424511;  // std dev = 0,377, 134,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=111 */
# %   | | | else if ( tweets(A, H), fan(A) )
# %   | | | | then return 0.05054696792642847;  // std dev = 0,433, 24,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=6 */
# %   | | | | else if ( club(A) )
# %   | | | | | then return 0.1586356002714991;  // std dev = 1,803, 16,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=11 */
# %   | | | | | else return 0.20831015455205476;  // std dev = 4,718, 95,000 (wgt'ed) examples reached here.  /* #neg=37 #pos=58 */
# WILL Produced-Tree #6
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( fan(B), news(A) )
# %   | then return -0.01836054795638432;  // std dev = 0,441, 49,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=13 */
# %   | else if ( club(B), fan(A) )
# %   | | then return 0.25723113487920063;  // std dev = 0,268, 128,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=118 */
# %   | | else if ( club(A), fan(B) )
# %   | | | then return 0.22555908121719967;  // std dev = 0,456, 78,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=55 */
# %   | | | else if ( news(B), news(A) )
# %   | | | | then return 0.29756423959666356;  // std dev = 0,266, 13,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=12 */
# %   | | | | else if ( fan(B), tweets(D, C), club(D) )
# %   | | | | | then return 0.13552623725071486;  // std dev = 10,424, 467,000 (wgt'ed) examples reached here.  /* #neg=295 #pos=172 */
# %   | | | | | else return 0.1587476914419556;  // std dev = 5,657, 189,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=147 */
# %   else if ( fan(B), fan(A) )
# %   | then return -0.0578774571156687;  // std dev = 0,262, 934,000 (wgt'ed) examples reached here.  /* #neg=865 #pos=69 */
# %   | else if ( news(A), fan(B) )
# %   | | then return -0.07138010019656747;  // std dev = 0,208, 44,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=2 */
# %   | | else return 0.12801310647677705;  // std dev = 0,480, 242,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=120 */
# WILL Produced-Tree #7
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( club(B) )
# %   | then return 0.21263936388281032;  // std dev = 0,258, 154,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=143 */
# %   | else if ( news(B), fan(A) )
# %   | | then return 0.08690678897213217;  // std dev = 0,436, 149,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=111 */
# %   | | else if ( club(A) )
# %   | | | then if ( fan(B) )
# %   | | | | then return 0.21753895425964856;  // std dev = 0,431, 73,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=55 */
# %   | | | | else return 0.15556810691570566;  // std dev = 0,386, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | else if ( news(A), fan(B) )
# %   | | | | then return -0.05581274236192139;  // std dev = 0,417, 58,000 (wgt'ed) examples reached here.  /* #neg=45 #pos=13 */
# %   | | | | else if ( fan(A), tweets(D, C), club(D) )
# %   | | | | | then return 0.10424920803361801;  // std dev = 10,475, 475,000 (wgt'ed) examples reached here.  /* #neg=303 #pos=172 */
# %   | | | | | else return 0.1333260781068917;  // std dev = 1,856, 19,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=14 */
# %   else if ( fan(B), fan(A) )
# %   | then return -0.04748204028763212;  // std dev = 0,268, 887,000 (wgt'ed) examples reached here.  /* #neg=818 #pos=69 */
# %   | else return 0.05100119207562922;  // std dev = 0,456, 301,000 (wgt'ed) examples reached here.  /* #neg=179 #pos=122 */
# WILL Produced-Tree #8
# % FOR follows(A, B):
# %   if ( tweets(B, C), tweets(A, C) )
# %   then if ( club(A), fan(B) )
# %   | then return 0.1963521760081638;  // std dev = 0,410, 70,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=55 */
# %   | else if ( fan(A) )
# %   | | then if ( club(B) )
# %   | | | then return 0.14053556257441724;  // std dev = 0,299, 131,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=118 */
# %   | | | else if ( fan(B), tweets(D, C), club(D) )
# %   | | | | then return 0.1022274861377626;  // std dev = 0,486, 452,000 (wgt'ed) examples reached here.  /* #neg=280 #pos=172 */
# %   | | | | else return 0.11265333245408776;  // std dev = 0,416, 144,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=113 */
# %   | | else if ( club(B) )
# %   | | | then return 0.18410674086529222;  // std dev = 0,262, 27,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=25 */
# %   | | | else if ( news(B) )
# %   | | | | then if ( news(A) )
# %   | | | | | then return -0.05322090361346799;  // std dev = 2,000, 18,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=12 */
# %   | | | | | else return -0.05361021274761292;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | | else return 0.020049504734953733;  // std dev = 0,453, 45,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=13 */
# %   else return -0.01683049127246132;  // std dev = 0,322, 1.193,000 (wgt'ed) examples reached here.  /* #neg=1.002 #pos=191 */
# WILL Produced-Tree #9
# % FOR follows(A, B):
# %   if ( fan(B), fan(A) )
# %   then return 0.002103351045469203;  // std dev = 0,363, 1.330,000 (wgt'ed) examples reached here.  /* #neg=1.087 #pos=243 */
# %   else if ( news(A), fan(B) )
# %   | then return -0.061848213449670515;  // std dev = 0,328, 112,000 (wgt'ed) examples reached here.  /* #neg=97 #pos=15 */
# %   | else if ( club(A) )
# %   | | then if ( tweets(B, C), tweets(A, C) )
# %   | | | then return 0.13873356006911805;  // std dev = 0,398, 96,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=77 */
# %   | | | else if ( fan(B) )
# %   | | | | then if ( tweets(B, D) )
# %   | | | | | then return 0.17422096913892698;  // std dev = 2,133, 20,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=7 */
# %   | | | | | else return 0.22558894095928542;  // std dev = 2,553, 27,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=11 */
# %   | | | | else return 0.32041369661562813;  // std dev = 0,845, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else if ( news(B) )
# %   | | | then if ( fan(A), tweets(A, E), tweets(B, E) )
# %   | | | | then return 0.11472495963777173;  // std dev = 0,387, 136,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=111 */
# %   | | | | else return 0.033416039403677884;  // std dev = 0,470, 88,000 (wgt'ed) examples reached here.  /* #neg=49 #pos=39 */
# %   | | | else return 0.11370945546276444;  // std dev = 0,388, 253,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=201 */
# WILL Produced-Tree #10
# % FOR follows(A, B):
# %   if ( fan(B), fan(A) )
# %   then return -0.01574144047237747;  // std dev = 0,355, 1.442,000 (wgt'ed) examples reached here.  /* #neg=1.199 #pos=243 */
# %   else if ( news(A), fan(B) )
# %   | then return -0.049589945545466946;  // std dev = 0,337, 106,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=15 */
# %   | else if ( fan(A), news(B), tweets(A, C) )
# %   | | then if ( tweets(B, C) )
# %   | | | then return 0.040608202472179195;  // std dev = 0,424, 145,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=111 */
# %   | | | else return -0.05416557947314412;  // std dev = 0,390, 32,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=6 */
# %   | | else if ( club(A) )
# %   | | | then return 0.1392922250021348;  // std dev = 0,406, 152,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=99 */
# %   | | | else if ( fan(A) )
# %   | | | | then if ( news(B) )
# %   | | | | | then return 0.11679826186455174;  // std dev = 3,078, 38,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=20 */
# %   | | | | | else return 0.08265632630263373;  // std dev = 6,079, 238,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=186 */
# %   | | | | else if ( tweets(A, D), tweets(B, D), club(B) )
# %   | | | | | then return 0.06248051672732851;  // std dev = 1,309, 14,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=12 */
# %   | | | | | else return 0.0253464157291069;  // std dev = 2,207, 24,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=16 */
# Results
#    AUC ROC   = 0.780467
#    AUC PR    = 0.198217
#    CLL	      = -0.350451
#    Precision = 0.194457 at threshold = 0.5
#    Recall    = 0.539744
#    F1        = 0.285908
#
#
# Total learning time: 41.126 seconds
# Total inference time: 5.023 seconds
# AUC ROC: 0.780467

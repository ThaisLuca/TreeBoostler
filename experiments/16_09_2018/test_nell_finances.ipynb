# %%
from datasets.get_datasets import *
from boostedrevision import *
from boostsrl import boostsrl
import random

# %% [markdown]
# ## Dataset

# %%
target = 'countryhascompanyoffice'

bk = ['countryhascompanyoffice(+country,+company).',
      'countryhascompanyoffice(+country,-company).',
      'countryhascompanyoffice(-country,+company).',
      'companyeconomicsector(+company,+sector).',
      'companyeconomicsector(+company,-sector).',
      'companyeconomicsector(-company,+sector).',
      'companyceo(+company,+person).',
      'companyceo(+company,-person).',
      'companyceo(-company,+person).',
      'companyalsoknownas(+company,+company).',
      'companyalsoknownas(+company,-company).',
      'companyalsoknownas(-company,+company).',
      'cityhascompanyoffice(+city,+company).',
      'cityhascompanyoffice(+city,-company).',
      'cityhascompanyoffice(-city,+company).',]

[facts, pos, neg] = datasets.load('nell_finances', bk, target=target)

pos = datasets.split_into_folds(pos[0])
neg = datasets.split_into_folds(neg[0])

# %% [markdown]
# ## Background  configuration

# %%
background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Learning

# %%
for i in range(1):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( companyceo(B, F), companyalsoknownas(D, G) )
# %   | then if ( companyeconomicsector(G, E) )
# %   | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.8581489350995115;  // std dev = 2,38e-07, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   else if ( companyceo(B, H), companyeconomicsector(B, I) )
# %   | then if ( companyalsoknownas(B, J) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | else if ( companyeconomicsector(B, K) )
# %   | | then if ( companyeconomicsector(L, K), companyeconomicsector(M, K), companyalsoknownas(L, M) )
# %   | | | then return -0.030739953789376676;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( companyceo(B, N) )
# %   | | | then return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else return 0.2265699877310899;  // std dev = 0,482, 95,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=35 */
# WILL Produced-Tree #2
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( companyalsoknownas(B, F), companyceo(F, G) )
# %   | then return -0.13860748366558612;  // std dev = 0,059, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | else if ( companyalsoknownas(D, D) )
# %   | | then return 0.6942252456841973;  // std dev = 0,169, 29,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=28 */
# %   | | else return 0.7194734122109545;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   else if ( companyceo(B, H) )
# %   | then if ( companyeconomicsector(B, I) )
# %   | | then if ( companyalsoknownas(B, J) )
# %   | | | then return 0.448295606241962;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.5580193346218546;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else return 0.30874113578563506;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | else if ( companyeconomicsector(B, K) )
# %   | | then if ( companyeconomicsector(L, K), companyeconomicsector(M, K), companyalsoknownas(L, M) )
# %   | | | then return -0.027039036105351237;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else return 0.050922032513554226;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else return 0.1966930866480224;  // std dev = 0,482, 95,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=35 */
# WILL Produced-Tree #3
# % FOR countryhascompanyoffice(A, B):
# %   if ( companyalsoknownas(B, C), cityhascompanyoffice(D, C), companyeconomicsector(C, E) )
# %   then return -0.14705207289694333;  // std dev = 0,118, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   else if ( cityhascompanyoffice(F, B), cityhascompanyoffice(F, G), companyeconomicsector(G, H) )
# %   | then if ( companyalsoknownas(G, G) )
# %   | | then return 0.5392198869445699;  // std dev = 0,165, 29,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=28 */
# %   | | else return 0.48872872250107563;  // std dev = 0,200, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# %   | else if ( companyceo(B, I) )
# %   | | then if ( companyeconomicsector(B, J) )
# %   | | | then if ( companyalsoknownas(B, K) )
# %   | | | | then return 0.36236334632262296;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.4419486100244409;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.3564123687585864;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else if ( companyeconomicsector(B, L) )
# %   | | | then if ( companyeconomicsector(M, L), companyeconomicsector(N, L), companyalsoknownas(M, N) )
# %   | | | | then return -0.009962138856268742;  // std dev = 0,331, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# %   | | | | else return 0.04434629760466851;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | else return 0.16688747751178193;  // std dev = 0,482, 95,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=35 */
# WILL Produced-Tree #4
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( companyceo(B, F) )
# %   | then if ( companyalsoknownas(B, G), companyceo(G, H) )
# %   | | then return -0.1223936384341487;  // std dev = 0,070, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else return 0.2723860711714849;  // std dev = 0,838, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else return 0.42907000192221145;  // std dev = 0,015, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   else if ( companyeconomicsector(B, I) )
# %   | then if ( companyceo(B, J) )
# %   | | then if ( companyalsoknownas(B, K) )
# %   | | | then return 0.2807538536965855;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.33541139495094313;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else if ( companyeconomicsector(L, I), companyeconomicsector(M, I), companyalsoknownas(L, M) )
# %   | | | then return -0.021013677473520915;  // std dev = 0,314, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else return 0.038428662236904595;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | else return 0.14240778604358859;  // std dev = 0,483, 101,000 (wgt'ed) examples reached here.  /* #neg=63 #pos=38 */
# WILL Produced-Tree #5
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( companyceo(B, F), companyalsoknownas(D, G) )
# %   | then if ( companyeconomicsector(G, E) )
# %   | | then return 0.07903677987333253;  // std dev = 0,853, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return -0.10346244901756319;  // std dev = 0,057, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.3297006592524559;  // std dev = 0,042, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   else if ( companyceo(B, H) )
# %   | then if ( companyalsoknownas(B, I) )
# %   | | then return 0.09867729385771704;  // std dev = 0,907, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( companyeconomicsector(B, J) )
# %   | | | then return 0.25176837314502193;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.25346151813748297;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | else if ( companyeconomicsector(B, K) )
# %   | | then return -1.3095289331818496E-4;  // std dev = 0,348, 14,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=2 */
# %   | | else if ( companyalsoknownas(B, L) )
# %   | | | then return 0.14411008631986627;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else return 0.11077675298653354;  // std dev = 0,482, 90,000 (wgt'ed) examples reached here.  /* #neg=57 #pos=33 */
# WILL Produced-Tree #6
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( companyalsoknownas(D, D) )
# %   | then if ( companyeconomicsector(B, F) )
# %   | | then return 0.1013280704129653;  // std dev = 0,869, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else return 0.2591550690082283;  // std dev = 5,16e-08, 25,000 (wgt'ed) examples reached here.  /* #pos=25 */
# %   | else return 0.15619424518159938;  // std dev = 0,168, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   else if ( companyeconomicsector(B, G) )
# %   | then if ( companyceo(B, H) )
# %   | | then if ( companyalsoknownas(B, I) )
# %   | | | then return 0.18792741358426127;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.19047961032437172;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else return -1.1494958806826185E-4;  // std dev = 0,348, 14,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=2 */
# %   | else if ( companyceo(B, J) )
# %   | | then return 0.11817268697823109;  // std dev = 1,172, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | else if ( companyalsoknownas(B, K) )
# %   | | | then return 0.11572045060952782;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else return 0.0891202343886799;  // std dev = 0,482, 90,000 (wgt'ed) examples reached here.  /* #neg=57 #pos=33 */
# WILL Produced-Tree #7
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( companyceo(B, F) )
# %   | then if ( companyalsoknownas(D, D) )
# %   | | then return 0.0397905076158939;  // std dev = 0,848, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return -0.03390427507344751;  // std dev = 0,338, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | else return 0.21861428188352117;  // std dev = 0,059, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   else return 0.06937659301201893;  // std dev = 0,466, 123,000 (wgt'ed) examples reached here.  /* #neg=77 #pos=46 */
# WILL Produced-Tree #8
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( companyceo(B, F), companyalsoknownas(D, G) )
# %   | then if ( companyeconomicsector(G, E) )
# %   | | then return 0.03111395715234922;  // std dev = 0,847, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return -0.10520643094362622;  // std dev = 0,058, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else return 0.18607506931022177;  // std dev = 0,100, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   else if ( companyceo(B, H) )
# %   | then if ( companyalsoknownas(B, I) )
# %   | | then return 0.018012117398016336;  // std dev = 0,895, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( companyeconomicsector(B, J) )
# %   | | | then return 0.13067076616096313;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.14816988142550727;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | else if ( companyeconomicsector(B, K) )
# %   | | then return -0.008788672598168979;  // std dev = 0,348, 14,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=2 */
# %   | | else return 0.05732075323355185;  // std dev = 0,482, 95,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=35 */
# WILL Produced-Tree #9
# % FOR countryhascompanyoffice(A, B):
# %   if ( companyalsoknownas(B, C), companyeconomicsector(C, D), cityhascompanyoffice(E, C) )
# %   then return -0.13921496780254994;  // std dev = 0,196, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   else if ( cityhascompanyoffice(F, B), cityhascompanyoffice(F, G), companyeconomicsector(G, H) )
# %   | then if ( companyeconomicsector(B, H), companyceo(B, I) )
# %   | | then return 0.030927964390325025;  // std dev = 0,841, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.15956661130011401;  // std dev = 0,090, 35,000 (wgt'ed) examples reached here.  /* #pos=35 */
# %   | else if ( companyalsoknownas(B, J), companyalsoknownas(J, K), companyeconomicsector(K, L) )
# %   | | then return 0.2554262208126801;  // std dev = 0,943, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | else if ( companyceo(B, M) )
# %   | | | then if ( companyeconomicsector(B, N) )
# %   | | | | then return 0.1024151068473493;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | else return 0.11127536180058953;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | else if ( companyeconomicsector(B, P) )
# %   | | | | then if ( companyeconomicsector(Q, P), companyeconomicsector(R, P), companyalsoknownas(Q, R) )
# %   | | | | | then return -0.013427463839984055;  // std dev = 0,935, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# %   | | | | | else return 0.024597499868362276;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else return 0.038319902951717985;  // std dev = 0,481, 94,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=34 */
# WILL Produced-Tree #10
# % FOR countryhascompanyoffice(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then return 0.10726840594262842;  // std dev = 0,148, 43,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=37 */
# %   else if ( companyalsoknownas(B, F) )
# %   | then if ( cityhascompanyoffice(G, F) )
# %   | | then return 0.07393996745376635;  // std dev = 0,661, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else if ( companyeconomicsector(B, H) )
# %   | | | then return 0.057062645427246074;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.094660425794589;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | else if ( companyceo(B, I) )
# %   | | then if ( companyeconomicsector(B, J) )
# %   | | | then return 0.08125624934122185;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.08346446547915867;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else if ( companyeconomicsector(B, K) )
# %   | | | then if ( companyeconomicsector(L, K), companyeconomicsector(M, K), companyalsoknownas(L, M) )
# %   | | | | then return -0.011833794534463416;  // std dev = 0,331, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# %   | | | | else return 0.0210113524677144;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | else return 0.035414563205932614;  // std dev = 0,482, 90,000 (wgt'ed) examples reached here.  /* #neg=57 #pos=33 */
# Results
#    AUC ROC   = 0.607347
#    AUC PR    = 0.684515
#    CLL	      = -0.702552
#    Precision = 0.673684 at threshold = 0.5
#    Recall    = 0.386707
#    F1        = 0.491363
#
#
# Total learning time: 139.531 seconds
# Total inference time: 4.263 seconds
# AUC ROC: 0.607347

# %%
target = 'companyeconomicsector'

bk = ['countryhascompanyoffice(+country,+company).',
      'countryhascompanyoffice(+country,-company).',
      'countryhascompanyoffice(-country,+company).',
      'companyeconomicsector(+company,+sector).',
      'companyeconomicsector(+company,-sector).',
      'companyeconomicsector(-company,+sector).',
      'companyceo(+company,+person).',
      'companyceo(+company,-person).',
      'companyceo(-company,+person).',
      'companyalsoknownas(+company,+company).',
      'companyalsoknownas(+company,-company).',
      'companyalsoknownas(-company,+company).',
      'cityhascompanyoffice(+city,+company).',
      'cityhascompanyoffice(+city,-company).',
      'cityhascompanyoffice(-city,+company).',]

[facts, pos, neg] = datasets.load('nell_finances', bk, target=target)

pos = datasets.split_into_folds(pos[0])
neg = datasets.split_into_folds(neg[0])

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(1):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C) )
# %   then if ( cityhascompanyoffice(D, A), companyalsoknownas(C, E), companyalsoknownas(E, E) )
# %   | then return 0.0803711573217344;  // std dev = 0,416, 9,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=2 */
# %   | else if ( cityhascompanyoffice(F, C) )
# %   | | then return 0.5248156017661789;  // std dev = 0,471, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | else if ( companyceo(A, G) )
# %   | | | then return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else return 0.274815601766179;  // std dev = 0,493, 12,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=5 */
# %   else if ( cityhascompanyoffice(H, A) )
# %   | then if ( cityhascompanyoffice(H, I), companyceo(I, J) )
# %   | | then if ( companyceo(A, K) )
# %   | | | then return 0.5581489350995124;  // std dev = 0,458, 10,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=7 */
# %   | | | else if ( countryhascompanyoffice(L, I) )
# %   | | | | then return 0.4036034805540578;  // std dev = 0,498, 33,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=18 */
# %   | | | | else return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else return 0.3471357192404781;  // std dev = 0,500, 227,000 (wgt'ed) examples reached here.  /* #neg=116 #pos=111 */
# WILL Produced-Tree #2
# % FOR companyeconomicsector(A, B):
# %   if ( countryhascompanyoffice(C, A), companyceo(A, D) )
# %   then return 0.6640575475112497;  // std dev = 0,334, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   else if ( companyalsoknownas(A, E), companyceo(A, F), cityhascompanyoffice(G, A) )
# %   | then if ( companyalsoknownas(E, H), companyalsoknownas(H, H) )
# %   | | then return 0.014747689426266836;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   | | else return 0.05268129702970058;  // std dev = 0,842, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | else if ( countryhascompanyoffice(I, A) )
# %   | | then if ( countryhascompanyoffice(I, J), companyceo(J, K) )
# %   | | | then return 0.10955611717950324;  // std dev = 0,459, 10,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=3 */
# %   | | | else return -0.1873530803108382;  // std dev = 0,047, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else if ( cityhascompanyoffice(L, A) )
# %   | | | then if ( companyalsoknownas(A, M) )
# %   | | | | then return 0.4925969950314985;  // std dev = 0,791, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( cityhascompanyoffice(L, N), companyceo(N, P) )
# %   | | | | | then return 0.3571690986692728;  // std dev = 3,247, 43,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=24 */
# %   | | | | | else return 0.7194734122109545;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.3066480802594986;  // std dev = 0,500, 230,000 (wgt'ed) examples reached here.  /* #neg=116 #pos=114 */
# WILL Produced-Tree #3
# % FOR companyeconomicsector(A, B):
# %   if ( countryhascompanyoffice(C, A), companyceo(A, D) )
# %   then return 0.5334812676036298;  // std dev = 0,335, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   else if ( companyceo(A, E) )
# %   | then return 0.15574542720525011;  // std dev = 0,475, 36,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=14 */
# %   | else if ( cityhascompanyoffice(F, A) )
# %   | | then if ( companyalsoknownas(A, G), companyceo(G, H) )
# %   | | | then return 0.1390923382684808;  // std dev = 0,780, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else if ( cityhascompanyoffice(F, I), companyalsoknownas(I, J), countryhascompanyoffice(K, J) )
# %   | | | | then return 0.2562786832661913;  // std dev = 0,498, 31,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=16 */
# %   | | | | else return 0.471770474128275;  // std dev = 0,357, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   | | else if ( countryhascompanyoffice(L, A) )
# %   | | | then return 0.05202920533694342;  // std dev = 0,428, 12,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=3 */
# %   | | | else if ( companyalsoknownas(A, M) )
# %   | | | | then if ( companyceo(M, N) )
# %   | | | | | then return 0.08947979694220869;  // std dev = 0,778, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.27180586601077555;  // std dev = 1,581, 10,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=5 */
# %   | | | | else return 0.2663568004760297;  // std dev = 0,500, 199,000 (wgt'ed) examples reached here.  /* #neg=98 #pos=101 */
# WILL Produced-Tree #4
# % FOR companyeconomicsector(A, B):
# %   if ( companyceo(A, C) )
# %   then if ( companyalsoknownas(A, D), cityhascompanyoffice(E, A) )
# %   | then return 0.04443929281147823;  // std dev = 0,419, 13,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=4 */
# %   | else if ( countryhascompanyoffice(F, A) )
# %   | | then return 0.5380557260357632;  // std dev = 0,068, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else if ( cityhascompanyoffice(G, A) )
# %   | | | then if ( cityhascompanyoffice(G, H), companyalsoknownas(H, H) )
# %   | | | | then return 0.17457186002263989;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.4245718600226399;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else return 0.11998205647537707;  // std dev = 0,488, 18,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=7 */
# %   else if ( companyalsoknownas(A, I), companyceo(I, J) )
# %   | then return 0.05314061648492505;  // std dev = 0,428, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# %   | else if ( countryhascompanyoffice(K, A) )
# %   | | then if ( countryhascompanyoffice(K, L), countryhascompanyoffice(K, M), companyalsoknownas(L, M) )
# %   | | | then return 0.11243705354971814;  // std dev = 0,475, 9,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=3 */
# %   | | | else return -0.1849714464787475;  // std dev = 0,038, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else return 0.2213170701791041;  // std dev = 0,496, 249,000 (wgt'ed) examples reached here.  /* #neg=119 #pos=130 */
# WILL Produced-Tree #5
# % FOR companyeconomicsector(A, B):
# %   if ( countryhascompanyoffice(C, A), companyceo(A, D) )
# %   then return 0.31891434671455177;  // std dev = 0,310, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   else if ( countryhascompanyoffice(E, A) )
# %   | then if ( countryhascompanyoffice(E, F), companyceo(F, G) )
# %   | | then return 0.06465814877185598;  // std dev = 0,459, 10,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=3 */
# %   | | else return -0.1618792274668506;  // std dev = 0,050, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else if ( cityhascompanyoffice(H, A) )
# %   | | then if ( companyalsoknownas(A, I), companyceo(A, J) )
# %   | | | then return -0.005155808253551611;  // std dev = 0,392, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# %   | | | else if ( companyalsoknownas(A, K) )
# %   | | | | then return 0.332683482305437;  // std dev = 0,744, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( cityhascompanyoffice(H, L), countryhascompanyoffice(M, L) )
# %   | | | | | then return 0.18130142738073646;  // std dev = 3,105, 41,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=23 */
# %   | | | | | else return 0.3552456695466002;  // std dev = 0,886, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | else if ( companyceo(A, N) )
# %   | | | then return 0.09575509071082175;  // std dev = 0,488, 18,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=7 */
# %   | | | else return 0.16534222422399486;  // std dev = 0,499, 212,000 (wgt'ed) examples reached here.  /* #neg=105 #pos=107 */
# WILL Produced-Tree #6
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), cityhascompanyoffice(D, A), countryhascompanyoffice(E, C) )
# %   then return -0.11390687000493074;  // std dev = 0,713, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   else if ( cityhascompanyoffice(F, A) )
# %   | then if ( companyalsoknownas(A, G), companyceo(A, H) )
# %   | | then if ( companyalsoknownas(G, I), countryhascompanyoffice(J, I), cityhascompanyoffice(F, I) )
# %   | | | then return 0.35571118170448296;  // std dev = 0,713, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return -0.07147653394704943;  // std dev = 0,331, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | else if ( cityhascompanyoffice(F, K), companyalsoknownas(K, K) )
# %   | | | then if ( companyceo(A, L) )
# %   | | | | then return 0.16390744645257563;  // std dev = 1,030, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | | else return 0.11836400207996252;  // std dev = 0,497, 31,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=16 */
# %   | | | else if ( cityhascompanyoffice(F, M), companyalsoknownas(M, N), companyceo(M, P) )
# %   | | | | then return 0.5037818480304165;  // std dev = 0,079, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else if ( cityhascompanyoffice(F, Q), companyceo(Q, R) )
# %   | | | | | then return 0.10308099953371297;  // std dev = 1,445, 9,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=5 */
# %   | | | | | else return 0.32351867921742383;  // std dev = 0,038, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else return 0.12163004243976022;  // std dev = 0,493, 245,000 (wgt'ed) examples reached here.  /* #neg=125 #pos=120 */
# WILL Produced-Tree #7
# % FOR companyeconomicsector(A, B):
# %   if ( countryhascompanyoffice(C, A) )
# %   then return 0.0666546387715477;  // std dev = 0,381, 22,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=10 */
# %   else if ( cityhascompanyoffice(D, A) )
# %   | then if ( companyceo(A, E), companyalsoknownas(A, F) )
# %   | | then if ( companyalsoknownas(F, G), companyalsoknownas(G, G) )
# %   | | | then return -0.02599604270888023;  // std dev = 0,864, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   | | | else return 0.023367302617432868;  // std dev = 0,840, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else if ( cityhascompanyoffice(D, H), countryhascompanyoffice(I, H) )
# %   | | | then if ( companyceo(H, J) )
# %   | | | | then if ( companyalsoknownas(H, H) )
# %   | | | | | then return 0.09751779537771395;  // std dev = 2,911, 34,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=18 */
# %   | | | | | else return 0.2994467497720546;  // std dev = 0,824, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else return -0.0790877543056469;  // std dev = 0,706, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.2318148592344195;  // std dev = 0,886, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | else if ( companyceo(A, K) )
# %   | | then return 0.04879209428495379;  // std dev = 0,488, 18,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=7 */
# %   | | else return 0.09840317801736496;  // std dev = 0,499, 212,000 (wgt'ed) examples reached here.  /* #neg=105 #pos=107 */
# WILL Produced-Tree #8
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C), cityhascompanyoffice(D, A), companyceo(A, E) )
# %   then if ( cityhascompanyoffice(D, C) )
# %   | then return -0.09520883734003416;  // std dev = 0,713, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | else if ( companyalsoknownas(C, F), companyalsoknownas(F, F) )
# %   | | then return 0.006976429421651181;  // std dev = 0,850, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else return 0.08141171698601794;  // std dev = 0,884, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   else if ( cityhascompanyoffice(G, A) )
# %   | then if ( cityhascompanyoffice(G, H), countryhascompanyoffice(I, H) )
# %   | | then if ( companyceo(H, J) )
# %   | | | then if ( companyalsoknownas(H, H) )
# %   | | | | then return 0.07245204117954601;  // std dev = 0,485, 37,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=20 */
# %   | | | | else return 0.22858452543159236;  // std dev = 0,825, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | else return -0.07463833158708835;  // std dev = 0,705, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else return 0.18048078881627813;  // std dev = 0,886, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | else return 0.07095599890294557;  // std dev = 0,493, 245,000 (wgt'ed) examples reached here.  /* #neg=125 #pos=120 */
# WILL Produced-Tree #9
# % FOR companyeconomicsector(A, B):
# %   if ( companyalsoknownas(A, C) )
# %   then if ( countryhascompanyoffice(D, C) )
# %   | then return -0.05208216675052782;  // std dev = 0,802, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | else if ( cityhascompanyoffice(E, C), cityhascompanyoffice(E, F), companyalsoknownas(F, F) )
# %   | | then return 0.31739597631805133;  // std dev = 0,775, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | else return 0.027941341786391474;  // std dev = 0,440, 25,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=10 */
# %   else if ( cityhascompanyoffice(G, A), companyceo(A, H) )
# %   | then return 0.09063690337584354;  // std dev = 0,423, 10,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=7 */
# %   | else if ( companyceo(A, I) )
# %   | | then return 0.02243532921809192;  // std dev = 0,475, 17,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=7 */
# %   | | else if ( countryhascompanyoffice(J, A) )
# %   | | | then return -0.024816764759071488;  // std dev = 0,423, 12,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=3 */
# %   | | | else if ( cityhascompanyoffice(K, A) )
# %   | | | | then if ( cityhascompanyoffice(K, L), companyceo(L, M) )
# %   | | | | | then return 0.05238021223112711;  // std dev = 2,863, 35,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=19 */
# %   | | | | | else return 0.23938684991471;  // std dev = 0,132, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | else return 0.05791885623597694;  // std dev = 0,500, 199,000 (wgt'ed) examples reached here.  /* #neg=98 #pos=101 */
# WILL Produced-Tree #10
# % FOR companyeconomicsector(A, B):
# %   if ( countryhascompanyoffice(C, A), companyceo(A, D) )
# %   then return 0.19945326246032352;  // std dev = 0,282, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   else if ( cityhascompanyoffice(E, A), cityhascompanyoffice(E, F), companyceo(F, G) )
# %   | then if ( countryhascompanyoffice(H, F) )
# %   | | then if ( companyalsoknownas(F, F) )
# %   | | | then if ( companyceo(A, I) )
# %   | | | | then if ( companyalsoknownas(A, J) )
# %   | | | | | then return 0.09719949011006097;  // std dev = 0,810, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return -0.012859896924072967;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.03607233027758612;  // std dev = 0,496, 31,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=16 */
# %   | | | else return 0.12409276623059627;  // std dev = 0,376, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | else return -0.11076681266389085;  // std dev = 0,343, 10,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=3 */
# %   | else if ( companyalsoknownas(A, K), companyceo(K, L) )
# %   | | then return -0.10512019583391703;  // std dev = 0,721, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( companyceo(A, M) )
# %   | | | then return 0.01606128237999935;  // std dev = 0,488, 18,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=7 */
# %   | | | else return 0.045417317599219076;  // std dev = 0,493, 224,000 (wgt'ed) examples reached here.  /* #neg=111 #pos=113 */
# Results
#    AUC ROC   = 0.471902
#    AUC PR    = 0.475697
#    CLL	      = -0.740571
#    Precision = 0.434426 at threshold = 0.5
#    Recall    = 0.085209
#    F1        = 0.142473
#
#
# Total learning time: 71.798 seconds
# Total inference time: 2.118 seconds
# AUC ROC: 0.471902

# %%
target = 'companyceo'

bk = ['countryhascompanyoffice(+country,+company).',
      'countryhascompanyoffice(+country,-company).',
      'countryhascompanyoffice(-country,+company).',
      'companyeconomicsector(+company,+sector).',
      'companyeconomicsector(+company,-sector).',
      'companyeconomicsector(-company,+sector).',
      'companyceo(+company,+person).',
      'companyceo(+company,-person).',
      'companyceo(-company,+person).',
      'companyalsoknownas(+company,+company).',
      'companyalsoknownas(+company,-company).',
      'companyalsoknownas(-company,+company).',
      'cityhascompanyoffice(+city,+company).',
      'cityhascompanyoffice(+city,-company).',
      'cityhascompanyoffice(-city,+company).',]

[facts, pos, neg] = datasets.load('nell_finances', bk, target=target)

pos = datasets.split_into_folds(pos[0])
neg = datasets.split_into_folds(neg[0])

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(1):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR companyceo(A, B):
# %   if ( countryhascompanyoffice(C, A), countryhascompanyoffice(C, D), companyalsoknownas(D, E) )
# %   then return 0.6581489350995123;  // std dev = 0,400, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   else if ( companyalsoknownas(A, F), companyeconomicsector(A, G), companyeconomicsector(F, H) )
# %   | then return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | else if ( companyeconomicsector(A, I), companyeconomicsector(J, I), countryhascompanyoffice(K, J) )
# %   | | then if ( companyalsoknownas(A, L) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.23314893509951234;  // std dev = 0,484, 16,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=6 */
# %   | | else if ( cityhascompanyoffice(M, A) )
# %   | | | then if ( companyalsoknownas(A, N), cityhascompanyoffice(M, P), companyeconomicsector(P, Q) )
# %   | | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.4945125714631487;  // std dev = 0,481, 11,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=7 */
# %   | | | else if ( companyeconomicsector(A, R), companyeconomicsector(S, R), companyalsoknownas(S, S) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( companyalsoknownas(A, T), companyeconomicsector(T, U) )
# %   | | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.331833145625827;  // std dev = 4,353, 76,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=36 */
# WILL Produced-Tree #2
# % FOR companyceo(A, B):
# %   if ( companyalsoknownas(A, C), companyeconomicsector(A, D), cityhascompanyoffice(E, A) )
# %   then if ( countryhascompanyoffice(F, A) )
# %   | then return 0.4246860012885212;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | else return 0.010246554172837527;  // std dev = 0,849, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   else if ( companyalsoknownas(A, G), cityhascompanyoffice(H, G) )
# %   | then if ( cityhascompanyoffice(H, A) )
# %   | | then return 0.4748101056949838;  // std dev = 0,788, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.5284986209313751;  // std dev = 0,880, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else if ( companyalsoknownas(A, I) )
# %   | | then return 0.18865547449468417;  // std dev = 0,477, 13,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=5 */
# %   | | else if ( countryhascompanyoffice(J, A), countryhascompanyoffice(J, K), companyalsoknownas(K, L) )
# %   | | | then return 0.5913526679551879;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | else if ( companyeconomicsector(A, M), companyeconomicsector(N, M), countryhascompanyoffice(P, N) )
# %   | | | | then if ( companyalsoknownas(N, N) )
# %   | | | | | then return 0.16066757255144135;  // std dev = 1,414, 9,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=3 */
# %   | | | | | else return 0.25590566778953655;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | | else return 0.32768347438065254;  // std dev = 0,498, 79,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=41 */
# WILL Produced-Tree #3
# % FOR companyceo(A, B):
# %   if ( companyalsoknownas(A, C), companyeconomicsector(A, D), cityhascompanyoffice(E, A) )
# %   then if ( countryhascompanyoffice(F, A) )
# %   | then return 0.33864910620798944;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | else return 0.008909592029982052;  // std dev = 0,849, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   else if ( countryhascompanyoffice(G, A), countryhascompanyoffice(G, H), companyalsoknownas(H, I) )
# %   | then return 0.4951925078901583;  // std dev = 0,352, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | else if ( companyalsoknownas(A, J), cityhascompanyoffice(K, J) )
# %   | | then return 0.3686861322067471;  // std dev = 1,149, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | else if ( companyalsoknownas(A, L) )
# %   | | | then return 0.15729166331153724;  // std dev = 0,476, 13,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=5 */
# %   | | | else if ( companyeconomicsector(A, M), companyeconomicsector(N, M), countryhascompanyoffice(P, N) )
# %   | | | | then if ( companyalsoknownas(N, N) )
# %   | | | | | then return 0.1364966155730606;  // std dev = 1,414, 9,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=3 */
# %   | | | | | else return 0.21624274059408158;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | | else if ( cityhascompanyoffice(Q, A) )
# %   | | | | | then return 0.3266722555885111;  // std dev = 1,549, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | | | | else return 0.26393776663134205;  // std dev = 4,144, 69,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=35 */
# WILL Produced-Tree #4
# % FOR companyceo(A, B):
# %   if ( countryhascompanyoffice(C, A), companyalsoknownas(A, D), companyeconomicsector(D, E) )
# %   then return 0.5766289783233298;  // std dev = 0,041, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   else if ( cityhascompanyoffice(F, A), cityhascompanyoffice(F, G), companyalsoknownas(G, H) )
# %   | then if ( companyalsoknownas(A, I), countryhascompanyoffice(J, H) )
# %   | | then return -0.18954366212362386;  // std dev = 0,252, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else return 0.21873972199250644;  // std dev = 0,495, 17,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=9 */
# %   | else if ( companyalsoknownas(A, K) )
# %   | | then if ( companyeconomicsector(K, L) )
# %   | | | then return 0.35478040128702837;  // std dev = 0,908, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else return 0.10073023121767409;  // std dev = 0,466, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | else if ( cityhascompanyoffice(M, A) )
# %   | | | then return 0.35105937245594226;  // std dev = 0,441, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   | | | else if ( companyeconomicsector(A, N) )
# %   | | | | then if ( countryhascompanyoffice(P, A) )
# %   | | | | | then return 0.33745180148798526;  // std dev = 0,739, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.12387434176655653;  // std dev = 1,709, 13,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=5 */
# %   | | | | else return 0.21834401370271608;  // std dev = 0,497, 66,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=34 */
# WILL Produced-Tree #5
# % FOR companyceo(A, B):
# %   if ( companyalsoknownas(A, C) )
# %   then if ( countryhascompanyoffice(D, A), companyeconomicsector(C, E) )
# %   | then return 0.43381017361403984;  // std dev = 0,041, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( companyeconomicsector(A, F), companyeconomicsector(C, G) )
# %   | | then return -0.10791297436393728;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | else if ( companyeconomicsector(C, H) )
# %   | | | then return 0.22364068066433873;  // std dev = 1,164, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else if ( cityhascompanyoffice(I, A), cityhascompanyoffice(I, J), companyeconomicsector(J, K) )
# %   | | | | then return -0.018677024098686018;  // std dev = 0,883, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else return 0.1305661357018083;  // std dev = 0,475, 12,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=5 */
# %   else if ( countryhascompanyoffice(L, A), companyeconomicsector(A, M) )
# %   | then return 0.34198107636010855;  // std dev = 0,766, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | else if ( cityhascompanyoffice(N, A), cityhascompanyoffice(N, P), companyalsoknownas(P, Q) )
# %   | | then if ( companyalsoknownas(P, P) )
# %   | | | then return 0.21853806542423015;  // std dev = 1,175, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else return -0.1803584094712229;  // std dev = 0,916, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else return 0.16804688427326944;  // std dev = 0,491, 86,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=44 */
# WILL Produced-Tree #6
# % FOR companyceo(A, B):
# %   if ( companyalsoknownas(A, C), companyalsoknownas(C, D), companyeconomicsector(D, E) )
# %   then if ( countryhascompanyoffice(F, D), countryhascompanyoffice(F, G), companyalsoknownas(G, G) )
# %   | then return -0.06358694963087978;  // std dev = 0,329, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# %   | else if ( cityhascompanyoffice(H, A), companyeconomicsector(C, I) )
# %   | | then return 0.10226367934348249;  // std dev = 0,775, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.24976665175542218;  // std dev = 1,023, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else if ( countryhascompanyoffice(J, A), countryhascompanyoffice(J, K), companyalsoknownas(K, L) )
# %   | then return 0.24450077558632785;  // std dev = 0,304, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | else if ( companyeconomicsector(A, M), companyeconomicsector(N, M), countryhascompanyoffice(P, N) )
# %   | | then if ( companyalsoknownas(N, N) )
# %   | | | then if ( cityhascompanyoffice(Q, A) )
# %   | | | | then return 0.09686407800877471;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | else return -0.023335352290900294;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.09393532883124357;  // std dev = 0,493, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | else if ( cityhascompanyoffice(R, A), cityhascompanyoffice(R, S), countryhascompanyoffice(T, S) )
# %   | | | then return 0.21329927060532367;  // std dev = 0,446, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.12232061263837005;  // std dev = 0,494, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #7
# % FOR companyceo(A, B):
# %   if ( countryhascompanyoffice(C, A), companyeconomicsector(A, D) )
# %   then return 0.17993736808578908;  // std dev = 0,335, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   else if ( cityhascompanyoffice(E, A), cityhascompanyoffice(E, F), companyalsoknownas(F, G) )
# %   | then if ( companyeconomicsector(G, H), companyeconomicsector(F, H), companyalsoknownas(A, I) )
# %   | | then return -0.1212424820283426;  // std dev = 0,113, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | else if ( companyalsoknownas(G, A) )
# %   | | | then return 0.22386920988812933;  // std dev = 1,095, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else if ( companyalsoknownas(F, F) )
# %   | | | | then return 0.14670719813086852;  // std dev = 1,162, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | | else return -0.19024560813835323;  // std dev = 0,920, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | else if ( companyalsoknownas(A, J), companyeconomicsector(J, K) )
# %   | | then return 0.19907038514259143;  // std dev = 0,878, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | else if ( cityhascompanyoffice(L, A) )
# %   | | | then return 0.18882828501536122;  // std dev = 0,438, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   | | | else if ( companyalsoknownas(A, M) )
# %   | | | | then return 0.02184426566287045;  // std dev = 0,463, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.09376660684665213;  // std dev = 0,493, 79,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=39 */
# WILL Produced-Tree #8
# % FOR companyceo(A, B):
# %   if ( companyalsoknownas(A, C), companyalsoknownas(C, D), companyalsoknownas(D, D) )
# %   then return -0.022297546449098222;  // std dev = 0,801, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   else if ( companyalsoknownas(A, E), companyeconomicsector(E, F) )
# %   | then return 0.17318112502113187;  // std dev = 0,331, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   | else if ( cityhascompanyoffice(G, A), cityhascompanyoffice(G, H), countryhascompanyoffice(I, H) )
# %   | | then if ( countryhascompanyoffice(I, A), cityhascompanyoffice(G, J), companyalsoknownas(J, K) )
# %   | | | then return -0.08198683544622709;  // std dev = 0,735, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( companyeconomicsector(H, L), companyeconomicsector(A, L) )
# %   | | | | then return 0.04309844167341111;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | else if ( companyalsoknownas(A, M) )
# %   | | | | | then return 0.15628826989827604;  // std dev = 0,882, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | | else return 0.1859893694531227;  // std dev = 0,973, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | else if ( companyalsoknownas(A, N) )
# %   | | | then return 0.01695407479979788;  // std dev = 0,463, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | else return 0.07168296503819134;  // std dev = 0,491, 87,000 (wgt'ed) examples reached here.  /* #neg=43 #pos=44 */
# WILL Produced-Tree #9
# % FOR companyceo(A, B):
# %   if ( companyalsoknownas(A, C), companyalsoknownas(C, D), companyeconomicsector(D, E) )
# %   then if ( countryhascompanyoffice(F, D), countryhascompanyoffice(F, G), companyalsoknownas(G, G) )
# %   | then return -0.0683555277995156;  // std dev = 0,326, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# %   | else if ( cityhascompanyoffice(H, A), companyeconomicsector(C, I) )
# %   | | then return 0.012891984474380554;  // std dev = 0,761, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.13991961039876039;  // std dev = 1,014, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else if ( countryhascompanyoffice(J, A), countryhascompanyoffice(J, K), companyalsoknownas(K, L) )
# %   | then return 0.15971269130576246;  // std dev = 0,268, 7,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=6 */
# %   | else if ( companyeconomicsector(A, M), companyeconomicsector(N, M), countryhascompanyoffice(P, N) )
# %   | | then if ( companyalsoknownas(N, N) )
# %   | | | then if ( cityhascompanyoffice(Q, A) )
# %   | | | | then return 0.03314652888988211;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | else return -0.052451432519368235;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.028264837407740655;  // std dev = 0,493, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | else if ( cityhascompanyoffice(R, A), cityhascompanyoffice(R, S), countryhascompanyoffice(T, S) )
# %   | | | then return 0.12586503738429955;  // std dev = 0,414, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.05417884012068425;  // std dev = 0,493, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #10
# % FOR companyceo(A, B):
# %   if ( companyalsoknownas(A, C) )
# %   then return 0.02848311827799055;  // std dev = 0,405, 29,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=13 */
# %   else if ( companyeconomicsector(A, D), companyeconomicsector(E, D), companyalsoknownas(E, E) )
# %   | then if ( countryhascompanyoffice(F, E) )
# %   | | then if ( cityhascompanyoffice(G, A) )
# %   | | | then return 0.025414100343903755;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else return -0.041501484870371017;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else return 0.31921468055927144;  // std dev = 0,806, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else if ( cityhascompanyoffice(H, A), cityhascompanyoffice(H, I), companyalsoknownas(I, I) )
# %   | | then return 0.3074555308383828;  // std dev = 0,098, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( cityhascompanyoffice(J, A), cityhascompanyoffice(J, K), companyalsoknownas(K, L) )
# %   | | | then return -0.20542023554931532;  // std dev = 0,898, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else if ( countryhascompanyoffice(M, A) )
# %   | | | | then return 0.1502237755094455;  // std dev = 0,754, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | else if ( companyeconomicsector(A, N) )
# %   | | | | | then return -0.09614816506576045;  // std dev = 1,088, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | | | else return 0.042282620004073325;  // std dev = 4,172, 70,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=36 */
# Results
#    AUC ROC   = 0.44943
#    AUC PR    = 0.462491
#    CLL	      = -0.768025
#    Precision = 0.442029 at threshold = 0.5
#    Recall    = 0.234615
#    F1        = 0.306533
#
#
# Total learning time: 15.856 seconds
# Total inference time: 1.357 seconds
# AUC ROC: 0.44943

# %%
target = 'companyalsoknownas'

bk = ['countryhascompanyoffice(+country,+company).',
      'countryhascompanyoffice(+country,-company).',
      'countryhascompanyoffice(-country,+company).',
      'companyeconomicsector(+company,+sector).',
      'companyeconomicsector(+company,-sector).',
      'companyeconomicsector(-company,+sector).',
      'companyceo(+company,+person).',
      'companyceo(+company,-person).',
      'companyceo(-company,+person).',
      'companyalsoknownas(+company,+company).',
      'companyalsoknownas(+company,-company).',
      'companyalsoknownas(-company,+company).',
      'cityhascompanyoffice(+city,+company).',
      'cityhascompanyoffice(+city,-company).',
      'cityhascompanyoffice(-city,+company).',]

[facts, pos, neg] = datasets.load('nell_finances', bk, target=target)

pos = datasets.split_into_folds(pos[0])
neg = datasets.split_into_folds(neg[0])

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(1):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR companyalsoknownas(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then return 0.564031288040688;  // std dev = 0,456, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   else if ( companyceo(A, F), companyceo(B, G) )
# %   | then return -0.1418510649004878;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | else if ( companyceo(A, H) )
# %   | | then if ( cityhascompanyoffice(I, A), cityhascompanyoffice(I, J), countryhascompanyoffice(K, J) )
# %   | | | then return 0.6081489350995123;  // std dev = 0,433, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   | | | else return 0.39386322081379804;  // std dev = 0,499, 28,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=15 */
# %   | | else if ( countryhascompanyoffice(L, B) )
# %   | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | else if ( companyeconomicsector(B, M) )
# %   | | | | then if ( companyceo(B, N) )
# %   | | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.35814893509951234;  // std dev = 1,871, 14,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=7 */
# %   | | | | else if ( companyceo(B, P) )
# %   | | | | | then return 0.3581489350995123;  // std dev = 1,581, 10,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=5 */
# %   | | | | | else return 0.24638422921715805;  // std dev = 4,493, 85,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=33 */
# WILL Produced-Tree #2
# % FOR companyalsoknownas(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(C, D), companyeconomicsector(D, E) )
# %   then if ( countryhascompanyoffice(F, D), companyeconomicsector(B, G), companyceo(D, H) )
# %   | then if ( cityhascompanyoffice(I, A) )
# %   | | then return 0.4415281974812335;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return -0.2251384691854331;  // std dev = 7,45e-09, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | else return 0.621015376968413;  // std dev = 0,361, 26,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=22 */
# %   else if ( companyeconomicsector(A, J), companyeconomicsector(B, J) )
# %   | then return 0.7948514112693306;  // std dev = 0,034, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( companyceo(A, K), companyceo(B, L) )
# %   | | then return -0.12544463852839138;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #neg=8 */
# %   | | else if ( countryhascompanyoffice(M, B), companyeconomicsector(A, N) )
# %   | | | then return 0.764678474930819;  // std dev = 0,044, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else if ( countryhascompanyoffice(P, A) )
# %   | | | | then return 0.04294345215241668;  // std dev = 0,415, 13,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=3 */
# %   | | | | else if ( companyceo(A, Q) )
# %   | | | | | then return 0.39387717103439573;  // std dev = 2,880, 35,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=21 */
# %   | | | | | else return 0.2556678576748843;  // std dev = 5,019, 103,000 (wgt'ed) examples reached here.  /* #neg=58 #pos=45 */
# WILL Produced-Tree #3
# % FOR companyalsoknownas(A, B):
# %   if ( companyceo(B, C), companyceo(A, D) )
# %   then return 0.11897213163384383;  // std dev = 0,405, 17,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=6 */
# %   else if ( companyceo(B, E), companyeconomicsector(B, F) )
# %   | then return 0.47335492760304176;  // std dev = 0,365, 18,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=14 */
# %   | else if ( companyceo(A, G) )
# %   | | then if ( companyeconomicsector(A, H) )
# %   | | | then if ( companyeconomicsector(I, H), countryhascompanyoffice(J, I) )
# %   | | | | then return 0.34795420501357216;  // std dev = 0,449, 11,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=7 */
# %   | | | | else return 0.22581835640771725;  // std dev = 0,493, 16,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=8 */
# %   | | | else return 0.41563415267807774;  // std dev = 0,470, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | else if ( countryhascompanyoffice(K, B) )
# %   | | | then return 0.44030471938694876;  // std dev = 0,384, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   | | | else if ( companyeconomicsector(A, L) )
# %   | | | | then if ( cityhascompanyoffice(M, A) )
# %   | | | | | then return 0.008540206251380588;  // std dev = 0,907, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | | else return 0.3706659806014977;  // std dev = 1,459, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | | | else return 0.18744138195677645;  // std dev = 0,487, 100,000 (wgt'ed) examples reached here.  /* #neg=59 #pos=41 */
# WILL Produced-Tree #4
# % FOR companyalsoknownas(A, B):
# %   if ( cityhascompanyoffice(C, B), countryhascompanyoffice(D, A) )
# %   then return 0.5897546121294246;  // std dev = 0,170, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( companyeconomicsector(A, E), companyeconomicsector(F, E), cityhascompanyoffice(G, F) )
# %   | then return 0.17129912336033573;  // std dev = 0,445, 56,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=27 */
# %   | else if ( companyceo(B, H), companyeconomicsector(B, I) )
# %   | | then return 0.32082132519016765;  // std dev = 0,385, 20,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=14 */
# %   | | else if ( companyceo(A, J) )
# %   | | | then if ( cityhascompanyoffice(K, A) )
# %   | | | | then return -0.07222937078397833;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.46094120747395;  // std dev = 0,385, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | else if ( cityhascompanyoffice(L, B), companyceo(B, M) )
# %   | | | | then if ( cityhascompanyoffice(L, N), companyeconomicsector(N, P), countryhascompanyoffice(Q, N) )
# %   | | | | | then return 0.2307941358213681;  // std dev = 0,843, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return -0.05057180169080343;  // std dev = 0,908, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else if ( cityhascompanyoffice(R, A) )
# %   | | | | | then return 0.25222353244297513;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | | | else return 0.1601865596013675;  // std dev = 4,685, 93,000 (wgt'ed) examples reached here.  /* #neg=54 #pos=39 */
# WILL Produced-Tree #5
# % FOR companyalsoknownas(A, B):
# %   if ( cityhascompanyoffice(C, B) )
# %   then return 0.23470328015243896;  // std dev = 0,405, 40,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=27 */
# %   else if ( countryhascompanyoffice(D, B), countryhascompanyoffice(D, E), companyceo(E, F) )
# %   | then return 0.5179150527529764;  // std dev = 0,105, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( companyceo(B, G), companyeconomicsector(A, H) )
# %   | | then return -0.18845355240816294;  // std dev = 0,240, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | else if ( companyeconomicsector(B, I), companyeconomicsector(J, I), cityhascompanyoffice(K, J) )
# %   | | | then if ( companyeconomicsector(A, I) )
# %   | | | | then return 0.5073145457271231;  // std dev = 0,046, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | | else if ( companyceo(B, L) )
# %   | | | | | then return 0.31600765688602006;  // std dev = 0,588, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.12490166106987992;  // std dev = 2,061, 19,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=9 */
# %   | | | else if ( countryhascompanyoffice(M, A) )
# %   | | | | then return -0.07424994217365782;  // std dev = 0,378, 11,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=2 */
# %   | | | | else if ( cityhascompanyoffice(N, A), cityhascompanyoffice(N, P), countryhascompanyoffice(Q, P) )
# %   | | | | | then return 0.2708385799300113;  // std dev = 1,697, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | | | else return 0.13374232686509127;  // std dev = 4,897, 100,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=44 */
# WILL Produced-Tree #6
# % FOR companyalsoknownas(A, B):
# %   if ( cityhascompanyoffice(C, B) )
# %   then return 0.17934512720628787;  // std dev = 0,403, 40,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=27 */
# %   else if ( countryhascompanyoffice(D, A) )
# %   | then return -0.007331052222005925;  // std dev = 0,357, 17,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=5 */
# %   | else if ( countryhascompanyoffice(E, B) )
# %   | | then return 0.26519439027185804;  // std dev = 0,804, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | else if ( cityhascompanyoffice(F, A), cityhascompanyoffice(F, G), countryhascompanyoffice(H, G) )
# %   | | | then if ( companyeconomicsector(A, I), companyceo(A, J) )
# %   | | | | then return 0.4083805252518803;  // std dev = 0,208, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   | | | | else if ( companyceo(A, K) )
# %   | | | | | then return -0.12086281093512923;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return -0.013164365812838918;  // std dev = 1,137, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | else if ( companyeconomicsector(A, L), companyceo(A, M) )
# %   | | | | then return -0.022819991254553425;  // std dev = 0,461, 18,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=6 */
# %   | | | | else if ( companyceo(B, N), companyeconomicsector(B, P) )
# %   | | | | | then return 0.03926437982193244;  // std dev = 0,811, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | | else return 0.133817580592543;  // std dev = 4,815, 97,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=45 */
# WILL Produced-Tree #7
# % FOR companyalsoknownas(A, B):
# %   if ( cityhascompanyoffice(C, B), cityhascompanyoffice(D, A), companyeconomicsector(B, E) )
# %   then return 0.24351745509615969;  // std dev = 0,824, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   else if ( cityhascompanyoffice(F, B), countryhascompanyoffice(G, A) )
# %   | then return 0.37125238084044176;  // std dev = 0,165, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( companyceo(A, H) )
# %   | | then if ( companyeconomicsector(B, I) )
# %   | | | then return -0.0220165378868912;  // std dev = 0,398, 13,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=5 */
# %   | | | else if ( cityhascompanyoffice(J, A), companyceo(B, K) )
# %   | | | | then return -0.01780906819706807;  // std dev = 0,559, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else return 0.14214843228359814;  // std dev = 0,445, 36,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=22 */
# %   | | else if ( companyceo(B, L), companyeconomicsector(B, M), countryhascompanyoffice(N, B) )
# %   | | | then return -0.1826037821802524;  // std dev = 0,623, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else if ( companyceo(B, P), companyeconomicsector(B, Q) )
# %   | | | | then return 0.26157001837172594;  // std dev = 0,279, 13,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=11 */
# %   | | | | else if ( companyeconomicsector(A, R) )
# %   | | | | | then return 0.13620387972061418;  // std dev = 1,662, 17,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=9 */
# %   | | | | | else return 0.06156119571984384;  // std dev = 4,954, 105,000 (wgt'ed) examples reached here.  /* #neg=61 #pos=44 */
# WILL Produced-Tree #8
# % FOR companyalsoknownas(A, B):
# %   if ( cityhascompanyoffice(C, B), countryhascompanyoffice(D, A) )
# %   then return 0.28140757334287486;  // std dev = 0,154, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   else if ( cityhascompanyoffice(E, B), countryhascompanyoffice(F, B), companyceo(B, G) )
# %   | then if ( cityhascompanyoffice(H, A) )
# %   | | then return 0.08826592370195836;  // std dev = 0,772, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return -0.26135469516670595;  // std dev = 0,754, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | else if ( countryhascompanyoffice(I, B), countryhascompanyoffice(I, J), companyceo(J, K) )
# %   | | then return 0.33649796730425163;  // std dev = 0,062, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( companyeconomicsector(B, L), companyceo(A, M), companyceo(B, N) )
# %   | | | then if ( cityhascompanyoffice(P, B) )
# %   | | | | then return 0.04030263401261909;  // std dev = 1,085, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return -0.17293949216603985;  // std dev = 0,069, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else if ( cityhascompanyoffice(Q, B), cityhascompanyoffice(Q, R), companyeconomicsector(R, S) )
# %   | | | | then return 0.18776755646909113;  // std dev = 0,325, 19,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=15 */
# %   | | | | else if ( cityhascompanyoffice(T, B), cityhascompanyoffice(T, U), countryhascompanyoffice(W, U) )
# %   | | | | | then return -0.30721603292915506;  // std dev = 0,130, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | | else return 0.06868674589627305;  // std dev = 5,790, 154,000 (wgt'ed) examples reached here.  /* #neg=83 #pos=71 */
# WILL Produced-Tree #9
# % FOR companyalsoknownas(A, B):
# %   if ( countryhascompanyoffice(C, A), countryhascompanyoffice(C, D), companyceo(D, E) )
# %   then return -0.07137832496175696;  // std dev = 0,297, 10,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=3 */
# %   else if ( cityhascompanyoffice(F, B), cityhascompanyoffice(F, G), countryhascompanyoffice(H, G) )
# %   | then if ( companyeconomicsector(B, I), companyceo(G, J) )
# %   | | then return -0.2274243880020153;  // std dev = 0,360, 8,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=2 */
# %   | | else if ( companyceo(B, K) )
# %   | | | then return 0.0306134059716896;  // std dev = 0,385, 11,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=6 */
# %   | | | else return 0.3825855619853142;  // std dev = 0,048, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( companyceo(B, L) )
# %   | | then return 0.14075710291873744;  // std dev = 0,353, 30,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=20 */
# %   | | else if ( companyeconomicsector(A, M), companyeconomicsector(B, M) )
# %   | | | then return 0.3204645717964531;  // std dev = 0,083, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( companyceo(A, N), companyeconomicsector(B, P) )
# %   | | | | then return 0.22891109128914353;  // std dev = 0,761, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( companyceo(A, Q) )
# %   | | | | | then return 0.07985628830769666;  // std dev = 2,559, 33,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=20 */
# %   | | | | | else return 0.037086481221843236;  // std dev = 4,790, 99,000 (wgt'ed) examples reached here.  /* #neg=58 #pos=41 */
# WILL Produced-Tree #10
# % FOR companyalsoknownas(A, B):
# %   if ( countryhascompanyoffice(C, B), companyeconomicsector(A, D) )
# %   then return 0.17006993405303952;  // std dev = 0,772, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   else if ( companyeconomicsector(A, E), companyeconomicsector(B, F) )
# %   | then return -0.037785779982078056;  // std dev = 0,345, 15,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=7 */
# %   | else if ( cityhascompanyoffice(G, B) )
# %   | | then return 0.09744365364175119;  // std dev = 0,347, 33,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=23 */
# %   | | else if ( companyeconomicsector(A, H), companyeconomicsector(I, H), cityhascompanyoffice(J, I) )
# %   | | | then if ( cityhascompanyoffice(K, A), cityhascompanyoffice(K, L), countryhascompanyoffice(M, L) )
# %   | | | | then return 0.17243328710553976;  // std dev = 0,351, 13,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=8 */
# %   | | | | else if ( countryhascompanyoffice(N, I) )
# %   | | | | | then return -0.24137225986438424;  // std dev = 0,896, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   | | | | | else return -0.005670124644323245;  // std dev = 1,812, 15,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=6 */
# %   | | | else if ( companyceo(B, P) )
# %   | | | | then return 0.1091029939091953;  // std dev = 0,391, 11,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=6 */
# %   | | | | else if ( cityhascompanyoffice(Q, A), cityhascompanyoffice(Q, R), companyeconomicsector(R, S) )
# %   | | | | | then return -0.07720802770493027;  // std dev = 1,188, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | | | else return 0.03728297058394005;  // std dev = 4,700, 95,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=42 */
# Results
#    AUC ROC   = 0.577903
#    AUC PR    = 0.606819
#    CLL	      = -0.697801
#    Precision = 0.597458 at threshold = 0.5
#    Recall    = 0.3525
#    F1        = 0.443396
#
#
# Total learning time: 15.53 seconds
# Total inference time: 1.392 seconds
# AUC ROC: 0.577903

# %%
target = 'cityhascompanyoffice'

bk = ['countryhascompanyoffice(+country,+company).',
      'countryhascompanyoffice(+country,-company).',
      'countryhascompanyoffice(-country,+company).',
      'companyeconomicsector(+company,+sector).',
      'companyeconomicsector(+company,-sector).',
      'companyeconomicsector(-company,+sector).',
      'companyceo(+company,+person).',
      'companyceo(+company,-person).',
      'companyceo(-company,+person).',
      'companyalsoknownas(+company,+company).',
      'companyalsoknownas(+company,-company).',
      'companyalsoknownas(-company,+company).',
      'cityhascompanyoffice(+city,+company).',
      'cityhascompanyoffice(+city,-company).',
      'cityhascompanyoffice(-city,+company).',]

[facts, pos, neg] = datasets.load('nell_finances', bk, target=target)

pos = datasets.split_into_folds(pos[0])
neg = datasets.split_into_folds(neg[0])

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(1):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.8463842292171592;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyceo(B, E) )
# %   | then if ( companyalsoknownas(B, F) )
# %   | | then if ( companyeconomicsector(B, G), companyeconomicsector(H, G), countryhascompanyoffice(I, H) )
# %   | | | then return 0.024815601766178853;  // std dev = 0,373, 12,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=2 */
# %   | | | else return 0.26991364098186527;  // std dev = 0,492, 17,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=7 */
# %   | | else return 0.5648156017661795;  // std dev = 0,455, 75,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=53 */
# %   | else if ( companyeconomicsector(B, J), companyeconomicsector(K, J), companyceo(K, L) )
# %   | | then if ( companyalsoknownas(K, K) )
# %   | | | then return 0.3025933795439568;  // std dev = 0,497, 36,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=16 */
# %   | | | else if ( countryhascompanyoffice(M, K), countryhascompanyoffice(M, N), companyalsoknownas(N, N) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else if ( countryhascompanyoffice(P, K) )
# %   | | | | | then return 0.4581489350995123;  // std dev = 1,549, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | | | | else return 0.35814893509951234;  // std dev = 2,000, 16,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=8 */
# %   | | else return 0.21389123201827578;  // std dev = 0,479, 357,000 (wgt'ed) examples reached here.  /* #neg=230 #pos=127 */
# WILL Produced-Tree #2
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.7100770511604786;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyceo(B, E) )
# %   | then if ( companyalsoknownas(B, F) )
# %   | | then if ( countryhascompanyoffice(G, B) )
# %   | | | then return -0.15316934955136638;  // std dev = 0,029, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | else return 0.19392856580834905;  // std dev = 0,477, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else return 0.48139134356295044;  // std dev = 0,455, 75,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=53 */
# %   | else if ( companyeconomicsector(B, H), companyeconomicsector(I, H), companyceo(I, J) )
# %   | | then if ( companyalsoknownas(I, I) )
# %   | | | then return 0.2616318086752119;  // std dev = 0,497, 36,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=16 */
# %   | | | else if ( countryhascompanyoffice(K, I), countryhascompanyoffice(K, L), companyalsoknownas(L, L) )
# %   | | | | then return 0.5170719622367217;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else if ( countryhascompanyoffice(M, I), companyeconomicsector(N, H), companyalsoknownas(I, N) )
# %   | | | | | then return 0.45946085024371547;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.32562684598302166;  // std dev = 2,394, 23,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=12 */
# %   | | else return 0.18581022637216005;  // std dev = 0,479, 357,000 (wgt'ed) examples reached here.  /* #neg=230 #pos=127 */
# WILL Produced-Tree #3
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.5488208200614395;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyceo(B, E) )
# %   | then if ( companyalsoknownas(B, F) )
# %   | | then return 0.12402397432779816;  // std dev = 0,454, 29,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=9 */
# %   | | else return 0.38667129114825693;  // std dev = 0,455, 75,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=53 */
# %   | else if ( companyeconomicsector(B, G), companyeconomicsector(H, G), companyceo(H, I) )
# %   | | then if ( companyalsoknownas(H, H) )
# %   | | | then return 0.2192721473492705;  // std dev = 0,497, 36,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=16 */
# %   | | | else if ( countryhascompanyoffice(J, H) )
# %   | | | | then if ( countryhascompanyoffice(J, K), companyalsoknownas(K, K) )
# %   | | | | | then return 0.41257245288266;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.32616071579989353;  // std dev = 1,546, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | | | else if ( companyeconomicsector(L, G), companyalsoknownas(H, L) )
# %   | | | | | then return 0.2148261378979952;  // std dev = 1,797, 13,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=6 */
# %   | | | | | else return 0.4199543430262003;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.15797355524826853;  // std dev = 0,479, 357,000 (wgt'ed) examples reached here.  /* #neg=230 #pos=127 */
# WILL Produced-Tree #4
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.4125020344881716;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyceo(B, E) )
# %   | then return 0.2436569037462397;  // std dev = 0,463, 104,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=62 */
# %   | else if ( companyeconomicsector(B, F), companyeconomicsector(G, F), companyceo(G, H) )
# %   | | then if ( companyalsoknownas(G, G) )
# %   | | | then return 0.1787352457468729;  // std dev = 0,497, 36,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=16 */
# %   | | | else if ( countryhascompanyoffice(I, G) )
# %   | | | | then if ( countryhascompanyoffice(I, J), companyalsoknownas(J, J) )
# %   | | | | | then return 0.3151786576185065;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.2568606385371627;  // std dev = 1,546, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | | | else if ( companyeconomicsector(K, F), companyalsoknownas(G, K) )
# %   | | | | | then return 0.17277518548726775;  // std dev = 1,797, 13,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=6 */
# %   | | | | | else return 0.33402690409722097;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( companyalsoknownas(B, L) )
# %   | | | then return 0.4426351191651583;  // std dev = 1,155, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else return 0.1263958029258399;  // std dev = 0,477, 351,000 (wgt'ed) examples reached here.  /* #neg=228 #pos=123 */
# WILL Produced-Tree #5
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.3161164121451027;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyceo(B, E) )
# %   | then return 0.1886082213145285;  // std dev = 0,461, 104,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=62 */
# %   | else if ( companyeconomicsector(B, F), companyeconomicsector(G, F), companyceo(G, H) )
# %   | | then if ( companyalsoknownas(G, G) )
# %   | | | then return 0.14243924477676304;  // std dev = 0,497, 36,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=16 */
# %   | | | else if ( countryhascompanyoffice(I, G) )
# %   | | | | then if ( countryhascompanyoffice(I, J), companyalsoknownas(J, J) )
# %   | | | | | then return 0.23676009386434207;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.19693322277228925;  // std dev = 1,546, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | | | else if ( companyeconomicsector(K, F), companyalsoknownas(G, K) )
# %   | | | | | then return 0.13604146530844366;  // std dev = 1,797, 13,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=6 */
# %   | | | | | else return 0.25624995230404973;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( companyalsoknownas(B, L) )
# %   | | | then return 0.35657480347202614;  // std dev = 1,155, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | else return 0.10366019171621402;  // std dev = 0,477, 351,000 (wgt'ed) examples reached here.  /* #neg=228 #pos=123 */
# WILL Produced-Tree #6
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.2505638949951353;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyalsoknownas(B, E), companyeconomicsector(B, F) )
# %   | then return -0.045043292666082306;  // std dev = 0,401, 14,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=3 */
# %   | else if ( companyceo(B, G) )
# %   | | then if ( companyalsoknownas(B, H) )
# %   | | | then if ( companyceo(H, I) )
# %   | | | | then return 0.29957718365190567;  // std dev = 1,058, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return -0.041620913512237824;  // std dev = 0,445, 11,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=3 */
# %   | | | else return 0.19038658313325793;  // std dev = 0,455, 75,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=53 */
# %   | | else if ( companyeconomicsector(B, J), companyeconomicsector(K, J), companyceo(K, L) )
# %   | | | then if ( companyalsoknownas(K, K) )
# %   | | | | then return 0.12429401269474243;  // std dev = 0,498, 35,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=16 */
# %   | | | | else if ( countryhascompanyoffice(M, K) )
# %   | | | | | then return 0.1571854670255366;  // std dev = 1,772, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | | | else return 0.12192902281381254;  // std dev = 1,979, 16,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=8 */
# %   | | | else return 0.08711444282477875;  // std dev = 0,478, 357,000 (wgt'ed) examples reached here.  /* #neg=230 #pos=127 */
# WILL Produced-Tree #7
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, E) )
# %   then return 0.18412110287070113;  // std dev = 0,220, 106,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=96 */
# %   else if ( companyceo(B, F) )
# %   | then if ( companyeconomicsector(B, G), companyeconomicsector(H, G), companyalsoknownas(H, H) )
# %   | | then return -0.015210660013549267;  // std dev = 0,453, 16,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=6 */
# %   | | else if ( companyalsoknownas(B, I) )
# %   | | | then return 0.11291386346082338;  // std dev = 0,485, 16,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=7 */
# %   | | | else return 0.15344399462899205;  // std dev = 0,450, 53,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=38 */
# %   | else if ( companyeconomicsector(B, J), companyeconomicsector(K, J), companyceo(K, L) )
# %   | | then if ( companyalsoknownas(K, K) )
# %   | | | then return 0.08450386019757772;  // std dev = 0,496, 36,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=16 */
# %   | | | else if ( countryhascompanyoffice(M, K), companyeconomicsector(N, J), companyalsoknownas(K, N) )
# %   | | | | then return 0.15298262733535065;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( countryhascompanyoffice(P, K), countryhascompanyoffice(P, Q), companyalsoknownas(Q, Q) )
# %   | | | | | then return 0.140093891147098;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.0925378069915431;  // std dev = 2,373, 23,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=12 */
# %   | | else return 0.06885708699569462;  // std dev = 0,477, 355,000 (wgt'ed) examples reached here.  /* #neg=229 #pos=126 */
# WILL Produced-Tree #8
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.17539299349130383;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyeconomicsector(B, E), companyeconomicsector(F, E), countryhascompanyoffice(G, F) )
# %   | then if ( countryhascompanyoffice(G, B) )
# %   | | then return -0.24084603008907626;  // std dev = 0,795, 6,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=1 */
# %   | | else if ( companyalsoknownas(B, H) )
# %   | | | then return -0.06143424075629043;  // std dev = 0,405, 10,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=2 */
# %   | | | else if ( companyalsoknownas(F, F) )
# %   | | | | then if ( companyceo(B, I) )
# %   | | | | | then return 0.01163624097735018;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | | | else return 0.07643157712619027;  // std dev = 2,947, 35,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=16 */
# %   | | | | else return 0.13420124978276823;  // std dev = 0,455, 16,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=11 */
# %   | else if ( companyeconomicsector(B, J), companyeconomicsector(K, J), companyalsoknownas(K, L) )
# %   | | then return 0.09894858957634509;  // std dev = 0,506, 14,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=7 */
# %   | | else if ( companyceo(B, M) )
# %   | | | then return 0.10172446266867703;  // std dev = 0,454, 81,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=53 */
# %   | | | else return 0.05646235498501053;  // std dev = 0,477, 358,000 (wgt'ed) examples reached here.  /* #neg=230 #pos=128 */
# WILL Produced-Tree #9
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.150159723041474;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyeconomicsector(B, E), companyceo(B, F) )
# %   | then if ( countryhascompanyoffice(G, B), companyalsoknownas(B, H) )
# %   | | then return -0.1863607357861534;  // std dev = 3,73e-09, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | else if ( companyalsoknownas(B, I), companyeconomicsector(I, E) )
# %   | | | then return -0.04110060467321984;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | else return 0.02905504308877238;  // std dev = 0,488, 22,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=12 */
# %   | else if ( companyceo(B, J) )
# %   | | then return 0.09019376976002007;  // std dev = 0,447, 74,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=49 */
# %   | | else if ( companyeconomicsector(B, K), companyeconomicsector(L, K), companyceo(L, M) )
# %   | | | then if ( companyalsoknownas(L, L) )
# %   | | | | then return 0.04752546847619365;  // std dev = 0,495, 36,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=16 */
# %   | | | | else if ( countryhascompanyoffice(N, L), companyeconomicsector(P, K), companyalsoknownas(L, P) )
# %   | | | | | then return 0.11298576779755375;  // std dev = 0,741, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.047782693997582754;  // std dev = 2,529, 27,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=15 */
# %   | | | else return 0.043313152064849904;  // std dev = 0,478, 357,000 (wgt'ed) examples reached here.  /* #neg=230 #pos=127 */
# WILL Produced-Tree #10
# % FOR cityhascompanyoffice(A, B):
# %   if ( countryhascompanyoffice(C, B), countryhascompanyoffice(C, D), companyalsoknownas(D, D) )
# %   then return 0.1308014036819867;  // std dev = 0,108, 85,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=84 */
# %   else if ( companyeconomicsector(B, E), companyalsoknownas(B, F), companyceo(F, G) )
# %   | then return -0.09552606115861402;  // std dev = 0,307, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | else if ( companyceo(B, H) )
# %   | | then return 0.05408686559311314;  // std dev = 0,456, 98,000 (wgt'ed) examples reached here.  /* #neg=37 #pos=61 */
# %   | | else if ( companyeconomicsector(B, I), companyeconomicsector(J, I), companyceo(J, K) )
# %   | | | then if ( countryhascompanyoffice(L, J), companyeconomicsector(M, I), companyalsoknownas(J, M) )
# %   | | | | then if ( countryhascompanyoffice(N, M) )
# %   | | | | | then return 0.04680606073914163;  // std dev = 2,947, 35,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=16 */
# %   | | | | | else return 0.08547535712275327;  // std dev = 0,742, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( countryhascompanyoffice(P, J), countryhascompanyoffice(P, Q), companyalsoknownas(Q, Q) )
# %   | | | | | then return 0.06669646068117185;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | | else return 0.03089264580335196;  // std dev = 2,375, 23,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=12 */
# %   | | | else if ( countryhascompanyoffice(R, B) )
# %   | | | | then return -0.0031087783994867557;  // std dev = 0,806, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.034260972470991365;  // std dev = 0,478, 354,000 (wgt'ed) examples reached here.  /* #neg=228 #pos=126 */
# Results
#    AUC ROC   = 0.695085
#    AUC PR    = 0.756443
#    CLL	      = -0.597461
#    Precision = 0.821637 at threshold = 0.5
#    Recall    = 0.45915
#    F1        = 0.589099
#
#
# Total learning time: 33.316 seconds
# Total inference time: 2.383 seconds
# AUC ROC: 0.695085

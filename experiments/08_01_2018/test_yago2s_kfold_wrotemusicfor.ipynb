# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold

# %% [markdown]
# ## Parameters

# %%
target = 'wrotemusicfor'
#test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.8
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %%
[facts, pos, neg] = get_yago2s_dataset(target, acceptedPredicates=[
'hascurrency',
'hascapital',
'hasacademicadvisor',
'participatedin',
'haswonprize',
'participatedin',
'owns',
'isinterestedin',
'livesin',
'happenedin',
'holdspoliticalposition',
'diedin',
'actedin',
'iscitizenof',
'worksat',
'directed',
'dealswith',
'wasbornin',
'created',
'isleaderof',
'haschild',
'ismarriedto',
'imports',
'hasmusicalrole',
'influences',
'isaffiliatedto',
'isknownfor',
'ispoliticianof',
'graduatedfrom',
'exports',
'edited',
'wrotemusicfor'
])

# %% [markdown]
# ## Background  configuration

# %%
bk = ['hascurrency(+place,+currency).',
'hascurrency(+place,-currency).',
'hascurrency(-place,+currency).',
'hascapital(+place,+place).',
'hascapital(+place,-place).',
'hascapital(-place,+place).',
'hasacademicadvisor(+person,+person).',
'hasacademicadvisor(+person,-person).',
'hasacademicadvisor(-person,+person).',
'haswonprize(+person,+prize).',
'haswonprize(+person,-prize).',
'haswonprize(-person,+prize).',
'participatedin(+place,+event).',
'participatedin(+place,-event).',
'participatedin(-place,+event).',
'owns(+institution,+institution).',
'owns(+institution,-institution).',
'owns(-institution,+institution).',
'isinterestedin(+person,+concept).',
'isinterestedin(+person,-concept).',
'isinterestedin(-person,+concept).',
'livesin(+person,+place).',
'livesin(+person,-place).',
'livesin(-person,+place).',
'happenedin(+event,+place).',
'happenedin(+event,-place).',
'happenedin(-event,+place).',
'holdspoliticalposition(+person,+politicalposition).',
'holdspoliticalposition(+person,-politicalposition).',
'holdspoliticalposition(-person,+politicalposition).',
'diedin(+person,+place).',
'diedin(+person,-place).',
'diedin(-person,+place).',
'actedin(+person,+media).',
'actedin(+person,-media).',
'actedin(-person,+media).',
'iscitizenof(+person,+place).',
'iscitizenof(+person,-place).',
'iscitizenof(-person,+place).',
'worksat(+person,+institution).',
'worksat(+person,-institution).',
'worksat(-person,+institution).',
'directed(+person,+media).',
'directed(+person,-media).',
'directed(-person,+media).',
'dealswith(+place,+place).',
'dealswith(+place,-place).',
'dealswith(-place,+place).',
'wasbornin(+person,+place).',
'wasbornin(+person,-place).',
'wasbornin(-person,+place).',
'created(+person,+media).',
'created(+person,-media).',
'created(-person,+media).',
'isleaderof(+person,+place).',
'isleaderof(+person,-place).',
'isleaderof(-person,+place).',
'haschild(+person,+person).',
'haschild(+person,-person).',
'haschild(-person,+person).',
'ismarriedto(+person,+person).',
'ismarriedto(+person,-person).',
'ismarriedto(-person,+person).',
'imports(+person,+material).',
'imports(+person,-material).',
'imports(-person,+material).',
'hasmusicalrole(+person,+musicalrole).',
'hasmusicalrole(+person,-musicalrole).',
'hasmusicalrole(-person,+musicalrole).',
'influences(+person,+person).',
'influences(+person,-person).',
'influences(-person,+person).',
'isaffiliatedto(+person,+team).',
'isaffiliatedto(+person,-team).',
'isaffiliatedto(-person,+team).',
'isknownfor(+person,+theory).',
'isknownfor(+person,-theory).',
'isknownfor(-person,+theory).',
'ispoliticianof(+person,+place).',
'ispoliticianof(+person,-place).',
'ispoliticianof(-person,+place).',
'graduatedfrom(+person,+institution).',
'graduatedfrom(+person,-institution).',
'graduatedfrom(-person,+institution).',
'exports(+place,+material).',
'exports(+place,-material).',
'exports(-place,+material).',
'edited(+person,+media).',
'edited(+person,-media).',
'edited(-person,+media).',
'wrotemusicfor(+person,+media).',
'wrotemusicfor(+person,-media).',
'wrotemusicfor(-person,+media).']

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

neg = neg[:len(pos)] # balanced

import numpy as np
pos = np.array(pos)
neg = np.array(neg)
small_dataset_aucroc = []
complete_dataset_aucroc = []
revision_dataset_aucroc = []


# separate train and test
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(pos):
    train_pos, test_pos = pos[train_index], pos[test_index]
    train_neg, test_neg = neg[train_index], neg[test_index]

    # learn from scratch in a small dataset
    s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
    s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

    # shuffle all train examples
    random.shuffle(train_pos)
    random.shuffle(train_neg)

    # train set used in revision and validation set
    r_train_pos = train_pos[int(validation_size*len(train_pos)):]
    r_train_neg = train_neg[int(validation_size*len(train_neg)):]
    validation_pos = train_pos[:int(validation_size*len(train_pos))]
    validation_neg = train_neg[:int(validation_size*len(train_neg))]

    print('Total examples')
    print('Positive examples: %s' % len(pos))
    print('Negative examples: %s' % len(neg))
    print('\n')
    print('Train and test sets from total')
    print('Train Positive examples: %s' % len(train_pos))
    print('Train Negative examples: %s' % len(train_neg))
    print('Test Positive examples: %s' % len(test_pos))
    print('Test Negative examples: %s' % len(test_neg))
    print('\n')
    print('Small dataset')
    print('Train Positive examples: %s' % len(s_train_pos))
    print('Train Negative examples: %s' % len(s_train_neg))
    print('\n')
    print('Revision theory train dataset and validation')
    print('Train Positive examples: %s' % len(r_train_pos))
    print('Train Negative examples: %s' % len(r_train_neg))
    print('Validation Positive examples: %s' % len(validation_pos))
    print('Validation Negative examples: %s' % len(validation_neg))
    
    # learning from small dataset
    delete_model_files()
    model = boostsrl.train(background, s_train_pos, s_train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    small_dataset_aucroc.append(t_results['AUC ROC'])
    
    # learning from complete dataset
    delete_model_files()
    model = boostsrl.train(background, train_pos, train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    #structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    complete_dataset_aucroc.append(t_results['AUC ROC'])
    
    # theory revision
    total_revision_time = 0
    best_aucroc = 0
    best_structured = None

    print('Performing parameter learning')
    print('******************************************')
    delete_model_files()
    model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=get_refine_file(structured))
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, validation_pos, validation_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    total_revision_time += learning_time + inference_time
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)

    best_aucroc = t_results['AUC ROC']
    best_structured = structured.copy()
    save_model_files()

    for i in range(max_revision_iterations):
        print('Refining iteration %s' % str(i+1))
        print('******************************************')
        found_better = False
        for candidate in get_cantidates(best_structured, revision_threshold):
            print('Refining node candidate')
            print('******************************************')
            delete_model_files()
            model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=candidate)
            learning_time = model.traintime()
            will = model.get_will_produced_tree()
            results = boostsrl.test(model, validation_pos, validation_neg, facts)
            inference_time = results.testtime()
            t_results = results.summarize_results()
            total_revision_time += learning_time + inference_time
            print('WILL-Produced Tree:')
            print_will_produced_tree(will)
            print('\n')
            print('Results:')
            print(t_results)
            print('\n')
            print('Total learning time: %s seconds' % learning_time)
            print('Total inference time: %s seconds' % inference_time)
            print('AUC ROC: %s' % t_results['AUC ROC'])
            print('\n')
            #print('Tree:')
            #model.tree(0, target, image=True)
            print('******************************************')

            if t_results['AUC ROC'] > best_aucroc:
                found_better = True
                best_aucroc = t_results['AUC ROC']
                best_structured = model.get_structured_tree().copy()
                save_model_files()
        print('Best Tree AUC ROC so far: %s' % best_aucroc)
        print('******************************************\n')
        if found_better == False:
            break

    print('******************************************')
    delete_model_files()
    get_saved_model_files()
    delete_test_files()
    print('Total revision time: %s' % total_revision_time)
    print('Best validation AUC ROC: %s' % best_aucroc)
    will = model.get_will_produced_tree()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    revision_dataset_aucroc.append(t_results['AUC ROC'])
# Out:
# Total examples
# Positive examples: 22380
# Negative examples: 22380
#
#
# Train and test sets from total
# Train Positive examples: 20142
# Train Negative examples: 20142
# Test Positive examples: 2238
# Test Negative examples: 2238
#
#
# Small dataset
# Train Positive examples: 6042
# Train Negative examples: 6042
#
#
# Revision theory train dataset and validation
# Train Positive examples: 16114
# Train Negative examples: 16114
# Validation Positive examples: 4028
# Validation Negative examples: 4028
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7022105851448384;  // std dev = 0,363, 1.103,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=931 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995092;  // std dev = 1,08e-06, 201,000 (wgt'ed) examples reached here.  /* #pos=201 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.1369213136161314;  // std dev = 0,448, 1.564,000 (wgt'ed) examples reached here.  /* #neg=1.128 #pos=436 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09988447228959223;  // std dev = 0,428, 484,000 (wgt'ed) examples reached here.  /* #neg=367 #pos=117 */
# %   | | | | else if ( created(A, M), created(N, M), haswonprize(N, I) )
# %   | | | | | then return 0.5310656017661747;  // std dev = 10,279, 480,000 (wgt'ed) examples reached here.  /* #neg=157 #pos=323 */
# %   | | | | | else return 0.2885180626162859;  // std dev = 29,608, 3.576,000 (wgt'ed) examples reached here.  /* #neg=2.037 #pos=1.539 */
# %   | | | else if ( created(A, P), actedin(Q, P), haswonprize(Q, R) )
# %   | | | | then return 0.19080613591086695;  // std dev = 0,471, 493,000 (wgt'ed) examples reached here.  /* #neg=329 #pos=164 */
# %   | | | | else if ( haswonprize(A, S), actedin(T, B) )
# %   | | | | | then return 0.30803757652489777;  // std dev = 10,541, 449,000 (wgt'ed) examples reached here.  /* #neg=247 #pos=202 */
# %   | | | | | else return 0.4283149768777612;  // std dev = 30,251, 3.734,000 (wgt'ed) examples reached here.  /* #neg=1.605 #pos=2.129 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.691666, 'Recall': 0.0, 'AUC ROC': 0.67025, 'CLL': -0.909114}
#
#
# Total learning time: 551.058 seconds
# Total inference time: 58.129 seconds
# AUC ROC: 0.67025
#
#
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), created(A, D), actedin(C, D) )
# %   then return 0.8083254749190443;  // std dev = 0,218, 2.549,000 (wgt'ed) examples reached here.  /* #neg=127 #pos=2.422 */
# %   else if ( haswonprize(A, E), actedin(F, B), haswonprize(F, E) )
# %   | then return 0.6424967611864638;  // std dev = 0,411, 2.300,000 (wgt'ed) examples reached here.  /* #neg=496 #pos=1.804 */
# %   | else if ( created(A, G), actedin(H, G), haswonprize(A, I) )
# %   | | then return 0.12861225556282763;  // std dev = 0,444, 5.180,000 (wgt'ed) examples reached here.  /* #neg=3.779 #pos=1.401 */
# %   | | else if ( actedin(J, B), livesin(J, K), isleaderof(L, K) )
# %   | | | then if ( haswonprize(J, M), livesin(L, N), wasbornin(P, N) )
# %   | | | | then return 0.039288690866129;  // std dev = 0,385, 1.474,000 (wgt'ed) examples reached here.  /* #neg=1.207 #pos=267 */
# %   | | | | else return 0.270992971796756;  // std dev = 0,492, 981,000 (wgt'ed) examples reached here.  /* #neg=576 #pos=405 */
# %   | | | else if ( actedin(Q, B), haswonprize(Q, R) )
# %   | | | | then if ( created(A, S), actedin(T, B), ismarriedto(T, U) )
# %   | | | | | then return 0.3638535791618565;  // std dev = 39,440, 6.223,000 (wgt'ed) examples reached here.  /* #neg=3.076 #pos=3.147 */
# %   | | | | | else return 0.27707205990498496;  // std dev = 39,551, 6.426,000 (wgt'ed) examples reached here.  /* #neg=3.734 #pos=2.692 */
# %   | | | | else if ( created(A, W), actedin(X, W), haswonprize(X, Y) )
# %   | | | | | then return 0.19237175030964745;  // std dev = 18,263, 1.499,000 (wgt'ed) examples reached here.  /* #neg=998 #pos=501 */
# %   | | | | | else return 0.4077387387912739;  // std dev = 58,133, 13.652,000 (wgt'ed) examples reached here.  /* #neg=6.149 #pos=7.503 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.697922, 'Recall': 0.0, 'AUC ROC': 0.675816, 'CLL': -0.907105}
#
#
# Total learning time: 1498.354 seconds
# Total inference time: 60.735 seconds
# AUC ROC: 0.675816
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7008156017661739;  // std dev = 19,943, 3.000,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=2.528 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995078;  // std dev = 2,65e-06, 559,000 (wgt'ed) examples reached here.  /* #pos=559 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.14419653192638537;  // std dev = 29,586, 4.286,000 (wgt'ed) examples reached here.  /* #neg=3.060 #pos=1.226 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09796793962439429;  // std dev = 15,548, 1.326,000 (wgt'ed) examples reached here.  /* #neg=1.008 #pos=318 */
# %   | | | | else if ( created(A, M), created(N, M), haswonprize(N, I) )
# %   | | | | | then return 0.53073580768638;  // std dev = 16,887, 1.295,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=871 */
# %   | | | | | else return 0.29557533484257537;  // std dev = 47,945, 9.341,000 (wgt'ed) examples reached here.  /* #neg=5.255 #pos=4.086 */
# %   | | | else if ( created(A, P), actedin(Q, P), haswonprize(Q, R) )
# %   | | | | then return 0.21871452818670303;  // std dev = 17,132, 1.273,000 (wgt'ed) examples reached here.  /* #neg=814 #pos=459 */
# %   | | | | else if ( haswonprize(A, S), actedin(T, B) )
# %   | | | | | then return 0.2931866551330364;  // std dev = 17,124, 1.193,000 (wgt'ed) examples reached here.  /* #neg=674 #pos=519 */
# %   | | | | | else return 0.41545682058430894;  // std dev = 49,559, 9.955,000 (wgt'ed) examples reached here.  /* #neg=4.407 #pos=5.548 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.699312, 'Recall': 0.0, 'AUC ROC': 0.683874, 'CLL': -0.906363}
#
#
# Total learning time: 70.571 seconds
# Total inference time: 58.418 seconds
# AUC ROC: 0.683874
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7008156017661739;  // std dev = 19,943, 3.000,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=2.528 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995078;  // std dev = 2,65e-06, 559,000 (wgt'ed) examples reached here.  /* #pos=559 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.14419653192638537;  // std dev = 29,586, 4.286,000 (wgt'ed) examples reached here.  /* #neg=3.060 #pos=1.226 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09796793962439429;  // std dev = 15,548, 1.326,000 (wgt'ed) examples reached here.  /* #neg=1.008 #pos=318 */
# %   | | | | else if ( created(A, M), created(N, M), haswonprize(N, I) )
# %   | | | | | then return 0.53073580768638;  // std dev = 16,887, 1.295,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=871 */
# %   | | | | | else return 0.29557533484257537;  // std dev = 47,945, 9.341,000 (wgt'ed) examples reached here.  /* #neg=5.255 #pos=4.086 */
# %   | | | else if ( created(A, P), actedin(Q, P), haswonprize(Q, R) )
# %   | | | | then return 0.21871452818670303;  // std dev = 0,480, 1.273,000 (wgt'ed) examples reached here.  /* #neg=814 #pos=459 */
# %   | | | | else if ( haswonprize(A, S), actedin(T, B) )
# %   | | | | | then return 0.2931866551330364;  // std dev = 17,124, 1.193,000 (wgt'ed) examples reached here.  /* #neg=674 #pos=519 */
# %   | | | | | else return 0.41545682058430894;  // std dev = 49,559, 9.955,000 (wgt'ed) examples reached here.  /* #neg=4.407 #pos=5.548 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.699312, 'Recall': 0.0, 'AUC ROC': 0.683874, 'CLL': -0.906363}
#
#
# Total learning time: 64.645 seconds
# Total inference time: 56.898 seconds
# AUC ROC: 0.683874
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7008156017661739;  // std dev = 19,943, 3.000,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=2.528 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995078;  // std dev = 2,65e-06, 559,000 (wgt'ed) examples reached here.  /* #pos=559 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.14419653192638537;  // std dev = 29,586, 4.286,000 (wgt'ed) examples reached here.  /* #neg=3.060 #pos=1.226 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09796793962439429;  // std dev = 15,548, 1.326,000 (wgt'ed) examples reached here.  /* #neg=1.008 #pos=318 */
# %   | | | | else return 0.3242076037719522;  // std dev = 51,447, 10.636,000 (wgt'ed) examples reached here.  /* #neg=5.679 #pos=4.957 */
# %   | | | else if ( created(A, M), actedin(N, M), haswonprize(N, P) )
# %   | | | | then return 0.21871452818670303;  // std dev = 17,132, 1.273,000 (wgt'ed) examples reached here.  /* #neg=814 #pos=459 */
# %   | | | | else if ( haswonprize(A, Q), actedin(R, B) )
# %   | | | | | then return 0.2931866551330364;  // std dev = 17,124, 1.193,000 (wgt'ed) examples reached here.  /* #neg=674 #pos=519 */
# %   | | | | | else return 0.41545682058430894;  // std dev = 49,559, 9.955,000 (wgt'ed) examples reached here.  /* #neg=4.407 #pos=5.548 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.688554, 'Recall': 0.0, 'AUC ROC': 0.672964, 'CLL': -0.908035}
#
#
# Total learning time: 68.594 seconds
# Total inference time: 88.309 seconds
# AUC ROC: 0.672964
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7008156017661739;  // std dev = 19,943, 3.000,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=2.528 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995078;  // std dev = 2,65e-06, 559,000 (wgt'ed) examples reached here.  /* #pos=559 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.14419653192638537;  // std dev = 29,586, 4.286,000 (wgt'ed) examples reached here.  /* #neg=3.060 #pos=1.226 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09796793962439429;  // std dev = 15,548, 1.326,000 (wgt'ed) examples reached here.  /* #neg=1.008 #pos=318 */
# %   | | | | else if ( created(A, M), created(N, M), haswonprize(N, I) )
# %   | | | | | then return 0.53073580768638;  // std dev = 16,887, 1.295,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=871 */
# %   | | | | | else return 0.29557533484257537;  // std dev = 47,945, 9.341,000 (wgt'ed) examples reached here.  /* #neg=5.255 #pos=4.086 */
# %   | | | else if ( created(A, P), actedin(Q, P), haswonprize(Q, R) )
# %   | | | | then return 0.21871452818670303;  // std dev = 17,132, 1.273,000 (wgt'ed) examples reached here.  /* #neg=814 #pos=459 */
# %   | | | | else return 0.40237211414507595;  // std dev = 52,585, 11.148,000 (wgt'ed) examples reached here.  /* #neg=5.081 #pos=6.067 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.697144, 'Recall': 0.0, 'AUC ROC': 0.682088, 'CLL': -0.906819}
#
#
# Total learning time: 94.143 seconds
# Total inference time: 87.414 seconds
# AUC ROC: 0.682088
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7008156017661739;  // std dev = 19,943, 3.000,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=2.528 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995078;  // std dev = 2,65e-06, 559,000 (wgt'ed) examples reached here.  /* #pos=559 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.14419653192638537;  // std dev = 0,452, 4.286,000 (wgt'ed) examples reached here.  /* #neg=3.060 #pos=1.226 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09796793962439429;  // std dev = 15,548, 1.326,000 (wgt'ed) examples reached here.  /* #neg=1.008 #pos=318 */
# %   | | | | else if ( created(A, M), created(N, M), haswonprize(N, I) )
# %   | | | | | then return 0.53073580768638;  // std dev = 16,887, 1.295,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=871 */
# %   | | | | | else return 0.29557533484257537;  // std dev = 47,945, 9.341,000 (wgt'ed) examples reached here.  /* #neg=5.255 #pos=4.086 */
# %   | | | else if ( created(A, P), actedin(Q, P), haswonprize(Q, R) )
# %   | | | | then return 0.21871452818670303;  // std dev = 17,132, 1.273,000 (wgt'ed) examples reached here.  /* #neg=814 #pos=459 */
# %   | | | | else if ( haswonprize(A, S), actedin(T, B) )
# %   | | | | | then return 0.2931866551330364;  // std dev = 17,124, 1.193,000 (wgt'ed) examples reached here.  /* #neg=674 #pos=519 */
# %   | | | | | else return 0.41545682058430894;  // std dev = 49,559, 9.955,000 (wgt'ed) examples reached here.  /* #neg=4.407 #pos=5.548 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.699312, 'Recall': 0.0, 'AUC ROC': 0.683874, 'CLL': -0.906363}
#
#
# Total learning time: 68.967 seconds
# Total inference time: 59.603 seconds
# AUC ROC: 0.683874
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7008156017661739;  // std dev = 19,943, 3.000,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=2.528 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995078;  // std dev = 2,65e-06, 559,000 (wgt'ed) examples reached here.  /* #pos=559 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.14419653192638537;  // std dev = 29,586, 4.286,000 (wgt'ed) examples reached here.  /* #neg=3.060 #pos=1.226 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09796793962439429;  // std dev = 0,427, 1.326,000 (wgt'ed) examples reached here.  /* #neg=1.008 #pos=318 */
# %   | | | | else if ( created(A, M), created(N, M), haswonprize(N, I) )
# %   | | | | | then return 0.53073580768638;  // std dev = 16,887, 1.295,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=871 */
# %   | | | | | else return 0.29557533484257537;  // std dev = 47,945, 9.341,000 (wgt'ed) examples reached here.  /* #neg=5.255 #pos=4.086 */
# %   | | | else if ( created(A, P), actedin(Q, P), haswonprize(Q, R) )
# %   | | | | then return 0.21871452818670303;  // std dev = 17,132, 1.273,000 (wgt'ed) examples reached here.  /* #neg=814 #pos=459 */
# %   | | | | else if ( haswonprize(A, S), actedin(T, B) )
# %   | | | | | then return 0.2931866551330364;  // std dev = 17,124, 1.193,000 (wgt'ed) examples reached here.  /* #neg=674 #pos=519 */
# %   | | | | | else return 0.41545682058430894;  // std dev = 49,559, 9.955,000 (wgt'ed) examples reached here.  /* #neg=4.407 #pos=5.548 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.699312, 'Recall': 0.0, 'AUC ROC': 0.683874, 'CLL': -0.906363}
#
#
# Total learning time: 96.27799999999999 seconds
# Total inference time: 59.468 seconds
# AUC ROC: 0.683874
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.683874
# ******************************************
#
# ******************************************
# Total revision time: 873.3079999999999
# Best validation AUC ROC: 0.683874
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( actedin(C, B), haswonprize(C, D), haswonprize(A, D) )
# %   then return 0.7008156017661739;  // std dev = 19,943, 3.000,000 (wgt'ed) examples reached here.  /* #neg=472 #pos=2.528 */
# %   else if ( created(A, B) )
# %   | then return 0.8581489350995078;  // std dev = 2,65e-06, 559,000 (wgt'ed) examples reached here.  /* #pos=559 */
# %   | else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | | then return 0.14419653192638537;  // std dev = 29,586, 4.286,000 (wgt'ed) examples reached here.  /* #neg=3.060 #pos=1.226 */
# %   | | else if ( actedin(H, B), haswonprize(H, I) )
# %   | | | then if ( livesin(H, J), isleaderof(K, J), livesin(K, L) )
# %   | | | | then return 0.09796793962439429;  // std dev = 15,548, 1.326,000 (wgt'ed) examples reached here.  /* #neg=1.008 #pos=318 */
# %   | | | | else if ( created(A, M), created(N, M), haswonprize(N, I) )
# %   | | | | | then return 0.53073580768638;  // std dev = 16,887, 1.295,000 (wgt'ed) examples reached here.  /* #neg=424 #pos=871 */
# %   | | | | | else return 0.29557533484257537;  // std dev = 47,945, 9.341,000 (wgt'ed) examples reached here.  /* #neg=5.255 #pos=4.086 */
# %   | | | else if ( created(A, P), actedin(Q, P), haswonprize(Q, R) )
# %   | | | | then return 0.21871452818670303;  // std dev = 17,132, 1.273,000 (wgt'ed) examples reached here.  /* #neg=814 #pos=459 */
# %   | | | | else if ( haswonprize(A, S), actedin(T, B) )
# %   | | | | | then return 0.2931866551330364;  // std dev = 17,124, 1.193,000 (wgt'ed) examples reached here.  /* #neg=674 #pos=519 */
# %   | | | | | else return 0.41545682058430894;  // std dev = 49,559, 9.955,000 (wgt'ed) examples reached here.  /* #neg=4.407 #pos=5.548 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.693115, 'Recall': 0.0, 'AUC ROC': 0.673163, 'CLL': -0.909715}
#
#
# Total inference time: 58.048 seconds
# AUC ROC: 0.673163
#
#
# Total examples
# Positive examples: 22380
# Negative examples: 22380
#
#
# Train and test sets from total
# Train Positive examples: 20142
# Train Negative examples: 20142
# Test Positive examples: 2238
# Test Negative examples: 2238
#
#
# Small dataset
# Train Positive examples: 6042
# Train Negative examples: 6042
#
#
# Revision theory train dataset and validation
# Train Positive examples: 16114
# Train Negative examples: 16114
# Validation Positive examples: 4028
# Validation Negative examples: 4028
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995083;  // std dev = 1,17e-06, 357,000 (wgt'ed) examples reached here.  /* #pos=357 */
# %   else if ( created(A, C), actedin(D, C), actedin(D, B) )
# %   | then return 0.797963749914323;  // std dev = 0,238, 432,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=406 */
# %   | else if ( created(A, E), actedin(F, E), wasbornin(F, G) )
# %   | | then return 0.23543941272041438;  // std dev = 0,485, 3.329,000 (wgt'ed) examples reached here.  /* #neg=2.073 #pos=1.256 */
# %   | | else if ( actedin(H, B), wasbornin(H, I), haswonprize(H, J) )
# %   | | | then if ( haswonprize(A, K), haswonprize(L, J), haswonprize(L, K) )
# %   | | | | then return 0.4501666734587098;  // std dev = 0,491, 451,000 (wgt'ed) examples reached here.  /* #neg=184 #pos=267 */
# %   | | | | else return 0.24579218372930328;  // std dev = 0,487, 2.007,000 (wgt'ed) examples reached here.  /* #neg=1.229 #pos=778 */
# %   | | | else if ( created(A, M), created(N, B), directed(N, B) )
# %   | | | | then if ( diedin(A, P), created(Q, M), wasbornin(Q, R) )
# %   | | | | | then return -0.1418510649004878;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   | | | | | else return 0.3469014913367269;  // std dev = 11,054, 489,000 (wgt'ed) examples reached here.  /* #neg=250 #pos=239 */
# %   | | | | else if ( actedin(S, B), haswonprize(S, T) )
# %   | | | | | then return 0.3566198831117398;  // std dev = 18,083, 1.308,000 (wgt'ed) examples reached here.  /* #neg=656 #pos=652 */
# %   | | | | | else return 0.4229662558031609;  // std dev = 30,137, 3.695,000 (wgt'ed) examples reached here.  /* #neg=1.608 #pos=2.087 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.652138, 'Recall': 0.0, 'AUC ROC': 0.61788, 'CLL': -0.914325}
#
#
# Total learning time: 559.408 seconds
# Total inference time: 59.398 seconds
# AUC ROC: 0.61788
#
#
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(C, B), haswonprize(A, D), haswonprize(C, E) )
# %   then return 0.4681590123584928;  // std dev = 0,488, 2.977,000 (wgt'ed) examples reached here.  /* #neg=1.161 #pos=1.816 */
# %   else if ( haswonprize(A, F), directed(G, B) )
# %   | then if ( edited(H, B), haswonprize(I, F), actedin(I, B) )
# %   | | then return 0.6413122004056306;  // std dev = 0,412, 392,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=307 */
# %   | | else return 0.28000045298348675;  // std dev = 0,494, 6.654,000 (wgt'ed) examples reached here.  /* #neg=3.847 #pos=2.807 */
# %   | else if ( actedin(J, B), haswonprize(J, K), haswonprize(A, K) )
# %   | | then return 0.7201561035582889;  // std dev = 0,345, 1.116,000 (wgt'ed) examples reached here.  /* #neg=154 #pos=962 */
# %   | | else if ( haswonprize(A, L), actedin(M, B) )
# %   | | | then return 0.15189095297945626;  // std dev = 0,455, 1.566,000 (wgt'ed) examples reached here.  /* #neg=1.106 #pos=460 */
# %   | | | else if ( actedin(N, B), haswonprize(N, P) )
# %   | | | | then if ( created(A, B) )
# %   | | | | | then return 0.8581489350995086;  // std dev = 1,08e-06, 277,000 (wgt'ed) examples reached here.  /* #pos=277 */
# %   | | | | | else return 0.3059054946401987;  // std dev = 56,439, 12.882,000 (wgt'ed) examples reached here.  /* #neg=7.114 #pos=5.768 */
# %   | | | | else if ( created(A, Q), directed(R, Q) )
# %   | | | | | then return 0.2882830211968961;  // std dev = 26,357, 2.834,000 (wgt'ed) examples reached here.  /* #neg=1.615 #pos=1.219 */
# %   | | | | | else return 0.4214149458020792;  // std dev = 53,387, 11.586,000 (wgt'ed) examples reached here.  /* #neg=5.060 #pos=6.526 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.618474, 'Recall': 0.0, 'AUC ROC': 0.600701, 'CLL': -0.923331}
#
#
# Total learning time: 1571.661 seconds
# Total inference time: 61.172 seconds
# AUC ROC: 0.600701
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995075;  // std dev = 4,16e-06, 927,000 (wgt'ed) examples reached here.  /* #pos=927 */
# %   else if ( created(A, C), actedin(D, C), actedin(D, B) )
# %   | then return 0.7658948010699165;  // std dev = 9,809, 1.149,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=1.043 */
# %   | else if ( created(A, E), actedin(F, E), wasbornin(F, G) )
# %   | | then return 0.26094261497127264;  // std dev = 45,836, 8.734,000 (wgt'ed) examples reached here.  /* #neg=5.216 #pos=3.518 */
# %   | | else if ( actedin(H, B), wasbornin(H, I), haswonprize(H, J) )
# %   | | | then if ( haswonprize(A, K), haswonprize(L, J), haswonprize(L, K) )
# %   | | | | then return 0.4209992153236868;  // std dev = 17,530, 1.249,000 (wgt'ed) examples reached here.  /* #neg=546 #pos=703 */
# %   | | | | else return 0.2461831231336955;  // std dev = 35,359, 5.265,000 (wgt'ed) examples reached here.  /* #neg=3.222 #pos=2.043 */
# %   | | | else if ( created(A, M), created(N, B), directed(N, B) )
# %   | | | | then if ( diedin(A, P), created(Q, M), wasbornin(Q, R) )
# %   | | | | | then return 0.21529179224236922;  // std dev = 3,586, 56,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=20 */
# %   | | | | | else return 0.34538617233674485;  // std dev = 18,242, 1.332,000 (wgt'ed) examples reached here.  /* #neg=683 #pos=649 */
# %   | | | | else if ( actedin(S, B), haswonprize(S, T) )
# %   | | | | | then return 0.3454018712209624;  // std dev = 29,533, 3.491,000 (wgt'ed) examples reached here.  /* #neg=1.790 #pos=1.701 */
# %   | | | | | else return 0.4077748702616019;  // std dev = 49,815, 10.025,000 (wgt'ed) examples reached here.  /* #neg=4.515 #pos=5.510 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.677571, 'Recall': 0.0, 'AUC ROC': 0.645273, 'CLL': -0.914083}
#
#
# Total learning time: 70.783 seconds
# Total inference time: 90.387 seconds
# AUC ROC: 0.645273
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995075;  // std dev = 4,16e-06, 927,000 (wgt'ed) examples reached here.  /* #pos=927 */
# %   else if ( created(A, C), actedin(D, C), actedin(D, B) )
# %   | then return 0.7658948010699165;  // std dev = 9,809, 1.149,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=1.043 */
# %   | else if ( created(A, E), actedin(F, E), wasbornin(F, G) )
# %   | | then return 0.26094261497127264;  // std dev = 45,836, 8.734,000 (wgt'ed) examples reached here.  /* #neg=5.216 #pos=3.518 */
# %   | | else if ( actedin(H, B), wasbornin(H, I), haswonprize(H, J) )
# %   | | | then return 0.2797025120107752;  // std dev = 39,855, 6.514,000 (wgt'ed) examples reached here.  /* #neg=3.768 #pos=2.746 */
# %   | | | else if ( created(A, K), created(L, B), directed(L, B) )
# %   | | | | then if ( diedin(A, M), created(N, K), wasbornin(N, P) )
# %   | | | | | then return 0.21529179224236922;  // std dev = 3,586, 56,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=20 */
# %   | | | | | else return 0.34538617233674485;  // std dev = 18,242, 1.332,000 (wgt'ed) examples reached here.  /* #neg=683 #pos=649 */
# %   | | | | else if ( actedin(Q, B), haswonprize(Q, R) )
# %   | | | | | then return 0.3454018712209624;  // std dev = 29,533, 3.491,000 (wgt'ed) examples reached here.  /* #neg=1.790 #pos=1.701 */
# %   | | | | | else return 0.4077748702616019;  // std dev = 49,815, 10.025,000 (wgt'ed) examples reached here.  /* #neg=4.515 #pos=5.510 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.672773, 'Recall': 0.0, 'AUC ROC': 0.640155, 'CLL': -0.915008}
#
#
# Total learning time: 81.59700000000001 seconds
# Total inference time: 89.777 seconds
# AUC ROC: 0.640155
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995075;  // std dev = 4,16e-06, 927,000 (wgt'ed) examples reached here.  /* #pos=927 */
# %   else if ( created(A, C), actedin(D, C), actedin(D, B) )
# %   | then return 0.7658948010699165;  // std dev = 9,809, 1.149,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=1.043 */
# %   | else if ( created(A, E), actedin(F, E), wasbornin(F, G) )
# %   | | then return 0.26094261497127264;  // std dev = 45,836, 8.734,000 (wgt'ed) examples reached here.  /* #neg=5.216 #pos=3.518 */
# %   | | else if ( actedin(H, B), wasbornin(H, I), haswonprize(H, J) )
# %   | | | then if ( haswonprize(A, K), haswonprize(L, J), haswonprize(L, K) )
# %   | | | | then return 0.4209992153236868;  // std dev = 17,530, 1.249,000 (wgt'ed) examples reached here.  /* #neg=546 #pos=703 */
# %   | | | | else return 0.2461831231336955;  // std dev = 35,359, 5.265,000 (wgt'ed) examples reached here.  /* #neg=3.222 #pos=2.043 */
# %   | | | else if ( created(A, M), created(N, B), directed(N, B) )
# %   | | | | then if ( diedin(A, P), created(Q, M), wasbornin(Q, R) )
# %   | | | | | then return 0.21529179224236922;  // std dev = 3,586, 56,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=20 */
# %   | | | | | else return 0.34538617233674485;  // std dev = 18,242, 1.332,000 (wgt'ed) examples reached here.  /* #neg=683 #pos=649 */
# %   | | | | else return 0.39166476818621926;  // std dev = 57,998, 13.516,000 (wgt'ed) examples reached here.  /* #neg=6.305 #pos=7.211 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.672835, 'Recall': 0.0, 'AUC ROC': 0.64077, 'CLL': -0.914388}
#
#
# Total learning time: 73.79599999999999 seconds
# Total inference time: 90.418 seconds
# AUC ROC: 0.64077
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995075;  // std dev = 4,16e-06, 927,000 (wgt'ed) examples reached here.  /* #pos=927 */
# %   else if ( created(A, C), actedin(D, C), actedin(D, B) )
# %   | then return 0.7658948010699165;  // std dev = 9,809, 1.149,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=1.043 */
# %   | else if ( created(A, E), actedin(F, E), wasbornin(F, G) )
# %   | | then return 0.26094261497127264;  // std dev = 0,490, 8.734,000 (wgt'ed) examples reached here.  /* #neg=5.216 #pos=3.518 */
# %   | | else if ( actedin(H, B), wasbornin(H, I), haswonprize(H, J) )
# %   | | | then if ( haswonprize(A, K), haswonprize(L, J), haswonprize(L, K) )
# %   | | | | then return 0.4209992153236868;  // std dev = 17,530, 1.249,000 (wgt'ed) examples reached here.  /* #neg=546 #pos=703 */
# %   | | | | else return 0.2461831231336955;  // std dev = 35,359, 5.265,000 (wgt'ed) examples reached here.  /* #neg=3.222 #pos=2.043 */
# %   | | | else if ( created(A, M), created(N, B), directed(N, B) )
# %   | | | | then if ( diedin(A, P), created(Q, M), wasbornin(Q, R) )
# %   | | | | | then return 0.21529179224236922;  // std dev = 3,586, 56,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=20 */
# %   | | | | | else return 0.34538617233674485;  // std dev = 18,242, 1.332,000 (wgt'ed) examples reached here.  /* #neg=683 #pos=649 */
# %   | | | | else if ( actedin(S, B), haswonprize(S, T) )
# %   | | | | | then return 0.3454018712209624;  // std dev = 29,533, 3.491,000 (wgt'ed) examples reached here.  /* #neg=1.790 #pos=1.701 */
# %   | | | | | else return 0.4077748702616019;  // std dev = 49,815, 10.025,000 (wgt'ed) examples reached here.  /* #neg=4.515 #pos=5.510 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.677571, 'Recall': 0.0, 'AUC ROC': 0.645273, 'CLL': -0.914083}
#
#
# Total learning time: 103.035 seconds
# Total inference time: 62.191 seconds
# AUC ROC: 0.645273
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995075;  // std dev = 4,16e-06, 927,000 (wgt'ed) examples reached here.  /* #pos=927 */
# %   else if ( created(A, C), actedin(D, C), actedin(D, B) )
# %   | then return 0.7658948010699165;  // std dev = 9,809, 1.149,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=1.043 */
# %   | else if ( created(A, E), actedin(F, E), wasbornin(F, G) )
# %   | | then return 0.26094261497127264;  // std dev = 45,836, 8.734,000 (wgt'ed) examples reached here.  /* #neg=5.216 #pos=3.518 */
# %   | | else if ( actedin(H, B), wasbornin(H, I), haswonprize(H, J) )
# %   | | | then if ( haswonprize(A, K), haswonprize(L, J), haswonprize(L, K) )
# %   | | | | then return 0.4209992153236868;  // std dev = 17,530, 1.249,000 (wgt'ed) examples reached here.  /* #neg=546 #pos=703 */
# %   | | | | else return 0.2461831231336955;  // std dev = 35,359, 5.265,000 (wgt'ed) examples reached here.  /* #neg=3.222 #pos=2.043 */
# %   | | | else if ( created(A, M), created(N, B), directed(N, B) )
# %   | | | | then return 0.3401374077219858;  // std dev = 18,616, 1.388,000 (wgt'ed) examples reached here.  /* #neg=719 #pos=669 */
# %   | | | | else if ( actedin(P, B), haswonprize(P, Q) )
# %   | | | | | then return 0.3454018712209624;  // std dev = 29,533, 3.491,000 (wgt'ed) examples reached here.  /* #neg=1.790 #pos=1.701 */
# %   | | | | | else return 0.4077748702616019;  // std dev = 49,815, 10.025,000 (wgt'ed) examples reached here.  /* #neg=4.515 #pos=5.510 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.677149, 'Recall': 0.0, 'AUC ROC': 0.644129, 'CLL': -0.914178}
#
#
# Total learning time: 72.591 seconds
# Total inference time: 90.991 seconds
# AUC ROC: 0.644129
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.645273
# ******************************************
#
# ******************************************
# Total revision time: 825.566
# Best validation AUC ROC: 0.645273
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995075;  // std dev = 4,16e-06, 927,000 (wgt'ed) examples reached here.  /* #pos=927 */
# %   else if ( created(A, C), actedin(D, C), actedin(D, B) )
# %   | then return 0.7658948010699165;  // std dev = 9,809, 1.149,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=1.043 */
# %   | else if ( created(A, E), actedin(F, E), wasbornin(F, G) )
# %   | | then return 0.26094261497127264;  // std dev = 45,836, 8.734,000 (wgt'ed) examples reached here.  /* #neg=5.216 #pos=3.518 */
# %   | | else if ( actedin(H, B), wasbornin(H, I), haswonprize(H, J) )
# %   | | | then if ( haswonprize(A, K), haswonprize(L, J), haswonprize(L, K) )
# %   | | | | then return 0.4209992153236868;  // std dev = 17,530, 1.249,000 (wgt'ed) examples reached here.  /* #neg=546 #pos=703 */
# %   | | | | else return 0.2461831231336955;  // std dev = 35,359, 5.265,000 (wgt'ed) examples reached here.  /* #neg=3.222 #pos=2.043 */
# %   | | | else if ( created(A, M), created(N, B), directed(N, B) )
# %   | | | | then if ( diedin(A, P), created(Q, M), wasbornin(Q, R) )
# %   | | | | | then return 0.21529179224236922;  // std dev = 3,586, 56,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=20 */
# %   | | | | | else return 0.34538617233674485;  // std dev = 18,242, 1.332,000 (wgt'ed) examples reached here.  /* #neg=683 #pos=649 */
# %   | | | | else if ( actedin(S, B), haswonprize(S, T) )
# %   | | | | | then return 0.3454018712209624;  // std dev = 29,533, 3.491,000 (wgt'ed) examples reached here.  /* #neg=1.790 #pos=1.701 */
# %   | | | | | else return 0.4077748702616019;  // std dev = 49,815, 10.025,000 (wgt'ed) examples reached here.  /* #neg=4.515 #pos=5.510 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.653112, 'Recall': 0.0, 'AUC ROC': 0.620709, 'CLL': -0.915814}
#
#
# Total inference time: 57.856 seconds
# AUC ROC: 0.620709
#
#
# Total examples
# Positive examples: 22380
# Negative examples: 22380
#
#
# Train and test sets from total
# Train Positive examples: 20142
# Train Negative examples: 20142
# Test Positive examples: 2238
# Test Negative examples: 2238
#
#
# Small dataset
# Train Positive examples: 6042
# Train Negative examples: 6042
#
#
# Revision theory train dataset and validation
# Train Positive examples: 16114
# Train Negative examples: 16114
# Validation Positive examples: 4028
# Validation Negative examples: 4028
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( haswonprize(A, C), actedin(D, B), haswonprize(D, C) )
# %   then return 0.7091021413386756;  // std dev = 0,356, 1.154,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=982 */
# %   else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | then return 0.17481560176617403;  // std dev = 0,465, 1.620,000 (wgt'ed) examples reached here.  /* #neg=1.107 #pos=513 */
# %   | else if ( actedin(H, B), livesin(H, I), isleaderof(J, I) )
# %   | | then return 0.18001625696682946;  // std dev = 0,467, 814,000 (wgt'ed) examples reached here.  /* #neg=552 #pos=262 */
# %   | | else if ( actedin(K, B), haswonprize(K, L) )
# %   | | | then if ( created(A, M), created(N, M), wasbornin(N, P) )
# %   | | | | then if ( haswonprize(N, L), haswonprize(Q, L), isleaderof(Q, R) )
# %   | | | | | then return 0.5663201413251897;  // std dev = 7,288, 257,000 (wgt'ed) examples reached here.  /* #neg=75 #pos=182 */
# %   | | | | | else return 0.35022386305339787;  // std dev = 18,626, 1.388,000 (wgt'ed) examples reached here.  /* #neg=705 #pos=683 */
# %   | | | | else return 0.2814173823607116;  // std dev = 0,494, 2.209,000 (wgt'ed) examples reached here.  /* #neg=1.274 #pos=935 */
# %   | | | else if ( created(A, S), created(T, B), created(T, S) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 83,000 (wgt'ed) examples reached here.  /* #pos=83 */
# %   | | | | else if ( created(A, U), actedin(W, U) )
# %   | | | | | then return 0.24867181091650123;  // std dev = 12,069, 612,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=239 */
# %   | | | | | else return 0.40616008280662663;  // std dev = 31,267, 3.947,000 (wgt'ed) examples reached here.  /* #neg=1.784 #pos=2.163 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.665957, 'Recall': 0.0, 'AUC ROC': 0.651532, 'CLL': -0.913909}
#
#
# Total learning time: 745.621 seconds
# Total inference time: 58.316 seconds
# AUC ROC: 0.651532
#
#
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( created(A, B) )
# %   then return 0.8581489350995075;  // std dev = 4,87e-06, 1.155,000 (wgt'ed) examples reached here.  /* #pos=1.155 */
# %   else if ( created(C, B), created(A, D), actedin(E, D) )
# %   | then if ( actedin(E, B) )
# %   | | then return 0.7450041763640669;  // std dev = 0,317, 601,000 (wgt'ed) examples reached here.  /* #neg=68 #pos=533 */
# %   | | else if ( livesin(E, F), iscitizenof(G, F) )
# %   | | | then return 0.011780220015709872;  // std dev = 0,361, 1.432,000 (wgt'ed) examples reached here.  /* #neg=1.212 #pos=220 */
# %   | | | else return 0.2851871187940377;  // std dev = 0,495, 4.845,000 (wgt'ed) examples reached here.  /* #neg=2.776 #pos=2.069 */
# %   | else if ( directed(H, B), diedin(H, I), diedin(A, J) )
# %   | | then return 0.5593254056877434;  // std dev = 0,458, 425,000 (wgt'ed) examples reached here.  /* #neg=127 #pos=298 */
# %   | | else if ( actedin(K, B), haswonprize(K, L), haswonprize(A, L) )
# %   | | | then return 0.7067203636709358;  // std dev = 0,358, 2.100,000 (wgt'ed) examples reached here.  /* #neg=318 #pos=1.782 */
# %   | | | else if ( haswonprize(A, M), created(A, N), directed(P, N) )
# %   | | | | then return 0.1672864244248702;  // std dev = 0,462, 2.342,000 (wgt'ed) examples reached here.  /* #neg=1.618 #pos=724 */
# %   | | | | else if ( actedin(Q, B), livesin(Q, R), wasbornin(S, R) )
# %   | | | | | then return 0.1490897016500299;  // std dev = 21,764, 2.296,000 (wgt'ed) examples reached here.  /* #neg=1.628 #pos=668 */
# %   | | | | | else return 0.3640880294875359;  // std dev = 79,190, 25.088,000 (wgt'ed) examples reached here.  /* #neg=12.395 #pos=12.693 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.666395, 'Recall': 0.0, 'AUC ROC': 0.640038, 'CLL': -0.910101}
#
#
# Total learning time: 2135.218 seconds
# Total inference time: 60.092 seconds
# AUC ROC: 0.640038
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( haswonprize(A, C), actedin(D, B), haswonprize(D, C) )
# %   then return 0.7069143671982726;  // std dev = 19,347, 2.916,000 (wgt'ed) examples reached here.  /* #neg=441 #pos=2.475 */
# %   else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | then return 0.1612542456305603;  // std dev = 30,638, 4.444,000 (wgt'ed) examples reached here.  /* #neg=3.097 #pos=1.347 */
# %   | else if ( actedin(H, B), livesin(H, I), isleaderof(J, I) )
# %   | | then return 0.19523285446190766;  // std dev = 21,832, 2.133,000 (wgt'ed) examples reached here.  /* #neg=1.414 #pos=719 */
# %   | | else if ( actedin(K, B), haswonprize(K, L) )
# %   | | | then if ( created(A, M), created(N, M), wasbornin(N, P) )
# %   | | | | then if ( haswonprize(N, L), haswonprize(Q, L), isleaderof(Q, R) )
# %   | | | | | then return 0.6001336679239353;  // std dev = 11,198, 655,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=486 */
# %   | | | | | else return 0.35604809476337274;  // std dev = 30,854, 3.808,000 (wgt'ed) examples reached here.  /* #neg=1.912 #pos=1.896 */
# %   | | | | else return 0.29733247199092433;  // std dev = 38,369, 5.977,000 (wgt'ed) examples reached here.  /* #neg=3.352 #pos=2.625 */
# %   | | | else if ( created(A, S), created(T, B), created(T, S) )
# %   | | | | then return 0.8581489350995087;  // std dev = 1,08e-06, 254,000 (wgt'ed) examples reached here.  /* #pos=254 */
# %   | | | | else if ( created(A, U), actedin(W, U) )
# %   | | | | | then return 0.2279695906344486;  // std dev = 19,413, 1.617,000 (wgt'ed) examples reached here.  /* #neg=1.019 #pos=598 */
# %   | | | | | else return 0.4063070317994304;  // std dev = 50,812, 10.424,000 (wgt'ed) examples reached here.  /* #neg=4.710 #pos=5.714 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.669486, 'Recall': 0.0, 'AUC ROC': 0.65731, 'CLL': -0.910424}
#
#
# Total learning time: 73.521 seconds
# Total inference time: 87.018 seconds
# AUC ROC: 0.65731
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( haswonprize(A, C), actedin(D, B), haswonprize(D, C) )
# %   then return 0.7069143671982726;  // std dev = 19,347, 2.916,000 (wgt'ed) examples reached here.  /* #neg=441 #pos=2.475 */
# %   else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | then return 0.1612542456305603;  // std dev = 0,460, 4.444,000 (wgt'ed) examples reached here.  /* #neg=3.097 #pos=1.347 */
# %   | else if ( actedin(H, B), livesin(H, I), isleaderof(J, I) )
# %   | | then return 0.19523285446190766;  // std dev = 21,832, 2.133,000 (wgt'ed) examples reached here.  /* #neg=1.414 #pos=719 */
# %   | | else if ( actedin(K, B), haswonprize(K, L) )
# %   | | | then if ( created(A, M), created(N, M), wasbornin(N, P) )
# %   | | | | then if ( haswonprize(N, L), haswonprize(Q, L), isleaderof(Q, R) )
# %   | | | | | then return 0.6001336679239353;  // std dev = 11,198, 655,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=486 */
# %   | | | | | else return 0.35604809476337274;  // std dev = 30,854, 3.808,000 (wgt'ed) examples reached here.  /* #neg=1.912 #pos=1.896 */
# %   | | | | else return 0.29733247199092433;  // std dev = 38,369, 5.977,000 (wgt'ed) examples reached here.  /* #neg=3.352 #pos=2.625 */
# %   | | | else if ( created(A, S), created(T, B), created(T, S) )
# %   | | | | then return 0.8581489350995087;  // std dev = 1,08e-06, 254,000 (wgt'ed) examples reached here.  /* #pos=254 */
# %   | | | | else if ( created(A, U), actedin(W, U) )
# %   | | | | | then return 0.2279695906344486;  // std dev = 19,413, 1.617,000 (wgt'ed) examples reached here.  /* #neg=1.019 #pos=598 */
# %   | | | | | else return 0.4063070317994304;  // std dev = 50,812, 10.424,000 (wgt'ed) examples reached here.  /* #neg=4.710 #pos=5.714 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.669486, 'Recall': 0.0, 'AUC ROC': 0.65731, 'CLL': -0.910424}
#
#
# Total learning time: 72.295 seconds
# Total inference time: 62.678 seconds
# AUC ROC: 0.65731
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( haswonprize(A, C), actedin(D, B), haswonprize(D, C) )
# %   then return 0.7069143671982726;  // std dev = 19,347, 2.916,000 (wgt'ed) examples reached here.  /* #neg=441 #pos=2.475 */
# %   else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | then return 0.1612542456305603;  // std dev = 30,638, 4.444,000 (wgt'ed) examples reached here.  /* #neg=3.097 #pos=1.347 */
# %   | else if ( actedin(H, B), livesin(H, I), isleaderof(J, I) )
# %   | | then return 0.19523285446190766;  // std dev = 21,832, 2.133,000 (wgt'ed) examples reached here.  /* #neg=1.414 #pos=719 */
# %   | | else if ( actedin(K, B), haswonprize(K, L) )
# %   | | | then if ( created(A, M), created(N, M), wasbornin(N, P) )
# %   | | | | then return 0.39187064695252083;  // std dev = 33,327, 4.463,000 (wgt'ed) examples reached here.  /* #neg=2.081 #pos=2.382 */
# %   | | | | else return 0.29733247199092433;  // std dev = 38,369, 5.977,000 (wgt'ed) examples reached here.  /* #neg=3.352 #pos=2.625 */
# %   | | | else if ( created(A, Q), created(R, B), created(R, Q) )
# %   | | | | then return 0.8581489350995087;  // std dev = 1,08e-06, 254,000 (wgt'ed) examples reached here.  /* #pos=254 */
# %   | | | | else if ( created(A, S), actedin(T, S) )
# %   | | | | | then return 0.2279695906344486;  // std dev = 19,413, 1.617,000 (wgt'ed) examples reached here.  /* #neg=1.019 #pos=598 */
# %   | | | | | else return 0.4063070317994304;  // std dev = 50,812, 10.424,000 (wgt'ed) examples reached here.  /* #neg=4.710 #pos=5.714 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.662754, 'Recall': 0.0, 'AUC ROC': 0.652037, 'CLL': -0.911331}
#
#
# Total learning time: 65.223 seconds
# Total inference time: 57.863 seconds
# AUC ROC: 0.652037
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( haswonprize(A, C), actedin(D, B), haswonprize(D, C) )
# %   then return 0.7069143671982726;  // std dev = 19,347, 2.916,000 (wgt'ed) examples reached here.  /* #neg=441 #pos=2.475 */
# %   else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | then return 0.1612542456305603;  // std dev = 30,638, 4.444,000 (wgt'ed) examples reached here.  /* #neg=3.097 #pos=1.347 */
# %   | else if ( actedin(H, B), livesin(H, I), isleaderof(J, I) )
# %   | | then return 0.19523285446190766;  // std dev = 21,832, 2.133,000 (wgt'ed) examples reached here.  /* #neg=1.414 #pos=719 */
# %   | | else if ( actedin(K, B), haswonprize(K, L) )
# %   | | | then if ( created(A, M), created(N, M), wasbornin(N, P) )
# %   | | | | then if ( haswonprize(N, L), haswonprize(Q, L), isleaderof(Q, R) )
# %   | | | | | then return 0.6001336679239353;  // std dev = 11,198, 655,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=486 */
# %   | | | | | else return 0.35604809476337274;  // std dev = 30,854, 3.808,000 (wgt'ed) examples reached here.  /* #neg=1.912 #pos=1.896 */
# %   | | | | else return 0.29733247199092433;  // std dev = 38,369, 5.977,000 (wgt'ed) examples reached here.  /* #neg=3.352 #pos=2.625 */
# %   | | | else if ( created(A, S), created(T, B), created(T, S) )
# %   | | | | then return 0.8581489350995087;  // std dev = 1,08e-06, 254,000 (wgt'ed) examples reached here.  /* #pos=254 */
# %   | | | | else return 0.3823578878442958;  // std dev = 54,801, 12.041,000 (wgt'ed) examples reached here.  /* #neg=5.729 #pos=6.312 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.662293, 'Recall': 0.0, 'AUC ROC': 0.647751, 'CLL': -0.911611}
#
#
# Total learning time: 68.608 seconds
# Total inference time: 90.963 seconds
# AUC ROC: 0.647751
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( haswonprize(A, C), actedin(D, B), haswonprize(D, C) )
# %   then return 0.7069143671982726;  // std dev = 19,347, 2.916,000 (wgt'ed) examples reached here.  /* #neg=441 #pos=2.475 */
# %   else if ( haswonprize(A, E), created(A, F), actedin(G, F) )
# %   | then return 0.1612542456305603;  // std dev = 30,638, 4.444,000 (wgt'ed) examples reached here.  /* #neg=3.097 #pos=1.347 */
# %   | else if ( actedin(H, B), livesin(H, I), isleaderof(J, I) )
# %   | | then return 0.19523285446190766;  // std dev = 0,473, 2.133,000 (wgt'ed) examples reached here.  /* #neg=1.414 #pos=719 */
# %   | | else if ( actedin(K, B), haswonprize(K, L) )
# %   | | | then if ( created(A, M), created(N, M), wasbornin(N, P) )
# %   | | | | then if ( haswonprize(N, L), haswonprize(Q, L), isleaderof(Q, R) )
# %   | | | | | then return 0.6001336679239353;  // std dev = 11,198, 655,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=486 */
# %   | | | | | else return 0.35604809476337274;  // std dev = 30,854, 3.808,000 (wgt'ed) examples reached here.  /* #neg=1.912 #pos=1.896 */
# ...
#
#
# Total learning time: 1044.13 seconds
# Total inference time: 57.959 seconds
# AUC ROC: 0.589028
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 7,402, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 47,466, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 22,173, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 33,924, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 17,511, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else if ( haswonprize(A, R), actedin(S, B) )
# %   | | | | | then return 0.3012079542183769;  // std dev = 17,229, 1.203,000 (wgt'ed) examples reached here.  /* #neg=670 #pos=533 */
# %   | | | | | else return 0.42022545961140795;  // std dev = 49,702, 10.036,000 (wgt'ed) examples reached here.  /* #neg=4.395 #pos=5.641 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.66503, 'Recall': 0.0, 'AUC ROC': 0.642085, 'CLL': -0.91453}
#
#
# Total learning time: 66.197 seconds
# Total inference time: 61.519 seconds
# AUC ROC: 0.642085
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 7,402, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 47,466, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 22,173, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 0,492, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 17,511, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else if ( haswonprize(A, R), actedin(S, B) )
# %   | | | | | then return 0.3012079542183769;  // std dev = 17,229, 1.203,000 (wgt'ed) examples reached here.  /* #neg=670 #pos=533 */
# %   | | | | | else return 0.42022545961140795;  // std dev = 49,702, 10.036,000 (wgt'ed) examples reached here.  /* #neg=4.395 #pos=5.641 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.66503, 'Recall': 0.0, 'AUC ROC': 0.642085, 'CLL': -0.91453}
#
#
# Total learning time: 68.327 seconds
# Total inference time: 57.718 seconds
# AUC ROC: 0.642085
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 7,402, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 47,466, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 22,173, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 33,924, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 0,487, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else if ( haswonprize(A, R), actedin(S, B) )
# %   | | | | | then return 0.3012079542183769;  // std dev = 17,229, 1.203,000 (wgt'ed) examples reached here.  /* #neg=670 #pos=533 */
# %   | | | | | else return 0.42022545961140795;  // std dev = 49,702, 10.036,000 (wgt'ed) examples reached here.  /* #neg=4.395 #pos=5.641 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.66503, 'Recall': 0.0, 'AUC ROC': 0.642085, 'CLL': -0.91453}
#
#
# Total learning time: 68.624 seconds
# Total inference time: 86.988 seconds
# AUC ROC: 0.642085
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 7,402, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 47,466, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 22,173, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 33,924, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 17,511, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else return 0.4074860647373753;  // std dev = 52,748, 11.239,000 (wgt'ed) examples reached here.  /* #neg=5.065 #pos=6.174 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.660326, 'Recall': 0.0, 'AUC ROC': 0.637964, 'CLL': -0.91528}
#
#
# Total learning time: 67.393 seconds
# Total inference time: 60.712 seconds
# AUC ROC: 0.637964
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 0,481, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 47,466, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 22,173, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 33,924, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 17,511, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else if ( haswonprize(A, R), actedin(S, B) )
# %   | | | | | then return 0.3012079542183769;  // std dev = 17,229, 1.203,000 (wgt'ed) examples reached here.  /* #neg=670 #pos=533 */
# %   | | | | | else return 0.42022545961140795;  // std dev = 49,702, 10.036,000 (wgt'ed) examples reached here.  /* #neg=4.395 #pos=5.641 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.66503, 'Recall': 0.0, 'AUC ROC': 0.642085, 'CLL': -0.91453}
#
#
# Total learning time: 99.98400000000001 seconds
# Total inference time: 54.681 seconds
# AUC ROC: 0.642085
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 7,402, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 47,466, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 0,468, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 33,924, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 17,511, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else if ( haswonprize(A, R), actedin(S, B) )
# %   | | | | | then return 0.3012079542183769;  // std dev = 17,229, 1.203,000 (wgt'ed) examples reached here.  /* #neg=670 #pos=533 */
# %   | | | | | else return 0.42022545961140795;  // std dev = 49,702, 10.036,000 (wgt'ed) examples reached here.  /* #neg=4.395 #pos=5.641 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.66503, 'Recall': 0.0, 'AUC ROC': 0.642085, 'CLL': -0.91453}
#
#
# Total learning time: 69.252 seconds
# Total inference time: 83.746 seconds
# AUC ROC: 0.642085
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 7,402, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 0,494, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 22,173, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 33,924, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 17,511, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else if ( haswonprize(A, R), actedin(S, B) )
# %   | | | | | then return 0.3012079542183769;  // std dev = 17,229, 1.203,000 (wgt'ed) examples reached here.  /* #neg=670 #pos=533 */
# %   | | | | | else return 0.42022545961140795;  // std dev = 49,702, 10.036,000 (wgt'ed) examples reached here.  /* #neg=4.395 #pos=5.641 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.66503, 'Recall': 0.0, 'AUC ROC': 0.642085, 'CLL': -0.91453}
#
#
# Total learning time: 93.90100000000001 seconds
# Total inference time: 89.315 seconds
# AUC ROC: 0.642085
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.642085
# ******************************************
#
# ******************************************
# Total revision time: 1028.357
# Best validation AUC ROC: 0.642085
# WILL-Produced Tree:
# % FOR wrotemusicfor(A, B):
# %   if ( directed(A, C), actedin(D, B), diedin(D, E) )
# %   then return 0.2210181334117476;  // std dev = 7,402, 237,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=86 */
# %   else if ( actedin(F, B), created(A, G), haswonprize(F, H) )
# %   | then if ( haswonprize(A, H) )
# %   | | then return 0.7008538230083643;  // std dev = 18,992, 2.721,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=2.293 */
# %   | | else if ( actedin(F, G) )
# %   | | | then return 0.8280284531717972;  // std dev = 3,814, 498,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=483 */
# %   | | | else return 0.2806094072675816;  // std dev = 47,466, 9.234,000 (wgt'ed) examples reached here.  /* #neg=5.333 #pos=3.901 */
# %   | else if ( haswonprize(A, I), created(A, J), actedin(K, J) )
# %   | | then return 0.18095907293854685;  // std dev = 22,173, 2.249,000 (wgt'ed) examples reached here.  /* #neg=1.523 #pos=726 */
# %   | | else if ( actedin(L, B), haswonprize(L, M) )
# %   | | | then return 0.26828137150900894;  // std dev = 33,924, 4.757,000 (wgt'ed) examples reached here.  /* #neg=2.806 #pos=1.951 */
# %   | | | else if ( created(A, N), actedin(P, N), haswonprize(P, Q) )
# %   | | | | then return 0.24484653757437208;  // std dev = 17,511, 1.293,000 (wgt'ed) examples reached here.  /* #neg=793 #pos=500 */
# %   | | | | else if ( haswonprize(A, R), actedin(S, B) )
# %   | | | | | then return 0.3012079542183769;  // std dev = 17,229, 1.203,000 (wgt'ed) examples reached here.  /* #neg=670 #pos=533 */
# %   | | | | | else return 0.42022545961140795;  // std dev = 49,702, 10.036,000 (wgt'ed) examples reached here.  /* #neg=4.395 #pos=5.641 */
#
#
# Results:
# {'Precision': [nan, 0.5], 'F1': nan, 'AUC PR': 0.668047, 'Recall': 0.0, 'AUC ROC': 0.640479, 'CLL': -0.915524}
#
#
# Total inference time: 58.343 seconds
# AUC ROC: 0.640479

# %%
small_dataset_aucroc
# Out:
# [0.67025,
#  0.61788,
#  0.651532,
#  0.653822,
#  0.602801,
#  0.569657,
#  0.620382,
#  0.646736,
#  0.626913,
#  0.63669]

# %%
complete_dataset_aucroc
# Out:
# [0.675816,
#  0.600701,
#  0.640038,
#  0.64855,
#  0.603423,
#  0.650971,
#  0.612524,
#  0.585307,
#  0.627308,
#  0.589028]

# %%
revision_dataset_aucroc
# Out:
# [0.673163,
#  0.620709,
#  0.651532,
#  0.624899,
#  0.604336,
#  0.569817,
#  0.622744,
#  0.646736,
#  0.627129,
#  0.640479]

# %%
print('Small dataset AUC ROC: %s +/- %s' % ((np.array(small_dataset_aucroc)).mean(), (np.array(small_dataset_aucroc)).std()))
print('Complete dataset AUC ROC: %s +/- %s' % ((np.array(complete_dataset_aucroc)).mean(), (np.array(complete_dataset_aucroc)).std()))
print('Theory revision dataset AUC ROC: %s +/- %s' % ((np.array(revision_dataset_aucroc)).mean(), (np.array(revision_dataset_aucroc)).std()))
# Out:
# Small dataset AUC ROC: 0.6296663 +/- 0.027576995104797046
# Complete dataset AUC ROC: 0.6233666 +/- 0.0284558034298805
# Theory revision dataset AUC ROC: 0.6281544 +/- 0.026714007150556794

# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold

# %% [markdown]
# ## Parameters

# %%
target = 'hasacademicadvisor'
#test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.8
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %%
[facts, pos, neg] = get_yago2s_dataset(target, acceptedPredicates=[
'hascurrency',
'hascapital',
'hasacademicadvisor',
'participatedin',
'haswonprize',
'participatedin',
'owns',
'isinterestedin',
'livesin',
'happenedin',
'holdspoliticalposition',
'diedin',
'actedin',
'iscitizenof',
'worksat',
'directed',
'dealswith',
'wasbornin',
'created',
'isleaderof',
'haschild',
'ismarriedto',
'imports',
'hasmusicalrole',
'influences',
'isaffiliatedto',
'isknownfor',
'ispoliticianof',
'graduatedfrom',
'exports',
'edited',
'wrotemusicfor'
])

# %% [markdown]
# ## Background  configuration

# %%
bk = ['hascurrency(+place,+currency).',
'hascurrency(+place,-currency).',
'hascurrency(-place,+currency).',
'hascapital(+place,+place).',
'hascapital(+place,-place).',
'hascapital(-place,+place).',
'hasacademicadvisor(+person,+person).',
'hasacademicadvisor(+person,-person).',
'hasacademicadvisor(-person,+person).',
'haswonprize(+person,+prize).',
'haswonprize(+person,-prize).',
'haswonprize(-person,+prize).',
'participatedin(+place,+event).',
'participatedin(+place,-event).',
'participatedin(-place,+event).',
'owns(+institution,+institution).',
'owns(+institution,-institution).',
'owns(-institution,+institution).',
'isinterestedin(+person,+concept).',
'isinterestedin(+person,-concept).',
'isinterestedin(-person,+concept).',
'livesin(+person,+place).',
'livesin(+person,-place).',
'livesin(-person,+place).',
'happenedin(+event,+place).',
'happenedin(+event,-place).',
'happenedin(-event,+place).',
'holdspoliticalposition(+person,+politicalposition).',
'holdspoliticalposition(+person,-politicalposition).',
'holdspoliticalposition(-person,+politicalposition).',
'diedin(+person,+place).',
'diedin(+person,-place).',
'diedin(-person,+place).',
'actedin(+person,+media).',
'actedin(+person,-media).',
'actedin(-person,+media).',
'iscitizenof(+person,+place).',
'iscitizenof(+person,-place).',
'iscitizenof(-person,+place).',
'worksat(+person,+institution).',
'worksat(+person,-institution).',
'worksat(-person,+institution).',
'directed(+person,+media).',
'directed(+person,-media).',
'directed(-person,+media).',
'dealswith(+place,+place).',
'dealswith(+place,-place).',
'dealswith(-place,+place).',
'wasbornin(+person,+place).',
'wasbornin(+person,-place).',
'wasbornin(-person,+place).',
'created(+person,+media).',
'created(+person,-media).',
'created(-person,+media).',
'isleaderof(+person,+place).',
'isleaderof(+person,-place).',
'isleaderof(-person,+place).',
'haschild(+person,+person).',
'haschild(+person,-person).',
'haschild(-person,+person).',
'ismarriedto(+person,+person).',
'ismarriedto(+person,-person).',
'ismarriedto(-person,+person).',
'imports(+person,+material).',
'imports(+person,-material).',
'imports(-person,+material).',
'hasmusicalrole(+person,+musicalrole).',
'hasmusicalrole(+person,-musicalrole).',
'hasmusicalrole(-person,+musicalrole).',
'influences(+person,+person).',
'influences(+person,-person).',
'influences(-person,+person).',
'isaffiliatedto(+person,+team).',
'isaffiliatedto(+person,-team).',
'isaffiliatedto(-person,+team).',
'isknownfor(+person,+theory).',
'isknownfor(+person,-theory).',
'isknownfor(-person,+theory).',
'ispoliticianof(+person,+place).',
'ispoliticianof(+person,-place).',
'ispoliticianof(-person,+place).',
'graduatedfrom(+person,+institution).',
'graduatedfrom(+person,-institution).',
'graduatedfrom(-person,+institution).',
'exports(+place,+material).',
'exports(+place,-material).',
'exports(-place,+material).',
'edited(+person,+media).',
'edited(+person,-media).',
'edited(-person,+media).',
'wrotemusicfor(+person,+media).',
'wrotemusicfor(+person,-media).',
'wrotemusicfor(-person,+media).']

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

neg = neg[:len(pos)] # balanced

import numpy as np
pos = np.array(pos)
neg = np.array(neg)
small_dataset_aucroc = []
complete_dataset_aucroc = []
revision_dataset_aucroc = []


# separate train and test
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(pos):
    train_pos, test_pos = pos[train_index], pos[test_index]
    train_neg, test_neg = neg[train_index], neg[test_index]

    # learn from scratch in a small dataset
    s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
    s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

    # shuffle all train examples
    random.shuffle(train_pos)
    random.shuffle(train_neg)

    # train set used in revision and validation set
    r_train_pos = train_pos[int(validation_size*len(train_pos)):]
    r_train_neg = train_neg[int(validation_size*len(train_neg)):]
    validation_pos = train_pos[:int(validation_size*len(train_pos))]
    validation_neg = train_neg[:int(validation_size*len(train_neg))]

    print('Total examples')
    print('Positive examples: %s' % len(pos))
    print('Negative examples: %s' % len(neg))
    print('\n')
    print('Train and test sets from total')
    print('Train Positive examples: %s' % len(train_pos))
    print('Train Negative examples: %s' % len(train_neg))
    print('Test Positive examples: %s' % len(test_pos))
    print('Test Negative examples: %s' % len(test_neg))
    print('\n')
    print('Small dataset')
    print('Train Positive examples: %s' % len(s_train_pos))
    print('Train Negative examples: %s' % len(s_train_neg))
    print('\n')
    print('Revision theory train dataset and validation')
    print('Train Positive examples: %s' % len(r_train_pos))
    print('Train Negative examples: %s' % len(r_train_neg))
    print('Validation Positive examples: %s' % len(validation_pos))
    print('Validation Negative examples: %s' % len(validation_neg))
    
    # learning from small dataset
    delete_model_files()
    model = boostsrl.train(background, s_train_pos, s_train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    small_dataset_aucroc.append(t_results['AUC ROC'])
    
    # learning from complete dataset
    delete_model_files()
    model = boostsrl.train(background, train_pos, train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    #structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    complete_dataset_aucroc.append(t_results['AUC ROC'])
    
    # theory revision
    total_revision_time = 0
    best_aucroc = 0
    best_structured = None

    print('Performing parameter learning')
    print('******************************************')
    delete_model_files()
    model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=get_refine_file(structured))
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, validation_pos, validation_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    total_revision_time += learning_time + inference_time
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)

    best_aucroc = t_results['AUC ROC']
    best_structured = structured.copy()
    save_model_files()

    for i in range(max_revision_iterations):
        print('Refining iteration %s' % str(i+1))
        print('******************************************')
        found_better = False
        for candidate in get_cantidates(best_structured, revision_threshold):
            print('Refining node candidate')
            print('******************************************')
            delete_model_files()
            model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=candidate)
            learning_time = model.traintime()
            will = model.get_will_produced_tree()
            results = boostsrl.test(model, validation_pos, validation_neg, facts)
            inference_time = results.testtime()
            t_results = results.summarize_results()
            total_revision_time += learning_time + inference_time
            print('WILL-Produced Tree:')
            print_will_produced_tree(will)
            print('\n')
            print('Results:')
            print(t_results)
            print('\n')
            print('Total learning time: %s seconds' % learning_time)
            print('Total inference time: %s seconds' % inference_time)
            print('AUC ROC: %s' % t_results['AUC ROC'])
            print('\n')
            #print('Tree:')
            #model.tree(0, target, image=True)
            print('******************************************')

            if t_results['AUC ROC'] > best_aucroc:
                found_better = True
                best_aucroc = t_results['AUC ROC']
                best_structured = model.get_structured_tree().copy()
                save_model_files()
        print('Best Tree AUC ROC so far: %s' % best_aucroc)
        print('******************************************\n')
        if found_better == False:
            break

    print('******************************************')
    delete_model_files()
    get_saved_model_files()
    delete_test_files()
    print('Total revision time: %s' % total_revision_time)
    print('Best validation AUC ROC: %s' % best_aucroc)
    will = model.get_will_produced_tree()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    revision_dataset_aucroc.append(t_results['AUC ROC'])
# Out:
# Total examples
# Positive examples: 2895
# Negative examples: 2895
#
#
# Train and test sets from total
# Train Positive examples: 2605
# Train Negative examples: 2605
# Test Positive examples: 290
# Test Negative examples: 290
#
#
# Small dataset
# Train Positive examples: 781
# Train Negative examples: 781
#
#
# Revision theory train dataset and validation
# Train Positive examples: 2084
# Train Negative examples: 2084
# Validation Positive examples: 521
# Validation Negative examples: 521
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), haswonprize(A, D), haswonprize(B, E) )
# %   then return 0.6273797043302815;  // std dev = 0,421, 52,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=40 */
# %   else if ( graduatedfrom(B, F), graduatedfrom(A, F) )
# %   | then return 0.8440644280572592;  // std dev = 0,118, 71,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=70 */
# %   | else if ( worksat(A, G), worksat(B, H), owns(H, I) )
# %   | | then if ( graduatedfrom(A, H) )
# %   | | | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | | | else if ( haswonprize(A, J), graduatedfrom(K, G), holdspoliticalposition(K, L) )
# %   | | | | then return 0.7405018762759829;  // std dev = 0,322, 17,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=15 */
# %   | | | | else return 0.2846195233348054;  // std dev = 0,495, 68,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=29 */
# %   | | else if ( graduatedfrom(A, M), worksat(B, M) )
# %   | | | then return 0.8116373071925351;  // std dev = 0,211, 43,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=41 */
# %   | | | else if ( worksat(A, N), graduatedfrom(A, P), worksat(Q, P) )
# %   | | | | then return 0.18937921901118096;  // std dev = 0,471, 317,000 (wgt'ed) examples reached here.  /* #neg=212 #pos=105 */
# %   | | | | else if ( diedin(A, R), graduatedfrom(A, S), wasbornin(A, T) )
# %   | | | | | then return 0.10814893509951236;  // std dev = 3,000, 48,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=12 */
# %   | | | | | else return 0.3413558690106679;  // std dev = 15,182, 923,000 (wgt'ed) examples reached here.  /* #neg=477 #pos=446 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.921514, 'AUC PR': 0.629011, 'AUC ROC': 0.587313}
#
#
# Total learning time: 1179.031 seconds
# Total inference time: 84.732 seconds
# AUC ROC: 0.587313
#
#
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(A, D) )
# %   then return 0.7002541982574055;  // std dev = 0,365, 114,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=96 */
# %   else if ( graduatedfrom(B, E), graduatedfrom(F, E), diedin(F, G) )
# %   | then if ( graduatedfrom(A, E), hascapital(H, G) )
# %   | | then return 0.7801672837233622;  // std dev = 0,268, 218,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=201 */
# %   | | else if ( wasbornin(A, G), diedin(I, G), wasbornin(I, G) )
# %   | | | then return 0.5504566274072056;  // std dev = 0,462, 104,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=72 */
# %   | | | else if ( influences(A, J), haswonprize(F, K), happenedin(L, G) )
# %   | | | | then return 0.1658412427918188;  // std dev = 0,462, 91,000 (wgt'ed) examples reached here.  /* #neg=63 #pos=28 */
# %   | | | | else if ( worksat(B, E), happenedin(M, G), participatedin(G, N) )
# %   | | | | | then return 0.19148226843284424;  // std dev = 4,967, 111,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=37 */
# %   | | | | | else return 0.3560190096468983;  // std dev = 21,668, 1.878,000 (wgt'ed) examples reached here.  /* #neg=943 #pos=935 */
# %   | else if ( iscitizenof(B, P), iscitizenof(A, Q), dealswith(P, Q) )
# %   | | then return 0.06723984419042099;  // std dev = 0,407, 110,000 (wgt'ed) examples reached here.  /* #neg=87 #pos=23 */
# %   | | else if ( iscitizenof(B, R), hascapital(R, S), dealswith(R, T) )
# %   | | | then return 0.41604367194161324;  // std dev = 0,497, 475,000 (wgt'ed) examples reached here.  /* #neg=210 #pos=265 */
# %   | | | else return 0.30765106881216764;  // std dev = 0,497, 2.109,000 (wgt'ed) examples reached here.  /* #neg=1.161 #pos=948 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.923976, 'AUC PR': 0.60761, 'AUC ROC': 0.592675}
#
#
# Total learning time: 2039.606 seconds
# Total inference time: 84.426 seconds
# AUC ROC: 0.592675
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), haswonprize(A, D), haswonprize(B, E) )
# %   then return 0.5701489350995105;  // std dev = 5,063, 125,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=89 */
# %   else if ( graduatedfrom(B, F), graduatedfrom(A, F) )
# %   | then return 0.7603228481429877;  // std dev = 4,030, 184,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=166 */
# %   | else if ( worksat(A, G), worksat(B, H), owns(H, I) )
# %   | | then if ( graduatedfrom(A, H) )
# %   | | | then return 0.8224346493852267;  // std dev = 1,389, 56,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=54 */
# %   | | | else if ( haswonprize(A, J), graduatedfrom(K, G), holdspoliticalposition(K, L) )
# %   | | | | then return 0.4735335504841266;  // std dev = 3,508, 52,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=32 */
# %   | | | | else return 0.3150017269776834;  // std dev = 6,992, 197,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=90 */
# %   | | else if ( graduatedfrom(A, M), worksat(B, M) )
# %   | | | then return 0.8387314593713558;  // std dev = 1,400, 103,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=101 */
# %   | | | else if ( worksat(A, N), graduatedfrom(A, P), worksat(Q, P) )
# %   | | | | then return 0.2473177008425807;  // std dev = 13,739, 794,000 (wgt'ed) examples reached here.  /* #neg=485 #pos=309 */
# %   | | | | else if ( diedin(A, R), graduatedfrom(A, S), wasbornin(A, T) )
# %   | | | | | then return 0.2938632208137992;  // std dev = 5,867, 140,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=61 */
# %   | | | | | else return 0.3277556097121419;  // std dev = 25,038, 2.517,000 (wgt'ed) examples reached here.  /* #neg=1.335 #pos=1.182 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.906592, 'AUC PR': 0.703793, 'AUC ROC': 0.663649}
#
#
# Total learning time: 58.009 seconds
# Total inference time: 58.898 seconds
# AUC ROC: 0.663649
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), haswonprize(A, D), haswonprize(B, E) )
# %   then return 0.5701489350995105;  // std dev = 5,063, 125,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=89 */
# %   else if ( graduatedfrom(B, F), graduatedfrom(A, F) )
# %   | then return 0.7603228481429877;  // std dev = 4,030, 184,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=166 */
# %   | else if ( worksat(A, G), worksat(B, H), owns(H, I) )
# %   | | then if ( graduatedfrom(A, H) )
# %   | | | then return 0.8224346493852267;  // std dev = 1,389, 56,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=54 */
# %   | | | else if ( haswonprize(A, J), graduatedfrom(K, G), holdspoliticalposition(K, L) )
# %   | | | | then return 0.4735335504841266;  // std dev = 3,508, 52,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=32 */
# %   | | | | else return 0.3150017269776834;  // std dev = 6,992, 197,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=90 */
# %   | | else if ( graduatedfrom(A, M), worksat(B, M) )
# %   | | | then return 0.8387314593713558;  // std dev = 1,400, 103,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=101 */
# %   | | | else if ( worksat(A, N), graduatedfrom(A, P), worksat(Q, P) )
# %   | | | | then return 0.2473177008425807;  // std dev = 0,488, 794,000 (wgt'ed) examples reached here.  /* #neg=485 #pos=309 */
# %   | | | | else if ( diedin(A, R), graduatedfrom(A, S), wasbornin(A, T) )
# %   | | | | | then return 0.2938632208137992;  // std dev = 5,867, 140,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=61 */
# %   | | | | | else return 0.3277556097121419;  // std dev = 25,038, 2.517,000 (wgt'ed) examples reached here.  /* #neg=1.335 #pos=1.182 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.906592, 'AUC PR': 0.703793, 'AUC ROC': 0.663649}
#
#
# Total learning time: 62.797 seconds
# Total inference time: 86.737 seconds
# AUC ROC: 0.663649
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), haswonprize(A, D), haswonprize(B, E) )
# %   then return 0.5701489350995105;  // std dev = 0,453, 125,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=89 */
# %   else if ( graduatedfrom(B, F), graduatedfrom(A, F) )
# %   | then return 0.7603228481429877;  // std dev = 4,030, 184,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=166 */
# %   | else if ( worksat(A, G), worksat(B, H), owns(H, I) )
# %   | | then if ( graduatedfrom(A, H) )
# %   | | | then return 0.8224346493852267;  // std dev = 1,389, 56,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=54 */
# %   | | | else if ( haswonprize(A, J), graduatedfrom(K, G), holdspoliticalposition(K, L) )
# %   | | | | then return 0.4735335504841266;  // std dev = 3,508, 52,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=32 */
# %   | | | | else return 0.3150017269776834;  // std dev = 6,992, 197,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=90 */
# %   | | else if ( graduatedfrom(A, M), worksat(B, M) )
# %   | | | then return 0.8387314593713558;  // std dev = 1,400, 103,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=101 */
# %   | | | else if ( worksat(A, N), graduatedfrom(A, P), worksat(Q, P) )
# %   | | | | then return 0.2473177008425807;  // std dev = 13,739, 794,000 (wgt'ed) examples reached here.  /* #neg=485 #pos=309 */
# %   | | | | else if ( diedin(A, R), graduatedfrom(A, S), wasbornin(A, T) )
# %   | | | | | then return 0.2938632208137992;  // std dev = 5,867, 140,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=61 */
# %   | | | | | else return 0.3277556097121419;  // std dev = 25,038, 2.517,000 (wgt'ed) examples reached here.  /* #neg=1.335 #pos=1.182 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.906592, 'AUC PR': 0.703793, 'AUC ROC': 0.663649}
#
#
# Total learning time: 60.116 seconds
# Total inference time: 55.889 seconds
# AUC ROC: 0.663649
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), haswonprize(A, D), haswonprize(B, E) )
# %   then return 0.5701489350995105;  // std dev = 5,063, 125,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=89 */
# %   else if ( graduatedfrom(B, F), graduatedfrom(A, F) )
# %   | then return 0.7603228481429877;  // std dev = 4,030, 184,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=166 */
# %   | else if ( worksat(A, G), worksat(B, H), owns(H, I) )
# %   | | then if ( graduatedfrom(A, H) )
# %   | | | then return 0.8224346493852267;  // std dev = 1,389, 56,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=54 */
# %   | | | else return 0.3481087744569385;  // std dev = 7,888, 249,000 (wgt'ed) examples reached here.  /* #neg=127 #pos=122 */
# %   | | else if ( graduatedfrom(A, J), worksat(B, J) )
# %   | | | then return 0.8387314593713558;  // std dev = 1,400, 103,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=101 */
# %   | | | else if ( worksat(A, K), graduatedfrom(A, L), worksat(M, L) )
# %   | | | | then return 0.2473177008425807;  // std dev = 13,739, 794,000 (wgt'ed) examples reached here.  /* #neg=485 #pos=309 */
# %   | | | | else if ( diedin(A, N), graduatedfrom(A, P), wasbornin(A, Q) )
# %   | | | | | then return 0.2938632208137992;  // std dev = 5,867, 140,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=61 */
# %   | | | | | else return 0.3277556097121419;  // std dev = 25,038, 2.517,000 (wgt'ed) examples reached here.  /* #neg=1.335 #pos=1.182 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.907293, 'AUC PR': 0.696276, 'AUC ROC': 0.656159}
#
#
# Total learning time: 60.317 seconds
# Total inference time: 82.24 seconds
# AUC ROC: 0.656159
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), haswonprize(A, D), haswonprize(B, E) )
# %   then return 0.5701489350995105;  // std dev = 5,063, 125,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=89 */
# %   else if ( graduatedfrom(B, F), graduatedfrom(A, F) )
# %   | then return 0.7603228481429877;  // std dev = 4,030, 184,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=166 */
# %   | else if ( worksat(A, G), worksat(B, H), owns(H, I) )
# %   | | then if ( graduatedfrom(A, H) )
# %   | | | then return 0.8224346493852267;  // std dev = 1,389, 56,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=54 */
# %   | | | else if ( haswonprize(A, J), graduatedfrom(K, G), holdspoliticalposition(K, L) )
# %   | | | | then return 0.4735335504841266;  // std dev = 3,508, 52,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=32 */
# %   | | | | else return 0.3150017269776834;  // std dev = 6,992, 197,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=90 */
# %   | | else if ( graduatedfrom(A, M), worksat(B, M) )
# %   | | | then return 0.8387314593713558;  // std dev = 1,400, 103,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=101 */
# %   | | | else if ( worksat(A, N), graduatedfrom(A, P), worksat(Q, P) )
# %   | | | | then return 0.2473177008425807;  // std dev = 13,739, 794,000 (wgt'ed) examples reached here.  /* #neg=485 #pos=309 */
# %   | | | | else return 0.3259697856828722;  // std dev = 25,720, 2.657,000 (wgt'ed) examples reached here.  /* #neg=1.414 #pos=1.243 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.906874, 'AUC PR': 0.697165, 'AUC ROC': 0.652536}
#
#
# Total learning time: 59.779 seconds
# Total inference time: 82.601 seconds
# AUC ROC: 0.652536
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.663649
# ******************************************
#
# ******************************************
# Total revision time: 667.383
# Best validation AUC ROC: 0.663649
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), haswonprize(A, D), haswonprize(B, E) )
# %   then return 0.5701489350995105;  // std dev = 5,063, 125,000 (wgt'ed) examples reached here.  /* #neg=36 #pos=89 */
# %   else if ( graduatedfrom(B, F), graduatedfrom(A, F) )
# %   | then return 0.7603228481429877;  // std dev = 4,030, 184,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=166 */
# %   | else if ( worksat(A, G), worksat(B, H), owns(H, I) )
# %   | | then if ( graduatedfrom(A, H) )
# %   | | | then return 0.8224346493852267;  // std dev = 1,389, 56,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=54 */
# %   | | | else if ( haswonprize(A, J), graduatedfrom(K, G), holdspoliticalposition(K, L) )
# %   | | | | then return 0.4735335504841266;  // std dev = 3,508, 52,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=32 */
# %   | | | | else return 0.3150017269776834;  // std dev = 6,992, 197,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=90 */
# %   | | else if ( graduatedfrom(A, M), worksat(B, M) )
# %   | | | then return 0.8387314593713558;  // std dev = 1,400, 103,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=101 */
# %   | | | else if ( worksat(A, N), graduatedfrom(A, P), worksat(Q, P) )
# %   | | | | then return 0.2473177008425807;  // std dev = 13,739, 794,000 (wgt'ed) examples reached here.  /* #neg=485 #pos=309 */
# %   | | | | else if ( diedin(A, R), graduatedfrom(A, S), wasbornin(A, T) )
# %   | | | | | then return 0.2938632208137992;  // std dev = 5,867, 140,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=61 */
# %   | | | | | else return 0.3277556097121419;  // std dev = 25,038, 2.517,000 (wgt'ed) examples reached here.  /* #neg=1.335 #pos=1.182 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.922501, 'AUC PR': 0.634937, 'AUC ROC': 0.58931}
#
#
# Total inference time: 55.479 seconds
# AUC ROC: 0.58931
#
#
# Total examples
# Positive examples: 2895
# Negative examples: 2895
#
#
# Train and test sets from total
# Train Positive examples: 2605
# Train Negative examples: 2605
# Test Positive examples: 290
# Test Negative examples: 290
#
#
# Small dataset
# Train Positive examples: 781
# Train Negative examples: 781
#
#
# Revision theory train dataset and validation
# Train Positive examples: 2084
# Train Negative examples: 2084
# Validation Positive examples: 521
# Validation Negative examples: 521
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.7929315437951642;  // std dev = 0,247, 46,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=43 */
# %   | else if ( worksat(B, E), haswonprize(F, D), created(F, G) )
# %   | | then return 0.59727936988212;  // std dev = 0,439, 46,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=34 */
# %   | | else return 0.3465210281227671;  // std dev = 0,500, 86,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=42 */
# %   else if ( wasbornin(B, H), wasbornin(A, I), diedin(A, J) )
# %   | then return 0.6039116469639193;  // std dev = 0,435, 59,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=44 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else if ( livesin(B, K), iscitizenof(A, K) )
# %   | | | then return 0.6255907955646276;  // std dev = 0,422, 43,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=33 */
# %   | | | else if ( iscitizenof(A, L), iscitizenof(B, L) )
# %   | | | | then return 0.7043027812533591;  // std dev = 0,361, 78,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=66 */
# %   | | | | else if ( iscitizenof(A, M), iscitizenof(B, N), dealswith(P, N) )
# %   | | | | | then return 0.05964147241294445;  // std dev = 4,643, 134,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=27 */
# %   | | | | | else return 0.31337984933136476;  // std dev = 16,221, 1.061,000 (wgt'ed) examples reached here.  /* #neg=578 #pos=483 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.908433, 'AUC PR': 0.674772, 'AUC ROC': 0.632937}
#
#
# Total learning time: 1376.881 seconds
# Total inference time: 81.494 seconds
# AUC ROC: 0.632937
#
#
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.49726183832531445;  // std dev = 0,480, 496,000 (wgt'ed) examples reached here.  /* #neg=179 #pos=317 */
# %   else if ( iscitizenof(B, F), iscitizenof(A, F) )
# %   | then return 0.7091208573457284;  // std dev = 0,356, 463,000 (wgt'ed) examples reached here.  /* #neg=69 #pos=394 */
# %   | else if ( iscitizenof(A, G), iscitizenof(B, H), dealswith(I, H) )
# %   | | then return 0.14579372274429553;  // std dev = 0,453, 518,000 (wgt'ed) examples reached here.  /* #neg=369 #pos=149 */
# %   | | else if ( haswonprize(B, J), haswonprize(A, K) )
# %   | | | then if ( haswonprize(B, K) )
# %   | | | | then return 0.7914822684328452;  // std dev = 0,249, 90,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=84 */
# %   | | | | else return 0.3516554286060024;  // std dev = 0,500, 231,000 (wgt'ed) examples reached here.  /* #neg=117 #pos=114 */
# %   | | | else if ( graduatedfrom(B, L) )
# %   | | | | then if ( graduatedfrom(A, L) )
# %   | | | | | then return 0.7533102254220911;  // std dev = 3,411, 124,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=111 */
# %   | | | | | else return 0.3134561976693398;  // std dev = 18,845, 1.432,000 (wgt'ed) examples reached here.  /* #neg=780 #pos=652 */
# %   | | | | else if ( influences(A, M), wasbornin(M, N), livesin(M, P) )
# %   | | | | | then return -0.026466449515872396;  // std dev = 1,629, 26,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=3 */
# %   | | | | | else return 0.28492489138366056;  // std dev = 21,159, 1.830,000 (wgt'ed) examples reached here.  /* #neg=1.049 #pos=781 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.911498, 'AUC PR': 0.664964, 'AUC ROC': 0.649768}
#
#
# Total learning time: 237.609 seconds
# Total inference time: 57.372 seconds
# AUC ROC: 0.649768
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else if ( worksat(B, E), haswonprize(F, D), created(F, G) )
# %   | | then return 0.4892168962645618;  // std dev = 4,897, 103,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=65 */
# %   | | else return 0.3015878491266604;  // std dev = 7,385, 221,000 (wgt'ed) examples reached here.  /* #neg=123 #pos=98 */
# %   else if ( wasbornin(B, H), wasbornin(A, I), diedin(A, J) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, K), iscitizenof(A, K) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, L), iscitizenof(B, L) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else if ( iscitizenof(A, M), iscitizenof(B, N), dealswith(P, N) )
# %   | | | | | then return 0.1217592502857578;  // std dev = 8,231, 349,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=92 */
# %   | | | | | else return 0.3136296020026647;  // std dev = 26,442, 2.819,000 (wgt'ed) examples reached here.  /* #neg=1.535 #pos=1.284 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.913714, 'AUC PR': 0.671825, 'AUC ROC': 0.634256}
#
#
# Total learning time: 59.709 seconds
# Total inference time: 56.058 seconds
# AUC ROC: 0.634256
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else return 0.3612353548525948;  // std dev = 9,000, 324,000 (wgt'ed) examples reached here.  /* #neg=161 #pos=163 */
# %   else if ( wasbornin(B, E), wasbornin(A, F), diedin(A, G) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, H), iscitizenof(A, H) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, I), iscitizenof(B, I) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else if ( iscitizenof(A, J), iscitizenof(B, K), dealswith(L, K) )
# %   | | | | | then return 0.1217592502857578;  // std dev = 8,231, 349,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=92 */
# %   | | | | | else return 0.3136296020026647;  // std dev = 26,442, 2.819,000 (wgt'ed) examples reached here.  /* #neg=1.535 #pos=1.284 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.914629, 'AUC PR': 0.686352, 'AUC ROC': 0.656622}
#
#
# Total learning time: 59.111 seconds
# Total inference time: 55.738 seconds
# AUC ROC: 0.656622
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else if ( worksat(B, E), haswonprize(F, D), created(F, G) )
# %   | | then return 0.4892168962645618;  // std dev = 4,897, 103,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=65 */
# %   | | else return 0.3015878491266604;  // std dev = 7,385, 221,000 (wgt'ed) examples reached here.  /* #neg=123 #pos=98 */
# %   else if ( wasbornin(B, H), wasbornin(A, I), diedin(A, J) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, K), iscitizenof(A, K) )
# %   | | | then return 0.6498156017661773;  // std dev = 0,406, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, L), iscitizenof(B, L) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else if ( iscitizenof(A, M), iscitizenof(B, N), dealswith(P, N) )
# %   | | | | | then return 0.1217592502857578;  // std dev = 8,231, 349,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=92 */
# %   | | | | | else return 0.3136296020026647;  // std dev = 26,442, 2.819,000 (wgt'ed) examples reached here.  /* #neg=1.535 #pos=1.284 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.913714, 'AUC PR': 0.671825, 'AUC ROC': 0.634256}
#
#
# Total learning time: 59.178 seconds
# Total inference time: 58.322 seconds
# AUC ROC: 0.634256
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then return 0.49431451244155594;  // std dev = 0,481, 459,000 (wgt'ed) examples reached here.  /* #neg=167 #pos=292 */
# %   else if ( wasbornin(B, E), wasbornin(A, F), diedin(A, G) )
# %   | then if ( influences(B, H), influences(I, H), livesin(I, J) )
# %   | | then return 0.7152917922423695;  // std dev = 0,350, 21,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=18 */
# %   | | else if ( livesin(B, K), isleaderof(L, K), iscitizenof(B, M) )
# %   | | | then return 0.17633075328133055;  // std dev = 0,466, 22,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=7 */
# %   | | | else if ( diedin(B, N), hascapital(P, N) )
# %   | | | | then return 0.6658412427918196;  // std dev = 0,394, 26,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=21 */
# %   | | | | else return 0.30551735615214304;  // std dev = 0,497, 76,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=34 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, Q), iscitizenof(A, Q) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, R), iscitizenof(B, R) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else return 0.2924923694429417;  // std dev = 0,496, 3.168,000 (wgt'ed) examples reached here.  /* #neg=1.792 #pos=1.376 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.918422, 'AUC PR': 0.657311, 'AUC ROC': 0.620477}
#
#
# Total learning time: 64.522 seconds
# Total inference time: 58.857 seconds
# AUC ROC: 0.620477
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else if ( worksat(B, E), haswonprize(F, D), created(F, G) )
# %   | | then return 0.4892168962645618;  // std dev = 4,897, 103,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=65 */
# %   | | else return 0.3015878491266604;  // std dev = 7,385, 221,000 (wgt'ed) examples reached here.  /* #neg=123 #pos=98 */
# %   else if ( wasbornin(B, H), wasbornin(A, I), diedin(A, J) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, K), iscitizenof(A, K) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, L), iscitizenof(B, L) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else return 0.2924923694429417;  // std dev = 27,899, 3.168,000 (wgt'ed) examples reached here.  /* #neg=1.792 #pos=1.376 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.917105, 'AUC PR': 0.676113, 'AUC ROC': 0.631209}
#
#
# Total learning time: 64.708 seconds
# Total inference time: 54.024 seconds
# AUC ROC: 0.631209
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.656622
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then return 0.49431451244155594;  // std dev = 0,481, 459,000 (wgt'ed) examples reached here.  /* #neg=167 #pos=292 */
# %   else if ( wasbornin(B, E), wasbornin(A, F), diedin(A, G) )
# %   | then if ( influences(B, H), wasbornin(H, I) )
# %   | | then return 0.762910839861417;  // std dev = 0,294, 21,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=19 */
# %   | | else if ( worksat(B, J), graduatedfrom(A, K), graduatedfrom(B, L) )
# %   | | | then return 0.5724346493852258;  // std dev = 0,452, 35,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=25 */
# %   | | | else return 0.2626433171219833;  // std dev = 0,491, 89,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=36 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, M), iscitizenof(A, M) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, N), iscitizenof(B, N) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else if ( iscitizenof(A, P), iscitizenof(B, Q), dealswith(R, Q) )
# %   | | | | | then return 0.1217592502857578;  // std dev = 8,231, 349,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=92 */
# %   | | | | | else return 0.3136296020026647;  // std dev = 26,442, 2.819,000 (wgt'ed) examples reached here.  /* #neg=1.535 #pos=1.284 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.915261, 'AUC PR': 0.659343, 'AUC ROC': 0.628332}
#
#
# Total learning time: 63.756 seconds
# Total inference time: 58.754 seconds
# AUC ROC: 0.628332
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else if ( influences(B, E), graduatedfrom(E, F), diedin(A, G) )
# %   | | then return 0.7217852987358758;  // std dev = 0,343, 22,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=19 */
# %   | | else return 0.33497012715248964;  // std dev = 0,499, 302,000 (wgt'ed) examples reached here.  /* #neg=158 #pos=144 */
# %   else if ( wasbornin(B, H), wasbornin(A, I), diedin(A, J) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, K), iscitizenof(A, K) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, L), iscitizenof(B, L) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else if ( iscitizenof(A, M), iscitizenof(B, N), dealswith(P, N) )
# %   | | | | | then return 0.1217592502857578;  // std dev = 8,231, 349,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=92 */
# %   | | | | | else return 0.3136296020026647;  // std dev = 26,442, 2.819,000 (wgt'ed) examples reached here.  /* #neg=1.535 #pos=1.284 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.915141, 'AUC PR': 0.685248, 'AUC ROC': 0.656437}
#
#
# Total learning time: 64.961 seconds
# Total inference time: 55.979 seconds
# AUC ROC: 0.656437
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else return 0.3612353548525948;  // std dev = 9,000, 324,000 (wgt'ed) examples reached here.  /* #neg=161 #pos=163 */
# %   else if ( wasbornin(B, E), wasbornin(A, F), diedin(A, G) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, H), iscitizenof(A, H) )
# %   | | | then if ( wasbornin(B, I), haswonprize(B, J), iscitizenof(B, K) )
# %   | | | | then return 0.324815601766179;  // std dev = 0,499, 15,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=7 */
# %   | | | | else return 0.696244173194751;  // std dev = 0,368, 105,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=88 */
# %   | | | else if ( iscitizenof(A, L), iscitizenof(B, L) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else if ( iscitizenof(A, M), iscitizenof(B, N), dealswith(P, N) )
# %   | | | | | then return 0.1217592502857578;  // std dev = 8,231, 349,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=92 */
# %   | | | | | else return 0.3136296020026647;  // std dev = 26,442, 2.819,000 (wgt'ed) examples reached here.  /* #neg=1.535 #pos=1.284 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.914814, 'AUC PR': 0.685218, 'AUC ROC': 0.656179}
#
#
# Total learning time: 94.782 seconds
# Total inference time: 82.93 seconds
# AUC ROC: 0.656179
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else return 0.3612353548525948;  // std dev = 9,000, 324,000 (wgt'ed) examples reached here.  /* #neg=161 #pos=163 */
# %   else if ( wasbornin(B, E), wasbornin(A, F), diedin(A, G) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, H), iscitizenof(A, H) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, I), iscitizenof(B, I) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else return 0.2924923694429417;  // std dev = 27,899, 3.168,000 (wgt'ed) examples reached here.  /* #neg=1.792 #pos=1.376 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.91802, 'AUC PR': 0.675484, 'AUC ROC': 0.630863}
#
#
# Total learning time: 86.656 seconds
# Total inference time: 84.071 seconds
# AUC ROC: 0.630863
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.656622
# ******************************************
#
# ******************************************
# Total revision time: 1182.116
# Best validation AUC ROC: 0.656622
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(A, C), haswonprize(B, D) )
# %   then if ( haswonprize(A, D) )
# %   | then return 0.8137044906550658;  // std dev = 2,394, 135,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=129 */
# %   | else return 0.3612353548525948;  // std dev = 9,000, 324,000 (wgt'ed) examples reached here.  /* #neg=161 #pos=163 */
# %   else if ( wasbornin(B, E), wasbornin(A, F), diedin(A, G) )
# %   | then return 0.4098730730305461;  // std dev = 5,988, 145,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=80 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( livesin(B, H), iscitizenof(A, H) )
# %   | | | then return 0.6498156017661773;  // std dev = 4,449, 120,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=95 */
# %   | | | else if ( iscitizenof(A, I), iscitizenof(B, I) )
# %   | | | | then return 0.7158725123352812;  // std dev = 5,479, 246,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=211 */
# %   | | | | else if ( iscitizenof(A, J), iscitizenof(B, K), dealswith(L, K) )
# %   | | | | | then return 0.1217592502857578;  // std dev = 8,231, 349,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=92 */
# %   | | | | | else return 0.3136296020026647;  // std dev = 26,442, 2.819,000 (wgt'ed) examples reached here.  /* #neg=1.535 #pos=1.284 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.910177, 'AUC PR': 0.674452, 'AUC ROC': 0.632753}
#
#
# Total inference time: 80.475 seconds
# AUC ROC: 0.632753
#
#
# Total examples
# Positive examples: 2895
# Negative examples: 2895
#
#
# Train and test sets from total
# Train Positive examples: 2605
# Train Negative examples: 2605
# Test Positive examples: 290
# Test Negative examples: 290
#
#
# Small dataset
# Train Positive examples: 781
# Train Negative examples: 781
#
#
# Revision theory train dataset and validation
# Train Positive examples: 2084
# Train Negative examples: 2084
# Validation Positive examples: 521
# Validation Negative examples: 521
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.5248156017661765;  // std dev = 0,471, 156,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=104 */
# %   else if ( influences(B, E), influences(F, E), livesin(F, G) )
# %   | then return 0.4788385902719271;  // std dev = 0,485, 116,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=72 */
# %   | else if ( iscitizenof(B, H), iscitizenof(A, H) )
# %   | | then return 0.7164166516349435;  // std dev = 0,349, 127,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=109 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I) )
# %   | | | then if ( exports(I, K), dealswith(J, L), iscitizenof(B, L) )
# %   | | | | then return 0.08672036367094033;  // std dev = 0,420, 105,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=24 */
# %   | | | | else if ( exports(I, M), hascapital(I, N), livesin(P, N) )
# %   | | | | | then return 0.31156508416783135;  // std dev = 8,933, 322,000 (wgt'ed) examples reached here.  /* #neg=176 #pos=146 */
# %   | | | | | else return -0.03840278903841881;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=3 */
# %   | | | else if ( livesin(A, Q), livesin(B, Q) )
# %   | | | | then return 0.8581489350995123;  // std dev = 0,000, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | | | | else if ( diedin(B, R), diedin(S, R), isleaderof(S, T) )
# %   | | | | | then return 0.2053711573217335;  // std dev = 4,040, 72,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=25 */
# %   | | | | | else return 0.31808483253540576;  // std dev = 12,450, 624,000 (wgt'ed) examples reached here.  /* #neg=337 #pos=287 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.916807, 'AUC PR': 0.632785, 'AUC ROC': 0.621171}
#
#
# Total learning time: 655.004 seconds
# Total inference time: 58.937 seconds
# AUC ROC: 0.621171
#
#
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( graduatedfrom(B, C), worksat(B, D), graduatedfrom(A, D) )
# %   then return 0.8291032919459819;  // std dev = 0,168, 241,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=234 */
# %   else if ( influences(B, E), influences(F, E), influences(F, A) )
# %   | then return 0.8581489350995122;  // std dev = 1,46e-07, 50,000 (wgt'ed) examples reached here.  /* #pos=50 */
# %   | else if ( haswonprize(B, G), haswonprize(A, H) )
# %   | | then return 0.4921111992504513;  // std dev = 0,482, 530,000 (wgt'ed) examples reached here.  /* #neg=194 #pos=336 */
# %   | | else if ( haswonprize(A, I) )
# %   | | | then if ( worksat(A, J), owns(J, K) )
# %   | | | | then return 0.16475270868441938;  // std dev = 0,461, 212,000 (wgt'ed) examples reached here.  /* #neg=147 #pos=65 */
# %   | | | | else return 0.25477986924958573;  // std dev = 0,489, 653,000 (wgt'ed) examples reached here.  /* #neg=394 #pos=259 */
# %   | | | else if ( influences(B, L), influences(M, L), worksat(M, N) )
# %   | | | | then if ( haswonprize(B, P), haswonprize(Q, P), iscitizenof(Q, R) )
# %   | | | | | then return 0.34406442805725995;  // std dev = 5,956, 142,000 (wgt'ed) examples reached here.  /* #neg=73 #pos=69 */
# %   | | | | | else return 0.5269801039306786;  // std dev = 5,840, 154,000 (wgt'ed) examples reached here.  /* #neg=51 #pos=103 */
# %   | | | | else if ( worksat(B, S), graduatedfrom(A, S) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else return 0.3150508713893262;  // std dev = 28,188, 3.202,000 (wgt'ed) examples reached here.  /* #neg=1.739 #pos=1.463 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.921162, 'AUC PR': 0.633049, 'AUC ROC': 0.585761}
#
#
# Total learning time: 571.621 seconds
# Total inference time: 83.114 seconds
# AUC ROC: 0.585761
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.5074995844501574;  // std dev = 10,256, 462,000 (wgt'ed) examples reached here.  /* #neg=162 #pos=300 */
# %   else if ( influences(B, E), influences(F, E), livesin(F, G) )
# %   | then return 0.455163860472643;  // std dev = 8,030, 268,000 (wgt'ed) examples reached here.  /* #neg=108 #pos=160 */
# %   | else if ( iscitizenof(B, H), iscitizenof(A, H) )
# %   | | then return 0.6956489350995084;  // std dev = 6,599, 320,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=268 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I) )
# %   | | | then if ( exports(I, K), dealswith(J, L), iscitizenof(B, L) )
# %   | | | | then return 0.06252849714330808;  // std dev = 6,675, 274,000 (wgt'ed) examples reached here.  /* #neg=218 #pos=56 */
# %   | | | | else if ( exports(I, M), hascapital(I, N), livesin(P, N) )
# %   | | | | | then return 0.2764181658687384;  // std dev = 14,228, 832,000 (wgt'ed) examples reached here.  /* #neg=484 #pos=348 */
# %   | | | | | else return 0.219851062759086;  // std dev = 4,659, 94,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=34 */
# %   | | | else if ( livesin(A, Q), livesin(B, Q) )
# %   | | | | then return 0.6914822684328449;  // std dev = 2,236, 36,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=30 */
# %   | | | | else if ( diedin(B, R), diedin(S, R), isleaderof(S, T) )
# %   | | | | | then return 0.37393840878371987;  // std dev = 6,889, 190,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=98 */
# %   | | | | | else return 0.32505200838555964;  // std dev = 20,522, 1.692,000 (wgt'ed) examples reached here.  /* #neg=902 #pos=790 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.910341, 'AUC PR': 0.673161, 'AUC ROC': 0.647804}
#
#
# Total learning time: 67.509 seconds
# Total inference time: 84.916 seconds
# AUC ROC: 0.647804
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.5074995844501574;  // std dev = 10,256, 462,000 (wgt'ed) examples reached here.  /* #neg=162 #pos=300 */
# %   else if ( influences(B, E), influences(F, E), livesin(F, G) )
# %   | then if ( worksat(B, H), diedin(B, I), diedin(A, J) )
# %   | | then return 0.7711924133603816;  // std dev = 0,282, 23,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=21 */
# %   | | else if ( influences(A, K), influences(B, L), iscitizenof(L, M) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #pos=17 */
# %   | | | else return 0.39323665439775474;  // std dev = 0,499, 228,000 (wgt'ed) examples reached here.  /* #neg=106 #pos=122 */
# %   | else if ( iscitizenof(B, N), iscitizenof(A, N) )
# %   | | then return 0.6956489350995084;  // std dev = 6,599, 320,000 (wgt'ed) examples reached here.  /* #neg=52 #pos=268 */
# %   | | else if ( iscitizenof(A, P), dealswith(Q, P) )
# %   | | | then return 0.22314893509950745;  // std dev = 0,481, 1.200,000 (wgt'ed) examples reached here.  /* #neg=762 #pos=438 */
# %   | | | else if ( livesin(A, R), livesin(B, R) )
# %   | | | | then return 0.6914822684328449;  // std dev = 2,236, 36,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=30 */
# %   | | | | else if ( diedin(B, S), diedin(T, S), isleaderof(T, U) )
# %   | | | | | then return 0.37393840878371987;  // std dev = 6,889, 190,000 (wgt'ed) examples reached here.  /* #neg=92 #pos=98 */
# %   | | | | | else return 0.32505200838555964;  // std dev = 20,522, 1.692,000 (wgt'ed) examples reached here.  /* #neg=902 #pos=790 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.913663, 'AUC PR': 0.653119, 'AUC ROC': 0.638203}
#
#
# Total learning time: 68.589 seconds
# Total inference time: 56.915 seconds
# AUC ROC: 0.638203
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.5074995844501574;  // std dev = 0,477, 462,000 (wgt'ed) examples reached here.  /* #neg=162 #pos=300 */
# %   else if ( influences(B, E), influences(F, E), livesin(F, G) )
# %   | then return 0.455163860472643;  // std dev = 8,030, 268,000 (wgt'ed) examples reached here.  /* #neg=108 #pos=160 */
# ...
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 7,973, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 8,575, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then return 0.3203338090490932;  // std dev = 5,439, 119,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=55 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(M, G), actedin(M, N) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else return 0.3724718517661744;  // std dev = 13,851, 768,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=395 */
# %   | else if ( influences(B, P), wasbornin(B, Q) )
# %   | | then return 0.4101489350995134;  // std dev = 5,560, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else if ( haswonprize(A, R), haswonprize(S, R), influences(T, S) )
# %   | | | then return 0.24372887240358365;  // std dev = 8,693, 319,000 (wgt'ed) examples reached here.  /* #neg=196 #pos=123 */
# %   | | | else return 0.321281171540702;  // std dev = 20,199, 1.641,000 (wgt'ed) examples reached here.  /* #neg=881 #pos=760 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.91316, 'AUC PR': 0.686923, 'AUC ROC': 0.680336}
#
#
# Total learning time: 64.167 seconds
# Total inference time: 85.35900000000001 seconds
# AUC ROC: 0.680336
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.4905340554496174;  // std dev = 10,307, 457,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=289 */
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 7,973, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 0,452, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then return 0.3203338090490932;  // std dev = 5,439, 119,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=55 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(M, G), actedin(M, N) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else return 0.3724718517661744;  // std dev = 13,851, 768,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=395 */
# %   | else if ( influences(B, P), wasbornin(B, Q) )
# %   | | then return 0.4101489350995134;  // std dev = 5,560, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else if ( haswonprize(A, R), haswonprize(S, R), influences(T, S) )
# %   | | | then return 0.24372887240358365;  // std dev = 8,693, 319,000 (wgt'ed) examples reached here.  /* #neg=196 #pos=123 */
# %   | | | else return 0.321281171540702;  // std dev = 20,199, 1.641,000 (wgt'ed) examples reached here.  /* #neg=881 #pos=760 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.91316, 'AUC PR': 0.686923, 'AUC ROC': 0.680336}
#
#
# Total learning time: 89.128 seconds
# Total inference time: 56.786 seconds
# AUC ROC: 0.680336
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.4905340554496174;  // std dev = 10,307, 457,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=289 */
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 0,434, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 8,575, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then return 0.3203338090490932;  // std dev = 5,439, 119,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=55 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(M, G), actedin(M, N) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else return 0.3724718517661744;  // std dev = 13,851, 768,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=395 */
# %   | else if ( influences(B, P), wasbornin(B, Q) )
# %   | | then return 0.4101489350995134;  // std dev = 5,560, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else if ( haswonprize(A, R), haswonprize(S, R), influences(T, S) )
# %   | | | then return 0.24372887240358365;  // std dev = 8,693, 319,000 (wgt'ed) examples reached here.  /* #neg=196 #pos=123 */
# %   | | | else return 0.321281171540702;  // std dev = 20,199, 1.641,000 (wgt'ed) examples reached here.  /* #neg=881 #pos=760 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.91316, 'AUC PR': 0.686923, 'AUC ROC': 0.680336}
#
#
# Total learning time: 89.496 seconds
# Total inference time: 54.65 seconds
# AUC ROC: 0.680336
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.4905340554496174;  // std dev = 10,307, 457,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=289 */
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 7,973, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 8,575, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then return 0.3203338090490932;  // std dev = 5,439, 119,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=55 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(M, G), actedin(M, N) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else return 0.3724718517661744;  // std dev = 13,851, 768,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=395 */
# %   | else if ( influences(B, P), wasbornin(B, Q) )
# %   | | then return 0.4101489350995134;  // std dev = 0,497, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else if ( haswonprize(A, R), haswonprize(S, R), influences(T, S) )
# %   | | | then return 0.24372887240358365;  // std dev = 8,693, 319,000 (wgt'ed) examples reached here.  /* #neg=196 #pos=123 */
# %   | | | else return 0.321281171540702;  // std dev = 20,199, 1.641,000 (wgt'ed) examples reached here.  /* #neg=881 #pos=760 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.91316, 'AUC PR': 0.686923, 'AUC ROC': 0.680336}
#
#
# Total learning time: 89.789 seconds
# Total inference time: 56.256 seconds
# AUC ROC: 0.680336
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.4905340554496174;  // std dev = 10,307, 457,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=289 */
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 7,973, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 8,575, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then return 0.3203338090490932;  // std dev = 5,439, 119,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=55 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(M, G), actedin(M, N) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else return 0.3724718517661744;  // std dev = 13,851, 768,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=395 */
# %   | else if ( influences(B, P), wasbornin(B, Q) )
# %   | | then return 0.4101489350995134;  // std dev = 5,560, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else return 0.3086591391811402;  // std dev = 22,027, 1.960,000 (wgt'ed) examples reached here.  /* #neg=1.077 #pos=883 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.913741, 'AUC PR': 0.681747, 'AUC ROC': 0.66858}
#
#
# Total learning time: 89.46000000000001 seconds
# Total inference time: 53.389 seconds
# AUC ROC: 0.66858
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.4905340554496174;  // std dev = 10,307, 457,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=289 */
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 7,973, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 8,575, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then if ( diedin(B, M), isleaderof(N, M) )
# %   | | | | | then return 0.5949910403626703;  // std dev = 1,919, 19,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=14 */
# %   | | | | | else return 0.2681489350995113;  // std dev = 4,918, 100,000 (wgt'ed) examples reached here.  /* #neg=59 #pos=41 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(P, G), actedin(P, Q) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else return 0.3724718517661744;  // std dev = 13,851, 768,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=395 */
# %   | else if ( influences(B, R), wasbornin(B, S) )
# %   | | then return 0.4101489350995134;  // std dev = 5,560, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else return 0.3086591391811402;  // std dev = 0,498, 1.960,000 (wgt'ed) examples reached here.  /* #neg=1.077 #pos=883 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.913293, 'AUC PR': 0.683175, 'AUC ROC': 0.675325}
#
#
# Total learning time: 256.609 seconds
# Total inference time: 60.94 seconds
# AUC ROC: 0.675325
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.4905340554496174;  // std dev = 10,307, 457,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=289 */
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 7,973, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 8,575, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then return 0.3203338090490932;  // std dev = 5,439, 119,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=55 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(M, G), actedin(M, N) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else if ( iscitizenof(B, P), dealswith(Q, P), exports(P, R) )
# %   | | | | | | then return 0.2914822684328417;  // std dev = 9,002, 330,000 (wgt'ed) examples reached here.  /* #neg=187 #pos=143 */
# %   | | | | | | else return 0.43349140085293336;  // std dev = 10,345, 438,000 (wgt'ed) examples reached here.  /* #neg=186 #pos=252 */
# %   | else if ( influences(B, S), wasbornin(B, T) )
# %   | | then return 0.4101489350995134;  // std dev = 5,560, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else return 0.3086591391811402;  // std dev = 0,498, 1.960,000 (wgt'ed) examples reached here.  /* #neg=1.077 #pos=883 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.913346, 'AUC PR': 0.676562, 'AUC ROC': 0.659018}
#
#
# Total learning time: 146.981 seconds
# Total inference time: 82.376 seconds
# AUC ROC: 0.659018
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.680336
# ******************************************
#
# ******************************************
# Total revision time: 1421.929
# Best validation AUC ROC: 0.680336
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( haswonprize(B, C), haswonprize(A, D) )
# %   then return 0.4905340554496174;  // std dev = 10,307, 457,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=289 */
# %   else if ( graduatedfrom(B, E), worksat(F, E), iscitizenof(F, G) )
# %   | then if ( iscitizenof(A, G), graduatedfrom(F, H) )
# %   | | then return 0.6059234158116745;  // std dev = 7,973, 337,000 (wgt'ed) examples reached here.  /* #neg=85 #pos=252 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), dealswith(J, G) )
# %   | | | then return 0.14426004621062105;  // std dev = 8,575, 360,000 (wgt'ed) examples reached here.  /* #neg=257 #pos=103 */
# %   | | | else if ( haswonprize(A, K), livesin(L, G), worksat(L, E) )
# %   | | | | then return 0.3203338090490932;  // std dev = 5,439, 119,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=55 */
# %   | | | | else if ( graduatedfrom(A, E), iscitizenof(M, G), actedin(M, N) )
# %   | | | | | then return 0.7445125714631483;  // std dev = 2,105, 44,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=39 */
# %   | | | | | else return 0.3724718517661744;  // std dev = 13,851, 768,000 (wgt'ed) examples reached here.  /* #neg=373 #pos=395 */
# %   | else if ( influences(B, P), wasbornin(B, Q) )
# %   | | then return 0.4101489350995134;  // std dev = 5,560, 125,000 (wgt'ed) examples reached here.  /* #neg=56 #pos=69 */
# %   | | else if ( haswonprize(A, R), haswonprize(S, R), influences(T, S) )
# %   | | | then return 0.24372887240358365;  // std dev = 8,693, 319,000 (wgt'ed) examples reached here.  /* #neg=196 #pos=123 */
# %   | | | else return 0.321281171540702;  // std dev = 20,199, 1.641,000 (wgt'ed) examples reached here.  /* #neg=881 #pos=760 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'Precision': [nan, 0.5], 'CLL': -0.912323, 'AUC PR': 0.693889, 'AUC ROC': 0.658176}
#
#
# Total inference time: 56.42 seconds
# AUC ROC: 0.658176

# %%
small_dataset_aucroc
# Out:
# [0.587313,
#  0.632937,
#  0.621171,
#  0.646005,
#  0.554168,
#  0.604632,
#  0.622957,
#  0.596479,
#  0.566851,
#  0.658176]

# %%
complete_dataset_aucroc
# Out:
# [0.592675,
#  0.649768,
#  0.585761,
#  0.595713,
#  0.601885,
#  0.679398,
#  0.6031,
#  0.619712,
#  0.646748,
#  0.583703]

# %%
revision_dataset_aucroc
# Out:
# [0.58931,
#  0.632753,
#  0.624423,
#  0.683864,
#  0.549982,
#  0.607991,
#  0.623005,
#  0.604986,
#  0.585769,
#  0.658176]

# %%
print('Small dataset AUC ROC: %s +/- %s' % ((np.array(small_dataset_aucroc)).mean(), (np.array(small_dataset_aucroc)).std()))
print('Complete dataset AUC ROC: %s +/- %s' % ((np.array(complete_dataset_aucroc)).mean(), (np.array(complete_dataset_aucroc)).std()))
print('Theory revision dataset AUC ROC: %s +/- %s' % ((np.array(revision_dataset_aucroc)).mean(), (np.array(revision_dataset_aucroc)).std()))
# Out:
# Small dataset AUC ROC: 0.6090689 +/- 0.03183202765596311
# Complete dataset AUC ROC: 0.6158463000000001 +/- 0.030655050135499694
# Theory revision dataset AUC ROC: 0.6160259 +/- 0.035993206010162544

# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold

# %% [markdown]
# ## Parameters

# %%
target = 'publication'
#test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.9
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %% [markdown]
# Sameproject, sameperson and samecourse predicates are not being used.

# %%
[facts, pos, neg] = get_uwcse_dataset(target, acceptedPredicates=[
'professor',
'student',
'advisedby',
'tempadvisedby',
'ta',
'hasposition',
'publication',
'inphase',
'courselevel',
'yearsinprogram',
'projectmember',
])

# %% [markdown]
# ## Background  configuration

# %%
bk = boostsrl.example_data('background')
bk = ['professor(+person).',
'student(+person).',
'advisedby(+person,+person).',
'advisedby(+person,-person).',
'advisedby(-person,+person).',
'tempadvisedby(+person,+person).',
'tempadvisedby(+person,-person).',
'tempadvisedby(-person,+person).',
'ta(+course,+person,+quarter).',
'ta(-course,+person,+quarter).',
'ta(+course,-person,+quarter).',
'ta(+course,+person,-quarter).',
'ta(-course,+person,-quarter).',
'ta(+course,-person,-quarter).',
'hasposition(+person,+faculty).',
'hasposition(+person,-faculty).',
'hasposition(-person,+faculty).',
'publication(+title,+person).',
'publication(+title,-person).',
'publication(-title,+person).',
'inphase(+person,+prequals).',
'inphase(+person,-prequals).',
'inphase(-person,+prequals).',
'courselevel(+course,+level).',
'courselevel(+course,-level).',
'courselevel(-course,+level).',
'yearsinprogram(+person,+year).',
'yearsinprogram(-person,+year).',
'yearsinprogram(+person,-year).',
'projectmember(+project,+person).',
'projectmember(+project,-person).',
'projectmember(-project,+person).']
#'sameproject(project, project).',
#'samecourse(course, course).',
#'sameperson(person, person).',]

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

neg = neg[:len(pos)] # balanced

import numpy as np
pos = np.array(pos)
neg = np.array(neg)
small_dataset_aucroc = []
complete_dataset_aucroc = []
revision_dataset_aucroc = []


# separate train and test
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(pos):
    train_pos, test_pos = pos[train_index], pos[test_index]
    train_neg, test_neg = neg[train_index], neg[test_index]

    # learn from scratch in a small dataset
    s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
    s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

    # shuffle all train examples
    random.shuffle(train_pos)
    random.shuffle(train_neg)

    # train set used in revision and validation set
    r_train_pos = train_pos[int(validation_size*len(train_pos)):]
    r_train_neg = train_neg[int(validation_size*len(train_neg)):]
    validation_pos = train_pos[:int(validation_size*len(train_pos))]
    validation_neg = train_neg[:int(validation_size*len(train_neg))]

    print('Total examples')
    print('Positive examples: %s' % len(pos))
    print('Negative examples: %s' % len(neg))
    print('\n')
    print('Train and test sets from total')
    print('Train Positive examples: %s' % len(train_pos))
    print('Train Negative examples: %s' % len(train_neg))
    print('Test Positive examples: %s' % len(test_pos))
    print('Test Negative examples: %s' % len(test_neg))
    print('\n')
    print('Small dataset')
    print('Train Positive examples: %s' % len(s_train_pos))
    print('Train Negative examples: %s' % len(s_train_neg))
    print('\n')
    print('Revision theory train dataset and validation')
    print('Train Positive examples: %s' % len(r_train_pos))
    print('Train Negative examples: %s' % len(r_train_neg))
    print('Validation Positive examples: %s' % len(validation_pos))
    print('Validation Negative examples: %s' % len(validation_neg))
    
    # learning from small dataset
    delete_model_files()
    model = boostsrl.train(background, s_train_pos, s_train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    small_dataset_aucroc.append(t_results['AUC ROC'])
    
    # learning from complete dataset
    delete_model_files()
    model = boostsrl.train(background, train_pos, train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    #structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    complete_dataset_aucroc.append(t_results['AUC ROC'])
    
    # theory revision
    total_revision_time = 0
    best_aucroc = 0
    best_structured = None

    print('Performing parameter learning')
    print('******************************************')
    delete_model_files()
    model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=get_refine_file(structured))
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, validation_pos, validation_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    total_revision_time += learning_time + inference_time
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)

    best_aucroc = t_results['AUC ROC']
    best_structured = structured.copy()
    save_model_files()

    for i in range(max_revision_iterations):
        print('Refining iteration %s' % str(i+1))
        print('******************************************')
        found_better = False
        for candidate in get_cantidates(best_structured, revision_threshold):
            print('Refining node candidate')
            print('******************************************')
            delete_model_files()
            model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=candidate)
            learning_time = model.traintime()
            will = model.get_will_produced_tree()
            results = boostsrl.test(model, validation_pos, validation_neg, facts)
            inference_time = results.testtime()
            t_results = results.summarize_results()
            total_revision_time += learning_time + inference_time
            print('WILL-Produced Tree:')
            print_will_produced_tree(will)
            print('\n')
            print('Results:')
            print(t_results)
            print('\n')
            print('Total learning time: %s seconds' % learning_time)
            print('Total inference time: %s seconds' % inference_time)
            print('AUC ROC: %s' % t_results['AUC ROC'])
            print('\n')
            #print('Tree:')
            #model.tree(0, target, image=True)
            print('******************************************')

            if t_results['AUC ROC'] > best_aucroc:
                found_better = True
                best_aucroc = t_results['AUC ROC']
                best_structured = model.get_structured_tree().copy()
                save_model_files()
        print('Best Tree AUC ROC so far: %s' % best_aucroc)
        print('******************************************\n')
        if found_better == False:
            break

    print('******************************************')
    delete_model_files()
    get_saved_model_files()
    delete_test_files()
    print('Total revision time: %s' % total_revision_time)
    print('Best validation AUC ROC: %s' % best_aucroc)
    will = model.get_will_produced_tree()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    revision_dataset_aucroc.append(t_results['AUC ROC'])
# Out:
# Total examples
# Positive examples: 734
# Negative examples: 734
#
#
# Train and test sets from total
# Train Positive examples: 660
# Train Negative examples: 660
# Test Positive examples: 74
# Test Negative examples: 74
#
#
# Small dataset
# Train Positive examples: 198
# Train Negative examples: 198
#
#
# Revision theory train dataset and validation
# Train Positive examples: 528
# Train Negative examples: 528
# Validation Positive examples: 132
# Validation Negative examples: 132
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16341209299425036;  // std dev = 0,461, 190,000 (wgt'ed) examples reached here.  /* #neg=132 #pos=58 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6581489350995123;  // std dev = 0,400, 55,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=44 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5504566274072036;  // std dev = 0,462, 52,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=36 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.4735335504841277;  // std dev = 1,754, 13,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=8 */
# %   | | | | | else return -0.04185106490048778;  // std dev = 0,949, 10,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=1 */
# %   | | | else return 0.6438632208137979;  // std dev = 0,410, 42,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=33 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.4945125714631487;  // std dev = 0,481, 11,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=7 */
# %   | | | else if ( professor(B) )
# %   | | | | then return -0.14185106490048777;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else return 0.40814893509951233;  // std dev = 0,497, 20,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=11 */
#
#
# Results:
# {'CLL': -0.886504, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.702703, 'AUC PR': 0.68226, 'Recall': 0.0}
#
#
# Total learning time: 4.352 seconds
# Total inference time: 0.434 seconds
# AUC ROC: 0.702703
#
#
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1612283516311123;  // std dev = 0,460, 617,000 (wgt'ed) examples reached here.  /* #neg=430 #pos=187 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6325079094584836;  // std dev = 0,418, 195,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=151 */
# %   | else if ( hasposition(B, G), hasposition(H, G), projectmember(I, H) )
# %   | | then if ( tempadvisedby(J, B) )
# %   | | | then if ( advisedby(K, B), ta(L, K, M) )
# %   | | | | then return 0.5386223078805746;  // std dev = 0,466, 169,000 (wgt'ed) examples reached here.  /* #neg=54 #pos=115 */
# %   | | | | else return 0.42957750652808374;  // std dev = 0,495, 21,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=12 */
# %   | | | else return 0.568293862635741;  // std dev = 0,454, 207,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=147 */
# %   | | else if ( advisedby(N, B), advisedby(N, P), projectmember(Q, P) )
# %   | | | then return -0.05851773156715445;  // std dev = 0,276, 12,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=1 */
# %   | | | else if ( hasposition(B, R), hasposition(S, R), tempadvisedby(T, S) )
# %   | | | | then return -0.04185106490048778;  // std dev = 0,300, 10,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=1 */
# %   | | | | else if ( professor(B) )
# %   | | | | | then return 0.35814893509951223;  // std dev = 3,082, 38,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=19 */
# %   | | | | | else return 0.3875606998053936;  // std dev = 3,565, 51,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=27 */
#
#
# Results:
# {'CLL': -0.888881, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.679237, 'AUC PR': 0.665042, 'Recall': 0.0}
#
#
# Total learning time: 11.498 seconds
# Total inference time: 0.479 seconds
# AUC ROC: 0.679237
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.893786, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.711576, 'AUC PR': 0.660035, 'Recall': 0.0}
#
#
# Total learning time: 0.646 seconds
# Total inference time: 0.527 seconds
# AUC ROC: 0.711576
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 0,395, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.893786, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.711576, 'AUC PR': 0.660035, 'Recall': 0.0}
#
#
# Total learning time: 0.733 seconds
# Total inference time: 0.449 seconds
# AUC ROC: 0.711576
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 0,467, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.893786, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.711576, 'AUC PR': 0.660035, 'Recall': 0.0}
#
#
# Total learning time: 0.844 seconds
# Total inference time: 0.546 seconds
# AUC ROC: 0.711576
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 0,457, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.893786, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.711576, 'AUC PR': 0.660035, 'Recall': 0.0}
#
#
# Total learning time: 0.807 seconds
# Total inference time: 0.58 seconds
# AUC ROC: 0.711576
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 0,415, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.893786, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.711576, 'AUC PR': 0.660035, 'Recall': 0.0}
#
#
# Total learning time: 0.69 seconds
# Total inference time: 0.467 seconds
# AUC ROC: 0.711576
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else return 0.34652102812276775;  // std dev = 3,278, 43,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=21 */
#
#
# Results:
# {'CLL': -0.895471, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.703914, 'AUC PR': 0.656702, 'Recall': 0.0}
#
#
# Total learning time: 0.7 seconds
# Total inference time: 0.5 seconds
# AUC ROC: 0.703914
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else return 0.3337586911970725;  // std dev = 4,522, 82,000 (wgt'ed) examples reached here.  /* #neg=43 #pos=39 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, M), hasposition(N, M), projectmember(P, N) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.896681, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.697486, 'AUC PR': 0.653438, 'Recall': 0.0}
#
#
# Total learning time: 0.747 seconds
# Total inference time: 0.547 seconds
# AUC ROC: 0.697486
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 0,442, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.893786, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.711576, 'AUC PR': 0.660035, 'Recall': 0.0}
#
#
# Total learning time: 0.84 seconds
# Total inference time: 0.591 seconds
# AUC ROC: 0.711576
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.711576
# ******************************************
#
# ******************************************
# Total revision time: 10.213999999999999
# Best validation AUC ROC: 0.711576
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1545199028414434;  // std dev = 10,170, 496,000 (wgt'ed) examples reached here.  /* #neg=349 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F) )
# %   | then return 0.6366299477577376;  // std dev = 5,220, 158,000 (wgt'ed) examples reached here.  /* #neg=35 #pos=123 */
# %   | else if ( advisedby(G, B) )
# %   | | then if ( ta(H, G, I), advisedby(G, J), tempadvisedby(K, J) )
# %   | | | then if ( tempadvisedby(L, B) )
# %   | | | | then return 0.5369810518878313;  // std dev = 5,465, 137,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=93 */
# %   | | | | else if ( ta(M, K, N) )
# %   | | | | | then return 0.49644680743993685;  // std dev = 3,294, 47,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=30 */
# %   | | | | | else return 0.11529179224236952;  // std dev = 2,586, 35,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=9 */
# %   | | | else return 0.5920938892279528;  // std dev = 4,614, 109,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=80 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then return 0.6646005480027375;  // std dev = 2,200, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | | else if ( professor(B) )
# %   | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | else return 0.4137044906550675;  // std dev = 2,981, 36,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=20 */
#
#
# Results:
# {'CLL': -0.888006, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.689554, 'AUC PR': 0.637062, 'Recall': 0.0}
#
#
# Total inference time: 0.469 seconds
# AUC ROC: 0.689554
#
#
# Total examples
# Positive examples: 734
# Negative examples: 734
#
#
# Train and test sets from total
# Train Positive examples: 660
# Train Negative examples: 660
# Test Positive examples: 74
# Test Negative examples: 74
#
#
# Small dataset
# Train Positive examples: 198
# Train Negative examples: 198
#
#
# Revision theory train dataset and validation
# Train Positive examples: 528
# Train Negative examples: 528
# Validation Positive examples: 132
# Validation Negative examples: 132
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.6165759013916443;  // std dev = 0,428, 178,000 (wgt'ed) examples reached here.  /* #neg=43 #pos=135 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.04276431971489699;  // std dev = 0,388, 65,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=12 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.4831489350995123;  // std dev = 0,484, 8,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=5 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.33183314562582816;  // std dev = 2,176, 19,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=9 */
# %   | | | | | else return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | | else return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else return 0.12917697248268992;  // std dev = 0,444, 107,000 (wgt'ed) examples reached here.  /* #neg=78 #pos=29 */
#
#
# Results:
# {'CLL': -0.879648, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.780862, 'AUC PR': 0.727821, 'Recall': 0.0}
#
#
# Total learning time: 4.301 seconds
# Total inference time: 0.542 seconds
# AUC ROC: 0.780862
#
#
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.1614822684328411;  // std dev = 0,460, 600,000 (wgt'ed) examples reached here.  /* #neg=418 #pos=182 */
# %   else if ( tempadvisedby(D, B) )
# %   | then return 0.5799534463777036;  // std dev = 0,448, 399,000 (wgt'ed) examples reached here.  /* #neg=111 #pos=288 */
# %   | else if ( advisedby(E, B), advisedby(E, F), projectmember(G, F) )
# %   | | then return -0.07042249347191636;  // std dev = 0,258, 14,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=1 */
# %   | | else if ( advisedby(H, B), advisedby(H, I), tempadvisedby(J, I) )
# %   | | | then if ( ta(K, H, L) )
# %   | | | | then return 0.3750028676837827;  // std dev = 0,500, 89,000 (wgt'ed) examples reached here.  /* #neg=43 #pos=46 */
# %   | | | | else return 0.7536713231592141;  // std dev = 0,306, 67,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=60 */
# %   | | | else if ( hasposition(B, M), hasposition(N, M), projectmember(P, N) )
# %   | | | | then if ( advisedby(Q, B) )
# %   | | | | | then return 0.4181489350995113;  // std dev = 3,510, 50,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=28 */
# %   | | | | | else return 0.5248156017661781;  // std dev = 2,944, 39,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=26 */
# %   | | | | else if ( professor(B) )
# %   | | | | | then return -0.04185106490048778;  // std dev = 0,949, 10,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=1 */
# %   | | | | | else return 0.3966104735610497;  // std dev = 3,595, 52,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=28 */
#
#
# Results:
# {'CLL': -0.896898, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.739865, 'AUC PR': 0.756324, 'Recall': 0.0}
#
#
# Total learning time: 8.237 seconds
# Total inference time: 0.527 seconds
# AUC ROC: 0.739865
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894475, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763803, 'AUC PR': 0.726512, 'Recall': 0.0}
#
#
# Total learning time: 0.92 seconds
# Total inference time: 0.561 seconds
# AUC ROC: 0.763803
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then return 0.2986251255757015;  // std dev = 4,550, 84,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=37 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.895021, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763602, 'AUC PR': 0.726339, 'Recall': 0.0}
#
#
# Total learning time: 0.896 seconds
# Total inference time: 0.592 seconds
# AUC ROC: 0.763602
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 0,495, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894475, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763803, 'AUC PR': 0.726512, 'Recall': 0.0}
#
#
# Total learning time: 1.138 seconds
# Total inference time: 0.586 seconds
# AUC ROC: 0.763803
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 0,476, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894475, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763803, 'AUC PR': 0.726512, 'Recall': 0.0}
#
#
# Total learning time: 0.876 seconds
# Total inference time: 0.587 seconds
# AUC ROC: 0.763803
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 0,452, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894475, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763803, 'AUC PR': 0.726512, 'Recall': 0.0}
#
#
# Total learning time: 0.893 seconds
# Total inference time: 0.572 seconds
# AUC ROC: 0.763803
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 0,460, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894475, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763803, 'AUC PR': 0.726512, 'Recall': 0.0}
#
#
# Total learning time: 0.904 seconds
# Total inference time: 0.561 seconds
# AUC ROC: 0.763803
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else return 0.21926004621062345;  // std dev = 2,882, 36,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=13 */
# %   | | else if ( advisedby(B, M), tempadvisedby(N, M), ta(P, N, Q) )
# %   | | | then if ( advisedby(R, M), ta(S, R, T) )
# %   | | | | then if ( ta(P, N, T) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894474, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763774, 'AUC PR': 0.726492, 'Recall': 0.0}
#
#
# Total learning time: 0.93 seconds
# Total inference time: 0.582 seconds
# AUC ROC: 0.763774
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 0,436, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894475, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.763803, 'AUC PR': 0.726512, 'Recall': 0.0}
#
#
# Total learning time: 0.897 seconds
# Total inference time: 0.587 seconds
# AUC ROC: 0.763803
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.763803
# ******************************************
#
# ******************************************
# Total revision time: 12.082
# Best validation AUC ROC: 0.763803
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( hasposition(B, C), hasposition(D, C), projectmember(E, D) )
# %   then return 0.5546146315652045;  // std dev = 10,084, 481,000 (wgt'ed) examples reached here.  /* #neg=146 #pos=335 */
# %   else if ( ta(F, B, G) )
# %   | then return 0.11424649607512129;  // std dev = 5,590, 164,000 (wgt'ed) examples reached here.  /* #neg=122 #pos=42 */
# %   | else if ( advisedby(H, B) )
# %   | | then if ( ta(I, H, J), ta(I, K, J), tempadvisedby(K, L) )
# %   | | | then return 0.2867203636709409;  // std dev = 1,852, 14,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=6 */
# %   | | | else if ( tempadvisedby(M, B) )
# %   | | | | then return 0.22178529873587596;  // std dev = 1,595, 11,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=4 */
# %   | | | | else return 0.21814893509951236;  // std dev = 2,400, 25,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=9 */
# %   | | else if ( advisedby(B, N), tempadvisedby(P, N), ta(Q, P, R) )
# %   | | | then if ( advisedby(S, N), ta(T, S, U) )
# %   | | | | then if ( ta(Q, P, U) )
# %   | | | | | then return 0.25520775862892287;  // std dev = 4,035, 68,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=27 */
# %   | | | | | else return 0.4831489350995123;  // std dev = 1,936, 16,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=10 */
# %   | | | | else return 0.14386322081379804;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=4 */
# %   | | | else return 0.20415653966224895;  // std dev = 7,714, 263,000 (wgt'ed) examples reached here.  /* #neg=172 #pos=91 */
#
#
# Results:
# {'CLL': -0.894731, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.766253, 'AUC PR': 0.719729, 'Recall': 0.0}
#
#
# Total inference time: 0.565 seconds
# AUC ROC: 0.766253
#
#
# Total examples
# Positive examples: 734
# Negative examples: 734
#
#
# Train and test sets from total
# Train Positive examples: 660
# Train Negative examples: 660
# Test Positive examples: 74
# Test Negative examples: 74
#
#
# Small dataset
# Train Positive examples: 198
# Train Negative examples: 198
#
#
# Revision theory train dataset and validation
# Train Positive examples: 528
# Train Negative examples: 528
# Validation Positive examples: 132
# Validation Negative examples: 132
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.15288577720477642;  // std dev = 0,456, 190,000 (wgt'ed) examples reached here.  /* #neg=134 #pos=56 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F), advisedby(G, B) )
# %   | then return 0.7059750220560338;  // std dev = 0,359, 46,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=39 */
# %   | else if ( hasposition(B, H), hasposition(I, H), projectmember(J, I) )
# %   | | then if ( tempadvisedby(K, B), advisedby(L, B) )
# %   | | | then if ( ta(M, L, N) )
# %   | | | | then return 0.5126943896449657;  // std dev = 0,476, 55,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=36 */
# %   | | | | else return 0.3581489350995123;  // std dev = 0,500, 8,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=4 */
# %   | | | else return 0.6005731775237548;  // std dev = 0,437, 66,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=49 */
# %   | | else if ( advisedby(P, B), advisedby(P, Q), projectmember(R, Q) )
# %   | | | then return -0.1418510649004878;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #neg=6 */
# %   | | | else if ( hasposition(B, S), hasposition(T, S), tempadvisedby(U, T) )
# %   | | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else if ( professor(B) )
# %   | | | | | then return 0.4295775065280837;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | | | else return 0.4581489350995123;  // std dev = 1,897, 15,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=9 */
#
#
# Results:
# {'CLL': -0.875046, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.742239, 'AUC PR': 0.719265, 'Recall': 0.0}
#
#
# Total learning time: 5.616 seconds
# Total inference time: 0.564 seconds
# AUC ROC: 0.742239
#
#
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then if ( advisedby(B, D), advisedby(E, D), ta(F, E, G) )
# %   | then return 0.20438549423929295;  // std dev = 0,476, 465,000 (wgt'ed) examples reached here.  /* #neg=304 #pos=161 */
# %   | else return 0.03623112688033407;  // std dev = 0,383, 146,000 (wgt'ed) examples reached here.  /* #neg=120 #pos=26 */
# %   else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | then return 0.6289822684328427;  // std dev = 0,420, 192,000 (wgt'ed) examples reached here.  /* #neg=44 #pos=148 */
# %   | else if ( tempadvisedby(K, B), advisedby(L, B), ta(M, L, N) )
# %   | | then return 0.5535512339500842;  // std dev = 0,460, 174,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=121 */
# %   | | else if ( hasposition(B, P), hasposition(Q, P), projectmember(R, Q) )
# %   | | | then if ( advisedby(S, B), ta(T, S, U) )
# %   | | | | then return 0.39661047356105167;  // std dev = 0,499, 104,000 (wgt'ed) examples reached here.  /* #neg=48 #pos=56 */
# %   | | | | else return 0.6178388575801327;  // std dev = 0,427, 129,000 (wgt'ed) examples reached here.  /* #neg=31 #pos=98 */
# %   | | | else if ( advisedby(W, B), advisedby(W, X), projectmember(Y, X) )
# %   | | | | then return -0.06492798797741087;  // std dev = 0,266, 13,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=1 */
# %   | | | | else if ( hasposition(B, Z), hasposition(AB, Z), tempadvisedby(BB, AB) )
# %   | | | | | then return 0.0010060779566550668;  // std dev = 0,926, 7,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=1 */
# %   | | | | | else return 0.3914822684328449;  // std dev = 4,733, 90,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=48 */
#
#
# Results:
# {'CLL': -0.881528, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.762692, 'AUC PR': 0.730569, 'Recall': 0.0}
#
#
# Total learning time: 11.556 seconds
# Total inference time: 0.447 seconds
# AUC ROC: 0.762692
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16249676118646447;  // std dev = 10,112, 483,000 (wgt'ed) examples reached here.  /* #neg=336 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F), advisedby(G, B) )
# %   | then return 0.6119950889456642;  // std dev = 4,912, 130,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=98 */
# %   | else if ( hasposition(B, H), hasposition(I, H), projectmember(J, I) )
# %   | | then if ( tempadvisedby(K, B), advisedby(L, B) )
# %   | | | then if ( ta(M, L, N) )
# %   | | | | then return 0.5827866162589305;  // std dev = 5,247, 138,000 (wgt'ed) examples reached here.  /* #neg=38 #pos=100 */
# %   | | | | else return 0.39148226843284567;  // std dev = 1,932, 15,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=8 */
# %   | | | else return 0.5315157692703641;  // std dev = 6,616, 199,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=134 */
# %   | | else if ( advisedby(P, B), advisedby(P, Q), projectmember(R, Q) )
# %   | | | then return -0.030739953789376676;  // std dev = 0,943, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else if ( hasposition(B, S), hasposition(T, S), tempadvisedby(U, T) )
# %   | | | | then return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | | else if ( professor(B) )
# %   | | | | | then return 0.35814893509951234;  // std dev = 3,000, 36,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=18 */
# %   | | | | | else return 0.3819584589090352;  // std dev = 3,237, 42,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=22 */
#
#
# Results:
# {'CLL': -0.899012, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.718664, 'AUC PR': 0.715377, 'Recall': 0.0}
#
#
# Total learning time: 0.775 seconds
# Total inference time: 0.477 seconds
# AUC ROC: 0.718664
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16249676118646447;  // std dev = 10,112, 483,000 (wgt'ed) examples reached here.  /* #neg=336 #pos=147 */
# %   else if ( tempadvisedby(D, B), ta(E, D, F), advisedby(G, B) )
# ...
# %   | | | else if ( tempadvisedby(T, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else if ( advisedby(U, B), advisedby(U, W), tempadvisedby(X, W) )
# %   | | | | | then return 0.7405018762759829;  // std dev = 2,301, 51,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=45 */
# %   | | | | | else return 0.386884567283421;  // std dev = 4,656, 87,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=46 */
#
#
# Results:
# {'CLL': -0.888427, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.750029, 'AUC PR': 0.767596, 'Recall': 0.0}
#
#
# Total learning time: 0.845 seconds
# Total inference time: 0.536 seconds
# AUC ROC: 0.750029
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 0,461, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 6,900, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then return 0.49965836906177535;  // std dev = 3,491, 53,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=34 */
# %   | | else if ( advisedby(K, B), ta(L, K, M) )
# %   | | | then if ( advisedby(K, N), tempadvisedby(P, N), ta(Q, P, M) )
# %   | | | | then return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else if ( advisedby(K, R), tempadvisedby(S, R) )
# %   | | | | | then return 0.21712329407387002;  // std dev = 4,237, 78,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=28 */
# %   | | | | | else return 0.564031288040688;  // std dev = 2,657, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   | | | else if ( tempadvisedby(T, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else if ( advisedby(U, B), advisedby(U, W), tempadvisedby(X, W) )
# %   | | | | | then return 0.7405018762759829;  // std dev = 2,301, 51,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=45 */
# %   | | | | | else return 0.386884567283421;  // std dev = 4,656, 87,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=46 */
#
#
# Results:
# {'CLL': -0.888427, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.750029, 'AUC PR': 0.767596, 'Recall': 0.0}
#
#
# Total learning time: 0.881 seconds
# Total inference time: 0.535 seconds
# AUC ROC: 0.750029
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 10,061, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 6,900, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then return 0.49965836906177535;  // std dev = 3,491, 53,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=34 */
# %   | | else if ( advisedby(K, B), ta(L, K, M) )
# %   | | | then if ( advisedby(K, N), tempadvisedby(P, N), ta(Q, P, M) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,373, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else if ( advisedby(K, R), tempadvisedby(S, R) )
# %   | | | | | then return 0.21712329407387002;  // std dev = 4,237, 78,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=28 */
# %   | | | | | else return 0.564031288040688;  // std dev = 2,657, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   | | | else if ( tempadvisedby(T, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else if ( advisedby(U, B), advisedby(U, W), tempadvisedby(X, W) )
# %   | | | | | then return 0.7405018762759829;  // std dev = 2,301, 51,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=45 */
# %   | | | | | else return 0.386884567283421;  // std dev = 4,656, 87,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=46 */
#
#
# Results:
# {'CLL': -0.888427, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.750029, 'AUC PR': 0.767596, 'Recall': 0.0}
#
#
# Total learning time: 0.808 seconds
# Total inference time: 0.543 seconds
# AUC ROC: 0.750029
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 10,061, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 6,900, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then return 0.49965836906177535;  // std dev = 3,491, 53,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=34 */
# %   | | else if ( advisedby(K, B), ta(L, K, M) )
# %   | | | then if ( advisedby(K, N), tempadvisedby(P, N), ta(Q, P, M) )
# %   | | | | then return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else return 0.3224346493852255;  // std dev = 5,278, 112,000 (wgt'ed) examples reached here.  /* #neg=60 #pos=52 */
# %   | | | else if ( tempadvisedby(R, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else if ( advisedby(S, B), advisedby(S, T), tempadvisedby(U, T) )
# %   | | | | | then return 0.7405018762759829;  // std dev = 2,301, 51,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=45 */
# %   | | | | | else return 0.386884567283421;  // std dev = 4,656, 87,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=46 */
#
#
# Results:
# {'CLL': -0.891978, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.74802, 'AUC PR': 0.765335, 'Recall': 0.0}
#
#
# Total learning time: 0.806 seconds
# Total inference time: 0.526 seconds
# AUC ROC: 0.74802
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 10,061, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 0,436, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then return 0.49965836906177535;  // std dev = 3,491, 53,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=34 */
# %   | | else if ( advisedby(K, B), ta(L, K, M) )
# %   | | | then if ( advisedby(K, N), tempadvisedby(P, N), ta(Q, P, M) )
# %   | | | | then return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else if ( advisedby(K, R), tempadvisedby(S, R) )
# %   | | | | | then return 0.21712329407387002;  // std dev = 4,237, 78,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=28 */
# %   | | | | | else return 0.564031288040688;  // std dev = 2,657, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   | | | else if ( tempadvisedby(T, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else if ( advisedby(U, B), advisedby(U, W), tempadvisedby(X, W) )
# %   | | | | | then return 0.7405018762759829;  // std dev = 2,301, 51,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=45 */
# %   | | | | | else return 0.386884567283421;  // std dev = 4,656, 87,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=46 */
#
#
# Results:
# {'CLL': -0.888427, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.750029, 'AUC PR': 0.767596, 'Recall': 0.0}
#
#
# Total learning time: 0.793 seconds
# Total inference time: 0.53 seconds
# AUC ROC: 0.750029
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 10,061, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 6,900, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then return 0.49965836906177535;  // std dev = 3,491, 53,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=34 */
# %   | | else if ( advisedby(K, B), ta(L, K, M) )
# %   | | | then if ( advisedby(K, N), tempadvisedby(P, N), ta(Q, P, M) )
# %   | | | | then return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else if ( advisedby(K, R), tempadvisedby(S, R) )
# %   | | | | | then return 0.21712329407387002;  // std dev = 4,237, 78,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=28 */
# %   | | | | | else return 0.564031288040688;  // std dev = 2,657, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   | | | else if ( tempadvisedby(T, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 0,492, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else if ( advisedby(U, B), advisedby(U, W), tempadvisedby(X, W) )
# %   | | | | | then return 0.7405018762759829;  // std dev = 2,301, 51,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=45 */
# %   | | | | | else return 0.386884567283421;  // std dev = 4,656, 87,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=46 */
#
#
# Results:
# {'CLL': -0.888427, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.750029, 'AUC PR': 0.767596, 'Recall': 0.0}
#
#
# Total learning time: 1.113 seconds
# Total inference time: 0.585 seconds
# AUC ROC: 0.750029
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 10,061, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 6,900, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then return 0.49965836906177535;  // std dev = 3,491, 53,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=34 */
# %   | | else if ( advisedby(K, B), ta(L, K, M) )
# %   | | | then if ( advisedby(K, N), tempadvisedby(P, N), ta(Q, P, M) )
# %   | | | | then return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else if ( advisedby(K, R), tempadvisedby(S, R) )
# %   | | | | | then return 0.21712329407387002;  // std dev = 4,237, 78,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=28 */
# %   | | | | | else return 0.564031288040688;  // std dev = 2,657, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   | | | else if ( tempadvisedby(T, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else return 0.5175692249545826;  // std dev = 5,567, 138,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=91 */
#
#
# Results:
# {'CLL': -0.890923, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.746643, 'AUC PR': 0.754087, 'Recall': 0.0}
#
#
# Total learning time: 0.814 seconds
# Total inference time: 0.599 seconds
# AUC ROC: 0.746643
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 10,061, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 6,900, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then if ( advisedby(K, B) )
# %   | | | then return 0.26723984419042146;  // std dev = 0,492, 22,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=9 */
# %   | | | else return 0.6646005480027375;  // std dev = 0,395, 31,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=25 */
# %   | | else if ( advisedby(L, B), ta(M, L, N) )
# %   | | | then if ( advisedby(L, P), tempadvisedby(Q, P), ta(R, Q, N) )
# %   | | | | then return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else if ( advisedby(L, S), tempadvisedby(T, S) )
# %   | | | | | then return 0.21712329407387002;  // std dev = 4,237, 78,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=28 */
# %   | | | | | else return 0.564031288040688;  // std dev = 2,657, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   | | | else if ( tempadvisedby(U, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else return 0.5175692249545826;  // std dev = 0,474, 138,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=91 */
#
#
# Results:
# {'CLL': -0.890574, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.738464, 'AUC PR': 0.72398, 'Recall': 0.0}
#
#
# Total learning time: 1.519 seconds
# Total inference time: 0.53 seconds
# AUC ROC: 0.738464
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.750029
# ******************************************
#
# ******************************************
# Total revision time: 11.963
# Best validation AUC ROC: 0.750029
# WILL-Produced Tree:
# % FOR publication(A, B):
# %   if ( inphase(B, C) )
# %   then return 0.16487162417513823;  // std dev = 10,061, 476,000 (wgt'ed) examples reached here.  /* #neg=330 #pos=146 */
# %   else if ( tempadvisedby(D, B), advisedby(E, B), ta(F, E, G) )
# %   | then return 0.6021489350995087;  // std dev = 6,900, 250,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=186 */
# %   | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | then return 0.49965836906177535;  // std dev = 3,491, 53,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=34 */
# %   | | else if ( advisedby(K, B), ta(L, K, M) )
# %   | | | then if ( advisedby(K, N), tempadvisedby(P, N), ta(Q, P, M) )
# %   | | | | then return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   | | | | else if ( advisedby(K, R), tempadvisedby(S, R) )
# %   | | | | | then return 0.21712329407387002;  // std dev = 4,237, 78,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=28 */
# %   | | | | | else return 0.564031288040688;  // std dev = 2,657, 34,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=24 */
# %   | | | else if ( tempadvisedby(T, B) )
# %   | | | | then return 0.44638422921715937;  // std dev = 2,029, 17,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=10 */
# %   | | | | else if ( advisedby(U, B), advisedby(U, W), tempadvisedby(X, W) )
# %   | | | | | then return 0.7405018762759829;  // std dev = 2,301, 51,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=45 */
# %   | | | | | else return 0.386884567283421;  // std dev = 4,656, 87,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=46 */
#
#
# Results:
# {'CLL': -0.899146, 'F1': nan, 'Precision': [nan, 0.5], 'AUC ROC': 0.741415, 'AUC PR': 0.775464, 'Recall': 0.0}
#
#
# Total inference time: 0.565 seconds
# AUC ROC: 0.741415

# %%
small_dataset_aucroc
# Out:
# [0.702703,
#  0.780862,
#  0.742239,
#  0.71439,
#  0.752862,
#  0.68465,
#  0.705855,
#  0.749672,
#  0.706418,
#  0.660161]

# %%
complete_dataset_aucroc
# Out:
# [0.679237,
#  0.739865,
#  0.762692,
#  0.71156,
#  0.740477,
#  0.655845,
#  0.692907,
#  0.73785,
#  0.707262,
#  0.694689]

# %%
revision_dataset_aucroc
# Out:
# [0.689554,
#  0.766253,
#  0.7605,
#  0.714116,
#  0.758773,
#  0.688591,
#  0.707356,
#  0.749672,
#  0.718897,
#  0.741415]

# %%
print('Small dataset AUC ROC: %s +/- %s' % ((np.array(small_dataset_aucroc)).mean(), (np.array(small_dataset_aucroc)).std()))
print('Complete dataset AUC ROC: %s +/- %s' % ((np.array(complete_dataset_aucroc)).mean(), (np.array(complete_dataset_aucroc)).std()))
print('Theory revision dataset AUC ROC: %s +/- %s' % ((np.array(revision_dataset_aucroc)).mean(), (np.array(revision_dataset_aucroc)).std()))
# Out:
# Small dataset AUC ROC: 0.7199812 +/- 0.03421202966443236
# Complete dataset AUC ROC: 0.7122384 +/- 0.03120638489219795
# Theory revision dataset AUC ROC: 0.7295127 +/- 0.027975424450935506

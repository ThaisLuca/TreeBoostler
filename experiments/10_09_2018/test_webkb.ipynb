# %%
from datasets.get_datasets import *
from boostedrevision import *
from boostsrl import boostsrl
import random

# %% [markdown]
# ## Dataset

# %%
target = 'pageclass'

bk = ['coursepage(+page).',
    'facultypage(+page).',
    'studentpage(+page).',
    'researchprojectpage(+page).',
    'linkto(+id,+page,+page).',
    'linkto(+id,+page,-page).',
    'linkto(+id,-page,+page).',
    'has(+word,+page).',
    'has(+word,-page).',
    'has(-word,+page).',
    'hasalphanumericword(+id).',
    'allwordscapitalized(+id).',
    'instructorsof(+page,+page).',
    'instructorsof(+page,-page).',
    'instructorsof(-page,+page).',
    'hasanchor(+word,+page).',
    'hasanchor(+word,-page).',
    'hasanchor(-word,+page).',
    'membersofproject(+page,+page).',
    'membersofproject(+page,-page).',
    'membersofproject(-page,+page).',
    'departmentof(+page,+page).',
    'departmentof(+page,-page).',
    'departmentof(-page,+page).',
    'pageclass(+page,+class).',
    'pageclass(+page,-class).',
    'pageclass(-page,+class).']

[facts, pos, neg] = datasets.load('webkb', bk, target=target)

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(1):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), departmentof(A, D) )
# %   then if ( studentpage(A) )
# %   | then return 0.8581489350995087;  // std dev = 1,08e-06, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   | else return 0.5914822684328462;  // std dev = 0,442, 75,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=55 */
# %   else if ( studentpage(A) )
# %   | then return -0.13415875720818057;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, E), coursepage(A) )
# %   | | then return -0.14185106490048774;  // std dev = 1,05e-08, 22,000 (wgt'ed) examples reached here.  /* #neg=22 */
# %   | | else if ( has(B, F), facultypage(F) )
# %   | | | then return -0.14185106490048777;  // std dev = 7,45e-09, 20,000 (wgt'ed) examples reached here.  /* #neg=20 */
# %   | | | else if ( facultypage(A), hasanchor(B, G) )
# %   | | | | then if ( has(B, H) )
# %   | | | | | then return -0.1418510649004878;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #neg=12 */
# %   | | | | | else return -0.0168510649004878;  // std dev = 1,323, 16,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=2 */
# %   | | | | else if ( departmentof(A, I) )
# %   | | | | | then return 0.3126943896449679;  // std dev = 5,477, 121,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=55 */
# %   | | | | | else return 0.5060362590431721;  // std dev = 5,692, 142,000 (wgt'ed) examples reached here.  /* #neg=50 #pos=92 */
# WILL Produced-Tree #2
# % FOR pageclass(A, B):
# %   if ( has(B, C), departmentof(A, D), facultypage(C) )
# %   then return 0.6705073611779079;  // std dev = 0,229, 331,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=311 */
# %   else if ( studentpage(A) )
# %   | then return -0.11859867500077363;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, E), facultypage(E) )
# %   | | then return -0.12544463852839133;  // std dev = 2,11e-08, 37,000 (wgt'ed) examples reached here.  /* #neg=37 */
# %   | | else if ( coursepage(A), hasanchor(B, F) )
# %   | | | then if ( instructorsof(A, G), hasanchor(H, F), has(H, A) )
# %   | | | | then return -0.16390379152988516;  // std dev = 0,117, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | | else return -0.09410065956852665;  // std dev = 0,312, 9,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=1 */
# %   | | | else if ( departmentof(A, I) )
# %   | | | | then if ( has(B, I), membersofproject(J, A) )
# %   | | | | | then return 0.6495938408338114;  // std dev = 1,479, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | | | | | else return 0.15084143913903822;  // std dev = 5,330, 132,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=43 */
# %   | | | | else if ( has(B, K) )
# %   | | | | | then return -0.21518266219854357;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #neg=7 */
# %   | | | | | else return 0.518688305543392;  // std dev = 4,921, 124,000 (wgt'ed) examples reached here.  /* #neg=33 #pos=91 */
# WILL Produced-Tree #3
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), departmentof(A, D) )
# %   then return 0.5214846948028197;  // std dev = 0,227, 331,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=311 */
# %   else if ( studentpage(A) )
# %   | then return -0.10608174678473933;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, E), facultypage(E) )
# %   | | then return -0.1123163781936064;  // std dev = 0,000, 37,000 (wgt'ed) examples reached here.  /* #neg=37 */
# %   | | else if ( departmentof(A, F) )
# %   | | | then if ( facultypage(A), hasanchor(B, G) )
# %   | | | | then return -0.08843802332016226;  // std dev = 0,259, 28,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=2 */
# %   | | | | else if ( facultypage(A) )
# %   | | | | | then return 0.33159041400883416;  // std dev = 3,956, 63,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=34 */
# %   | | | | | else return 0.13130533522242782;  // std dev = 3,437, 58,000 (wgt'ed) examples reached here.  /* #neg=37 #pos=21 */
# %   | | | else if ( has(B, H) )
# %   | | | | then return -0.15142432140774537;  // std dev = 0,122, 12,000 (wgt'ed) examples reached here.  /* #neg=12 */
# %   | | | | else if ( membersofproject(A, I), facultypage(I) )
# %   | | | | | then return 0.5179943032767446;  // std dev = 1,581, 18,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=15 */
# %   | | | | | else return 0.35393116384302137;  // std dev = 4,998, 117,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=77 */
# WILL Produced-Tree #4
# % FOR pageclass(A, B):
# %   if ( has(B, C), studentpage(A), facultypage(C) )
# %   then return 0.4377887967082624;  // std dev = 5,06e-07, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.09581581164240507;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( hasanchor(B, D), coursepage(A) )
# %   | | then return -0.12279494732419081;  // std dev = 0,168, 33,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=1 */
# %   | | else if ( coursepage(A) )
# %   | | | then if ( instructorsof(A, E), facultypage(E) )
# %   | | | | then return 0.2838048774548699;  // std dev = 0,466, 25,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=17 */
# %   | | | | else return 0.4475548774548699;  // std dev = 0,363, 32,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=27 */
# %   | | | else if ( has(B, F), departmentof(A, F) )
# %   | | | | then if ( facultypage(A) )
# %   | | | | | then return 0.1296339648204599;  // std dev = 3,403, 61,000 (wgt'ed) examples reached here.  /* #neg=27 #pos=34 */
# %   | | | | | else return 0.48655310452361067;  // std dev = 2,421, 47,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=42 */
# %   | | | | else if ( has(B, G) )
# %   | | | | | then return -0.11665645857862762;  // std dev = 0,132, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | | | | | else return 0.15281083881312219;  // std dev = 6,279, 183,000 (wgt'ed) examples reached here.  /* #neg=100 #pos=83 */
# WILL Produced-Tree #5
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), studentpage(A) )
# %   then return 0.3344937603841474;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.08725638292308427;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( membersofproject(D, A), has(B, E) )
# %   | | then return 0.2508005731676576;  // std dev = 0,412, 52,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=40 */
# %   | | else if ( membersofproject(F, A) )
# %   | | | then if ( facultypage(A) )
# %   | | | | then if ( hasanchor(B, G), instructorsof(H, A) )
# %   | | | | | then return -0.1677529723633438;  // std dev = 5,27e-09, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | | | else return 0.2262496003601299;  // std dev = 2,526, 25,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=13 */
# %   | | | | else return -0.2587744758743388;  // std dev = 0,000, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
# %   | | | else if ( has(B, I) )
# %   | | | | then return 0.05457551173329664;  // std dev = 0,347, 105,000 (wgt'ed) examples reached here.  /* #neg=69 #pos=36 */
# %   | | | | else if ( membersofproject(A, J), facultypage(J) )
# %   | | | | | then return 0.3594271785361054;  // std dev = 1,581, 18,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=15 */
# %   | | | | | else return 0.1766582449362833;  // std dev = 6,133, 179,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=100 */
# WILL Produced-Tree #6
# % FOR pageclass(A, B):
# %   if ( has(B, C), departmentof(A, D), facultypage(C) )
# %   then if ( studentpage(A) )
# %   | then return 0.26455559163963627;  // std dev = 4,21e-07, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   | else return 0.13994534665841976;  // std dev = 0,440, 75,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=55 */
# %   else if ( studentpage(A) )
# %   | then return -0.08001854292865287;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, E), facultypage(E) )
# %   | | then return -0.09582410596581095;  // std dev = 0,002, 37,000 (wgt'ed) examples reached here.  /* #neg=37 */
# %   | | else if ( membersofproject(F, A), has(B, G), membersofproject(F, G) )
# %   | | | then return 0.4922638065752779;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | else if ( membersofproject(H, A) )
# %   | | | | then if ( facultypage(A) )
# %   | | | | | then return 0.08789201333696814;  // std dev = 2,694, 33,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=13 */
# %   | | | | | else return -0.0713864981900758;  // std dev = 1,544, 30,000 (wgt'ed) examples reached here.  /* #neg=24 #pos=6 */
# %   | | | | else if ( departmentof(A, I), hasanchor(B, J) )
# %   | | | | | then return 0.03700840481656291;  // std dev = 2,135, 30,000 (wgt'ed) examples reached here.  /* #neg=22 #pos=8 */
# %   | | | | | else return 0.1530704217723464;  // std dev = 6,231, 195,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=114 */
# WILL Produced-Tree #7
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), studentpage(A) )
# %   then return 0.2163645616321826;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.07382333654412492;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( membersofproject(D, A), has(B, E) )
# %   | | then return 0.1524984460172329;  // std dev = 0,406, 52,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=40 */
# %   | | else if ( has(B, F), departmentof(A, F) )
# %   | | | then if ( facultypage(A) )
# %   | | | | then if ( instructorsof(G, A), instructorsof(G, H), has(B, H) )
# %   | | | | | then return -0.24297312439238386;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.07492407293465708;  // std dev = 2,538, 38,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=21 */
# %   | | | | else return 0.41869641171695965;  // std dev = 0,325, 15,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=14 */
# %   | | | else if ( facultypage(A) )
# %   | | | | then if ( hasanchor(B, I) )
# %   | | | | | then return -0.06238020952363761;  // std dev = 1,294, 16,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=2 */
# %   | | | | | else return 0.16876084520519616;  // std dev = 3,955, 63,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=34 */
# %   | | | | else return 0.027983422086276778;  // std dev = 0,379, 221,000 (wgt'ed) examples reached here.  /* #neg=129 #pos=92 */
# WILL Produced-Tree #8
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), studentpage(A) )
# %   then return 0.1819273520590196;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.06846412184025766;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( membersofproject(D, A), membersofproject(D, E), has(B, E) )
# %   | | then if ( instructorsof(F, E), instructorsof(F, G), studentpage(G) )
# %   | | | then return 0.3164862893949313;  // std dev = 0,061, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( facultypage(E) )
# %   | | | | then return -0.5035722089187235;  // std dev = 0,947, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else if ( facultypage(A) )
# %   | | | | | then return -0.6584405877130003;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | | else return 0.21823295628698036;  // std dev = 1,010, 9,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=8 */
# %   | | else if ( hasanchor(B, H), membersofproject(I, A), has(B, J) )
# %   | | | then return 0.24231494581212587;  // std dev = 0,260, 32,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=28 */
# %   | | | else if ( has(B, K), coursepage(A) )
# %   | | | | then return -0.09355478712469618;  // std dev = 0,033, 22,000 (wgt'ed) examples reached here.  /* #neg=22 */
# %   | | | | else return 0.062363509210861104;  // std dev = 0,421, 334,000 (wgt'ed) examples reached here.  /* #neg=170 #pos=164 */
# WILL Produced-Tree #9
# % FOR pageclass(A, B):
# %   if ( has(B, C), studentpage(A), facultypage(C) )
# %   then return 0.1563987554217405;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.06378482883491592;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( membersofproject(D, A) )
# %   | | then if ( has(B, E) )
# %   | | | then return 0.09589792453491751;  // std dev = 0,360, 52,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=40 */
# %   | | | else if ( facultypage(A) )
# %   | | | | then return 0.06085761264932467;  // std dev = 0,475, 30,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=13 */
# %   | | | | else return -0.21548708795021634;  // std dev = 0,000, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
# %   | | else if ( has(B, F), instructorsof(F, G), studentpage(G) )
# %   | | | then return -0.14437560751379802;  // std dev = 0,332, 52,000 (wgt'ed) examples reached here.  /* #neg=45 #pos=7 */
# %   | | | else if ( has(B, H), departmentof(A, H) )
# %   | | | | then return 0.3572173703873971;  // std dev = 0,067, 29,000 (wgt'ed) examples reached here.  /* #pos=29 */
# %   | | | | else if ( departmentof(A, I), hasanchor(B, J) )
# %   | | | | | then return -0.16300219294845472;  // std dev = 1,020, 14,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=1 */
# %   | | | | | else return 0.08316210676495879;  // std dev = 6,197, 207,000 (wgt'ed) examples reached here.  /* #neg=93 #pos=114 */
# WILL Produced-Tree #10
# % FOR pageclass(A, B):
# %   if ( has(B, C), studentpage(A), facultypage(C) )
# %   then return 0.13685392688010967;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.059665537564658394;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( membersofproject(D, A), has(B, E), membersofproject(D, E) )
# %   | | then if ( instructorsof(F, E), instructorsof(F, G), studentpage(G) )
# %   | | | then return 0.2350210576045736;  // std dev = 0,051, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( facultypage(E) )
# %   | | | | then return -0.41290199955020634;  // std dev = 0,954, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else if ( facultypage(A) )
# %   | | | | | then return -0.5234353139837871;  // std dev = 1,05e-08, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | | else return 0.15301535296155822;  // std dev = 1,001, 9,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=8 */
# %   | | else if ( hasanchor(B, H), coursepage(A) )
# %   | | | then return -0.1381012058443798;  // std dev = 0,182, 33,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=1 */
# %   | | | else if ( coursepage(A) )
# %   | | | | then return 0.159652280032931;  // std dev = 0,416, 57,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=44 */
# %   | | | | else return 0.03805157105672519;  // std dev = 0,395, 298,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=147 */
# Results
#    AUC ROC   = 0.263729
#    AUC PR    = 0.379257
#    CLL	      = -1.187007
#    Precision = 0.318822 at threshold = 0.5
#    Recall    = 0.32613
#    F1        = 0.322434
#
#
# Total learning time: 360.92 seconds
# Total inference time: 6.164 seconds
# AUC ROC: 0.263729

# %%
for i in range(2):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), departmentof(A, D) )
# %   then return 0.7977259743744329;  // std dev = 0,238, 331,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=311 */
# %   else if ( studentpage(A) )
# %   | then return -0.13415875720818057;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, E), facultypage(E) )
# %   | | then return -0.14185106490048768;  // std dev = 3,80e-08, 37,000 (wgt'ed) examples reached here.  /* #neg=37 */
# %   | | else if ( facultypage(A), hasanchor(B, F) )
# %   | | | then if ( has(B, G) )
# %   | | | | then return -0.1418510649004878;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #neg=12 */
# %   | | | | else return -0.0168510649004878;  // std dev = 0,331, 16,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=2 */
# %   | | | else if ( departmentof(A, H) )
# %   | | | | then if ( has(B, H) )
# %   | | | | | then return 0.8581489350995122;  // std dev = 0,000, 21,000 (wgt'ed) examples reached here.  /* #pos=21 */
# %   | | | | | else return 0.19814893509951095;  // std dev = 4,737, 100,000 (wgt'ed) examples reached here.  /* #neg=66 #pos=34 */
# %   | | | | else if ( has(B, I) )
# %   | | | | | then return -0.1418510649004878;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #neg=12 */
# %   | | | | | else return 0.5396304165809918;  // std dev = 5,413, 135,000 (wgt'ed) examples reached here.  /* #neg=43 #pos=92 */
# WILL Produced-Tree #2
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), departmentof(A, D) )
# %   then return 0.6710824834888682;  // std dev = 0,238, 331,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=311 */
# %   else if ( studentpage(A) )
# %   | then return -0.11859867500077363;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, E), facultypage(E) )
# %   | | then return -0.12544463852839147;  // std dev = 0,000, 37,000 (wgt'ed) examples reached here.  /* #neg=37 */
# %   | | else if ( departmentof(A, F) )
# %   | | | then if ( facultypage(A) )
# %   | | | | then return 0.23836392353846753;  // std dev = 0,482, 91,000 (wgt'ed) examples reached here.  /* #neg=55 #pos=36 */
# %   | | | | else return 0.15350324763213583;  // std dev = 0,426, 58,000 (wgt'ed) examples reached here.  /* #neg=37 #pos=21 */
# %   | | | else if ( hasanchor(B, G) )
# %   | | | | then if ( coursepage(A) )
# %   | | | | | then return -0.12857726501453276;  // std dev = 0,954, 16,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=1 */
# %   | | | | | else return 0.5268805194240709;  // std dev = 2,525, 37,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=27 */
# %   | | | | else if ( coursepage(A) )
# %   | | | | | then return 0.5510195475077155;  // std dev = 3,168, 57,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=44 */
# %   | | | | | else return 0.31963026348685225;  // std dev = 3,031, 37,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=20 */
# WILL Produced-Tree #3
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), studentpage(A) )
# %   then return 0.5820492691230356;  // std dev = 7,05e-07, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.10608174678473933;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( hasanchor(B, D), coursepage(A) )
# %   | | then return -0.11105260352612903;  // std dev = 0,166, 33,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=1 */
# %   | | else if ( coursepage(A) )
# %   | | | then if ( instructorsof(A, E), facultypage(E) )
# %   | | | | then return 0.35025752560177564;  // std dev = 0,466, 25,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=17 */
# %   | | | | else return 0.5140075256017759;  // std dev = 0,363, 32,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=27 */
# %   | | | else if ( hasanchor(B, F), departmentof(A, G), has(B, G) )
# %   | | | | then if ( facultypage(A), hasanchor(H, F), has(H, A) )
# %   | | | | | then return -0.11891295749260367;  // std dev = 2,190, 34,000 (wgt'ed) examples reached here.  /* #neg=27 #pos=7 */
# %   | | | | | else return 0.5444002300774367;  // std dev = 2,265, 74,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=69 */
# %   | | | | else if ( has(B, I) )
# %   | | | | | then return -0.13386986462021783;  // std dev = 0,189, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
# %   | | | | | else return 0.22006681298315042;  // std dev = 6,430, 183,000 (wgt'ed) examples reached here.  /* #neg=100 #pos=83 */
# WILL Produced-Tree #4
# % FOR pageclass(A, B):
# %   if ( has(B, C), studentpage(A), facultypage(C) )
# %   then return 0.43761239454042633;  // std dev = 5,59e-07, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then if ( hasanchor(B, D), hasanchor(E, D), has(E, A) )
# %   | | then return -0.07719232986102895;  // std dev = 0,160, 76,000 (wgt'ed) examples reached here.  /* #neg=74 #pos=2 */
# %   | | else return -0.10350811933471288;  // std dev = 8,69e-08, 184,000 (wgt'ed) examples reached here.  /* #neg=184 */
# %   | else if ( has(B, F), membersofproject(F, G), has(B, G) )
# %   | | then if ( departmentof(A, H) )
# %   | | | then return -0.4302772325590697;  // std dev = 0,071, 20,000 (wgt'ed) examples reached here.  /* #neg=20 */
# %   | | | else return -0.10059934729300843;  // std dev = 0,004, 13,000 (wgt'ed) examples reached here.  /* #neg=13 */
# %   | | else if ( has(B, I), researchprojectpage(A) )
# %   | | | then return -0.12484851705511374;  // std dev = 0,123, 12,000 (wgt'ed) examples reached here.  /* #neg=12 */
# %   | | | else if ( has(B, J), departmentof(A, K), facultypage(J) )
# %   | | | | then return 0.46774168132541255;  // std dev = 0,055, 55,000 (wgt'ed) examples reached here.  /* #pos=55 */
# %   | | | | else if ( membersofproject(L, A), has(B, M), membersofproject(L, M) )
# %   | | | | | then return 0.5606862395479729;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | | | else return 0.18007525002714198;  // std dev = 7,691, 300,000 (wgt'ed) examples reached here.  /* #neg=159 #pos=141 */
# WILL Produced-Tree #5
# % FOR pageclass(A, B):
# %   if ( has(B, C), studentpage(A), facultypage(C) )
# %   then return 0.3343734887003891;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.0872613802138276;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, D), membersofproject(D, E), has(B, E) )
# %   | | then return -0.2369797791398347;  // std dev = 0,128, 33,000 (wgt'ed) examples reached here.  /* #neg=33 */
# %   | | else if ( membersofproject(A, F), hasanchor(B, G) )
# %   | | | then if ( studentpage(F) )
# %   | | | | then return -0.20557092168563101;  // std dev = 0,251, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | | else return -0.046808521117573845;  // std dev = 0,291, 13,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=2 */
# %   | | | else if ( membersofproject(A, H) )
# %   | | | | then if ( studentpage(H) )
# %   | | | | | then return 0.3819513439769136;  // std dev = 1,500, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   | | | | | else return 0.6319513439769137;  // std dev = 2,98e-08, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | | else if ( has(B, I), departmentof(A, I) )
# %   | | | | | then return 0.31514763087199865;  // std dev = 1,897, 88,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=76 */
# %   | | | | | else return 0.11124856491480023;  // std dev = 6,960, 248,000 (wgt'ed) examples reached here.  /* #neg=141 #pos=107 */
# WILL Produced-Tree #6
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), studentpage(A) )
# %   then return 0.26447386995868444;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.0800228800301794;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, D), coursepage(A) )
# %   | | then return -0.11600239550452471;  // std dev = 0,118, 22,000 (wgt'ed) examples reached here.  /* #neg=22 */
# %   | | else if ( coursepage(A), hasanchor(B, E) )
# %   | | | then if ( instructorsof(A, F) )
# %   | | | | then return -0.2299354656040616;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else return -0.10493546560406156;  // std dev = 0,331, 8,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=1 */
# %   | | | else if ( coursepage(A) )
# %   | | | | then if ( instructorsof(A, G), facultypage(G) )
# %   | | | | | then return 0.19693569277161813;  // std dev = 2,332, 25,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=17 */
# %   | | | | | else return 0.31977307812086686;  // std dev = 2,054, 32,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=27 */
# %   | | | | else if ( membersofproject(H, A), has(B, I) )
# %   | | | | | then return 0.1815912475908394;  // std dev = 1,906, 52,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=40 */
# %   | | | | | else return 0.08853036975466755;  // std dev = 6,674, 266,000 (wgt'ed) examples reached here.  /* #neg=147 #pos=119 */
# WILL Produced-Tree #7
# % FOR pageclass(A, B):
# %   if ( has(B, C), studentpage(A), facultypage(C) )
# %   then return 0.2163072012096075;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.07382713700315525;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, D), has(B, E), membersofproject(D, E) )
# %   | | then return -0.2163440935258308;  // std dev = 0,127, 33,000 (wgt'ed) examples reached here.  /* #neg=33 */
# %   | | else if ( membersofproject(F, A), has(B, G) )
# %   | | | then if ( instructorsof(H, A), facultypage(A) )
# %   | | | | then return 0.10736882803005644;  // std dev = 0,252, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | | | else return 0.28429149195331244;  // std dev = 0,062, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | | | else if ( membersofproject(I, A) )
# %   | | | | then if ( facultypage(A) )
# %   | | | | | then return 0.12440004115001504;  // std dev = 2,689, 30,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=13 */
# %   | | | | | else return -0.2997629721118465;  // std dev = 3,65e-08, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
# %   | | | | else if ( has(B, J), coursepage(A) )
# %   | | | | | then return -0.11878306048630942;  // std dev = 0,000608, 16,000 (wgt'ed) examples reached here.  /* #neg=16 */
# %   | | | | | else return 0.1371079168690232;  // std dev = 6,561, 262,000 (wgt'ed) examples reached here.  /* #neg=111 #pos=151 */
# WILL Produced-Tree #8
# % FOR pageclass(A, B):
# %   if ( has(B, C), departmentof(A, D), facultypage(C) )
# %   then return 0.16267372665598484;  // std dev = 0,113, 331,000 (wgt'ed) examples reached here.  /* #neg=20 #pos=311 */
# %   else if ( studentpage(A) )
# %   | then return -0.0684674802782366;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( has(B, E), facultypage(E) )
# %   | | then return -0.0963754429210926;  // std dev = 0,193, 37,000 (wgt'ed) examples reached here.  /* #neg=37 */
# %   | | else if ( departmentof(A, F) )
# %   | | | then if ( facultypage(A), hasanchor(B, G) )
# %   | | | | then return -0.20832795684513236;  // std dev = 0,253, 28,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=2 */
# %   | | | | else if ( facultypage(A) )
# %   | | | | | then return 0.1924652404795543;  // std dev = 3,955, 63,000 (wgt'ed) examples reached here.  /* #neg=29 #pos=34 */
# %   | | | | | else return -0.058800449583729174;  // std dev = 2,185, 58,000 (wgt'ed) examples reached here.  /* #neg=37 #pos=21 */
# %   | | | else if ( has(B, H) )
# %   | | | | then return -0.1674389904517466;  // std dev = 0,062, 12,000 (wgt'ed) examples reached here.  /* #neg=12 */
# %   | | | | else if ( hasanchor(B, I) )
# %   | | | | | then return 0.2605508177080586;  // std dev = 2,396, 41,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=28 */
# %   | | | | | else return 0.11496207165783567;  // std dev = 4,236, 94,000 (wgt'ed) examples reached here.  /* #neg=30 #pos=64 */
# WILL Produced-Tree #9
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), studentpage(A) )
# %   then return 0.15891832135599043;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.06378781889208307;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( membersofproject(D, A), has(B, E) )
# %   | | then return 0.10052245708075289;  // std dev = 0,235, 52,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=40 */
# %   | | else if ( membersofproject(F, A) )
# %   | | | then if ( facultypage(A) )
# %   | | | | then if ( hasanchor(B, G), instructorsof(H, A) )
# %   | | | | | then return -0.25683312527175467;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #neg=5 */
# %   | | | | | else return 0.13518704167661355;  // std dev = 2,527, 25,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=13 */
# %   | | | | else return -0.23023402627169445;  // std dev = 0,000, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
# %   | | | else if ( has(B, I), instructorsof(I, J), studentpage(J) )
# %   | | | | then return -0.08706531793795057;  // std dev = 0,208, 52,000 (wgt'ed) examples reached here.  /* #neg=45 #pos=7 */
# %   | | | | else if ( membersofproject(A, K), hasanchor(B, L) )
# %   | | | | | then return -0.10362277238171644;  // std dev = 1,082, 13,000 (wgt'ed) examples reached here.  /* #neg=11 #pos=2 */
# %   | | | | | else return 0.09486532353559586;  // std dev = 6,114, 237,000 (wgt'ed) examples reached here.  /* #neg=95 #pos=142 */
# WILL Produced-Tree #10
# % FOR pageclass(A, B):
# %   if ( has(B, C), facultypage(C), studentpage(A) )
# %   then return 0.138809083442659;  // std dev = 0,000, 256,000 (wgt'ed) examples reached here.  /* #pos=256 */
# %   else if ( studentpage(A) )
# %   | then return -0.059668217382627335;  // std dev = 0,087, 260,000 (wgt'ed) examples reached here.  /* #neg=258 #pos=2 */
# %   | else if ( membersofproject(A, D), hasanchor(B, E) )
# %   | | then return -0.09342784248195475;  // std dev = 0,243, 20,000 (wgt'ed) examples reached here.  /* #neg=18 #pos=2 */
# %   | | else if ( membersofproject(A, F) )
# %   | | | then if ( studentpage(F) )
# %   | | | | then if ( membersofproject(A, G), facultypage(G), instructorsof(H, G) )
# %   | | | | | then return 0.2645669572485383;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | | else return 0.0979002905818716;  // std dev = 1,155, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   | | | | else return 0.37125893139073707;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | | | else if ( hasanchor(B, I), coursepage(A) )
# %   | | | | then return -0.12601479344186753;  // std dev = 0,176, 33,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=1 */
# %   | | | | else if ( hasanchor(B, J) )
# %   | | | | | then return 0.07834147090574436;  // std dev = 3,573, 168,000 (wgt'ed) examples reached here.  /* #neg=65 #pos=103 */
# %   | | | | | else return 0.004825984588179786;  // std dev = 5,723, 165,000 (wgt'ed) examples reached here.  /* #neg=86 #pos=79 */
# Results
#    AUC ROC   = 0.264659
#    AUC PR    = 0.380381
#    CLL	      = -1.144282
#    Precision = 0.318822 at threshold = 0.5
#    Recall    = 0.32613
#    F1        = 0.322434
#
#
# Total learning time: 366.014 seconds
# Total inference time: 14.982 seconds
# AUC ROC: 0.264659
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      68         p = subprocess.Popen(call, shell=True)
# ---> 69         os.waitpid(p.pid, 0)
#      70     except:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-c6a6bc779425> in <module>()
#       4     [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
#       5     [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
# ----> 6     [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
#
# /home/rodrigoazs/Projetos/TPRE/boostedrevision.py in learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine, trees, verbose)
#     222     '''Train and test a boosted or single tree'''
#     223     delete_model_files()
# --> 224     model = boostsrl.train(background, train_pos, train_neg, train_facts, refine=refine, trees=trees)
#     225     will = ['WILL Produced-Tree #'+str(i+1)+'\n'+('\n'.join(model.get_will_produced_tree(treenumber=i+1))) for i in range(trees)]
#     226     if verbose:
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in __init__(self, background, train_pos, train_neg, train_facts, refine, save, advice, softm, alpha, beta, trees)
#     249         CALL = '(cd boostsrl; java -jar v1-0.jar -l ' + ('-refine refine.txt ' if refine else '') + combine + '-train train/ -target ' + ','.join(self.target) + \
#     250                ' -trees ' + str(self.trees) + ' > train_output.txt 2>&1)'
# --> 251         call_process(CALL)
#     252
#     253     def tree(self, treenumber, target, image=False):
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      69         os.waitpid(p.pid, 0)
#      70     except:
# ---> 71         raise(Exception('Encountered problems while running process: ', call))
#      72
#      73 def inspect_mode_syntax(example):
#
# Exception: ('Encountered problems while running process: ', '(cd boostsrl; java -jar v1-0.jar -l -combine -train train/ -target pageclass -trees 10 > train_output.txt 2>&1)')

# %%
target = 'instructorsof'

bk = ['coursepage(+page).',
    'facultypage(+page).',
    'studentpage(+page).',
    'researchprojectpage(+page).',
    'linkto(+id,+page,+page).',
    'linkto(+id,+page,-page).',
    'linkto(+id,-page,+page).',
    'has(+word,+page).',
    'has(+word,-page).',
    'has(-word,+page).',
    'hasalphanumericword(+id).',
    'allwordscapitalized(+id).',
    'instructorsof(+page,+page).',
    'instructorsof(+page,-page).',
    'instructorsof(-page,+page).',
    'hasanchor(+word,+page).',
    'hasanchor(+word,-page).',
    'hasanchor(-word,+page).',
    'membersofproject(+page,+page).',
    'membersofproject(+page,-page).',
    'membersofproject(-page,+page).',
    'departmentof(+page,+page).',
    'departmentof(+page,-page).',
    'departmentof(-page,+page).',
    'pageclass(+page,+class).',
    'pageclass(+page,-class).',
    'pageclass(-page,+class).']

[facts, pos, neg] = datasets.load('webkb', bk, target=target)

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %%
for i in range(2):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# WILL Produced-Tree #1
# % FOR instructorsof(A, B):
# %   if ( facultypage(B) )
# %   then if ( membersofproject(C, B), membersofproject(C, D), studentpage(D) )
# %   | then return 0.44148226843284566;  // std dev = 0,493, 12,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=7 */
# %   | else if ( membersofproject(E, B) )
# %   | | then return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( pageclass(B, F), has(F, A) )
# %   | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.26723984419042146;  // std dev = 0,492, 22,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=9 */
# %   else if ( studentpage(B), pageclass(B, G), has(G, A) )
# %   | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( studentpage(B) )
# %   | | then if ( pageclass(B, H), has(H, B) )
# %   | | | then return 0.4295775065280837;  // std dev = 0,495, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else if ( membersofproject(I, B) )
# %   | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #2
# % FOR instructorsof(A, B):
# %   if ( facultypage(B) )
# %   then if ( membersofproject(C, B), membersofproject(C, D), studentpage(D) )
# %   | then return 0.3788520179768205;  // std dev = 0,493, 12,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=7 */
# %   | else if ( pageclass(B, E), has(E, B) )
# %   | | then return 0.42320411232198457;  // std dev = 1,094, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | else if ( pageclass(B, F), has(F, A) )
# %   | | | then return 0.09446743783575562;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.18616651320655747;  // std dev = 0,481, 22,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=8 */
# %   else if ( studentpage(B) )
# %   | then if ( membersofproject(G, B) )
# %   | | then return 0.4694694292941552;  // std dev = 0,771, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( pageclass(B, H), has(H, B) )
# %   | | | then return 0.41270153104936186;  // std dev = 0,477, 8,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=5 */
# %   | | | else return 0.1361360959608219;  // std dev = 0,714, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | else if ( membersofproject(I, B) )
# %   | | then return 0.308741135785635;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else return 0.7194734122109545;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #3
# % FOR instructorsof(A, B):
# %   if ( facultypage(B), pageclass(B, C), has(C, B) )
# %   then return 0.45991277063978037;  // std dev = 0,447, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   else if ( facultypage(B) )
# %   | then if ( membersofproject(D, B) )
# %   | | then return 0.23837780615519866;  // std dev = 0,501, 12,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=6 */
# %   | | else return 0.1332522092602102;  // std dev = 0,470, 24,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=8 */
# %   | else if ( studentpage(B) )
# %   | | then if ( membersofproject(E, B) )
# %   | | | then return 0.3869707017955188;  // std dev = 0,761, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( pageclass(B, F), has(F, B) )
# %   | | | | then return 0.3359927044471662;  // std dev = 0,476, 8,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=5 */
# %   | | | | else return 0.11422362562343724;  // std dev = 0,707, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else if ( membersofproject(G, B) )
# %   | | | then return 0.2564123687585864;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.5553664367462845;  // std dev = 1,05e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #4
# % FOR instructorsof(A, B):
# %   if ( facultypage(B), pageclass(B, C), has(C, B) )
# %   then return 0.3635668682426824;  // std dev = 0,446, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   else if ( facultypage(B) )
# %   | then if ( membersofproject(D, B) )
# %   | | then return 0.18997931888199396;  // std dev = 0,501, 12,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=6 */
# %   | | else if ( pageclass(B, E), has(E, A) )
# %   | | | then return 0.06216375122865348;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.1208896431209276;  // std dev = 0,477, 20,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=7 */
# %   | else if ( studentpage(B), pageclass(B, F), has(F, A) )
# %   | | then return 0.5785926638334482;  // std dev = 0,109, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( studentpage(B) )
# %   | | | then if ( pageclass(B, G), has(G, B) )
# %   | | | | then return 0.22204008317925888;  // std dev = 0,495, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | | else return 0.0030916572568420037;  // std dev = 0,807, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else if ( membersofproject(H, B) )
# %   | | | | then return 0.20613740734453975;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.41751358415830997;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #5
# % FOR instructorsof(A, B):
# %   if ( facultypage(B) )
# %   then if ( membersofproject(C, B), membersofproject(C, D), studentpage(D) )
# %   | then return 0.20186050627210775;  // std dev = 0,481, 12,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=7 */
# %   | else if ( membersofproject(E, B) )
# %   | | then return 0.03056952771902578;  // std dev = 1,132, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( pageclass(B, F), has(F, A) )
# %   | | | then return 0.05249594188078522;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.14176968966980927;  // std dev = 0,475, 22,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=9 */
# %   else if ( studentpage(B), pageclass(B, G), has(G, A) )
# %   | then return 0.4373851868602774;  // std dev = 0,113, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( studentpage(B) )
# %   | | then if ( pageclass(B, H), has(H, B) )
# %   | | | then return 0.1700413098800209;  // std dev = 0,495, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.002525908265468113;  // std dev = 0,807, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else if ( membersofproject(I, B) )
# %   | | | then return 0.16162857548414666;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.32071184716014967;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #6
# % FOR instructorsof(A, B):
# %   if ( facultypage(B), pageclass(B, C), has(C, B) )
# %   then return 0.24949910478467682;  // std dev = 0,433, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   else if ( facultypage(B) )
# %   | then if ( membersofproject(D, B) )
# %   | | then return 0.10711691067245299;  // std dev = 0,502, 12,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=6 */
# %   | | else if ( pageclass(B, E), has(E, A) )
# %   | | | then return 0.04404324823199646;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.07125233326247332;  // std dev = 0,477, 20,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=7 */
# %   | else if ( studentpage(B), pageclass(B, F), has(F, A) )
# %   | | then return 0.33585253989140806;  // std dev = 0,104, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( studentpage(B) )
# %   | | | then if ( pageclass(B, G), has(G, B) )
# %   | | | | then return 0.12858929783121933;  // std dev = 0,495, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | | else return 0.002063052890131742;  // std dev = 0,807, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else if ( membersofproject(H, B) )
# %   | | | | then return 0.12455597792081964;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.25517224256948945;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #7
# % FOR instructorsof(A, B):
# %   if ( facultypage(B) )
# %   then if ( membersofproject(C, B), membersofproject(C, D), studentpage(D) )
# %   | then return 0.12136300372577773;  // std dev = 0,476, 12,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=7 */
# %   | else if ( pageclass(B, E), has(E, A) )
# %   | | then return 0.13015265500593248;  // std dev = 0,962, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( membersofproject(F, B) )
# %   | | | then return -0.1542355814028477;  // std dev = 0,984, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else return 0.09461513954975773;  // std dev = 0,470, 22,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=9 */
# %   else if ( studentpage(B), pageclass(B, G), has(G, A) )
# %   | then return 0.266480880357511;  // std dev = 0,092, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( studentpage(B) )
# %   | | then if ( pageclass(B, H), has(H, B) )
# %   | | | then return 0.09667148380793458;  // std dev = 0,495, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return 0.0016845898564903372;  // std dev = 0,807, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else if ( membersofproject(I, B) )
# %   | | | then return 0.09492800936730683;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.20975771563253554;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #8
# % FOR instructorsof(A, B):
# %   if ( facultypage(B), pageclass(B, C), has(C, B) )
# %   then return 0.1786932172436678;  // std dev = 0,403, 7,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=5 */
# %   else if ( facultypage(B) )
# %   | then if ( membersofproject(D, B) )
# %   | | then return 0.061818021367341165;  // std dev = 0,505, 12,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=6 */
# %   | | else return 0.03294692651417427;  // std dev = 0,470, 24,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=8 */
# %   | else if ( membersofproject(E, B), studentpage(B) )
# %   | | then return 0.18953535648438705;  // std dev = 0,707, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( studentpage(B) )
# %   | | | then if ( pageclass(B, F), has(F, B) )
# %   | | | | then return 0.08769130434283118;  // std dev = 0,465, 8,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=5 */
# %   | | | | else return -0.033988306815064685;  // std dev = 0,389, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else if ( membersofproject(G, B) )
# %   | | | | then return 0.0718608885005586;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.17709649774527736;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #9
# % FOR instructorsof(A, B):
# %   if ( studentpage(B), membersofproject(C, B) )
# %   then return 0.1531620318571312;  // std dev = 0,707, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   else if ( membersofproject(D, B), membersofproject(D, E), studentpage(E) )
# %   | then if ( facultypage(B) )
# %   | | then return 0.0715586566934144;  // std dev = 0,474, 12,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=7 */
# %   | | else return 0.05418307375954945;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | else if ( facultypage(B), pageclass(B, F), has(F, A) )
# %   | | then return 0.09190292445486505;  // std dev = 0,944, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( membersofproject(G, B) )
# %   | | | then return -0.14754555019918414;  // std dev = 1,002, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | else if ( studentpage(B) )
# %   | | | | then if ( pageclass(B, H), has(H, B) )
# %   | | | | | then return 0.0668521937754249;  // std dev = 1,315, 8,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=5 */
# %   | | | | | else return -0.02818067007878398;  // std dev = 0,390, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else if ( facultypage(B) )
# %   | | | | | then return 0.0638494369239074;  // std dev = 2,193, 22,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=9 */
# %   | | | | | else return 0.15274385809367097;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# WILL Produced-Tree #10
# % FOR instructorsof(A, B):
# %   if ( facultypage(B) )
# %   then if ( membersofproject(C, B), membersofproject(C, D), studentpage(D) )
# %   | then return 0.053950983748596325;  // std dev = 0,474, 12,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=7 */
# %   | else if ( pageclass(B, E), has(E, A) )
# %   | | then return 0.07363832784113278;  // std dev = 0,942, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( pageclass(B, F), has(F, B) )
# %   | | | then return -0.037163554989120245;  // std dev = 0,857, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.03564531669663362;  // std dev = 0,483, 22,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=8 */
# %   else if ( studentpage(B), pageclass(B, G), has(G, A) )
# %   | then return 0.20003405253845244;  // std dev = 0,121, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | else if ( studentpage(B) )
# %   | | then if ( pageclass(B, H), has(H, B) )
# %   | | | then return 0.033959593142290724;  // std dev = 0,495, 7,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=4 */
# %   | | | else return -0.032369853067423585;  // std dev = 0,769, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else if ( membersofproject(I, B) )
# %   | | | then return 0.04076025323305622;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.13400703000801117;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# Results
#    AUC ROC   = 0.5
#    AUC PR    = 0.5
#    CLL	      = -1.126925
#    Precision = 0.5 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.666667
#
#
# Total learning time: 26.559 seconds
# Total inference time: 1.938 seconds
# AUC ROC: 0.5
#
#
# WILL Produced-Tree #1
# % FOR instructorsof(A, B):
# %   return 0;  // std dev = 0,500, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #2
# % FOR instructorsof(A, B):
# %   return 0;  // std dev = 0,500, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #3
# % FOR instructorsof(A, B):
# %   return 0;  // std dev = 0,500, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #4
# % FOR instructorsof(A, B):
# %   if ( has(C, B) )
# %   then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return 0.35181982117546096;  // std dev = 0,500, 79,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=39 */
# WILL Produced-Tree #5
# % FOR instructorsof(A, B):
# %   return 0;  // std dev = 0,500, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #6
# % FOR instructorsof(A, B):
# %   if ( has(C, B) )
# %   then return 0.3927941835770488;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return 0.3033890898025781;  // std dev = 0,500, 79,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=39 */
# WILL Produced-Tree #7
# % FOR instructorsof(A, B):
# %   return 0;  // std dev = 0,500, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #8
# % FOR instructorsof(A, B):
# %   if ( has(C, B) )
# %   then return 0.32092546969114216;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   else return 0.25222908846569936;  // std dev = 0,500, 79,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=39 */
# WILL Produced-Tree #9
# % FOR instructorsof(A, B):
# %   return 0;  // std dev = 0,500, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# WILL Produced-Tree #10
# % FOR instructorsof(A, B):
# %   return 0;  // std dev = 0,500, 84,000 (wgt'ed) examples reached here.  /* #neg=42 #pos=42 */
# Results
#    AUC ROC   = 0.502392
#    AUC PR    = 0.502622
#    CLL	      = -0.781594
#    Precision = nan at threshold = 0.5
#    Recall    = 0.0
#    F1        = nan
#
#
# Total learning time: 2.897 seconds
# Total inference time: 1.479 seconds
# AUC ROC: 0.502392

# %%
target = 'has'

bk = ['coursepage(+page).',
    'facultypage(+page).',
    'studentpage(+page).',
    'researchprojectpage(+page).',
    'linkto(+id,+page,+page).',
    'linkto(+id,+page,-page).',
    'linkto(+id,-page,+page).',
    'has(+word,+page).',
    'has(+word,-page).',
    'has(-word,+page).',
    'hasalphanumericword(+id).',
    'allwordscapitalized(+id).',
    'instructorsof(+page,+page).',
    'instructorsof(+page,-page).',
    'instructorsof(-page,+page).',
    'hasanchor(+word,+page).',
    'hasanchor(+word,-page).',
    'hasanchor(-word,+page).',
    'membersofproject(+page,+page).',
    'membersofproject(+page,-page).',
    'membersofproject(-page,+page).',
    'departmentof(+page,+page).',
    'departmentof(+page,-page).',
    'departmentof(-page,+page).',
    'pageclass(+page,+class).',
    'pageclass(+page,-class).',
    'pageclass(-page,+class).']

[facts, pos, neg] = datasets.load('webkb', bk, target=target)

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

for i in range(2):
    train_facts = facts[0]
    test_facts = facts[0]
    [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
    [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
    [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      68         p = subprocess.Popen(call, shell=True)
# ---> 69         os.waitpid(p.pid, 0)
#      70     except:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-29-d3b693815b73> in <module>()
#      38     [train_pos, test_pos] = datasets.get_kfold_small(i, pos)
#      39     [train_neg, test_neg] = datasets.get_kfold_small(i, neg)
# ---> 40     [model, learning_time, inference_time, t_results, structured, will] = learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine=None, trees=10, verbose=True)
#
# /home/rodrigoazs/Projetos/TPRE/boostedrevision.py in learn_test_model(background, boostsrl, target, train_pos, train_neg, train_facts, test_pos, test_neg, test_facts, refine, trees, verbose)
#     222     '''Train and test a boosted or single tree'''
#     223     delete_model_files()
# --> 224     model = boostsrl.train(background, train_pos, train_neg, train_facts, refine=refine, trees=trees)
#     225     will = ['WILL Produced-Tree #'+str(i+1)+'\n'+('\n'.join(model.get_will_produced_tree(treenumber=i+1))) for i in range(trees)]
#     226     if verbose:
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in __init__(self, background, train_pos, train_neg, train_facts, refine, save, advice, softm, alpha, beta, trees)
#     249         CALL = '(cd boostsrl; java -jar v1-0.jar -l ' + ('-refine refine.txt ' if refine else '') + combine + '-train train/ -target ' + ','.join(self.target) + \
#     250                ' -trees ' + str(self.trees) + ' > train_output.txt 2>&1)'
# --> 251         call_process(CALL)
#     252
#     253     def tree(self, treenumber, target, image=False):
#
# /home/rodrigoazs/anaconda3/lib/python3.5/site-packages/boostsrl/boostsrl.py in call_process(call)
#      69         os.waitpid(p.pid, 0)
#      70     except:
# ---> 71         raise(Exception('Encountered problems while running process: ', call))
#      72
#      73 def inspect_mode_syntax(example):
#
# Exception: ('Encountered problems while running process: ', '(cd boostsrl; java -jar v1-0.jar -l -combine -train train/ -target has -trees 10 > train_output.txt 2>&1)')

# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random

# %% [markdown]
# ## Parameters

# %%
target = 'advisedby'
test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.8
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %% [markdown]
# Sameproject, sameperson and samecourse predicates are not being used.

# %%
[facts, pos, neg] = get_uwcse_dataset(target, acceptedPredicates=[
'professor',
'student',
'advisedby',
'tempadvisedby',
'ta',
'hasposition',
'publication',
'inphase',
'courselevel',
'yearsinprogram',
'projectmember',
])

# %% [markdown]
# ## Background  configuration

# %%
bk = boostsrl.example_data('background')
bk = ['professor(+person).',
'student(+person).',
'advisedby(+person,+person).',
'advisedby(+person,-person).',
'advisedby(-person,+person).',
'tempadvisedby(+person,+person).',
'tempadvisedby(+person,-person).',
'tempadvisedby(-person,+person).',
'ta(+course,+person,+quarter).',
'ta(-course,+person,+quarter).',
'ta(+course,-person,+quarter).',
'ta(+course,+person,-quarter).',
'ta(-course,+person,-quarter).',
'ta(+course,-person,-quarter).',
'hasposition(+person,+faculty).',
'hasposition(+person,-faculty).',
'hasposition(-person,+faculty).',
'publication(+title,+person).',
'publication(+title,-person).',
'publication(-title,+person).',
'inphase(+person,+prequals).',
'inphase(+person,-prequals).',
'inphase(-person,+prequals).',
'courselevel(+course,+level).',
'courselevel(+course,-level).',
'courselevel(-course,+level).',
'yearsinprogram(+person,+year).',
'yearsinprogram(-person,+year).',
'yearsinprogram(+person,-year).',
'projectmember(+project,+person).',
'projectmember(+project,-person).',
'projectmember(-project,+person).']
#'sameproject(project, project).',
#'samecourse(course, course).',
#'sameperson(person, person).',]

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

# separate train and test
test_pos = pos[:int(test_size*len(pos))]
test_neg = neg[:int(test_size*len(neg))]
train_pos = pos[int(test_size*len(pos)):]
train_neg = neg[int(test_size*len(neg)):]

# learn from scratch in a small dataset
s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

# shuffle all train examples
random.shuffle(train_pos)
random.shuffle(train_neg)

# train set used in revision and validation set
r_train_pos = train_pos[int(validation_size*len(train_pos)):]
r_train_neg = train_neg[int(validation_size*len(train_neg)):]
validation_pos = train_pos[:int(validation_size*len(train_pos))]
validation_neg = train_neg[:int(validation_size*len(train_neg))]

print('Total examples')
print('Positive examples: %s' % len(pos))
print('Negative examples: %s' % len(neg))
print('\n')
print('Train and test sets from total')
print('Train Positive examples: %s' % len(train_pos))
print('Train Negative examples: %s' % len(train_neg))
print('Test Positive examples: %s' % len(test_pos))
print('Test Negative examples: %s' % len(test_neg))
print('\n')
print('Small dataset')
print('Train Positive examples: %s' % len(s_train_pos))
print('Train Negative examples: %s' % len(s_train_neg))
print('\n')
print('Revision theory train dataset and validation')
print('Train Positive examples: %s' % len(r_train_pos))
print('Train Negative examples: %s' % len(r_train_neg))
print('Validation Positive examples: %s' % len(validation_pos))
print('Validation Negative examples: %s' % len(validation_neg))
# Out:
# Total examples
# Positive examples: 113
# Negative examples: 4079
#
#
# Train and test sets from total
# Train Positive examples: 80
# Train Negative examples: 2856
# Test Positive examples: 33
# Test Negative examples: 1223
#
#
# Small dataset
# Train Positive examples: 24
# Train Negative examples: 856
#
#
# Revision theory train dataset and validation
# Train Positive examples: 64
# Train Negative examples: 2285
# Validation Positive examples: 16
# Validation Negative examples: 571

# %% [markdown]
# ## Learning from small dataset

# %%
delete_model_files()
model = boostsrl.train(background, s_train_pos, s_train_neg, facts)
learning_time = model.traintime()
will = model.get_will_produced_tree()
structured = model.get_structured_tree().copy()
results = boostsrl.test(model, test_pos, test_neg, facts)
inference_time = results.testtime()
t_results = results.summarize_results()
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total learning time: %s seconds' % learning_time)
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
print('Tree:')
model.tree(0, target, image=True)
# Out:
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995122;  // std dev = 0,000, 10,000 (wgt'ed) examples reached here.  /* #pos=10 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else if ( ta(G, A, H) )
# %   | | | then if ( ta(G, I, J), tempadvisedby(I, K) )
# %   | | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else if ( publication(L, B) )
# %   | | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else return -0.14185106490048774;  // std dev = 1,05e-08, 28,000 (wgt'ed) examples reached here.  /* #neg=28 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.192403, 'Precision': [nan, 0.5], 'AUC PR': 0.140409, 'AUC ROC': 0.914207}
#
#
# Total learning time: 2.02 seconds
# Total inference time: 0.899 seconds
# AUC ROC: 0.914207
#
#
# Tree:

# %% [markdown]
# ## Learning from complete dataset

# %%
delete_model_files()
model = boostsrl.train(background, train_pos, train_neg, facts)
learning_time = model.traintime()
will = model.get_will_produced_tree()
#structured = model.get_structured_tree().copy()
results = boostsrl.test(model, test_pos, test_neg, facts)
inference_time = results.testtime()
t_results = results.summarize_results()
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total learning time: %s seconds' % learning_time)
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
print('Tree:')
model.tree(0, target, image=True)
# Out:
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then return 0.8581489350995115;  // std dev = 2,38e-07, 34,000 (wgt'ed) examples reached here.  /* #pos=34 */
# %   | else if ( publication(D, A), publication(D, E), professor(E) )
# %   | | then if ( projectmember(F, B) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( tempadvisedby(G, B) )
# %   | | | | then return -0.14185106490048777;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #neg=4 */
# %   | | | | else return 0.19148226843284558;  // std dev = 0,471, 9,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=3 */
# %   | | else if ( publication(H, B) )
# %   | | | then return 0.6407576307516852;  // std dev = 0,412, 46,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=36 */
# %   | | | else if ( ta(I, A, J) )
# %   | | | | then return -0.14185106490048777;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else if ( tempadvisedby(K, B) )
# %   | | | | | then return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | | | else return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   else return -0.14185106490048766;  // std dev = 9,19e-08, 115,000 (wgt'ed) examples reached here.  /* #neg=115 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.1836, 'Precision': [nan, 0.5], 'AUC PR': 0.291499, 'AUC ROC': 0.874229}
#
#
# Total learning time: 3.31 seconds
# Total inference time: 0.884 seconds
# AUC ROC: 0.874229
#
#
# Tree:

# %% [markdown]
# ## Theory Revision

# %%
total_revision_time = 0
best_aucroc = 0
best_structured = None

print('Performing parameter learning')
print('******************************************')
delete_model_files()
model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=get_refine_file(structured))
learning_time = model.traintime()
will = model.get_will_produced_tree()
structured = model.get_structured_tree().copy()
results = boostsrl.test(model, test_pos, test_neg, facts)
inference_time = results.testtime()
t_results = results.summarize_results()
total_revision_time += learning_time + inference_time
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total learning time: %s seconds' % learning_time)
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
#print('Tree:')
#model.tree(0, target, image=True)

best_aucroc = t_results['AUC ROC']
best_structured = structured.copy()
save_model_files()

for i in range(max_revision_iterations):
    print('Refining iteration %s' % str(i+1))
    print('******************************************')
    found_better = False
    for candidate in get_cantidates(best_structured, revision_threshold):
        print('Refining node candidate')
        print('******************************************')
        delete_model_files()
        model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=candidate)
        learning_time = model.traintime()
        will = model.get_will_produced_tree()
        results = boostsrl.test(model, test_pos, test_neg, facts)
        inference_time = results.testtime()
        t_results = results.summarize_results()
        total_revision_time += learning_time + inference_time
        print('WILL-Produced Tree:')
        print_will_produced_tree(will)
        print('\n')
        print('Results:')
        print(t_results)
        print('\n')
        print('Total learning time: %s seconds' % learning_time)
        print('Total inference time: %s seconds' % inference_time)
        print('AUC ROC: %s' % t_results['AUC ROC'])
        print('\n')
        #print('Tree:')
        #model.tree(0, target, image=True)
        print('******************************************')

        if t_results['AUC ROC'] > best_aucroc:
            found_better = True
            best_aucroc = t_results['AUC ROC']
            best_structured = model.get_structured_tree().copy()
            save_model_files()
    print('Best Tree AUC ROC so far: %s' % best_aucroc)
    print('******************************************\n')
    if found_better == False:
        break

print('******************************************')
delete_model_files()
get_saved_model_files()
delete_test_files()
print('Total revision time: %s' % total_revision_time)
print('Best validation AUC ROC: %s' % best_aucroc)
will = model.get_will_produced_tree()
results = boostsrl.test(model, test_pos, test_neg, facts)
inference_time = results.testtime()
t_results = results.summarize_results()
print('WILL-Produced Tree:')
print_will_produced_tree(will)
print('\n')
print('Results:')
print(t_results)
print('\n')
print('Total inference time: %s seconds' % inference_time)
print('AUC ROC: %s' % t_results['AUC ROC'])
print('\n')
print('Tree:')
model.tree(0, target, image=True)
# Out:
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then return 0.4581489350995123;  // std dev = 1,549, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | else if ( ta(G, A, H) )
# %   | | | then if ( ta(G, I, J), tempadvisedby(I, K) )
# %   | | | | then return 0.7581489350995123;  // std dev = 0,949, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# %   | | | | else return 0.6081489350995123;  // std dev = 1,500, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   | | | else if ( publication(L, B) )
# %   | | | | then return 0.2812258581764354;  // std dev = 2,519, 26,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=11 */
# %   | | | | else return 0.6081489350995123;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   else return -0.14185106490048768;  // std dev = 7,60e-08, 100,000 (wgt'ed) examples reached here.  /* #neg=100 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.190504, 'Precision': [nan, 0.5], 'AUC PR': 0.249331, 'AUC ROC': 0.923177}
#
#
# Total learning time: 0.665 seconds
# Total inference time: 0.709 seconds
# AUC ROC: 0.923177
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then return 0.6081489350995123;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   | | else if ( ta(G, A, H) )
# %   | | | then if ( ta(G, I, J), tempadvisedby(I, K) )
# %   | | | | then return 0.5504566274072047;  // std dev = 1,664, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | | | else return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | else return 0.3733004502510275;  // std dev = 2,871, 33,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=17 */
# %   else return -0.14185106490048766;  // std dev = 8,43e-08, 102,000 (wgt'ed) examples reached here.  /* #neg=102 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.189707, 'Precision': [nan, 0.5], 'AUC PR': 0.244816, 'AUC ROC': 0.920575}
#
#
# Total learning time: 0.625 seconds
# Total inference time: 0.813 seconds
# AUC ROC: 0.920575
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then return 0.4581489350995123;  // std dev = 1,549, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   | | else if ( ta(G, A, H) )
# %   | | | then if ( ta(G, I, J), tempadvisedby(I, K) )
# %   | | | | then return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | | else if ( publication(L, A), publication(L, M), professor(M) )
# %   | | | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.8581489350995122;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | | | else if ( publication(N, B) )
# %   | | | | then return 0.43709630352056494;  // std dev = 2,152, 19,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=11 */
# %   | | | | else return 0.5248156017661789;  // std dev = 1,414, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   else return -0.14185106490048766;  // std dev = 7,88e-08, 103,000 (wgt'ed) examples reached here.  /* #neg=103 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.189182, 'Precision': [nan, 0.5], 'AUC PR': 0.175641, 'AUC ROC': 0.925531}
#
#
# Total learning time: 1.195 seconds
# Total inference time: 0.926 seconds
# AUC ROC: 0.925531
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.6763307532813305;  // std dev = 1,279, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | | else return 0.6081489350995123;  // std dev = 1,500, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   | | | else if ( publication(R, B) )
# %   | | | | then return 0.5052077586289241;  // std dev = 1,970, 17,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=11 */
# %   | | | | else return 0.4581489350995123;  // std dev = 1,549, 10,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=6 */
# %   else return -0.14185106490048766;  // std dev = 8,43e-08, 102,000 (wgt'ed) examples reached here.  /* #neg=102 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.190149, 'Precision': [nan, 0.5], 'AUC PR': 0.252523, 'AUC ROC': 0.926633}
#
#
# Total learning time: 1.993 seconds
# Total inference time: 0.947 seconds
# AUC ROC: 0.926633
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.926633
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.7100007869513637;  // std dev = 1,846, 27,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.6763307532813305;  // std dev = 1,279, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | | else return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | else return 0.424815601766179;  // std dev = 2,714, 30,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=17 */
# %   else return -0.14185106490048766;  // std dev = 7,88e-08, 104,000 (wgt'ed) examples reached here.  /* #neg=104 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.189816, 'Precision': [nan, 0.5], 'AUC PR': 0.182755, 'AUC ROC': 0.926844}
#
#
# Total learning time: 0.925 seconds
# Total inference time: 0.911 seconds
# AUC ROC: 0.926844
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else if ( ta(J, A, K) )
# %   | | | then if ( ta(J, L, M), tempadvisedby(L, N) )
# %   | | | | then return 0.6763307532813305;  // std dev = 1,279, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | | else return 0.6081489350995123;  // std dev = 1,500, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   | | | else if ( publication(P, B) )
# %   | | | | then return 0.40814893509951233;  // std dev = 2,225, 20,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=11 */
# %   | | | | else return 0.6081489350995123;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   else return -0.14185106490048766;  // std dev = 8,43e-08, 110,000 (wgt'ed) examples reached here.  /* #neg=110 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.191939, 'Precision': [nan, 0.5], 'AUC PR': 0.23807, 'AUC ROC': 0.914889}
#
#
# Total learning time: 0.633 seconds
# Total inference time: 0.725 seconds
# AUC ROC: 0.914889
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.7781489350995119;  // std dev = 1,356, 25,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.10814893509951218;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.7581489350995123;  // std dev = 0,949, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# %   | | | | else return 0.7581489350995123;  // std dev = 0,300, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# %   | | | else if ( publication(R, B) )
# %   | | | | then return 0.40814893509951233;  // std dev = 2,225, 20,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=11 */
# %   | | | | else return 0.40360348055405776;  // std dev = 1,651, 11,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=6 */
# %   else return -0.14185106490048768;  // std dev = 7,88e-08, 100,000 (wgt'ed) examples reached here.  /* #neg=100 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.191002, 'Precision': [nan, 0.5], 'AUC PR': 0.178766, 'AUC ROC': 0.9248}
#
#
# Total learning time: 0.643 seconds
# Total inference time: 0.979 seconds
# AUC ROC: 0.9248
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.7427643197148964;  // std dev = 1,629, 26,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.2581489350995122;  // std dev = 0,490, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.10814893509951218;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.4581489350995123;  // std dev = 1,897, 15,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=9 */
# %   | | | | else return 0.6081489350995123;  // std dev = 1,500, 12,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=9 */
# %   | | | else if ( publication(R, B) )
# %   | | | | then return 0.5052077586289241;  // std dev = 1,970, 17,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=11 */
# %   | | | | else return 0.5248156017661789;  // std dev = 1,414, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   else return -0.14185106490048766;  // std dev = 7,88e-08, 105,000 (wgt'ed) examples reached here.  /* #neg=105 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.189648, 'Precision': [nan, 0.5], 'AUC PR': 0.253903, 'AUC ROC': 0.92511}
#
#
# Total learning time: 1.335 seconds
# Total inference time: 1.002 seconds
# AUC ROC: 0.92511
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.926844
# ******************************************
#
# Refining iteration 3
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.7427643197148964;  // std dev = 1,629, 26,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | | else return 0.5504566274072047;  // std dev = 1,664, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | | else return 0.35814893509951234;  // std dev = 2,915, 34,000 (wgt'ed) examples reached here.  /* #neg=17 #pos=17 */
# %   else return -0.14185106490048766;  // std dev = 8,43e-08, 110,000 (wgt'ed) examples reached here.  /* #neg=110 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.191243, 'Precision': [nan, 0.5], 'AUC PR': 0.133485, 'AUC ROC': 0.913278}
#
#
# Total learning time: 1.533 seconds
# Total inference time: 0.972 seconds
# AUC ROC: 0.913278
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.1438632208137979;  // std dev = 1,195, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.4581489350995123;  // std dev = 1,897, 15,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=9 */
# %   | | | | else return 0.5504566274072047;  // std dev = 1,664, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | | else if ( projectmember(R, B) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | else return 0.5081489350995123;  // std dev = 0,477, 20,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=13 */
# %   else return -0.14185106490048766;  // std dev = 8,94e-08, 113,000 (wgt'ed) examples reached here.  /* #neg=113 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.189578, 'Precision': [nan, 0.5], 'AUC PR': 0.205354, 'AUC ROC': 0.929495}
#
#
# Total learning time: 1.045 seconds
# Total inference time: 0.909 seconds
# AUC ROC: 0.929495
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.42064893509951234;  // std dev = 1,984, 16,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=9 */
# %   | | | | else if ( tempadvisedby(R, B), publication(S, B) )
# %   | | | | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | | | else return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | else return 0.48777856472914194;  // std dev = 2,509, 27,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=17 */
# %   else return -0.14185106490048766;  // std dev = 8,69e-08, 104,000 (wgt'ed) examples reached here.  /* #neg=104 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.189422, 'Precision': [nan, 0.5], 'AUC PR': 0.171513, 'AUC ROC': 0.927587}
#
#
# Total learning time: 1.209 seconds
# Total inference time: 0.995 seconds
# AUC ROC: 0.927587
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.5504566274072047;  // std dev = 1,664, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | | | else return 0.7581489350995123;  // std dev = 0,949, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# %   | | | else return 0.4443558316512365;  // std dev = 2,652, 29,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=17 */
# %   else return -0.14185106490048766;  // std dev = 8,94e-08, 110,000 (wgt'ed) examples reached here.  /* #neg=110 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.191893, 'Precision': [nan, 0.5], 'AUC PR': 0.184921, 'AUC ROC': 0.923858}
#
#
# Total learning time: 1.471 seconds
# Total inference time: 0.937 seconds
# AUC ROC: 0.923858
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.929495
# ******************************************
#
# Refining iteration 4
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | | else return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.33183314562582816;  // std dev = 2,176, 19,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=9 */
# %   | | | | else return 0.5504566274072047;  // std dev = 1,664, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | | else if ( projectmember(R, B) )
# %   | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | else return 0.47719655414713136;  // std dev = 2,225, 21,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=13 */
# %   else return -0.14185106490048766;  // std dev = 8,69e-08, 107,000 (wgt'ed) examples reached here.  /* #neg=107 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.191431, 'Precision': [nan, 0.5], 'AUC PR': 0.155235, 'AUC ROC': 0.91723}
#
#
# Total learning time: 1.079 seconds
# Total inference time: 1.087 seconds
# AUC ROC: 0.91723
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.7581489350995123;  // std dev = 0,949, 10,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=9 */
# %   | | | | else return 0.4581489350995123;  // std dev = 1,897, 15,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=9 */
# %   | | | else if ( projectmember(R, B) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | else return 0.5803711573217345;  // std dev = 0,448, 18,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=13 */
# %   else return -0.14185106490048766;  // std dev = 8,16e-08, 107,000 (wgt'ed) examples reached here.  /* #neg=107 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.190673, 'Precision': [nan, 0.5], 'AUC PR': 0.226206, 'AUC ROC': 0.928579}
#
#
# Total learning time: 0.953 seconds
# Total inference time: 1.005 seconds
# AUC ROC: 0.928579
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.7781489350995119;  // std dev = 1,356, 25,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then return 0.6763307532813305;  // std dev = 1,809, 22,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=18 */
# %   | | | else if ( projectmember(N, B) )
# %   | | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | | else return 0.3396304165809938;  // std dev = 2,596, 27,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=13 */
# %   else return -0.14185106490048766;  // std dev = 8,16e-08, 112,000 (wgt'ed) examples reached here.  /* #neg=112 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.190712, 'Precision': [nan, 0.5], 'AUC PR': 0.229253, 'AUC ROC': 0.926311}
#
#
# Total learning time: 0.79 seconds
# Total inference time: 0.946 seconds
# AUC ROC: 0.926311
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.929495
# ******************************************
#
# ******************************************
# Total revision time: 29.957
# Best validation AUC ROC: 0.929495
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.8581489350995121;  // std dev = 8,43e-08, 23,000 (wgt'ed) examples reached here.  /* #pos=23 */
# %   | else if ( publication(D, B), publication(D, E), tempadvisedby(E, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | else if ( ta(J, A, K) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 2,000 (wgt'ed) examples reached here.  /* #pos=2 */
# %   | | | | else return 0.1438632208137979;  // std dev = 1,195, 7,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=2 */
# %   | | else if ( ta(L, A, M) )
# %   | | | then if ( ta(L, N, P), tempadvisedby(N, Q) )
# %   | | | | then return 0.4581489350995123;  // std dev = 1,897, 15,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=9 */
# %   | | | | else return 0.5504566274072047;  // std dev = 1,664, 13,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=9 */
# %   | | | else if ( projectmember(R, B) )
# %   | | | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | else return 0.5081489350995123;  // std dev = 0,477, 20,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=13 */
# %   else return -0.14185106490048766;  // std dev = 8,94e-08, 113,000 (wgt'ed) examples reached here.  /* #neg=113 */
#
#
# Results:
# {'F1': nan, 'Recall': 0.0, 'CLL': -0.189578, 'Precision': [nan, 0.5], 'AUC PR': 0.205354, 'AUC ROC': 0.929495}
#
#
# Total inference time: 1.13 seconds
# AUC ROC: 0.929495
#
#
# Tree:

# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold

# %% [markdown]
# ## Parameters

# %%
target = 'advisedby'
#test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.8
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %% [markdown]
# Sameproject, sameperson and samecourse predicates are not being used.

# %%
[facts, pos, neg] = get_uwcse_dataset(target, acceptedPredicates=[
'professor',
'student',
'advisedby',
'tempadvisedby',
'ta',
'hasposition',
'publication',
'inphase',
'courselevel',
'yearsinprogram',
'projectmember',
])

# %% [markdown]
# ## Background  configuration

# %%
bk = boostsrl.example_data('background')
bk = ['professor(+person).',
'student(+person).',
'advisedby(+person,+person).',
'advisedby(+person,-person).',
'advisedby(-person,+person).',
'tempadvisedby(+person,+person).',
'tempadvisedby(+person,-person).',
'tempadvisedby(-person,+person).',
'ta(+course,+person,+quarter).',
'ta(-course,+person,+quarter).',
'ta(+course,-person,+quarter).',
'ta(+course,+person,-quarter).',
'ta(-course,+person,-quarter).',
'ta(+course,-person,-quarter).',
'hasposition(+person,+faculty).',
'hasposition(+person,-faculty).',
'hasposition(-person,+faculty).',
'publication(+title,+person).',
'publication(+title,-person).',
'publication(-title,+person).',
'inphase(+person,+prequals).',
'inphase(+person,-prequals).',
'inphase(-person,+prequals).',
'courselevel(+course,+level).',
'courselevel(+course,-level).',
'courselevel(-course,+level).',
'yearsinprogram(+person,+year).',
'yearsinprogram(-person,+year).',
'yearsinprogram(+person,-year).',
'projectmember(+project,+person).',
'projectmember(+project,-person).',
'projectmember(-project,+person).']
#'sameproject(project, project).',
#'samecourse(course, course).',
#'sameperson(person, person).',]

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

neg = neg[:len(pos)] # balanced

import numpy as np
pos = np.array(pos)
neg = np.array(neg)
small_dataset_aucroc = []
complete_dataset_aucroc = []
revision_dataset_aucroc = []


# separate train and test
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(pos):
    train_pos, test_pos = pos[train_index], pos[test_index]
    train_neg, test_neg = neg[train_index], neg[test_index]

    # learn from scratch in a small dataset
    s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
    s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

    # shuffle all train examples
    random.shuffle(train_pos)
    random.shuffle(train_neg)

    # train set used in revision and validation set
    r_train_pos = train_pos[int(validation_size*len(train_pos)):]
    r_train_neg = train_neg[int(validation_size*len(train_neg)):]
    validation_pos = train_pos[:int(validation_size*len(train_pos))]
    validation_neg = train_neg[:int(validation_size*len(train_neg))]

    print('Total examples')
    print('Positive examples: %s' % len(pos))
    print('Negative examples: %s' % len(neg))
    print('\n')
    print('Train and test sets from total')
    print('Train Positive examples: %s' % len(train_pos))
    print('Train Negative examples: %s' % len(train_neg))
    print('Test Positive examples: %s' % len(test_pos))
    print('Test Negative examples: %s' % len(test_neg))
    print('\n')
    print('Small dataset')
    print('Train Positive examples: %s' % len(s_train_pos))
    print('Train Negative examples: %s' % len(s_train_neg))
    print('\n')
    print('Revision theory train dataset and validation')
    print('Train Positive examples: %s' % len(r_train_pos))
    print('Train Negative examples: %s' % len(r_train_neg))
    print('Validation Positive examples: %s' % len(validation_pos))
    print('Validation Negative examples: %s' % len(validation_neg))
    
    # learning from small dataset
    delete_model_files()
    model = boostsrl.train(background, s_train_pos, s_train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    small_dataset_aucroc.append(t_results['AUC ROC'])
    
    # learning from complete dataset
    delete_model_files()
    model = boostsrl.train(background, train_pos, train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    #structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    complete_dataset_aucroc.append(t_results['AUC ROC'])
    
    # theory revision
    total_revision_time = 0
    best_aucroc = 0
    best_structured = None

    print('Performing parameter learning')
    print('******************************************')
    delete_model_files()
    model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=get_refine_file(structured))
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    total_revision_time += learning_time + inference_time
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)

    best_aucroc = t_results['AUC ROC']
    best_structured = structured.copy()
    save_model_files()

    for i in range(max_revision_iterations):
        print('Refining iteration %s' % str(i+1))
        print('******************************************')
        found_better = False
        for candidate in get_cantidates(best_structured, revision_threshold):
            print('Refining node candidate')
            print('******************************************')
            delete_model_files()
            model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=candidate)
            learning_time = model.traintime()
            will = model.get_will_produced_tree()
            results = boostsrl.test(model, test_pos, test_neg, facts)
            inference_time = results.testtime()
            t_results = results.summarize_results()
            total_revision_time += learning_time + inference_time
            print('WILL-Produced Tree:')
            print_will_produced_tree(will)
            print('\n')
            print('Results:')
            print(t_results)
            print('\n')
            print('Total learning time: %s seconds' % learning_time)
            print('Total inference time: %s seconds' % inference_time)
            print('AUC ROC: %s' % t_results['AUC ROC'])
            print('\n')
            #print('Tree:')
            #model.tree(0, target, image=True)
            print('******************************************')

            if t_results['AUC ROC'] > best_aucroc:
                found_better = True
                best_aucroc = t_results['AUC ROC']
                best_structured = model.get_structured_tree().copy()
                save_model_files()
        print('Best Tree AUC ROC so far: %s' % best_aucroc)
        print('******************************************\n')
        if found_better == False:
            break

    print('******************************************')
    delete_model_files()
    get_saved_model_files()
    delete_test_files()
    print('Total revision time: %s' % total_revision_time)
    print('Best validation AUC ROC: %s' % best_aucroc)
    will = model.get_will_produced_tree()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    revision_dataset_aucroc.append(t_results['AUC ROC'])
# Out:
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 101
# Train Negative examples: 101
# Test Positive examples: 12
# Test Negative examples: 12
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 81
# Train Negative examples: 81
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, B) )
# %   then if ( ta(D, A, E) )
# %   | then return 0.8581489350995123;  // std dev = 0,000, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | else if ( publication(C, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | else if ( tempadvisedby(F, B), publication(C, G), ta(H, G, I) )
# %   | | | then return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else return 0.6914822684328454;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   else if ( tempadvisedby(J, B) )
# %   | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | else return -0.1418510649004877;  // std dev = 2,11e-08, 26,000 (wgt'ed) examples reached here.  /* #neg=26 */
#
#
# Results:
# {'AUC PR': 0.903108, 'AUC ROC': 0.947917, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.736679}
#
#
# Total learning time: 2.454 seconds
# Total inference time: 0.735 seconds
# AUC ROC: 0.947917
#
#
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), tempadvisedby(E, D) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995116;  // std dev = 2,15e-07, 32,000 (wgt'ed) examples reached here.  /* #pos=32 */
# %   | | else return 0.7311648081153856;  // std dev = 0,333, 63,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=55 */
# %   | else if ( publication(F, A), publication(F, G), professor(G) )
# %   | | then if ( projectmember(H, B), publication(F, I), tempadvisedby(I, G) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( publication(J, B) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( tempadvisedby(K, B) )
# %   | | | | | then return -0.14185106490048777;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | | else return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | else if ( tempadvisedby(L, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   else return -0.14185106490048766;  // std dev = 7,45e-08, 85,000 (wgt'ed) examples reached here.  /* #neg=85 */
#
#
# Results:
# {'AUC PR': 0.957428, 'AUC ROC': 0.916667, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.76321}
#
#
# Total learning time: 5.437 seconds
# Total inference time: 0.494 seconds
# AUC ROC: 0.916667
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, B) )
# %   then if ( ta(D, A, E) )
# %   | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | else if ( publication(C, A) )
# %   | | then return 0.7748156017661786;  // std dev = 1,354, 24,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=22 */
# %   | | else if ( tempadvisedby(F, B), publication(C, G), ta(H, G, I) )
# %   | | | then return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else if ( tempadvisedby(J, B) )
# %   | then return 0.5581489350995124;  // std dev = 1,449, 10,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=7 */
# %   | else return -0.06938729678454568;  // std dev = 2,154, 69,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=5 */
#
#
# Results:
# {'AUC PR': 0.963743, 'AUC ROC': 0.96875, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.762881}
#
#
# Total learning time: 0.553 seconds
# Total inference time: 0.41 seconds
# AUC ROC: 0.96875
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, B) )
# %   then if ( ta(D, A, E) )
# %   | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | else if ( publication(C, A) )
# %   | | then return 0.7748156017661786;  // std dev = 1,354, 24,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=22 */
# %   | | else if ( tempadvisedby(F, B), publication(C, G), ta(H, G, I) )
# %   | | | then return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else if ( tempadvisedby(J, B) )
# %   | then if ( projectmember(K, B), student(A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | else return -0.06938729678454568;  // std dev = 2,154, 69,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=5 */
#
#
# Results:
# {'AUC PR': 0.973194, 'AUC ROC': 0.975694, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763533}
#
#
# Total learning time: 0.818 seconds
# Total inference time: 0.385 seconds
# AUC ROC: 0.975694
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, B) )
# %   then if ( ta(D, A, E) )
# %   | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | else if ( publication(C, A) )
# %   | | then return 0.7748156017661786;  // std dev = 1,354, 24,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=22 */
# %   | | else return 0.5133213488926157;  // std dev = 2,560, 29,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=19 */
# %   else if ( tempadvisedby(F, B) )
# %   | then return 0.5581489350995124;  // std dev = 1,449, 10,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=7 */
# %   | else return -0.06938729678454568;  // std dev = 2,154, 69,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=5 */
#
#
# Results:
# {'AUC PR': 0.963743, 'AUC ROC': 0.96875, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763256}
#
#
# Total learning time: 0.467 seconds
# Total inference time: 0.497 seconds
# AUC ROC: 0.96875
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.975694
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, B) )
# %   then if ( ta(D, A, E) )
# %   | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | else if ( publication(C, A) )
# %   | | then return 0.7748156017661786;  // std dev = 1,354, 24,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=22 */
# %   | | else if ( tempadvisedby(F, B), publication(C, G), ta(H, G, I) )
# %   | | | then return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else if ( tempadvisedby(J, B) )
# %   | then if ( projectmember(K, B), student(A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.2581489350995122;  // std dev = 0,490, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | else return -0.06938729678454568;  // std dev = 2,154, 69,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=5 */
#
#
# Results:
# {'AUC PR': 0.973194, 'AUC ROC': 0.975694, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763533}
#
#
# Total learning time: 0.815 seconds
# Total inference time: 0.505 seconds
# AUC ROC: 0.975694
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, B) )
# %   then if ( ta(D, A, E) )
# %   | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | else if ( publication(C, A) )
# %   | | then return 0.7748156017661786;  // std dev = 1,354, 24,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=22 */
# %   | | else return 0.5133213488926157;  // std dev = 2,560, 29,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=19 */
# %   else if ( tempadvisedby(F, B) )
# %   | then if ( projectmember(G, B), student(A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | else return -0.06938729678454568;  // std dev = 2,154, 69,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=5 */
#
#
# Results:
# {'AUC PR': 0.973194, 'AUC ROC': 0.975694, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763908}
#
#
# Total learning time: 0.578 seconds
# Total inference time: 0.391 seconds
# AUC ROC: 0.975694
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.975694
# ******************************************
#
# ******************************************
# Total revision time: 5.419
# Best validation AUC ROC: 0.975694
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), publication(C, B) )
# %   then if ( ta(D, A, E) )
# %   | then return 0.791482268432845;  // std dev = 1,366, 30,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=28 */
# %   | else if ( publication(C, A) )
# %   | | then return 0.7748156017661786;  // std dev = 1,354, 24,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=22 */
# %   | | else if ( tempadvisedby(F, B), publication(C, G), ta(H, G, I) )
# %   | | | then return 0.5010060779566552;  // std dev = 1,793, 14,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=9 */
# %   | | | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else if ( tempadvisedby(J, B) )
# %   | then if ( projectmember(K, B), student(A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | else return 0.2581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | else return -0.06938729678454568;  // std dev = 2,154, 69,000 (wgt'ed) examples reached here.  /* #neg=64 #pos=5 */
#
#
# Results:
# {'AUC PR': 0.973194, 'AUC ROC': 0.975694, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763533}
#
#
# Total inference time: 0.381 seconds
# AUC ROC: 0.975694
#
#
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 101
# Train Negative examples: 101
# Test Positive examples: 12
# Test Negative examples: 12
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 81
# Train Negative examples: 81
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | | else if ( tempadvisedby(F, B), inphase(D, G), ta(H, F, I) )
# %   | | | then if ( ta(J, D, I) )
# %   | | | | then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else return 0.8581489350995123;  // std dev = 0,000, 8,000 (wgt'ed) examples reached here.  /* #pos=8 */
# %   | else if ( tempadvisedby(K, B) )
# %   | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else return -0.14185106490048774;  // std dev = 1,49e-08, 25,000 (wgt'ed) examples reached here.  /* #neg=25 */
#
#
# Results:
# {'AUC PR': 0.823399, 'AUC ROC': 0.895833, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.742962}
#
#
# Total learning time: 3.893 seconds
# Total inference time: 0.547 seconds
# AUC ROC: 0.895833
#
#
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), tempadvisedby(E, D) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995117;  // std dev = 1,98e-07, 30,000 (wgt'ed) examples reached here.  /* #pos=30 */
# %   | | else if ( publication(F, E) )
# %   | | | then return 0.7110901115700998;  // std dev = 0,354, 34,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=29 */
# %   | | | else return 0.8236661764788221;  // std dev = 0,182, 29,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=28 */
# %   | else if ( publication(G, A), publication(G, H), professor(H) )
# %   | | then if ( ta(I, A, J) )
# %   | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else if ( tempadvisedby(K, B) )
# %   | | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else if ( tempadvisedby(L, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   else return -0.14185106490048766;  // std dev = 7,60e-08, 88,000 (wgt'ed) examples reached here.  /* #neg=88 */
#
#
# Results:
# {'AUC PR': 0.951587, 'AUC ROC': 0.947917, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.775937}
#
#
# Total learning time: 7.093 seconds
# Total inference time: 0.434 seconds
# AUC ROC: 0.947917
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8318331456258272;  // std dev = 0,987, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | | else if ( tempadvisedby(F, B), inphase(D, G), ta(H, F, I) )
# %   | | | then if ( ta(J, D, I) )
# %   | | | | then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | else if ( tempadvisedby(K, B) )
# %   | | then return 0.6273797043302815;  // std dev = 1,519, 13,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=10 */
# %   | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.87613, 'AUC ROC': 0.899306, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.753535}
#
#
# Total learning time: 0.595 seconds
# Total inference time: 0.482 seconds
# AUC ROC: 0.899306
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8318331456258272;  // std dev = 0,987, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | | else if ( tempadvisedby(F, B), inphase(D, G), ta(H, F, I) )
# %   | | | then if ( ta(J, D, I) )
# %   | | | | then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | else if ( tempadvisedby(K, B) )
# %   | | then if ( ta(L, A, M) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else if ( publication(N, A) )
# %   | | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.906451, 'AUC ROC': 0.920139, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763842}
#
#
# Total learning time: 1.384 seconds
# Total inference time: 0.531 seconds
# AUC ROC: 0.920139
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8318331456258272;  // std dev = 0,987, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | | else if ( tempadvisedby(F, B), inphase(D, G), ta(H, F, I) )
# %   | | | then if ( ta(J, D, I) )
# %   | | | | then return 0.4581489350995122;  // std dev = 0,490, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | else if ( tempadvisedby(K, B) )
# %   | | then return 0.6273797043302815;  // std dev = 1,519, 13,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=10 */
# %   | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.87613, 'AUC ROC': 0.899306, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.753535}
#
#
# Total learning time: 1.35 seconds
# Total inference time: 0.458 seconds
# AUC ROC: 0.899306
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.920139
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8318331456258272;  // std dev = 0,987, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | | else if ( tempadvisedby(F, B), inphase(D, G), ta(H, F, I) )
# %   | | | then if ( ta(J, D, I) )
# %   | | | | then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | else if ( tempadvisedby(K, B) )
# %   | | then if ( ta(L, A, M) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else if ( publication(N, A) )
# %   | | | | then return 0.10814893509951219;  // std dev = 0,433, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.906451, 'AUC ROC': 0.920139, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763842}
#
#
# Total learning time: 0.751 seconds
# Total inference time: 0.436 seconds
# AUC ROC: 0.920139
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8318331456258272;  // std dev = 0,987, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | | else if ( tempadvisedby(F, B), inphase(D, G), ta(H, F, I) )
# %   | | | then if ( ta(J, D, I) )
# %   | | | | then return 0.4581489350995122;  // std dev = 0,490, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | else if ( tempadvisedby(K, B) )
# %   | | then if ( ta(L, A, M) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else if ( publication(N, A) )
# %   | | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.906451, 'AUC ROC': 0.920139, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763842}
#
#
# Total learning time: 0.772 seconds
# Total inference time: 0.528 seconds
# AUC ROC: 0.920139
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.920139
# ******************************************
#
# ******************************************
# Total revision time: 7.287
# Best validation AUC ROC: 0.920139
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), student(D) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8318331456258272;  // std dev = 0,987, 38,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=37 */
# %   | | else if ( tempadvisedby(F, B), inphase(D, G), ta(H, F, I) )
# %   | | | then if ( ta(J, D, I) )
# %   | | | | then return 0.4581489350995122;  // std dev = 1,095, 5,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=3 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.6816783468642181;  // std dev = 1,572, 17,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=14 */
# %   | else if ( tempadvisedby(K, B) )
# %   | | then if ( ta(L, A, M) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 6,000 (wgt'ed) examples reached here.  /* #pos=6 */
# %   | | | else if ( publication(N, A) )
# %   | | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | else return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else return 0.6914822684328455;  // std dev = 1,291, 12,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.906451, 'AUC ROC': 0.920139, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.763842}
#
#
# Total inference time: 0.597 seconds
# AUC ROC: 0.920139
#
#
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 101
# Train Negative examples: 101
# Test Positive examples: 12
# Test Negative examples: 12
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 81
# Train Negative examples: 81
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.8581489350995123;  // std dev = 0,000, 16,000 (wgt'ed) examples reached here.  /* #pos=16 */
# %   | else if ( tempadvisedby(E, B), ta(F, E, G) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | else if ( publication(H, B), publication(H, A) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( publication(I, B), publication(I, J), student(J) )
# %   | | | | then return -0.14185106490048777;  // std dev = 0,000, 3,000 (wgt'ed) examples reached here.  /* #neg=3 */
# %   | | | | else return 0.5248156017661788;  // std dev = 1,155, 6,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=4 */
# %   else return -0.14185106490048774;  // std dev = 1,49e-08, 25,000 (wgt'ed) examples reached here.  /* #neg=25 */
#
#
# Results:
# {'AUC PR': 0.775793, 'AUC ROC': 0.78125, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.855267}
#
#
# Total learning time: 2.027 seconds
# Total inference time: 0.406 seconds
# AUC ROC: 0.78125
#
#
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), tempadvisedby(E, D) )
# %   | then if ( publication(F, E) )
# %   | | then return 0.7260734634013991;  // std dev = 0,339, 53,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=46 */
# %   | | else return 0.8581489350995117;  // std dev = 2,46e-07, 40,000 (wgt'ed) examples reached here.  /* #pos=40 */
# %   | else if ( publication(G, A), publication(G, H), professor(H) )
# %   | | then if ( projectmember(I, B), publication(G, J), tempadvisedby(J, H) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( publication(K, B) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( tempadvisedby(L, B), tempadvisedby(M, H) )
# %   | | | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( tempadvisedby(N, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   else return -0.14185106490048766;  // std dev = 7,45e-08, 86,000 (wgt'ed) examples reached here.  /* #neg=86 */
#
#
# Results:
# {'AUC PR': 0.863194, 'AUC ROC': 0.927083, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.751009}
#
#
# Total learning time: 6.359 seconds
# Total inference time: 0.526 seconds
# AUC ROC: 0.927083
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7831489350995114;  // std dev = 1,666, 40,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=37 */
# %   | else if ( tempadvisedby(E, B), ta(F, E, G) )
# %   | | then return 0.724815601766179;  // std dev = 1,317, 15,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=13 */
# %   | | else if ( publication(H, B), publication(H, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | | else if ( publication(I, B), publication(I, J), student(J) )
# %   | | | | then return 0.6581489350995123;  // std dev = 1,265, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   | | | | else return 0.5724346493852266;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 6,32e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.940724, 'AUC ROC': 0.954861, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.759494}
#
#
# Total learning time: 0.646 seconds
# Total inference time: 0.483 seconds
# AUC ROC: 0.954861
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7831489350995114;  // std dev = 1,666, 40,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=37 */
# %   | else if ( tempadvisedby(E, B), ta(F, E, G) )
# %   | | then return 0.724815601766179;  // std dev = 1,317, 15,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=13 */
# %   | | else if ( publication(H, B), publication(H, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | | else if ( publication(I, B), publication(I, J), student(J) )
# %   | | | | then return 0.6581489350995123;  // std dev = 1,265, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   | | | | else if ( publication(K, A), publication(K, L), professor(L) )
# %   | | | | | then return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | | | else return 0.7331489350995123;  // std dev = 0,935, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   else return -0.14185106490048768;  // std dev = 6,32e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.95305, 'AUC ROC': 0.961806, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.754413}
#
#
# Total learning time: 0.835 seconds
# Total inference time: 0.401 seconds
# AUC ROC: 0.961806
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.961806
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7831489350995114;  // std dev = 1,666, 40,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=37 */
# %   | else if ( tempadvisedby(E, B), ta(F, E, G) )
# %   | | then return 0.724815601766179;  // std dev = 1,317, 15,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=13 */
# %   | | else if ( publication(H, B), publication(H, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | | else if ( publication(I, B), publication(I, J), student(J) )
# %   | | | | then return 0.6581489350995123;  // std dev = 1,265, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   | | | | else if ( publication(K, A), publication(K, L), professor(L) )
# %   | | | | | then if ( projectmember(M, B) )
# %   | | | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | | else return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.7331489350995123;  // std dev = 0,935, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   else return -0.14185106490048768;  // std dev = 6,32e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.95305, 'AUC ROC': 0.961806, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.754413}
#
#
# Total learning time: 0.748 seconds
# Total inference time: 0.404 seconds
# AUC ROC: 0.961806
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.961806
# ******************************************
#
# ******************************************
# Total revision time: 3.5170000000000003
# Best validation AUC ROC: 0.961806
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7831489350995114;  // std dev = 1,666, 40,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=37 */
# %   | else if ( tempadvisedby(E, B), ta(F, E, G) )
# %   | | then return 0.724815601766179;  // std dev = 1,317, 15,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=13 */
# %   | | else if ( publication(H, B), publication(H, A) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 13,000 (wgt'ed) examples reached here.  /* #pos=13 */
# %   | | | else if ( publication(I, B), publication(I, J), student(J) )
# %   | | | | then return 0.6581489350995123;  // std dev = 1,265, 10,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=8 */
# %   | | | | else if ( publication(K, A), publication(K, L), professor(L) )
# %   | | | | | then return 0.35814893509951223;  // std dev = 1,225, 6,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=3 */
# %   | | | | | else return 0.7331489350995123;  // std dev = 0,935, 8,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=7 */
# %   else return -0.14185106490048768;  // std dev = 6,32e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.95305, 'AUC ROC': 0.961806, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.754413}
#
#
# Total inference time: 0.492 seconds
# AUC ROC: 0.961806
#
#
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 102
# Train Negative examples: 102
# Test Positive examples: 11
# Test Negative examples: 11
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 82
# Train Negative examples: 82
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), publication(D, B) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else if ( ta(F, A, G) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( publication(D, H), ta(I, H, J), ta(K, C, J) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.8581489350995122;  // std dev = 2,98e-08, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | else if ( ta(L, A, M) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( publication(N, B), publication(N, P), student(P) )
# %   | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   else return -0.14185106490048774;  // std dev = 1,29e-08, 24,000 (wgt'ed) examples reached here.  /* #neg=24 */
#
#
# Results:
# {'AUC PR': 0.926717, 'AUC ROC': 0.946281, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.834833}
#
#
# Total learning time: 3.07 seconds
# Total inference time: 0.522 seconds
# AUC ROC: 0.946281
#
#
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), tempadvisedby(E, D) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995116;  // std dev = 2,15e-07, 32,000 (wgt'ed) examples reached here.  /* #pos=32 */
# %   | | else if ( ta(F, A, G) )
# %   | | | then return 0.8258908705833826;  // std dev = 0,177, 31,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=30 */
# %   | | | else return 0.6816783468642175;  // std dev = 0,381, 34,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=28 */
# %   | else if ( publication(H, A) )
# %   | | then if ( projectmember(I, B), publication(H, J), tempadvisedby(J, K) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( publication(L, B) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( tempadvisedby(M, B), publication(H, N), tempadvisedby(P, N) )
# %   | | | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   else return -0.14185106490048766;  // std dev = 7,45e-08, 87,000 (wgt'ed) examples reached here.  /* #neg=87 */
#
#
# Results:
# {'AUC PR': 0.919153, 'AUC ROC': 0.942149, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.77043}
#
#
# Total learning time: 6.313 seconds
# Total inference time: 0.405 seconds
# AUC ROC: 0.942149
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), publication(D, B) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | | else if ( ta(F, A, G) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | | | else if ( publication(D, H), ta(I, H, J), ta(K, C, J) )
# %   | | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | else if ( ta(L, A, M) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else if ( publication(N, B), publication(N, P), student(P) )
# %   | | | then return 0.7405018762759829;  // std dev = 1,328, 17,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=15 */
# %   | | | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.944405, 'AUC ROC': 0.954545, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.767326}
#
#
# Total learning time: 0.534 seconds
# Total inference time: 0.432 seconds
# AUC ROC: 0.954545
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), publication(D, B) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | | else if ( ta(F, A, G) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | | | else return 0.6081489350995123;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   | else if ( ta(H, A, I) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else if ( publication(J, B), publication(J, K), student(K) )
# %   | | | then return 0.7405018762759829;  // std dev = 1,328, 17,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=15 */
# %   | | | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.944405, 'AUC ROC': 0.954545, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.767326}
#
#
# Total learning time: 0.596 seconds
# Total inference time: 0.512 seconds
# AUC ROC: 0.954545
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), publication(D, B) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | | else if ( ta(F, A, G) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | | | else return 0.6081489350995123;  // std dev = 0,433, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   | else if ( ta(H, A, I) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else if ( publication(J, B), publication(J, K), student(K) )
# %   | | | then return 0.7405018762759829;  // std dev = 1,328, 17,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=15 */
# %   | | | else if ( publication(L, A), publication(L, M), professor(M) )
# %   | | | | then if ( projectmember(N, B) )
# %   | | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.987948, 'AUC ROC': 0.987603, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.721786}
#
#
# Total learning time: 1.388 seconds
# Total inference time: 0.494 seconds
# AUC ROC: 0.987603
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.987603
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), publication(D, B) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | | else if ( ta(F, A, G) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | | | else return 0.6081489350995123;  // std dev = 0,433, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   | else if ( ta(H, A, I) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else if ( publication(J, B), publication(J, K), student(K) )
# %   | | | then return 0.7405018762759829;  // std dev = 1,328, 17,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=15 */
# %   | | | else if ( publication(L, A), publication(L, M), professor(M) )
# %   | | | | then if ( projectmember(N, B) )
# %   | | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.987948, 'AUC ROC': 0.987603, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.721786}
#
#
# Total learning time: 0.6 seconds
# Total inference time: 0.389 seconds
# AUC ROC: 0.987603
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), publication(D, B) )
# %   | then if ( publication(E, A) )
# %   | | then return 0.8164822684328453;  // std dev = 0,979, 24,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=23 */
# %   | | else if ( ta(F, A, G) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | | | else return 0.6081489350995123;  // std dev = 1,225, 8,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=6 */
# %   | else if ( ta(H, A, I) )
# %   | | then return 0.7470378239884012;  // std dev = 1,333, 18,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=16 */
# %   | | else if ( publication(J, B), publication(J, K), student(K) )
# %   | | | then return 0.7405018762759829;  // std dev = 1,328, 17,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=15 */
# %   | | | else if ( publication(L, A), publication(L, M), professor(M) )
# %   | | | | then if ( projectmember(N, B) )
# %   | | | | | then return 0.5248156017661788;  // std dev = 0,471, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | | | else return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.987948, 'AUC ROC': 0.987603, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.721786}
#
#
# Total learning time: 0.723 seconds
# Total inference time: 0.397 seconds
# AUC ROC: 0.987603
#
#
# ******************************************
# ...
# %   else return -0.1418510649004877;  // std dev = 1,83e-08, 25,000 (wgt'ed) examples reached here.  /* #neg=25 */
#
#
# Results:
# {'AUC PR': 0.751581, 'AUC ROC': 0.85124, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.789052}
#
#
# Total learning time: 3.31 seconds
# Total inference time: 0.528 seconds
# AUC ROC: 0.85124
#
#
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995115;  // std dev = 2,60e-07, 38,000 (wgt'ed) examples reached here.  /* #pos=38 */
# %   | | else if ( ta(D, A, E), tempadvisedby(F, B) )
# %   | | | then return 0.8581489350995123;  // std dev = 0,000, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | | | else if ( tempadvisedby(G, B), publication(C, H), ta(I, H, J) )
# %   | | | | then return 0.524815601766179;  // std dev = 0,471, 12,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=8 */
# %   | | | | else return 0.7643989350995117;  // std dev = 0,291, 32,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=29 */
# %   | else if ( publication(K, A), publication(K, L), professor(L) )
# %   | | then if ( tempadvisedby(M, B), tempadvisedby(N, L) )
# %   | | | then return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else return 0.0581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=1 */
# %   | | else if ( tempadvisedby(P, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.6081489350995122;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.14185106490048766;  // std dev = 7,60e-08, 89,000 (wgt'ed) examples reached here.  /* #neg=89 */
#
#
# Results:
# {'AUC PR': 0.904706, 'AUC ROC': 0.900826, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.766737}
#
#
# Total learning time: 4.223 seconds
# Total inference time: 0.508 seconds
# AUC ROC: 0.900826
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995116;  // std dev = 2,06e-07, 31,000 (wgt'ed) examples reached here.  /* #pos=31 */
# %   | | else if ( tempadvisedby(D, B), publication(C, E), ta(F, E, G) )
# %   | | | then if ( publication(H, A) )
# %   | | | | then return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | else return 0.7152917922423694;  // std dev = 1,309, 14,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=12 */
# %   | | | else if ( ta(I, A, J), ta(I, K, J), publication(L, K) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else return 0.7781489350995122;  // std dev = 1,356, 25,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=23 */
# %   | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 6,50e-08, 71,000 (wgt'ed) examples reached here.  /* #neg=71 */
#
#
# Results:
# {'AUC PR': 0.850282, 'AUC ROC': 0.876033, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.771359}
#
#
# Total learning time: 0.756 seconds
# Total inference time: 0.508 seconds
# AUC ROC: 0.876033
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995116;  // std dev = 2,06e-07, 31,000 (wgt'ed) examples reached here.  /* #pos=31 */
# %   | | else if ( tempadvisedby(D, B), publication(C, E), ta(F, E, G) )
# %   | | | then if ( publication(H, A) )
# %   | | | | then return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | else return 0.7152917922423694;  // std dev = 1,309, 14,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=12 */
# %   | | | else if ( ta(I, A, J), ta(I, K, J), publication(L, K) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else return 0.7781489350995122;  // std dev = 1,356, 25,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=23 */
# %   | else if ( projectmember(M, B) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | else if ( publication(N, A), publication(N, P), professor(P) )
# %   | | | then return 0.19148226843284552;  // std dev = 1,155, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   else return -0.14185106490048768;  // std dev = 6,50e-08, 71,000 (wgt'ed) examples reached here.  /* #neg=71 */
#
#
# Results:
# {'AUC PR': 0.698816, 'AUC ROC': 0.81405, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.759073}
#
#
# Total learning time: 1.208 seconds
# Total inference time: 0.502 seconds
# AUC ROC: 0.81405
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995116;  // std dev = 2,06e-07, 31,000 (wgt'ed) examples reached here.  /* #pos=31 */
# %   | | else if ( tempadvisedby(D, B), publication(C, E), ta(F, E, G) )
# %   | | | then if ( publication(H, A) )
# %   | | | | then return 0.3581489350995122;  // std dev = 0,500, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | else return 0.7152917922423694;  // std dev = 1,309, 14,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=12 */
# %   | | | else if ( ta(I, A, J), ta(I, K, J), publication(L, K) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else return 0.7781489350995122;  // std dev = 1,356, 25,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=23 */
# %   | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 6,50e-08, 71,000 (wgt'ed) examples reached here.  /* #neg=71 */
#
#
# Results:
# {'AUC PR': 0.850282, 'AUC ROC': 0.876033, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.771359}
#
#
# Total learning time: 1.278 seconds
# Total inference time: 0.538 seconds
# AUC ROC: 0.876033
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.876033
# ******************************************
#
# ******************************************
# Total revision time: 4.79
# Best validation AUC ROC: 0.876033
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995116;  // std dev = 2,06e-07, 31,000 (wgt'ed) examples reached here.  /* #pos=31 */
# %   | | else if ( tempadvisedby(D, B), publication(C, E), ta(F, E, G) )
# %   | | | then if ( publication(H, A) )
# %   | | | | then return 0.3581489350995122;  // std dev = 0,707, 2,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=1 */
# %   | | | | else return 0.7152917922423694;  // std dev = 1,309, 14,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=12 */
# %   | | | else if ( ta(I, A, J), ta(I, K, J), publication(L, K) )
# %   | | | | then return 0.6914822684328455;  // std dev = 0,913, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | | | else return 0.7781489350995122;  // std dev = 1,356, 25,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=23 */
# %   | else return 0.5248156017661789;  // std dev = 1,826, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   else return -0.14185106490048768;  // std dev = 6,50e-08, 71,000 (wgt'ed) examples reached here.  /* #neg=71 */
#
#
# Results:
# {'AUC PR': 0.850282, 'AUC ROC': 0.876033, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.771359}
#
#
# Total inference time: 0.547 seconds
# AUC ROC: 0.876033
#
#
# Total examples
# Positive examples: 113
# Negative examples: 113
#
#
# Train and test sets from total
# Train Positive examples: 102
# Train Negative examples: 102
# Test Positive examples: 11
# Test Negative examples: 11
#
#
# Small dataset
# Train Positive examples: 30
# Train Negative examples: 30
#
#
# Revision theory train dataset and validation
# Train Positive examples: 82
# Train Negative examples: 82
# Validation Positive examples: 20
# Validation Negative examples: 20
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.8581489350995123;  // std dev = 0,000, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | else if ( publication(E, B), publication(F, A) )
# %   | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | else if ( publication(G, A) )
# %   | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else return 0.8581489350995121;  // std dev = 4,21e-08, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   else return -0.14185106490048774;  // std dev = 1,49e-08, 27,000 (wgt'ed) examples reached here.  /* #neg=27 */
#
#
# Results:
# {'AUC PR': 0.894786, 'AUC ROC': 0.938017, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.739312}
#
#
# Total learning time: 2.128 seconds
# Total inference time: 0.468 seconds
# AUC ROC: 0.938017
#
#
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, D), tempadvisedby(E, D) )
# %   | then if ( publication(C, A) )
# %   | | then return 0.8581489350995116;  // std dev = 2,06e-07, 31,000 (wgt'ed) examples reached here.  /* #pos=31 */
# %   | | else return 0.745245709293061;  // std dev = 0,316, 62,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=55 */
# %   | else if ( publication(F, A), publication(F, G), professor(G) )
# %   | | then if ( ta(H, A, I) )
# %   | | | then return 0.8581489350995121;  // std dev = 2,11e-08, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | | else if ( projectmember(J, B) )
# %   | | | | then return 0.5248156017661788;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | | else if ( tempadvisedby(K, G) )
# %   | | | | | then return 0.10814893509951219;  // std dev = 0,866, 4,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=1 */
# %   | | | | | else return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | else if ( tempadvisedby(L, B) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   else return -0.14185106490048766;  // std dev = 7,60e-08, 88,000 (wgt'ed) examples reached here.  /* #neg=88 */
#
#
# Results:
# {'AUC PR': 0.819115, 'AUC ROC': 0.896694, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.745175}
#
#
# Total learning time: 5.4 seconds
# Total inference time: 0.535 seconds
# AUC ROC: 0.896694
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7993254056877469;  // std dev = 1,372, 34,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=32 */
# %   | else if ( publication(E, B), publication(F, A) )
# %   | | then return 0.7510060779566546;  // std dev = 1,637, 28,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=25 */
# %   | | else if ( publication(G, A) )
# %   | | | then return 0.28672036367094084;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,581, 18,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=15 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.759596, 'AUC ROC': 0.867769, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.741878}
#
#
# Total learning time: 0.622 seconds
# Total inference time: 0.474 seconds
# AUC ROC: 0.867769
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7993254056877469;  // std dev = 1,372, 34,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=32 */
# %   | else if ( publication(E, B), publication(F, A) )
# %   | | then return 0.7510060779566546;  // std dev = 1,637, 28,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=25 */
# %   | | else if ( publication(G, A) )
# %   | | | then if ( tempadvisedby(H, B) )
# %   | | | | then return 0.19148226843284552;  // std dev = 0,816, 3,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=1 */
# %   | | | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   | | | else if ( tempadvisedby(I, B), ta(J, I, K) )
# %   | | | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,581, 18,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=15 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.759596, 'AUC ROC': 0.867769, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.741878}
#
#
# Total learning time: 0.89 seconds
# Total inference time: 0.504 seconds
# AUC ROC: 0.867769
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.867769
# ******************************************
#
# ******************************************
# Total revision time: 2.49
# Best validation AUC ROC: 0.867769
# WILL-Produced Tree:
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( ta(C, A, D) )
# %   | then return 0.7993254056877469;  // std dev = 1,372, 34,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=32 */
# %   | else if ( publication(E, B), publication(F, A) )
# %   | | then return 0.7510060779566546;  // std dev = 1,637, 28,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=25 */
# %   | | else if ( publication(G, A) )
# %   | | | then return 0.28672036367094084;  // std dev = 1,309, 7,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=3 */
# %   | | | else if ( tempadvisedby(H, B), ta(I, H, J) )
# %   | | | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | | else return 0.6914822684328455;  // std dev = 1,581, 18,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=15 */
# %   else return -0.14185106490048766;  // std dev = 6,83e-08, 70,000 (wgt'ed) examples reached here.  /* #neg=70 */
#
#
# Results:
# {'AUC PR': 0.759596, 'AUC ROC': 0.867769, 'Recall': 0.0, 'F1': nan, 'Precision': [nan, 0.5], 'CLL': -0.741878}
#
#
# Total inference time: 0.527 seconds
# AUC ROC: 0.867769

# %%
small_dataset_aucroc
# Out:
# [0.947917,
#  0.895833,
#  0.78125,
#  0.946281,
#  1.0,
#  0.81405,
#  0.880165,
#  1.0,
#  0.85124,
#  0.938017]

# %%
complete_dataset_aucroc
# Out:
# [0.916667,
#  0.947917,
#  0.927083,
#  0.942149,
#  1.0,
#  0.938017,
#  0.838843,
#  0.909091,
#  0.900826,
#  0.896694]

# %%
revision_dataset_aucroc
# Out:
# [0.975694,
#  0.920139,
#  0.961806,
#  0.987603,
#  1.0,
#  0.938017,
#  0.904959,
#  1.0,
#  0.876033,
#  0.867769]

# %%
print('Small dataset AUC ROC: %s +/- %s' % ((np.array(small_dataset_aucroc)).mean(), (np.array(small_dataset_aucroc)).std()))
print('Complete dataset AUC ROC: %s +/- %s' % ((np.array(complete_dataset_aucroc)).mean(), (np.array(complete_dataset_aucroc)).std()))
print('Theory revision dataset AUC ROC: %s +/- %s' % ((np.array(revision_dataset_aucroc)).mean(), (np.array(revision_dataset_aucroc)).std()))
# Out:
# Small dataset AUC ROC: 0.9054753 +/- 0.07061215670980459
# Complete dataset AUC ROC: 0.9217287000000001 +/- 0.03955024647470607
# Theory revision dataset AUC ROC: 0.9432020000000001 +/- 0.046955764909114205

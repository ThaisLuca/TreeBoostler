# %%
from datasets.get_datasets import *
from revision import *
from boostsrl import boostsrl
import random
from sklearn.model_selection import KFold

# %% [markdown]
# ## Parameters

# %%
target = 'hasacademicadvisor'
#test_size = 0.3
small_train_size = 0.3
validation_size = 0.2
revision_threshold = 0.8
max_revision_iterations = 10

# %% [markdown]
# ## Dataset

# %%
[facts, pos, neg] = get_yago2s_dataset(target, acceptedPredicates=[
'hascurrency',
'hascapital',
'hasacademicadvisor',
'participatedin',
'haswonprize',
'participatedin',
'owns',
'isinterestedin',
'livesin',
'happenedin',
'holdspoliticalposition',
'diedin',
'actedin',
'iscitizenof',
'worksat',
'directed',
'dealswith',
'wasbornin',
'created',
'isleaderof',
'haschild',
'ismarriedto',
'imports',
'hasmusicalrole',
'influences',
'isaffiliatedto',
'isknownfor',
'ispoliticianof',
'graduatedfrom',
'exports',
'edited',
'wrotemusicfor'
])

# %% [markdown]
# ## Background  configuration

# %%
bk = ['hascurrency(+place,+currency).',
'hascurrency(+place,-currency).',
'hascurrency(-place,+currency).',
'hascapital(+place,+place).',
'hascapital(+place,-place).',
'hascapital(-place,+place).',
'hasacademicadvisor(+person,+person).',
'hasacademicadvisor(+person,-person).',
'hasacademicadvisor(-person,+person).',
'haswonprize(+person,+prize).',
'haswonprize(+person,-prize).',
'haswonprize(-person,+prize).',
'participatedin(+place,+event).',
'participatedin(+place,-event).',
'participatedin(-place,+event).',
'owns(+institution,+institution).',
'owns(+institution,-institution).',
'owns(-institution,+institution).',
'isinterestedin(+person,+concept).',
'isinterestedin(+person,-concept).',
'isinterestedin(-person,+concept).',
'livesin(+person,+place).',
'livesin(+person,-place).',
'livesin(-person,+place).',
'happenedin(+event,+place).',
'happenedin(+event,-place).',
'happenedin(-event,+place).',
'holdspoliticalposition(+person,+politicalposition).',
'holdspoliticalposition(+person,-politicalposition).',
'holdspoliticalposition(-person,+politicalposition).',
'diedin(+person,+place).',
'diedin(+person,-place).',
'diedin(-person,+place).',
'actedin(+person,+media).',
'actedin(+person,-media).',
'actedin(-person,+media).',
'iscitizenof(+person,+place).',
'iscitizenof(+person,-place).',
'iscitizenof(-person,+place).',
'worksat(+person,+institution).',
'worksat(+person,-institution).',
'worksat(-person,+institution).',
'directed(+person,+media).',
'directed(+person,-media).',
'directed(-person,+media).',
'dealswith(+place,+place).',
'dealswith(+place,-place).',
'dealswith(-place,+place).',
'wasbornin(+person,+place).',
'wasbornin(+person,-place).',
'wasbornin(-person,+place).',
'created(+person,+media).',
'created(+person,-media).',
'created(-person,+media).',
'isleaderof(+person,+place).',
'isleaderof(+person,-place).',
'isleaderof(-person,+place).',
'haschild(+person,+person).',
'haschild(+person,-person).',
'haschild(-person,+person).',
'ismarriedto(+person,+person).',
'ismarriedto(+person,-person).',
'ismarriedto(-person,+person).',
'imports(+person,+material).',
'imports(+person,-material).',
'imports(-person,+material).',
'hasmusicalrole(+person,+musicalrole).',
'hasmusicalrole(+person,-musicalrole).',
'hasmusicalrole(-person,+musicalrole).',
'influences(+person,+person).',
'influences(+person,-person).',
'influences(-person,+person).',
'isaffiliatedto(+person,+team).',
'isaffiliatedto(+person,-team).',
'isaffiliatedto(-person,+team).',
'isknownfor(+person,+theory).',
'isknownfor(+person,-theory).',
'isknownfor(-person,+theory).',
'ispoliticianof(+person,+place).',
'ispoliticianof(+person,-place).',
'ispoliticianof(-person,+place).',
'graduatedfrom(+person,+institution).',
'graduatedfrom(+person,-institution).',
'graduatedfrom(-person,+institution).',
'exports(+place,+material).',
'exports(+place,-material).',
'exports(-place,+material).',
'edited(+person,+media).',
'edited(+person,-media).',
'edited(-person,+media).',
'wrotemusicfor(+person,+media).',
'wrotemusicfor(+person,-media).',
'wrotemusicfor(-person,+media).']

background = boostsrl.modes(bk, [target], useStdLogicVariables=False, treeDepth=8, nodeSize=3, numOfClauses=8)

# %% [markdown]
# ## Sampling examples

# %%
# shuffle all examples
random.shuffle(pos)
random.shuffle(neg)

neg = neg[:len(pos)] # balanced

import numpy as np
pos = np.array(pos)
neg = np.array(neg)
small_dataset_aucroc = []
complete_dataset_aucroc = []
revision_dataset_aucroc = []


# separate train and test
kf = KFold(n_splits=10)
for train_index, test_index in kf.split(pos):
    train_pos, test_pos = pos[train_index], pos[test_index]
    train_neg, test_neg = neg[train_index], neg[test_index]

    # learn from scratch in a small dataset
    s_train_pos = train_pos[:int(small_train_size*len(train_pos))]
    s_train_neg = train_neg[:int(small_train_size*len(train_neg))]

    # shuffle all train examples
    random.shuffle(train_pos)
    random.shuffle(train_neg)

    # train set used in revision and validation set
    r_train_pos = train_pos[int(validation_size*len(train_pos)):]
    r_train_neg = train_neg[int(validation_size*len(train_neg)):]
    validation_pos = train_pos[:int(validation_size*len(train_pos))]
    validation_neg = train_neg[:int(validation_size*len(train_neg))]

    print('Total examples')
    print('Positive examples: %s' % len(pos))
    print('Negative examples: %s' % len(neg))
    print('\n')
    print('Train and test sets from total')
    print('Train Positive examples: %s' % len(train_pos))
    print('Train Negative examples: %s' % len(train_neg))
    print('Test Positive examples: %s' % len(test_pos))
    print('Test Negative examples: %s' % len(test_neg))
    print('\n')
    print('Small dataset')
    print('Train Positive examples: %s' % len(s_train_pos))
    print('Train Negative examples: %s' % len(s_train_neg))
    print('\n')
    print('Revision theory train dataset and validation')
    print('Train Positive examples: %s' % len(r_train_pos))
    print('Train Negative examples: %s' % len(r_train_neg))
    print('Validation Positive examples: %s' % len(validation_pos))
    print('Validation Negative examples: %s' % len(validation_neg))
    
    # learning from small dataset
    delete_model_files()
    model = boostsrl.train(background, s_train_pos, s_train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    small_dataset_aucroc.append(t_results['AUC ROC'])
    
    # learning from complete dataset
    delete_model_files()
    model = boostsrl.train(background, train_pos, train_neg, facts)
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    #structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    complete_dataset_aucroc.append(t_results['AUC ROC'])
    
    # theory revision
    total_revision_time = 0
    best_aucroc = 0
    best_structured = None

    print('Performing parameter learning')
    print('******************************************')
    delete_model_files()
    model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=get_refine_file(structured))
    learning_time = model.traintime()
    will = model.get_will_produced_tree()
    structured = model.get_structured_tree().copy()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    total_revision_time += learning_time + inference_time
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total learning time: %s seconds' % learning_time)
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)

    best_aucroc = t_results['AUC ROC']
    best_structured = structured.copy()
    save_model_files()

    for i in range(max_revision_iterations):
        print('Refining iteration %s' % str(i+1))
        print('******************************************')
        found_better = False
        for candidate in get_cantidates(best_structured, revision_threshold):
            print('Refining node candidate')
            print('******************************************')
            delete_model_files()
            model = boostsrl.train(background, r_train_pos, r_train_neg, facts, refine=candidate)
            learning_time = model.traintime()
            will = model.get_will_produced_tree()
            results = boostsrl.test(model, test_pos, test_neg, facts)
            inference_time = results.testtime()
            t_results = results.summarize_results()
            total_revision_time += learning_time + inference_time
            print('WILL-Produced Tree:')
            print_will_produced_tree(will)
            print('\n')
            print('Results:')
            print(t_results)
            print('\n')
            print('Total learning time: %s seconds' % learning_time)
            print('Total inference time: %s seconds' % inference_time)
            print('AUC ROC: %s' % t_results['AUC ROC'])
            print('\n')
            #print('Tree:')
            #model.tree(0, target, image=True)
            print('******************************************')

            if t_results['AUC ROC'] > best_aucroc:
                found_better = True
                best_aucroc = t_results['AUC ROC']
                best_structured = model.get_structured_tree().copy()
                save_model_files()
        print('Best Tree AUC ROC so far: %s' % best_aucroc)
        print('******************************************\n')
        if found_better == False:
            break

    print('******************************************')
    delete_model_files()
    get_saved_model_files()
    delete_test_files()
    print('Total revision time: %s' % total_revision_time)
    print('Best validation AUC ROC: %s' % best_aucroc)
    will = model.get_will_produced_tree()
    results = boostsrl.test(model, test_pos, test_neg, facts)
    inference_time = results.testtime()
    t_results = results.summarize_results()
    print('WILL-Produced Tree:')
    print_will_produced_tree(will)
    print('\n')
    print('Results:')
    print(t_results)
    print('\n')
    print('Total inference time: %s seconds' % inference_time)
    print('AUC ROC: %s' % t_results['AUC ROC'])
    print('\n')
    #print('Tree:')
    #model.tree(0, target, image=True)
    revision_dataset_aucroc.append(t_results['AUC ROC'])
# Out:
# Total examples
# Positive examples: 2895
# Negative examples: 2895
#
#
# Train and test sets from total
# Train Positive examples: 2605
# Train Negative examples: 2605
# Test Positive examples: 290
# Test Negative examples: 290
#
#
# Small dataset
# Train Positive examples: 781
# Train Negative examples: 781
#
#
# Revision theory train dataset and validation
# Train Positive examples: 2084
# Train Negative examples: 2084
# Validation Positive examples: 521
# Validation Negative examples: 521
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.5378364350995104;  // std dev = 0,467, 128,000 (wgt'ed) examples reached here.  /* #neg=41 #pos=87 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.7914822684328456;  // std dev = 0,249, 15,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=14 */
# %   | | else if ( diedin(H, F), influences(H, K), wasbornin(H, L) )
# %   | | | then return 0.04419544672741935;  // std dev = 0,389, 86,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=16 */
# %   | | | else return 0.28805547715558616;  // std dev = 0,495, 107,000 (wgt'ed) examples reached here.  /* #neg=61 #pos=46 */
# %   | else if ( haswonprize(B, M), haswonprize(A, M) )
# %   | | then return 0.7748156017661788;  // std dev = 0,276, 48,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=44 */
# %   | | else if ( wasbornin(A, N), happenedin(P, N), worksat(B, Q) )
# %   | | | then return 0.1460277229783002;  // std dev = 0,453, 66,000 (wgt'ed) examples reached here.  /* #neg=47 #pos=19 */
# %   | | | else if ( worksat(B, R), graduatedfrom(A, R) )
# %   | | | | then return 0.8581489350995123;  // std dev = 8,43e-08, 53,000 (wgt'ed) examples reached here.  /* #pos=53 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995123;  // std dev = 0,000, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | | | else return 0.3286812544911425;  // std dev = 16,189, 1.052,000 (wgt'ed) examples reached here.  /* #neg=557 #pos=495 */
#
#
# Results:
# {'CLL': -0.912756, 'Recall': 0.0, 'AUC ROC': 0.596873, 'AUC PR': 0.660474, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 239.18200000000002 seconds
# Total inference time: 55.044 seconds
# AUC ROC: 0.596873
#
#
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), diedin(D, E) )
# %   then if ( diedin(A, F), graduatedfrom(B, G), happenedin(H, E) )
# %   | then return 0.6951054568386422;  // std dev = 0,369, 92,000 (wgt'ed) examples reached here.  /* #neg=15 #pos=77 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995118;  // std dev = 1,58e-07, 27,000 (wgt'ed) examples reached here.  /* #pos=27 */
# %   | | else return 0.4029919844268623;  // std dev = 0,498, 446,000 (wgt'ed) examples reached here.  /* #neg=203 #pos=243 */
# %   else if ( iscitizenof(B, I), iscitizenof(A, I) )
# %   | then return 0.7414088469937812;  // std dev = 0,321, 454,000 (wgt'ed) examples reached here.  /* #neg=53 #pos=401 */
# %   | else if ( iscitizenof(A, J), dealswith(K, J), livesin(L, K) )
# %   | | then return 0.24039531191110156;  // std dev = 0,486, 1.656,000 (wgt'ed) examples reached here.  /* #neg=1.023 #pos=633 */
# %   | | else if ( graduatedfrom(B, M), graduatedfrom(A, M) )
# %   | | | then return 0.7506220533790815;  // std dev = 0,310, 93,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=83 */
# %   | | | else if ( haswonprize(B, N), haswonprize(A, N) )
# %   | | | | then return 0.7993254056877476;  // std dev = 0,235, 51,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=48 */
# %   | | | | else if ( haswonprize(A, P), haswonprize(Q, P), haschild(Q, R) )
# %   | | | | | then return 0.20837934984605716;  // std dev = 7,027, 217,000 (wgt'ed) examples reached here.  /* #neg=141 #pos=76 */
# %   | | | | | else return 0.32595022304798954;  // std dev = 23,265, 2.174,000 (wgt'ed) examples reached here.  /* #neg=1.157 #pos=1.017 */
#
#
# Results:
# {'CLL': -0.908042, 'Recall': 0.0, 'AUC ROC': 0.658936, 'AUC PR': 0.686024, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 364.758 seconds
# Total inference time: 55.374 seconds
# AUC ROC: 0.658936
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.8126943896449664;  // std dev = 1,382, 44,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=42 */
# %   | | else if ( diedin(H, F), influences(H, K), wasbornin(H, L) )
# %   | | | then return 0.1810188902564644;  // std dev = 6,982, 223,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=72 */
# %   | | | else return 0.2665996393248627;  // std dev = 8,284, 284,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=116 */
# %   | else if ( haswonprize(B, M), haswonprize(A, M) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, N), happenedin(P, N), worksat(B, Q) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, R), graduatedfrom(A, R) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else return 0.31419096662314994;  // std dev = 26,613, 2.855,000 (wgt'ed) examples reached here.  /* #neg=1.553 #pos=1.302 */
#
#
# Results:
# {'CLL': -0.91095, 'Recall': 0.0, 'AUC ROC': 0.608312, 'AUC PR': 0.667862, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 61.513 seconds
# Total inference time: 55.818 seconds
# AUC ROC: 0.608312
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 0,476, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.8126943896449664;  // std dev = 1,382, 44,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=42 */
# %   | | else if ( diedin(H, F), influences(H, K), wasbornin(H, L) )
# %   | | | then return 0.1810188902564644;  // std dev = 6,982, 223,000 (wgt'ed) examples reached here.  /* #neg=151 #pos=72 */
# %   | | | else return 0.2665996393248627;  // std dev = 8,284, 284,000 (wgt'ed) examples reached here.  /* #neg=168 #pos=116 */
# %   | else if ( haswonprize(B, M), haswonprize(A, M) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, N), happenedin(P, N), worksat(B, Q) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, R), graduatedfrom(A, R) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else return 0.31419096662314994;  // std dev = 26,613, 2.855,000 (wgt'ed) examples reached here.  /* #neg=1.553 #pos=1.302 */
#
#
# Results:
# {'CLL': -0.91095, 'Recall': 0.0, 'AUC ROC': 0.608312, 'AUC PR': 0.667862, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 60.579 seconds
# Total inference time: 81.701 seconds
# AUC ROC: 0.608312
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then return 0.2755718026131195;  // std dev = 0,493, 551,000 (wgt'ed) examples reached here.  /* #neg=321 #pos=230 */
# %   | else if ( haswonprize(B, I), haswonprize(A, I) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, J), happenedin(K, J), worksat(B, L) )
# %   | | | then if ( worksat(A, M), iscitizenof(B, N), dealswith(N, P) )
# %   | | | | then return 0.6081489350995117;  // std dev = 0,433, 28,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=21 */
# %   | | | | else if ( haswonprize(B, Q), wasbornin(B, R), graduatedfrom(A, S) )
# %   | | | | | then return 0.7152917922423694;  // std dev = 1,309, 14,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=12 */
# %   | | | | | else return 0.28870449065506776;  // std dev = 5,942, 144,000 (wgt'ed) examples reached here.  /* #neg=82 #pos=62 */
# %   | | | else if ( worksat(B, T), graduatedfrom(A, T) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else return 0.31419096662314994;  // std dev = 26,613, 2.855,000 (wgt'ed) examples reached here.  /* #neg=1.553 #pos=1.302 */
#
#
# Results:
# {'CLL': -0.913778, 'Recall': 0.0, 'AUC ROC': 0.584887, 'AUC PR': 0.650718, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 68.041 seconds
# Total inference time: 54.766 seconds
# AUC ROC: 0.584887
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.8126943896449664;  // std dev = 1,382, 44,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=42 */
# %   | | else return 0.2289576136004965;  // std dev = 0,483, 507,000 (wgt'ed) examples reached here.  /* #neg=319 #pos=188 */
# %   | else if ( haswonprize(B, K), haswonprize(A, K) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, L), happenedin(M, L), worksat(B, N) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, P), graduatedfrom(A, P) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else if ( livesin(B, Q), livesin(A, Q) )
# %   | | | | | | then return 0.7593835030007475;  // std dev = 2,685, 81,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=73 */
# %   | | | | | | else return 0.3011914729509854;  // std dev = 26,163, 2.774,000 (wgt'ed) examples reached here.  /* #neg=1.545 #pos=1.229 */
#
#
# Results:
# {'CLL': -0.907567, 'Recall': 0.0, 'AUC ROC': 0.620559, 'AUC PR': 0.680656, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 376.709 seconds
# Total inference time: 54.747 seconds
# AUC ROC: 0.620559
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.8126943896449664;  // std dev = 1,382, 44,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=42 */
# %   | | else return 0.2289576136004965;  // std dev = 10,876, 507,000 (wgt'ed) examples reached here.  /* #neg=319 #pos=188 */
# %   | else if ( haswonprize(B, K), haswonprize(A, K) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, L), happenedin(M, L), worksat(B, N) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, P), graduatedfrom(A, P) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else return 0.31419096662314994;  // std dev = 26,613, 2.855,000 (wgt'ed) examples reached here.  /* #neg=1.553 #pos=1.302 */
#
#
# Results:
# {'CLL': -0.910573, 'Recall': 0.0, 'AUC ROC': 0.608514, 'AUC PR': 0.667915, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 65.174 seconds
# Total inference time: 82.054 seconds
# AUC ROC: 0.608514
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.620559
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.8126943896449664;  // std dev = 1,382, 44,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=42 */
# %   | | else return 0.2289576136004965;  // std dev = 0,483, 507,000 (wgt'ed) examples reached here.  /* #neg=319 #pos=188 */
# %   | else if ( haswonprize(B, K), haswonprize(A, K) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, L), happenedin(M, L), worksat(B, N) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, P), graduatedfrom(A, P) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else if ( livesin(B, Q), livesin(A, Q) )
# %   | | | | | | then return 0.7593835030007475;  // std dev = 2,685, 81,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=73 */
# %   | | | | | | else return 0.3011914729509854;  // std dev = 26,163, 2.774,000 (wgt'ed) examples reached here.  /* #neg=1.545 #pos=1.229 */
#
#
# Results:
# {'CLL': -0.907567, 'Recall': 0.0, 'AUC ROC': 0.620559, 'AUC PR': 0.680656, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 90.43299999999999 seconds
# Total inference time: 54.908 seconds
# AUC ROC: 0.620559
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 0,476, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.8126943896449664;  // std dev = 1,382, 44,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=42 */
# %   | | else return 0.2289576136004965;  // std dev = 10,876, 507,000 (wgt'ed) examples reached here.  /* #neg=319 #pos=188 */
# %   | else if ( haswonprize(B, K), haswonprize(A, K) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, L), happenedin(M, L), worksat(B, N) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, P), graduatedfrom(A, P) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else if ( livesin(B, Q), livesin(A, Q) )
# %   | | | | | | then return 0.7593835030007475;  // std dev = 2,685, 81,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=73 */
# %   | | | | | | else return 0.3011914729509854;  // std dev = 26,163, 2.774,000 (wgt'ed) examples reached here.  /* #neg=1.545 #pos=1.229 */
#
#
# Results:
# {'CLL': -0.907567, 'Recall': 0.0, 'AUC ROC': 0.620559, 'AUC PR': 0.680656, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 62.655 seconds
# Total inference time: 84.332 seconds
# AUC ROC: 0.620559
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then return 0.2755718026131195;  // std dev = 0,493, 551,000 (wgt'ed) examples reached here.  /* #neg=321 #pos=230 */
# %   | else if ( haswonprize(B, I), haswonprize(A, I) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, J), happenedin(K, J), worksat(B, L) )
# %   | | | then if ( worksat(A, M), iscitizenof(B, N), iscitizenof(A, N) )
# %   | | | | then return 0.7331489350995123;  // std dev = 0,331, 16,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=14 */
# %   | | | | else if ( diedin(B, P), diedin(Q, P), livesin(Q, P) )
# %   | | | | | then return 0.5551186320692085;  // std dev = 2,640, 33,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=23 */
# %   | | | | | else return 0.28150659933308986;  // std dev = 5,783, 137,000 (wgt'ed) examples reached here.  /* #neg=79 #pos=58 */
# %   | | | else if ( worksat(B, R), graduatedfrom(A, R) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else return 0.31419096662314994;  // std dev = 0,498, 2.855,000 (wgt'ed) examples reached here.  /* #neg=1.553 #pos=1.302 */
#
#
# Results:
# {'CLL': -0.913336, 'Recall': 0.0, 'AUC ROC': 0.590452, 'AUC PR': 0.656969, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 122.303 seconds
# Total inference time: 56.66 seconds
# AUC ROC: 0.590452
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then return 0.2755718026131195;  // std dev = 0,493, 551,000 (wgt'ed) examples reached here.  /* #neg=321 #pos=230 */
# %   | else if ( haswonprize(B, I), haswonprize(A, I) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, J), happenedin(K, J), worksat(B, L) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, M), graduatedfrom(A, M) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else if ( livesin(B, N), livesin(A, N) )
# %   | | | | | | then return 0.7593835030007475;  // std dev = 2,685, 81,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=73 */
# %   | | | | | | else if ( livesin(A, P), isleaderof(Q, P), graduatedfrom(A, R) )
# %   | | | | | | | then return 0.2229783314249675;  // std dev = 9,396, 381,000 (wgt'ed) examples reached here.  /* #neg=242 #pos=139 */
# %   | | | | | | | else return 0.3136441294162652;  // std dev = 24,362, 2.393,000 (wgt'ed) examples reached here.  /* #neg=1.303 #pos=1.090 */
#
#
# Results:
# {'CLL': -0.911142, 'Recall': 0.0, 'AUC ROC': 0.610499, 'AUC PR': 0.671418, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 210.09199999999998 seconds
# Total inference time: 53.677 seconds
# AUC ROC: 0.610499
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.620559
# ******************************************
#
# ******************************************
# Total revision time: 1696.1620000000003
# Best validation AUC ROC: 0.620559
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( diedin(B, C), diedin(A, D), livesin(E, D) )
# %   then return 0.509906123597911;  // std dev = 8,429, 313,000 (wgt'ed) examples reached here.  /* #neg=109 #pos=204 */
# %   else if ( diedin(A, F), diedin(G, F), influences(G, H) )
# %   | then if ( iscitizenof(B, I), iscitizenof(A, I), livesin(J, F) )
# %   | | then return 0.8126943896449664;  // std dev = 1,382, 44,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=42 */
# %   | | else return 0.2289576136004965;  // std dev = 0,483, 507,000 (wgt'ed) examples reached here.  /* #neg=319 #pos=188 */
# %   | else if ( haswonprize(B, K), haswonprize(A, K) )
# %   | | then return 0.7875606998053944;  // std dev = 2,361, 85,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=79 */
# %   | | else if ( wasbornin(A, L), happenedin(M, L), worksat(B, N) )
# %   | | | then return 0.36890162327155235;  // std dev = 6,818, 186,000 (wgt'ed) examples reached here.  /* #neg=91 #pos=95 */
# %   | | | else if ( worksat(B, P), graduatedfrom(A, P) )
# %   | | | | then return 0.8318331456258257;  // std dev = 1,974, 152,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=148 */
# %   | | | | else if ( influences(B, A) )
# %   | | | | | then return 0.8581489350995118;  // std dev = 1,46e-07, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | | | | | else if ( livesin(B, Q), livesin(A, Q) )
# %   | | | | | | then return 0.7593835030007475;  // std dev = 2,685, 81,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=73 */
# %   | | | | | | else return 0.3011914729509854;  // std dev = 26,163, 2.774,000 (wgt'ed) examples reached here.  /* #neg=1.545 #pos=1.229 */
#
#
# Results:
# {'CLL': -0.907567, 'Recall': 0.0, 'AUC ROC': 0.620559, 'AUC PR': 0.680656, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total inference time: 80.91499999999999 seconds
# AUC ROC: 0.620559
#
#
# Total examples
# Positive examples: 2895
# Negative examples: 2895
#
#
# Train and test sets from total
# Train Positive examples: 2605
# Train Negative examples: 2605
# Test Positive examples: 290
# Test Negative examples: 290
#
#
# Small dataset
# Train Positive examples: 781
# Train Negative examples: 781
#
#
# Revision theory train dataset and validation
# Train Positive examples: 2084
# Train Negative examples: 2084
# Validation Positive examples: 521
# Validation Negative examples: 521
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), iscitizenof(C, D), hascapital(D, E) )
# %   then if ( livesin(A, D), iscitizenof(A, F) )
# %   | then return 0.8581489350995123;  // std dev = 0,000, 12,000 (wgt'ed) examples reached here.  /* #pos=12 */
# %   | else if ( exports(D, G), iscitizenof(B, H), happenedin(I, H) )
# %   | | then return 0.3420199028414466;  // std dev = 0,500, 62,000 (wgt'ed) examples reached here.  /* #neg=32 #pos=30 */
# %   | | else return 0.5470378239884016;  // std dev = 0,463, 90,000 (wgt'ed) examples reached here.  /* #neg=28 #pos=62 */
# %   else if ( graduatedfrom(B, J), iscitizenof(B, K), iscitizenof(A, K) )
# %   | then return 0.7168445872734247;  // std dev = 0,348, 92,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=79 */
# %   | else if ( iscitizenof(A, L), livesin(B, L) )
# %   | | then return 0.6816783468642175;  // std dev = 0,381, 34,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=28 */
# %   | | else if ( iscitizenof(A, M), worksat(B, N), graduatedfrom(A, N) )
# %   | | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | | else if ( iscitizenof(A, P), iscitizenof(B, P) )
# %   | | | | then return 0.6706489350995116;  // std dev = 0,390, 32,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=26 */
# %   | | | | else if ( iscitizenof(A, Q), worksat(B, R), graduatedfrom(S, R) )
# %   | | | | | then return 0.10033643509951119;  // std dev = 4,847, 128,000 (wgt'ed) examples reached here.  /* #neg=97 #pos=31 */
# %   | | | | | else return 0.3096141365647095;  // std dev = 16,445, 1.092,000 (wgt'ed) examples reached here.  /* #neg=599 #pos=493 */
#
#
# Results:
# {'CLL': -0.906091, 'Recall': 0.0, 'AUC ROC': 0.669346, 'AUC PR': 0.672999, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 824.861 seconds
# Total inference time: 53.167 seconds
# AUC ROC: 0.669346
#
#
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( graduatedfrom(B, C), graduatedfrom(A, C) )
# %   then return 0.786076863027437;  // std dev = 0,259, 222,000 (wgt'ed) examples reached here.  /* #neg=16 #pos=206 */
# %   else if ( influences(B, D), influences(A, E) )
# %   | then return 0.6349346493852251;  // std dev = 0,416, 112,000 (wgt'ed) examples reached here.  /* #neg=25 #pos=87 */
# %   | else if ( influences(B, F), diedin(B, G), haswonprize(A, H) )
# %   | | then return 0.5907070746343968;  // std dev = 0,443, 86,000 (wgt'ed) examples reached here.  /* #neg=23 #pos=63 */
# %   | | else if ( influences(A, I), influences(J, I), graduatedfrom(J, K) )
# %   | | | then if ( diedin(B, L), diedin(M, L), worksat(M, K) )
# %   | | | | then return 0.8581489350995123;  // std dev = 0,000, 11,000 (wgt'ed) examples reached here.  /* #pos=11 */
# %   | | | | else return 0.1648716241751427;  // std dev = 0,461, 238,000 (wgt'ed) examples reached here.  /* #neg=165 #pos=73 */
# %   | | | else if ( haswonprize(B, N), haswonprize(P, N), created(P, Q) )
# %   | | | | then if ( haswonprize(A, N) )
# %   | | | | | then return 0.7820619785777726;  // std dev = 2,543, 92,000 (wgt'ed) examples reached here.  /* #neg=7 #pos=85 */
# %   | | | | | else return 0.3557702481347121;  // std dev = 16,209, 1.051,000 (wgt'ed) examples reached here.  /* #neg=528 #pos=523 */
# %   | | | | else if ( haswonprize(A, R), haswonprize(S, R), diedin(S, T) )
# %   | | | | | then return 0.23334516743859723;  // std dev = 12,220, 637,000 (wgt'ed) examples reached here.  /* #neg=398 #pos=239 */
# %   | | | | | else return 0.3355122092755306;  // std dev = 26,246, 2.761,000 (wgt'ed) examples reached here.  /* #neg=1.443 #pos=1.318 */
#
#
# Results:
# {'CLL': -0.916811, 'Recall': 0.0, 'AUC ROC': 0.602218, 'AUC PR': 0.64099, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 994.774 seconds
# Total inference time: 53.078 seconds
# AUC ROC: 0.602218
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), iscitizenof(C, D), hascapital(D, E) )
# %   then if ( livesin(A, D), iscitizenof(A, F) )
# %   | then return 0.5618526388032159;  // std dev = 2,373, 27,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=19 */
# %   | else if ( exports(D, G), iscitizenof(B, H), happenedin(I, H) )
# %   | | then return 0.3697768420762539;  // std dev = 6,556, 172,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=88 */
# %   | | else return 0.49636031721333074;  // std dev = 7,537, 246,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=157 */
# %   else if ( graduatedfrom(B, J), iscitizenof(B, K), iscitizenof(A, K) )
# %   | then return 0.7188046728044268;  // std dev = 5,409, 244,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=210 */
# %   | else if ( iscitizenof(A, L), livesin(B, L) )
# %   | | then return 0.601392178342756;  // std dev = 3,758, 74,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=55 */
# %   | | else if ( iscitizenof(A, M), worksat(B, N), graduatedfrom(A, N) )
# %   | | | then return 0.8581489350995117;  // std dev = 2,46e-07, 41,000 (wgt'ed) examples reached here.  /* #pos=41 */
# %   | | | else if ( iscitizenof(A, P), iscitizenof(B, P) )
# %   | | | | then return 0.7369368138873902;  // std dev = 3,247, 99,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=87 */
# %   | | | | else if ( iscitizenof(A, Q), worksat(B, R), graduatedfrom(S, R) )
# %   | | | | | then return 0.1053711573217341;  // std dev = 8,185, 360,000 (wgt'ed) examples reached here.  /* #neg=271 #pos=89 */
# %   | | | | | else return 0.318734133034103;  // std dev = 26,865, 2.905,000 (wgt'ed) examples reached here.  /* #neg=1.567 #pos=1.338 */
#
#
# Results:
# {'CLL': -0.905249, 'Recall': 0.0, 'AUC ROC': 0.670963, 'AUC PR': 0.696717, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 57.092 seconds
# Total inference time: 55.633 seconds
# AUC ROC: 0.670963
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), iscitizenof(C, D), hascapital(D, E) )
# %   then if ( livesin(A, D), iscitizenof(A, F) )
# %   | then return 0.5618526388032159;  // std dev = 2,373, 27,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=19 */
# %   | else if ( exports(D, G), iscitizenof(B, H), happenedin(I, H) )
# %   | | then return 0.3697768420762539;  // std dev = 6,556, 172,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=88 */
# %   | | else return 0.49636031721333074;  // std dev = 7,537, 246,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=157 */
# %   else if ( graduatedfrom(B, J), iscitizenof(B, K), iscitizenof(A, K) )
# %   | then return 0.7188046728044268;  // std dev = 5,409, 244,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=210 */
# %   | else if ( iscitizenof(A, L), livesin(B, L) )
# %   | | then return 0.601392178342756;  // std dev = 3,758, 74,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=55 */
# %   | | else if ( iscitizenof(A, M), worksat(B, N), graduatedfrom(A, N) )
# %   | | | then return 0.8581489350995117;  // std dev = 2,46e-07, 41,000 (wgt'ed) examples reached here.  /* #pos=41 */
# %   | | | else if ( iscitizenof(A, P), iscitizenof(B, P) )
# %   | | | | then return 0.7369368138873902;  // std dev = 3,247, 99,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=87 */
# %   | | | | else return 0.2952086594486651;  // std dev = 28,343, 3.265,000 (wgt'ed) examples reached here.  /* #neg=1.838 #pos=1.427 */
#
#
# Results:
# {'CLL': -0.911595, 'Recall': 0.0, 'AUC ROC': 0.623567, 'AUC PR': 0.676599, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 61.884 seconds
# Total inference time: 87.936 seconds
# AUC ROC: 0.623567
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), iscitizenof(C, D), hascapital(D, E) )
# %   then if ( livesin(A, D), iscitizenof(A, F) )
# %   | then return 0.5618526388032159;  // std dev = 2,373, 27,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=19 */
# %   | else if ( exports(D, G), iscitizenof(B, H), happenedin(I, H) )
# %   | | then return 0.3697768420762539;  // std dev = 6,556, 172,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=88 */
# %   | | else return 0.49636031721333074;  // std dev = 7,537, 246,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=157 */
# %   else if ( graduatedfrom(B, J), iscitizenof(B, K), iscitizenof(A, K) )
# %   | then return 0.7188046728044268;  // std dev = 5,409, 244,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=210 */
# %   | else if ( iscitizenof(A, L), livesin(B, L) )
# %   | | then return 0.601392178342756;  // std dev = 0,437, 74,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=55 */
# %   | | else if ( iscitizenof(A, M), worksat(B, N), graduatedfrom(A, N) )
# %   | | | then return 0.8581489350995117;  // std dev = 2,46e-07, 41,000 (wgt'ed) examples reached here.  /* #pos=41 */
# %   | | | else if ( iscitizenof(A, P), iscitizenof(B, P) )
# %   | | | | then return 0.7369368138873902;  // std dev = 3,247, 99,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=87 */
# %   | | | | else if ( iscitizenof(A, Q), worksat(B, R), graduatedfrom(S, R) )
# %   | | | | | then return 0.1053711573217341;  // std dev = 8,185, 360,000 (wgt'ed) examples reached here.  /* #neg=271 #pos=89 */
# %   | | | | | else return 0.318734133034103;  // std dev = 26,865, 2.905,000 (wgt'ed) examples reached here.  /* #neg=1.567 #pos=1.338 */
#
#
# Results:
# {'CLL': -0.905249, 'Recall': 0.0, 'AUC ROC': 0.670963, 'AUC PR': 0.696717, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 61.919 seconds
# Total inference time: 58.242 seconds
# AUC ROC: 0.670963
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), iscitizenof(C, D), hascapital(D, E) )
# %   then if ( livesin(A, D), iscitizenof(A, F) )
# %   | then return 0.5618526388032159;  // std dev = 0,457, 27,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=19 */
# %   | else if ( exports(D, G), iscitizenof(B, H), happenedin(I, H) )
# %   | | then return 0.3697768420762539;  // std dev = 6,556, 172,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=88 */
# %   | | else return 0.49636031721333074;  // std dev = 7,537, 246,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=157 */
# %   else if ( graduatedfrom(B, J), iscitizenof(B, K), iscitizenof(A, K) )
# %   | then return 0.7188046728044268;  // std dev = 5,409, 244,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=210 */
# %   | else if ( iscitizenof(A, L), livesin(B, L) )
# %   | | then return 0.601392178342756;  // std dev = 3,758, 74,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=55 */
# %   | | else if ( iscitizenof(A, M), worksat(B, N), graduatedfrom(A, N) )
# %   | | | then return 0.8581489350995117;  // std dev = 2,46e-07, 41,000 (wgt'ed) examples reached here.  /* #pos=41 */
# %   | | | else if ( iscitizenof(A, P), iscitizenof(B, P) )
# %   | | | | then return 0.7369368138873902;  // std dev = 3,247, 99,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=87 */
# %   | | | | else if ( iscitizenof(A, Q), worksat(B, R), graduatedfrom(S, R) )
# %   | | | | | then return 0.1053711573217341;  // std dev = 8,185, 360,000 (wgt'ed) examples reached here.  /* #neg=271 #pos=89 */
# %   | | | | | else return 0.318734133034103;  // std dev = 26,865, 2.905,000 (wgt'ed) examples reached here.  /* #neg=1.567 #pos=1.338 */
#
#
# Results:
# {'CLL': -0.905249, 'Recall': 0.0, 'AUC ROC': 0.670963, 'AUC PR': 0.696717, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 61.202 seconds
# Total inference time: 57.105 seconds
# AUC ROC: 0.670963
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), iscitizenof(C, D), hascapital(D, E) )
# %   then if ( livesin(A, D), iscitizenof(A, F) )
# %   | then return 0.5618526388032159;  // std dev = 2,373, 27,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=19 */
# %   | else return 0.44427333701338384;  // std dev = 10,070, 418,000 (wgt'ed) examples reached here.  /* #neg=173 #pos=245 */
# %   else if ( graduatedfrom(B, G), iscitizenof(B, H), iscitizenof(A, H) )
# %   | then return 0.7188046728044268;  // std dev = 5,409, 244,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=210 */
# %   | else if ( iscitizenof(A, I), livesin(B, I) )
# %   | | then return 0.601392178342756;  // std dev = 3,758, 74,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=55 */
# %   | | else if ( iscitizenof(A, J), worksat(B, K), graduatedfrom(A, K) )
# %   | | | then return 0.8581489350995117;  // std dev = 2,46e-07, 41,000 (wgt'ed) examples reached here.  /* #pos=41 */
# %   | | | else if ( iscitizenof(A, L), iscitizenof(B, L) )
# %   | | | | then return 0.7369368138873902;  // std dev = 3,247, 99,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=87 */
# %   | | | | else if ( iscitizenof(A, M), worksat(B, N), graduatedfrom(P, N) )
# %   | | | | | then return 0.1053711573217341;  // std dev = 8,185, 360,000 (wgt'ed) examples reached here.  /* #neg=271 #pos=89 */
# %   | | | | | else return 0.318734133034103;  // std dev = 26,865, 2.905,000 (wgt'ed) examples reached here.  /* #neg=1.567 #pos=1.338 */
#
#
# Results:
# {'CLL': -0.906083, 'Recall': 0.0, 'AUC ROC': 0.669501, 'AUC PR': 0.693381, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 60.868 seconds
# Total inference time: 84.431 seconds
# AUC ROC: 0.669501
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.670963
# ******************************************
#
# ******************************************
# Total revision time: 646.3119999999999
# Best validation AUC ROC: 0.670963
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), iscitizenof(C, D), hascapital(D, E) )
# %   then if ( livesin(A, D), iscitizenof(A, F) )
# %   | then return 0.5618526388032159;  // std dev = 2,373, 27,000 (wgt'ed) examples reached here.  /* #neg=8 #pos=19 */
# %   | else if ( exports(D, G), iscitizenof(B, H), happenedin(I, H) )
# %   | | then return 0.3697768420762539;  // std dev = 6,556, 172,000 (wgt'ed) examples reached here.  /* #neg=84 #pos=88 */
# %   | | else return 0.49636031721333074;  // std dev = 7,537, 246,000 (wgt'ed) examples reached here.  /* #neg=89 #pos=157 */
# %   else if ( graduatedfrom(B, J), iscitizenof(B, K), iscitizenof(A, K) )
# %   | then return 0.7188046728044268;  // std dev = 5,409, 244,000 (wgt'ed) examples reached here.  /* #neg=34 #pos=210 */
# %   | else if ( iscitizenof(A, L), livesin(B, L) )
# %   | | then return 0.601392178342756;  // std dev = 3,758, 74,000 (wgt'ed) examples reached here.  /* #neg=19 #pos=55 */
# %   | | else if ( iscitizenof(A, M), worksat(B, N), graduatedfrom(A, N) )
# %   | | | then return 0.8581489350995117;  // std dev = 2,46e-07, 41,000 (wgt'ed) examples reached here.  /* #pos=41 */
# %   | | | else if ( iscitizenof(A, P), iscitizenof(B, P) )
# %   | | | | then return 0.7369368138873902;  // std dev = 3,247, 99,000 (wgt'ed) examples reached here.  /* #neg=12 #pos=87 */
# %   | | | | else if ( iscitizenof(A, Q), worksat(B, R), graduatedfrom(S, R) )
# %   | | | | | then return 0.1053711573217341;  // std dev = 8,185, 360,000 (wgt'ed) examples reached here.  /* #neg=271 #pos=89 */
# %   | | | | | else return 0.318734133034103;  // std dev = 26,865, 2.905,000 (wgt'ed) examples reached here.  /* #neg=1.567 #pos=1.338 */
#
#
# Results:
# {'CLL': -0.905249, 'Recall': 0.0, 'AUC ROC': 0.670963, 'AUC PR': 0.696717, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total inference time: 84.6 seconds
# AUC ROC: 0.670963
#
#
# Total examples
# Positive examples: 2895
# Negative examples: 2895
#
#
# Train and test sets from total
# Train Positive examples: 2605
# Train Negative examples: 2605
# Test Positive examples: 290
# Test Negative examples: 290
#
#
# Small dataset
# Train Positive examples: 781
# Train Negative examples: 781
#
#
# Revision theory train dataset and validation
# Train Positive examples: 2084
# Train Negative examples: 2084
# Validation Positive examples: 521
# Validation Negative examples: 521
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( graduatedfrom(B, C), graduatedfrom(A, C) )
# %   then return 0.8170530446885539;  // std dev = 0,199, 73,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=70 */
# %   else if ( haswonprize(A, D), haswonprize(B, D) )
# %   | then return 0.7699136409818645;  // std dev = 0,284, 34,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=31 */
# %   | else if ( influences(B, E), influences(A, F), influences(E, G) )
# %   | | then return 0.7002541982574071;  // std dev = 0,365, 19,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=16 */
# %   | | else if ( haswonprize(A, H), haswonprize(I, H), diedin(I, J) )
# %   | | | then if ( haschild(K, I), iscitizenof(A, L), diedin(K, J) )
# %   | | | | then if ( iscitizenof(B, L), haswonprize(M, H), isaffiliatedto(M, N) )
# %   | | | | | then return 0.8581489350995122;  // std dev = 0,000, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | | | | | else return 0.424815601766179;  // std dev = 2,714, 30,000 (wgt'ed) examples reached here.  /* #neg=13 #pos=17 */
# %   | | | | else return 0.21253490001179276;  // std dev = 0,478, 285,000 (wgt'ed) examples reached here.  /* #neg=184 #pos=101 */
# %   | | | else if ( graduatedfrom(A, P), diedin(B, Q), owns(P, R) )
# %   | | | | then return 0.21298764477693108;  // std dev = 0,478, 62,000 (wgt'ed) examples reached here.  /* #neg=40 #pos=22 */
# %   | | | | else if ( graduatedfrom(A, S), owns(S, T) )
# %   | | | | | then return 0.4249505545327072;  // std dev = 7,788, 247,000 (wgt'ed) examples reached here.  /* #neg=107 #pos=140 */
# %   | | | | | else return 0.3284459648024784;  // std dev = 14,188, 808,000 (wgt'ed) examples reached here.  /* #neg=428 #pos=380 */
#
#
# Results:
# {'CLL': -0.920133, 'Recall': 0.0, 'AUC ROC': 0.568424, 'AUC PR': 0.609639, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 211.145 seconds
# Total inference time: 86.48400000000001 seconds
# AUC ROC: 0.568424
#
#
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), influences(D, A) )
# %   then return 0.8581489350995122;  // std dev = 1,19e-07, 51,000 (wgt'ed) examples reached here.  /* #pos=51 */
# %   else if ( graduatedfrom(B, E), diedin(B, F), influences(B, G) )
# %   | then return 0.514928596116458;  // std dev = 0,475, 236,000 (wgt'ed) examples reached here.  /* #neg=81 #pos=155 */
# %   | else if ( iscitizenof(B, H), iscitizenof(A, H) )
# %   | | then return 0.7120111480431406;  // std dev = 0,353, 479,000 (wgt'ed) examples reached here.  /* #neg=70 #pos=409 */
# %   | | else if ( iscitizenof(A, I), dealswith(J, I), livesin(K, J) )
# %   | | | then if ( iscitizenof(B, L), dealswith(J, L), holdspoliticalposition(K, M) )
# %   | | | | then return 0.05748448327227009;  // std dev = 0,400, 301,000 (wgt'ed) examples reached here.  /* #neg=241 #pos=60 */
# %   | | | | else return 0.2821995680109008;  // std dev = 0,494, 1.422,000 (wgt'ed) examples reached here.  /* #neg=819 #pos=603 */
# %   | | | else if ( graduatedfrom(B, N), graduatedfrom(A, P) )
# %   | | | | then if ( worksat(B, P) )
# %   | | | | | then return 0.8004566274072035;  // std dev = 2,378, 104,000 (wgt'ed) examples reached here.  /* #neg=6 #pos=98 */
# %   | | | | | else return 0.330932760915993;  // std dev = 12,660, 643,000 (wgt'ed) examples reached here.  /* #neg=339 #pos=304 */
# %   | | | | else if ( haswonprize(B, Q), haswonprize(R, Q), livesin(R, S) )
# %   | | | | | then return 0.38690589242789375;  // std dev = 11,589, 539,000 (wgt'ed) examples reached here.  /* #neg=254 #pos=285 */
# %   | | | | | else return 0.30414196645839253;  // std dev = 18,830, 1.435,000 (wgt'ed) examples reached here.  /* #neg=795 #pos=640 */
#
#
# Results:
# {'CLL': -0.9086, 'Recall': 0.0, 'AUC ROC': 0.667592, 'AUC PR': 0.718387, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 931.458 seconds
# Total inference time: 59.005 seconds
# AUC ROC: 0.667592
#
#
# Performing parameter learning
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( graduatedfrom(B, C), graduatedfrom(A, C) )
# %   then return 0.7828801178952083;  // std dev = 3,598, 186,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=172 */
# %   else if ( haswonprize(A, D), haswonprize(B, D) )
# %   | then return 0.7855682899382201;  // std dev = 2,889, 124,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=115 */
# %   | else if ( influences(B, E), influences(A, F), influences(E, G) )
# %   | | then return 0.6581489350995122;  // std dev = 2,828, 50,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=40 */
# %   | | else if ( haswonprize(A, H), haswonprize(I, H), diedin(I, J) )
# %   | | | then if ( haschild(K, I), iscitizenof(A, L), diedin(K, J) )
# %   | | | | then if ( iscitizenof(B, L), haswonprize(M, H), isaffiliatedto(M, N) )
# %   | | | | | then return 0.41370449065506787;  // std dev = 1,491, 9,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=5 */
# %   | | | | | else return 0.18756069980539394;  // std dev = 4,333, 85,000 (wgt'ed) examples reached here.  /* #neg=57 #pos=28 */
# %   | | | | else return 0.2800467453184865;  // std dev = 12,926, 685,000 (wgt'ed) examples reached here.  /* #neg=396 #pos=289 */
# %   | | | else if ( graduatedfrom(A, P), diedin(B, Q), owns(P, R) )
# %   | | | | then return 0.22448556876288003;  // std dev = 6,848, 202,000 (wgt'ed) examples reached here.  /* #neg=128 #pos=74 */
# %   | | | | else if ( graduatedfrom(A, S), owns(S, T) )
# %   | | | | | then return 0.3588725241009549;  // std dev = 13,143, 691,000 (wgt'ed) examples reached here.  /* #neg=345 #pos=346 */
# %   | | | | | else return 0.3333362010171105;  // std dev = 23,080, 2.136,000 (wgt'ed) examples reached here.  /* #neg=1.121 #pos=1.015 */
#
#
# Results:
# {'CLL': -0.921653, 'Recall': 0.0, 'AUC ROC': 0.566106, 'AUC PR': 0.61665, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 62.897 seconds
# Total inference time: 80.901 seconds
# AUC ROC: 0.566106
#
#
# Refining iteration 1
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( graduatedfrom(B, C), graduatedfrom(A, C) )
# %   then return 0.7828801178952083;  // std dev = 3,598, 186,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=172 */
# %   else if ( haswonprize(A, D), haswonprize(B, D) )
# %   | then return 0.7855682899382201;  // std dev = 2,889, 124,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=115 */
# %   | else if ( influences(B, E), influences(A, F), influences(E, G) )
# %   | | then return 0.6581489350995122;  // std dev = 2,828, 50,000 (wgt'ed) examples reached here.  /* #neg=10 #pos=40 */
# %   | | else if ( haswonprize(A, H), haswonprize(I, H), diedin(I, J) )
# %   | | | then if ( haschild(K, I), iscitizenof(A, L), diedin(K, J) )
# %   | | | | then if ( iscitizenof(B, L), haswonprize(M, H), isaffiliatedto(M, N) )
# %   | | | | | then return 0.41370449065506787;  // std dev = 1,491, 9,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=5 */
# %   | | | | | else return 0.18756069980539394;  // std dev = 4,333, 85,000 (wgt'ed) examples reached here.  /* #neg=57 #pos=28 */
# ...
#
#
# Total learning time: 64.733 seconds
# Total inference time: 58.427 seconds
# AUC ROC: 0.587224
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 0,492, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 12,793, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then if ( iscitizenof(K, I), iscitizenof(L, I), graduatedfrom(L, J) )
# %   | | | | then return 0.5649158523927433;  // std dev = 5,250, 133,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=94 */
# %   | | | | else return 0.06085163780221421;  // std dev = 4,891, 148,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=30 */
# %   | | | else if ( graduatedfrom(B, M), worksat(A, M) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, N), iscitizenof(A, N) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else return 0.3029151742389365;  // std dev = 24,431, 2.417,000 (wgt'ed) examples reached here.  /* #neg=1.342 #pos=1.075 */
#
#
# Results:
# {'CLL': -0.915865, 'Recall': 0.0, 'AUC ROC': 0.613852, 'AUC PR': 0.656828, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 70.564 seconds
# Total inference time: 82.271 seconds
# AUC ROC: 0.613852
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 9,992, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 0,496, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then if ( iscitizenof(K, I), iscitizenof(L, I), graduatedfrom(L, J) )
# %   | | | | then return 0.5649158523927433;  // std dev = 5,250, 133,000 (wgt'ed) examples reached here.  /* #neg=39 #pos=94 */
# %   | | | | else return 0.06085163780221421;  // std dev = 4,891, 148,000 (wgt'ed) examples reached here.  /* #neg=118 #pos=30 */
# %   | | | else if ( graduatedfrom(B, M), worksat(A, M) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, N), iscitizenof(A, N) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else return 0.3029151742389365;  // std dev = 24,431, 2.417,000 (wgt'ed) examples reached here.  /* #neg=1.342 #pos=1.075 */
#
#
# Results:
# {'CLL': -0.915865, 'Recall': 0.0, 'AUC ROC': 0.613852, 'AUC PR': 0.656828, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 94.244 seconds
# Total inference time: 86.54599999999999 seconds
# AUC ROC: 0.613852
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 9,992, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 12,793, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then return 0.2994300738895442;  // std dev = 0,497, 281,000 (wgt'ed) examples reached here.  /* #neg=157 #pos=124 */
# %   | | | else if ( graduatedfrom(B, L), worksat(A, L) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, M), iscitizenof(A, M) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else if ( iscitizenof(A, N), livesin(P, N), isaffiliatedto(P, Q) )
# %   | | | | | | then return 0.2260245827679014;  // std dev = 13,399, 772,000 (wgt'ed) examples reached here.  /* #neg=488 #pos=284 */
# %   | | | | | | else return 0.3389999989292952;  // std dev = 20,264, 1.645,000 (wgt'ed) examples reached here.  /* #neg=854 #pos=791 */
#
#
# Results:
# {'CLL': -0.918503, 'Recall': 0.0, 'AUC ROC': 0.63123, 'AUC PR': 0.656709, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 476.119 seconds
# Total inference time: 53.815 seconds
# AUC ROC: 0.63123
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.63123
# ******************************************
#
# Refining iteration 2
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 9,992, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 0,496, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then return 0.2994300738895442;  // std dev = 8,324, 281,000 (wgt'ed) examples reached here.  /* #neg=157 #pos=124 */
# %   | | | else if ( graduatedfrom(B, L), worksat(A, L) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, M), iscitizenof(A, M) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else if ( iscitizenof(A, N), livesin(P, N), isaffiliatedto(P, Q) )
# %   | | | | | | then return 0.2260245827679014;  // std dev = 13,399, 772,000 (wgt'ed) examples reached here.  /* #neg=488 #pos=284 */
# %   | | | | | | else return 0.3389999989292952;  // std dev = 20,264, 1.645,000 (wgt'ed) examples reached here.  /* #neg=854 #pos=791 */
#
#
# Results:
# {'CLL': -0.918503, 'Recall': 0.0, 'AUC ROC': 0.63123, 'AUC PR': 0.656709, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 91.799 seconds
# Total inference time: 85.301 seconds
# AUC ROC: 0.63123
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 0,492, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 12,793, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then return 0.2994300738895442;  // std dev = 8,324, 281,000 (wgt'ed) examples reached here.  /* #neg=157 #pos=124 */
# %   | | | else if ( graduatedfrom(B, L), worksat(A, L) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, M), iscitizenof(A, M) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else if ( iscitizenof(A, N), livesin(P, N), isaffiliatedto(P, Q) )
# %   | | | | | | then return 0.2260245827679014;  // std dev = 13,399, 772,000 (wgt'ed) examples reached here.  /* #neg=488 #pos=284 */
# %   | | | | | | else return 0.3389999989292952;  // std dev = 20,264, 1.645,000 (wgt'ed) examples reached here.  /* #neg=854 #pos=791 */
#
#
# Results:
# {'CLL': -0.918503, 'Recall': 0.0, 'AUC ROC': 0.63123, 'AUC PR': 0.656709, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 64.239 seconds
# Total inference time: 85.69 seconds
# AUC ROC: 0.63123
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 9,992, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 12,793, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then return 0.2994300738895442;  // std dev = 0,497, 281,000 (wgt'ed) examples reached here.  /* #neg=157 #pos=124 */
# %   | | | else if ( graduatedfrom(B, L), worksat(A, L) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, M), iscitizenof(A, M) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else if ( iscitizenof(A, N), livesin(P, N), isaffiliatedto(P, Q) )
# %   | | | | | | then return 0.2260245827679014;  // std dev = 13,399, 772,000 (wgt'ed) examples reached here.  /* #neg=488 #pos=284 */
# %   | | | | | | else return 0.3389999989292952;  // std dev = 20,264, 1.645,000 (wgt'ed) examples reached here.  /* #neg=854 #pos=791 */
#
#
# Results:
# {'CLL': -0.918503, 'Recall': 0.0, 'AUC ROC': 0.63123, 'AUC PR': 0.656709, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 89.051 seconds
# Total inference time: 58.5 seconds
# AUC ROC: 0.63123
#
#
# ******************************************
# Refining node candidate
# ******************************************
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 9,992, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 12,793, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then return 0.2994300738895442;  // std dev = 8,324, 281,000 (wgt'ed) examples reached here.  /* #neg=157 #pos=124 */
# %   | | | else if ( graduatedfrom(B, L), worksat(A, L) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, M), iscitizenof(A, M) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else return 0.3029151742389365;  // std dev = 24,431, 2.417,000 (wgt'ed) examples reached here.  /* #neg=1.342 #pos=1.075 */
#
#
# Results:
# {'CLL': -0.9195, 'Recall': 0.0, 'AUC ROC': 0.587224, 'AUC PR': 0.636522, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total learning time: 65.157 seconds
# Total inference time: 86.762 seconds
# AUC ROC: 0.587224
#
#
# ******************************************
# Best Tree AUC ROC so far: 0.63123
# ******************************************
#
# ******************************************
# Total revision time: 1742.2959999999998
# Best validation AUC ROC: 0.63123
# WILL-Produced Tree:
# % FOR hasacademicadvisor(A, B):
# %   if ( influences(B, C), influences(D, C), worksat(D, E) )
# %   then return 0.4489479665765057;  // std dev = 9,992, 413,000 (wgt'ed) examples reached here.  /* #neg=169 #pos=244 */
# %   else if ( livesin(A, F), livesin(G, F), influences(G, H) )
# %   | then if ( livesin(B, F) )
# %   | | then return 0.7308762078267836;  // std dev = 3,495, 110,000 (wgt'ed) examples reached here.  /* #neg=14 #pos=96 */
# %   | | else return 0.2957429200619137;  // std dev = 12,793, 665,000 (wgt'ed) examples reached here.  /* #neg=374 #pos=291 */
# %   | else if ( influences(B, A) )
# %   | | then return 0.8581489350995122;  // std dev = 0,000, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | | else if ( livesin(B, I), graduatedfrom(A, J), worksat(K, J) )
# %   | | | then return 0.2994300738895442;  // std dev = 0,497, 281,000 (wgt'ed) examples reached here.  /* #neg=157 #pos=124 */
# %   | | | else if ( graduatedfrom(B, L), worksat(A, L) )
# %   | | | | then return 0.7547006592374428;  // std dev = 1,640, 29,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=26 */
# %   | | | | else if ( iscitizenof(B, M), iscitizenof(A, M) )
# %   | | | | | then return 0.7475106372271685;  // std dev = 4,809, 235,000 (wgt'ed) examples reached here.  /* #neg=26 #pos=209 */
# %   | | | | | else if ( iscitizenof(A, N), livesin(P, N), isaffiliatedto(P, Q) )
# %   | | | | | | then return 0.2260245827679014;  // std dev = 13,399, 772,000 (wgt'ed) examples reached here.  /* #neg=488 #pos=284 */
# %   | | | | | | else return 0.3389999989292952;  // std dev = 20,264, 1.645,000 (wgt'ed) examples reached here.  /* #neg=854 #pos=791 */
#
#
# Results:
# {'CLL': -0.918503, 'Recall': 0.0, 'AUC ROC': 0.63123, 'AUC PR': 0.656709, 'Precision': [nan, 0.5], 'F1': nan}
#
#
# Total inference time: 60.476 seconds
# AUC ROC: 0.63123

# %%
small_dataset_aucroc
# Out:
# [0.596873,
#  0.669346,
#  0.568424,
#  0.625612,
#  0.586504,
#  0.646951,
#  0.54882,
#  0.614265,
#  0.612092,
#  0.613486]

# %%
complete_dataset_aucroc
# Out:
# [0.658936,
#  0.602218,
#  0.667592,
#  0.592426,
#  0.673716,
#  0.650321,
#  0.59967,
#  0.59503,
#  0.653997,
#  0.66263]

# %%
revision_dataset_aucroc
# Out:
# [0.620559,
#  0.670963,
#  0.582741,
#  0.626635,
#  0.609328,
#  0.647634,
#  0.565666,
#  0.619982,
#  0.61718,
#  0.63123]

# %%
print('Small dataset AUC ROC: %s +/- %s' % ((np.array(small_dataset_aucroc)).mean(), (np.array(small_dataset_aucroc)).std()))
print('Complete dataset AUC ROC: %s +/- %s' % ((np.array(complete_dataset_aucroc)).mean(), (np.array(complete_dataset_aucroc)).std()))
print('Theory revision dataset AUC ROC: %s +/- %s' % ((np.array(revision_dataset_aucroc)).mean(), (np.array(revision_dataset_aucroc)).std()))
# Out:
# Small dataset AUC ROC: 0.6082373 +/- 0.03366102011838025
# Complete dataset AUC ROC: 0.6356536 +/- 0.03197167189309936
# Theory revision dataset AUC ROC: 0.6191918000000001 +/- 0.02826135701554333
